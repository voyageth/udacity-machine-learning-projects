# %%
import os

if not os.path.exists('svhn'):
    os.makedirs('svhn')
if not os.path.exists('svhn/raw'):
    os.makedirs('svhn/raw')
if not os.path.exists('svhn/converted'):
    os.makedirs('svhn/converted')
if not os.path.exists('svhn/reader'):
    os.makedirs('svhn/reader')
if not os.path.exists('svhn/reader/v2'):
    os.makedirs('svhn/reader/v2')
if not os.path.exists('graph'):
    os.makedirs('graph')
if not os.path.exists('graph/v2'):
    os.makedirs('graph/v2')

# %%
import gc
import os
import os.path
import time
import random

import PIL.Image as Image
import matplotlib.pyplot as plt
import numpy as np
from six.moves import cPickle as pickle
from skimage.transform import resize
from skimage.transform import rotate
from scipy.ndimage import gaussian_filter


class MultiDigitSVHNData(object):
    def __init__(self, digit_count=5, input_total_data_count=1, 
                image_size=32, use_standard_score=False, add_margin=False, margin_ratio=0.1,
                random_position_count=0, random_rotate_count=0, apply_gaussian_filter=False
                ):
        random.seed(42)
        self.use_standard_score = use_standard_score
        self.add_margin = add_margin
        self.margin_ratio = margin_ratio
        self.random_position_count = random_position_count
        self.random_rotate_count = random_rotate_count
        self.apply_gaussian_filter = apply_gaussian_filter
        self.digit_count = digit_count
        self.image_width = image_size
        self.image_height = image_size
        self.target_digit_num_labels = 10
        self.num_channels = 3

        self.input_total_data_count = input_total_data_count
        self.total_data_count = input_total_data_count  # ds.num_examples
        self.update_data_counts()

        self.train_data = None
        self.train_label_length = None
        self.train_label_digits = None
        self.validation_data = None
        self.validation_label_length = None
        self.validation_label_digits = None
        self.test_data = None
        self.test_label_length = None
        self.test_label_digits = None

    def update_data_counts(self):
        self.train_data_count = int(0.9 * self.total_data_count)
        self.validation_data_count = int(0.05 * self.total_data_count)
        self.test_data_count = self.total_data_count - self.train_data_count - self.validation_data_count

    def print_image(self, image):
        sample_image = image
        plt.figure()
        plt.imshow(sample_image)  # display it
        gc.collect()

    @staticmethod
    def maybe_pickle(digit_count, total_data_count, image_size=54, force=False, 
                     use_standard_score=False, add_margin=False, margin_ratio=0.1,
                     random_position_count=0, random_rotate_count=0, 
                     apply_gaussian_filter=False):
        filename = 'svhn/reader/svhn_' + str(digit_count) \
            + '_' + str(image_size) \
            + '_' + str(total_data_count) \
            + '_' + str(use_standard_score) \
            + '_' + str(add_margin) \
            + '_' + str(margin_ratio) \
            + '_' + str(apply_gaussian_filter) \
        
        if random_position_count > 0:
            filename += '_position' + str(random_position_count) \
        
        if random_rotate_count > 0:
            filename += '_rotate' + str(random_rotate_count) \
            
        filename += '.pickle'

        if os.path.exists(filename) and not force:
            # You may override by setting force=True.
            print('%s already present - Skipping pickling.' % filename)
            svhn_data = MultiDigitSVHNData.load_pickle(filename)
        else:
            print('Pickling %s.' % filename)
            svhn_data = MultiDigitSVHNData(digit_count=digit_count, input_total_data_count=total_data_count,
                                            image_size=image_size, use_standard_score=use_standard_score, add_margin=add_margin,
                                            random_position_count=random_position_count, random_rotate_count=random_rotate_count,
                                            margin_ratio=margin_ratio, apply_gaussian_filter=apply_gaussian_filter)
            svhn_data.load_data()
            try:
                MultiDigitSVHNData.write_pickle(filename, svhn_data)
            except Exception as e:
                print('Unable to save data to', filename, ':', e)
        return svhn_data

    @staticmethod
    def write_pickle(filename, data):
        with open(filename, 'wb') as f:
            pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)

    @staticmethod
    def load_pickle(filename):
        with open(filename, 'rb') as f:
            return pickle.load(f)

    def reformat_target_length(self, target_length):
        return (np.arange(self.digit_count + 1) == target_length).astype(np.float32)

    def reformat_target_digits(self, target_digits):
        return (np.arange(10) == target_digits).astype(np.float32)
    
    def generate_data(self, rows, total_data_index, target_image_length, data_index, target_image,top,bottom,left,right,rotate_rand=False):
        self.total_label[total_data_index][0] = target_image_length

        for digit_index in range(0, target_image_length):
            self.total_label[total_data_index][1 + digit_index] = rows[1][data_index][digit_index][0]
            
        rand_rotate_angle = 0
        if rotate_rand:
            if random.choice([True, False]):
                rand_rotate_angle = random.randrange(1,91)
            else:
                rand_rotate_angle = random.randrange(-91, -1)

        for channel_index in range(0, self.num_channels):
            if self.use_standard_score:
                mean = np.mean(target_image[:][:][channel_index], dtype='float32')
                std = np.std(target_image[:][:][channel_index], dtype='float32', ddof=1)
                if std < 1e-4:std = 1
                target_image[:][:][channel_index] = ((target_image[:][:][channel_index] - mean) / std).astype('uint8')
            
            croped = target_image[channel_index][top:bottom, left:right]
            if rotate_rand:
                croped = rotate(croped, rand_rotate_angle)
            resized_image = resize(croped,output_shape=[self.image_width, self.image_height])
            for image_height_index in range(0, self.image_height):
                for image_width_index in range(0, self.image_width):
                    self.total_data[total_data_index][image_height_index][image_width_index][channel_index] = \
                        resized_image[image_height_index][image_width_index] * 255

        if self.apply_gaussian_filter:
            self.total_data[total_data_index] = gaussian_filter(self.total_data[total_data_index], 1)
        total_data_index += 1
        
        return total_data_index

    def load_data(self):
        from fuel.config_parser import config
        from fuel.datasets.svhn import SVHN
        config.data_path = './svhn/converted'
        ds = SVHN(which_format=1, which_sets=('train', 'test', 'extra'))
        fetched_total_data_count = min(ds.num_examples, self.input_total_data_count)
        rows = np.array(ds.get_data(state=ds.open(), request=range(0, fetched_total_data_count)))
        rows_len = len(rows)
        print("rows[5][0]", rows[5][0].shape, rows[5][0].dtype)

        new_cnt = 0
        for data_index in range(0, fetched_total_data_count):
            target_image = rows[5][data_index]
            target_image_length = len(rows[1][data_index])
            if target_image_length <= self.digit_count:
                new_cnt += 1
                if self.add_margin:
                    if self.random_position_count > 0:
                        new_cnt += self.random_position_count
                    if self.random_rotate_count > 0:
                        new_cnt += self.random_rotate_count
        self.total_data_count = new_cnt
        self.update_data_counts()

        self.total_data = np.zeros((self.total_data_count, self.image_height, self.image_width, self.num_channels), dtype='uint8')
        self.total_label = np.zeros((self.total_data_count, self.digit_count + 1), dtype=int)
        print("total_data", self.total_data.shape)
        print("total_label", self.total_label.shape)

        print("start : {}".format(time.strftime("%Y-%m-%dT%H:%M:%S%z")))
        total_data_index = 0
        for data_index in range(0, fetched_total_data_count):
            target_image = rows[5][data_index]
            target_image_length = len(rows[1][data_index])
            top = int(np.min(rows[3][data_index]))
            bottom = int(np.max(rows[0][data_index] + rows[3][data_index]))
            left = int(np.min(rows[2][data_index]))
            right = int(np.max(rows[2][data_index] + rows[4][data_index]))
            
            rand_max_width = 0
            rand_max_height = 0

            if self.add_margin:
                width = right - left
                height = bottom - top
                top = max(0, int(top - height * self.margin_ratio))
                bottom = min(len(target_image[0]), int(bottom + height * self.margin_ratio))
                left = max(0, int(left - width * self.margin_ratio))
                right = min(len(target_image[0][0]), int(right + width * self.margin_ratio))
                rand_max_width = int(width * self.margin_ratio)
                rand_max_height = int(height * self.margin_ratio)

            if target_image_length <= self.digit_count:
                #def generate_data(self, total_data_index, target_image_length, data_index, target_image,top,bottom,left,right):
                total_data_index = self.generate_data(rows,total_data_index,target_image_length,data_index,target_image,top,bottom,left,right)
                if self.add_margin:
                    if self.random_position_count > 0:
                        for rand_i in range(0, self.random_position_count):
                            rand_width = random.randrange(-rand_max_width, rand_max_width)
                            rand_height = random.randrange(-rand_max_height, rand_max_height)
                            rand_top = max(0, top + rand_height)
                            rand_bottom = min(len(target_image[0]), bottom + rand_height)
                            rand_left = max(0, left + rand_width)
                            rand_right = min(len(target_image[0][0]), right + rand_width)
                            
                            total_data_index = self.generate_data(rows,total_data_index,target_image_length,data_index,target_image,
                                                                  rand_top,rand_bottom,rand_left,rand_right)
                    if self.random_rotate_count > 0:
                        for rand_i in range(0, self.random_rotate_count):
                            total_data_index = self.generate_data(rows,total_data_index,target_image_length,data_index,target_image
                                                                  ,top,bottom,left,right, rotate_rand=True)
                    
        print("end : {}".format(time.strftime("%Y-%m-%dT%H:%M:%S%z")))

        self.train_data = self.total_data[:self.train_data_count]
        self.train_label = self.total_label[:self.train_data_count]
        print("train_data", self.train_data.shape)
        print("train_label", self.train_label.shape)
        
        self.validation_data = self.total_data[self.train_data_count:self.train_data_count + self.validation_data_count]
        self.validation_label = self.total_label[
                                       self.train_data_count:self.train_data_count + self.validation_data_count]
        print("validation_data", self.validation_data.shape)
        print("validation_label", self.validation_label.shape)

        self.test_data = self.total_data[self.train_data_count + self.validation_data_count:]
        self.test_label = self.total_label[self.train_data_count + self.validation_data_count:]
        print("test_data", self.test_data.shape)
        print("test_label", self.test_label.shape)

# %%
import re

import numpy as np
import tensorflow as tf

from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat



class MultiDigitModel(object):
    def __init__(self, multi_digit_dataset, digit_count=1, num_channels=1, pooling_stride=2, num_steps=10001,
                 batch_size=128, patch_size=5, num_convs=None, num_fc_1=1600, num_fc_2=512, beta=0.001,
                 use_drop_out=False, drop_out_rate=0.5, use_norm=False, use_LCN=False,
                 learning_rate_start=0.1, learning_rate_decay_rate=0.1, add_l2_loss=False):
        if num_convs is None:
            num_convs = [24, 32, 32, 32, 32, 32, 32, 64]

        self.num_channels = num_channels
        self.pooling_stride = pooling_stride

        self.num_steps = num_steps
        self.batch_size = batch_size
        self.patch_size = patch_size
        self.num_conv_1 = num_convs[0]
        self.num_conv_2 = num_convs[1]
        self.num_conv_3 = num_convs[2]
        self.num_conv_4 = num_convs[3]
        self.num_conv_5 = num_convs[4]
        self.num_conv_6 = num_convs[5]
        self.num_conv_7 = num_convs[6]
        self.num_conv_8 = num_convs[7]

        self.last_num_conv = 0
        for i in range(7, -1, -1):
            if num_convs[i] > 0:
                self.last_num_conv = num_convs[i]
                break

        self.num_fc_1 = num_fc_1
        self.num_fc_2 = num_fc_2

        self.beta = beta
        self.learning_rate_start = learning_rate_start
        self.learning_rate_decay_rate = learning_rate_decay_rate

        self.digit_count = digit_count
        self.multi_digit_dataset = multi_digit_dataset
        self.graph = tf.Graph()

        self.add_l2_loss = add_l2_loss
        self.NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN = 50000
        self.NUM_EXAMPLES_PER_EPOCH_FOR_EVAL = 10000

        # Constants describing the training process.
        self.MOVING_AVERAGE_DECAY = 0.9999     # The decay to use for the moving average.
        self.NUM_EPOCHS_PER_DECAY = 350.0      # Epochs after which learning rate decays.
        
        self.use_norm = use_norm
        self.use_drop_out = use_drop_out
        self.drop_out_rate = drop_out_rate
        self.use_LCN = use_LCN


    @staticmethod
    def accuracy_digit(p_length, p_digits,
                       batch_length_labels, batch_digits_labels, digit):
        eq_count = 0.0
        total_count = 0.0
        for i in range(0, len(p_digits[digit])):
            if np.argmax(batch_length_labels[i]) >= digit:
                total_count += 1.0
                if np.argmax(p_digits[digit][i]) == np.argmax(batch_digits_labels[i][digit]):
                    eq_count += 1.0
                    #         elif digit == 1:
                    #           print("np.argmax(p_digits[digit][i]):{}, np.argmax(batch_digits_labels[i][digit]:{}".format(np.argmax(p_digits[digit][i]), np.argmax(batch_digits_labels[i][digit])))

        if total_count == 0:
            return 0
        return eq_count / total_count * 100

    @staticmethod
    def accuracy_length(p_length, p_0, p_1, p_2, p_3, p_4,
                        batch_length_labels, batch_digits_labels):
        eq_count = 0.0
        for i in range(0, len(p_length)):
            if np.argmax(p_length[i]) == np.argmax(batch_length_labels[i]):
                eq_count += 1.0
        return eq_count / len(p_length) * 100

    @staticmethod
    def accuracy(p_length, p_digits,
                 batch_length_labels, batch_digits_labels):
        eq_count = 0.0
        for row_index in range(0, len(p_length)):
            # print("row_index:{}".format(row_index))
            one_based_length_predicted = np.argmax(p_length[row_index])
            one_based_length_real = np.argmax(batch_length_labels[row_index])

            # print("one_based_length_predicted : {}, one_based_length_real :{}".format(one_based_length_predicted, one_based_length_real))
            if one_based_length_predicted == one_based_length_real:
                is_equal = True
                for digit_index in range(0, one_based_length_real):
                    # print("\tdigit_index:{}".format(digit_index))
                    if np.argmax(p_digits[digit_index][row_index]) != np.argmax(
                            batch_digits_labels[row_index][digit_index]):
                        # print("\t\tnp.argmax(p_digits[digit_index][row_index]) :{}, np.argmax(batch_digits_labels[row_index][digit_index]) :{}".format(np.argmax(p_digits[digit_index][row_index]), np.argmax(batch_digits_labels[row_index][digit_index])))
                        is_equal = False
                        break
                if is_equal:
                    eq_count += 1.0

        return eq_count / len(p_length) * 100, eq_count, len(p_length)
    
    
    def _activation_summary(self, x):
        tf.histogram_summary(x.op.name + '/activations', x)
        tf.scalar_summary(x.op.name + '/sparsity', tf.nn.zero_fraction(x))

    def _add_loss_summaries(self, total_loss):
        # Compute the moving average of all individual losses and the total loss.
        loss_averages = tf.train.ExponentialMovingAverage(0.9, name='avg')
        losses = tf.get_collection('losses')
        loss_averages_op = loss_averages.apply(losses + [total_loss])

        # Attach a scalar summary to all individual losses and the total loss; do the
        # same for the averaged version of the losses.
        for l in losses + [total_loss]:
        # Name each loss as '(raw)' and name the moving average version of the loss
        # as the original loss name.
            tf.scalar_summary(l.op.name +' (raw)', l)
            tf.scalar_summary(l.op.name, loss_averages.average(l))

        return loss_averages_op

        
    def _variable_on_cpu(self, name, shape, initializer):
        return tf.get_variable(name, shape, initializer=initializer, dtype=tf.float32)
        
        
    def _variable_with_weight_decay(self, name, shape, stddev, wd):
        var = self._variable_on_cpu(
            name,
            shape,
            tf.truncated_normal_initializer(stddev=stddev, dtype=tf.float32))
        if wd is not None:
            weight_decay = tf.mul(tf.nn.l2_loss(var), wd, name='weight_loss')
            tf.add_to_collection('losses', weight_decay)
        return var
    
    def conv_layer(self, number, input_data, input_num, output_num):
        with tf.variable_scope('conv_' + str(number)) as scope:
            kernel = self._variable_with_weight_decay('weights',
                             shape=[self.patch_size, self.patch_size, input_num, output_num],
                             stddev=5e-2,
                             wd=0.0)
            conv = tf.nn.conv2d(input_data, kernel, [1, 1, 1, 1], padding='SAME')
            biases = self._variable_on_cpu('biases', [output_num], tf.constant_initializer(0.0))
            pre_activation = tf.nn.bias_add(conv, biases)
            conv = tf.nn.relu(pre_activation, name=scope.name)
            self._activation_summary(conv)
        if self.use_norm:
            conv = tf.nn.lrn(conv, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm' + str(number))
        return conv
    
    # inference.
    def inference(self, data, is_training=True):
        stride = 2
        conv = None
        with tf.variable_scope('conv_1') as scope:
            kernel = self._variable_with_weight_decay('weights',
                             shape=[self.patch_size, self.patch_size, self.num_channels, self.num_conv_1],
                             stddev=5e-2,
                             wd=0.0)
            conv = tf.nn.conv2d(data, kernel, [1, 1, 1, 1], padding='SAME')
            biases = self._variable_on_cpu('biases', [self.num_conv_1], tf.constant_initializer(0.0))
            pre_activation = tf.nn.bias_add(conv, biases)
            conv1 = tf.nn.relu(pre_activation, name=scope.name)
            self._activation_summary(conv1)
        pool1 = tf.nn.max_pool(conv1, [1, 2, 2, 1], [1, stride, stride, 1], padding='SAME', name='pool1')
        if self.use_norm:
            conv = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm1')
        else:
            conv = pool1

        with tf.variable_scope('conv_2') as scope:
            kernel = self._variable_with_weight_decay('weights',
                             shape=[self.patch_size, self.patch_size, self.num_conv_1, self.num_conv_2],
                             stddev=5e-2,
                             wd=0.0)
            conv = tf.nn.conv2d(conv, kernel, [1, 1, 1, 1], padding='SAME')
            biases = self._variable_on_cpu('biases', [self.num_conv_2], tf.constant_initializer(0.0))
            pre_activation = tf.nn.bias_add(conv, biases)
            conv2 = tf.nn.relu(pre_activation, name=scope.name)
            self._activation_summary(conv2)
        if self.use_norm:
            conv2 = tf.nn.lrn(conv2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm2')
        pool2 = tf.nn.max_pool(conv2, [1, 2, 2, 1], [1, stride, stride, 1], padding='SAME', name='pool2')
        conv = pool2
        
        if self.num_conv_3 > 0:
            conv = self.conv_layer(3, conv, self.num_conv_2, self.num_conv_3)
        if self.num_conv_4 > 0:
            conv = self.conv_layer(4, conv, self.num_conv_3, self.num_conv_4)
        if self.num_conv_5 > 0:
            conv = self.conv_layer(5, conv, self.num_conv_4, self.num_conv_5)
        if self.num_conv_6 > 0:
            conv = self.conv_layer(6, conv, self.num_conv_5, self.num_conv_6)
        if self.num_conv_7 > 0:
            conv = self.conv_layer(7, conv, self.num_conv_6, self.num_conv_7)
        if self.num_conv_8 > 0:
            conv = self.conv_layer(8, conv, self.num_conv_7, self.num_conv_8)
        
        if self.use_drop_out:
            conv = tf.nn.dropout(conv, self.drop_out_rate)
        
        with tf.variable_scope('local_1') as scope:
            shape = conv.get_shape().as_list()
            reshape = tf.reshape(conv, [shape[0], -1])
            dim = reshape.get_shape()[1].value
            weights = self._variable_with_weight_decay('weights', shape=[dim, self.num_fc_1],stddev=0.04, wd=0.004)
            biases = self._variable_on_cpu('biases', [self.num_fc_1], tf.constant_initializer(0.1))
            local3 = tf.nn.relu(tf.matmul(reshape, weights) + biases, name=scope.name)
            self._activation_summary(local3)

        with tf.variable_scope('local_2') as scope:
            weights = self._variable_with_weight_decay('weights', shape=[self.num_fc_1, self.num_fc_2],stddev=0.04, wd=0.004)
            biases = self._variable_on_cpu('biases', [self.num_fc_2], tf.constant_initializer(0.1))
            local4 = tf.nn.relu(tf.matmul(local3, weights) + biases, name=scope.name)
            self._activation_summary(local4)

        with tf.variable_scope('digit_length') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, self.multi_digit_dataset.digit_count + 1],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [self.multi_digit_dataset.digit_count + 1],tf.constant_initializer(0.0))
            digit_length_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digit_length_logit)

        with tf.variable_scope('digit_0') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, 10],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [10],tf.constant_initializer(0.0))
            digits_0_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_0_logit)
        with tf.variable_scope('digit_1') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, 10],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [10],tf.constant_initializer(0.0))
            digits_1_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_1_logit)
        with tf.variable_scope('digit_2') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, 10],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [10],tf.constant_initializer(0.0))
            digits_2_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_2_logit)
        with tf.variable_scope('digit_3') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, 10],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [10],tf.constant_initializer(0.0))
            digits_3_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_3_logit)
        with tf.variable_scope('digit_4') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, 10],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [10],tf.constant_initializer(0.0))
            digits_4_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_4_logit)

        return digit_length_logit, digits_0_logit, digits_1_logit, digits_2_logit, digits_3_logit, digits_4_logit

    
    def loss_(self, logits, length_label, digit_labels):
        # Calculate the average cross entropy loss across the batch.
        length_label = tf.cast(length_label, tf.int64)
        digit_labels = tf.cast(digit_labels, tf.int64)
#         print(logits[0], length_label, digit_labels)
        cross_entropy_sum = tf.nn.softmax_cross_entropy_with_logits(logits[0], length_label, name='cross_entropy_for_length')
        for i in range(0, self.digit_count):
#             print(i, logits[i + 1], digit_labels[:,i])
            cross_entropy_sum += tf.nn.softmax_cross_entropy_with_logits(logits[i + 1], digit_labels[:, i], name='cross_entropy_for_digit' + str(i))
        cross_entropy_mean = tf.reduce_mean(cross_entropy_sum, name='cross_entropy')
        tf.add_to_collection('losses', cross_entropy_mean)

        # The total loss is defined as the cross entropy loss plus all of the weight
        # decay terms (L2 loss).
        return tf.add_n(tf.get_collection('losses'), name='total_loss')

    
    def train(self, total_loss, global_step):
        # Variables that affect learning rate.
        num_batches_per_epoch = self.NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN / self.batch_size
        decay_steps = int(num_batches_per_epoch * self.NUM_EPOCHS_PER_DECAY)

        # Decay the learning rate exponentially based on the number of steps.
        lr = tf.train.exponential_decay(self.learning_rate_start,
                                      global_step,
                                      decay_steps,
                                      self.learning_rate_decay_rate,
                                      staircase=True)
        tf.scalar_summary('learning_rate', lr)

        # Generate moving averages of all losses and associated summaries.
        loss_averages_op = self._add_loss_summaries(total_loss)

        # Compute gradients.
        with tf.control_dependencies([loss_averages_op]):
            #opt = tf.train.GradientDescentOptimizer(lr)
            opt = tf.train.AdagradOptimizer(lr)
            grads = opt.compute_gradients(total_loss)

        # Apply gradients.
        apply_gradient_op = opt.apply_gradients(grads, global_step=global_step)

        # Add histograms for trainable variables.
        for var in tf.trainable_variables():
            tf.histogram_summary(var.op.name, var)

        # Add histograms for gradients.
        for grad, var in grads:
            if grad is not None:
                tf.histogram_summary(var.op.name + '/gradients', grad)

        # Track the moving averages of all trainable variables.
        variable_averages = tf.train.ExponentialMovingAverage(self.MOVING_AVERAGE_DECAY, global_step)
        variables_averages_op = variable_averages.apply(tf.trainable_variables())

        with tf.control_dependencies([apply_gradient_op, variables_averages_op]):
            train_op = tf.no_op(name='train')

        return train_op
    
    def run(self):
        import time
        
        with self.graph.as_default():
            # Input data.
            tf_train_dataset = tf.placeholder(tf.float32, shape=(
                self.batch_size, self.multi_digit_dataset.image_width, self.multi_digit_dataset.image_height,
                self.multi_digit_dataset.num_channels), name="tf_train_dataset")
            print("tf_train_dataset : {}".format(tf_train_dataset))
            tf_train_length_labels = tf.placeholder(tf.float32,
                                                    shape=(self.batch_size, self.multi_digit_dataset.digit_count + 1))
            print("tf_train_length_labels : {}".format(tf_train_length_labels))
            tf_train_digits_labels = tf.placeholder(tf.float32,
                                                    shape=(self.batch_size, self.multi_digit_dataset.digit_count, 10))
            print("tf_train_digits_labels : {}".format(tf_train_digits_labels))

            # Training computation.
            logits = self.inference(tf_train_dataset, True)
            #   digits_1_mult = tf.to_float((tf.argmax(tf.nn.softmax(tf_train_length_labels), dimension=1) > 1))
            #   digits_2_mult = tf.to_float((tf.argmax(tf.nn.softmax(tf_train_length_labels), dimension=1) > 2))
            #   digits_3_mult = tf.to_float((tf.argmax(tf.nn.softmax(tf_train_length_labels), dimension=1) > 3))
            #   digits_4_mult = tf.to_float((tf.argmax(tf.nn.softmax(tf_train_length_labels), dimension=1) > 4))
            loss = self.loss_(logits, tf_train_length_labels, tf_train_digits_labels)

            global_step = tf.Variable(0, trainable=False)
            train_op = self.train(loss, global_step)

            # Predictions for the training, validation, and test data.
            train_length_prediction = tf.nn.softmax(logits[0], name='p_digit_length')
            train_digits_0_prediction = tf.nn.softmax(logits[1], name='p_digit_0')
            train_digits_1_prediction = tf.nn.softmax(logits[2], name='p_digit_1')
            train_digits_2_prediction = tf.nn.softmax(logits[3], name='p_digit_2')
            train_digits_3_prediction = tf.nn.softmax(logits[4], name='p_digit_3')
            train_digits_4_prediction = tf.nn.softmax(logits[5], name='p_digit_4')
            
            summary_op = tf.merge_all_summaries()
            init = tf.initialize_all_variables()
            session = tf.Session()
            session.run(init)
            summary_writer = tf.train.SummaryWriter('logs/tensorboard/voyageth/svhn/' + time.strftime("%Y-%m-%dT%H:%M:%S%z"), session.graph)

            saver = tf.train.Saver()
            
            print('Initialized')
            for step in range(self.num_steps):
                offset = (step * self.batch_size) % (self.multi_digit_dataset.train_data.shape[0] - self.batch_size)
                batch_data = self.multi_digit_dataset.train_data[offset:(offset + self.batch_size), :, :, :]
                batch_length_labels = self.multi_digit_dataset.reformat_target_length(self.multi_digit_dataset.train_label[offset:(offset + self.batch_size), 0, None])
                batch_digits_labels = self.multi_digit_dataset.reformat_target_digits(self.multi_digit_dataset.train_label[offset:(offset + self.batch_size), 1:, None])

                feed_dict = {tf_train_dataset: batch_data, tf_train_length_labels: batch_length_labels,
                             tf_train_digits_labels: batch_digits_labels}

                _, summary_str, l, p_length, p_0, p_1, p_2, p_3, p_4 = session.run([train_op, summary_op, loss, train_length_prediction, train_digits_0_prediction, train_digits_1_prediction,
                     train_digits_2_prediction, train_digits_3_prediction, train_digits_4_prediction],feed_dict=feed_dict)
                if step % 100 == 0:
                    summary_writer.add_summary(summary_str, step)

                if step % 500 == 0:
                    print('Minibatch loss at step %d: %f' % (step, l))
                    accuracy_result = self.accuracy_length(p_length, p_0, p_1, p_2, p_3, p_4, batch_length_labels,
                                                           batch_digits_labels)
                    print('Minibatch accuracy_length: %.1f%%' % accuracy_result)
                    for k in range(0, self.digit_count):
                        accuracy_result = self.accuracy_digit(p_length, [p_0, p_1, p_2, p_3, p_4], batch_length_labels,
                                                              batch_digits_labels, k)
                        print("Minibatch accuracy_digit_{}".format(k) + ": %.1f%%" % accuracy_result)
                    accuracy_result, _, _ = self.accuracy(p_length, [p_0, p_1, p_2, p_3, p_4], batch_length_labels,
                                                    batch_digits_labels)
                    print('Minibatch accuracy: %.1f%%' % accuracy_result)

                    validation_accuracy_numerator = 0
                    validation_accuracy_denominator = 0
                    for step in range(0, len(self.multi_digit_dataset.validation_label) / self.batch_size):
                        valid_offset = (step * self.batch_size) % (self.multi_digit_dataset.validation_data.shape[0] - self.batch_size)
                        valid_batch_data = self.multi_digit_dataset.validation_data[valid_offset:(valid_offset + self.batch_size), :, :, :]
                        valid_batch_length_labels = self.multi_digit_dataset.reformat_target_length(self.multi_digit_dataset.validation_label[valid_offset:(valid_offset + self.batch_size), 0, None])
                        valid_batch_digits_labels = self.multi_digit_dataset.reformat_target_digits(self.multi_digit_dataset.validation_label[valid_offset:(valid_offset + self.batch_size), 1:, None])

                        feed_dict = {tf_train_dataset: valid_batch_data, tf_train_length_labels: valid_batch_length_labels,
                             tf_train_digits_labels: valid_batch_digits_labels}

                        p_length, p_0, p_1, p_2, p_3, p_4 = session.run([train_length_prediction, 
                                                                         train_digits_0_prediction, 
                                                                         train_digits_1_prediction,
                                                                         train_digits_2_prediction, 
                                                                         train_digits_3_prediction, 
                                                                         train_digits_4_prediction],feed_dict=feed_dict)

                        accuracy_result, numerator, denominator = self.accuracy(p_length, [p_0, p_1, p_2, p_3, p_4], 
                                                        valid_batch_length_labels, valid_batch_digits_labels)
                        validation_accuracy_numerator += numerator
                        validation_accuracy_denominator += denominator
                    accuracy_result = validation_accuracy_numerator / validation_accuracy_denominator * 100
                    print('Validation accuracy: %.1f%%' % accuracy_result)
                    print("finish : {}".format(time.strftime("%Y-%m-%dT%H:%M:%S%z")))

            test_accuracy_numerator = 0
            test_accuracy_denominator = 0
            for step in range(0, len(self.multi_digit_dataset.test_label) / self.batch_size):
                test_offset = (step * self.batch_size) % (self.multi_digit_dataset.test_data.shape[0] - self.batch_size)
                test_batch_data = self.multi_digit_dataset.test_data[test_offset:(test_offset + self.batch_size), :, :, :]
                test_batch_length_labels = self.multi_digit_dataset.reformat_target_length(self.multi_digit_dataset.test_label[test_offset:(test_offset + self.batch_size), 0, None])
                test_batch_digits_labels = self.multi_digit_dataset.reformat_target_digits(self.multi_digit_dataset.test_label[test_offset:(test_offset + self.batch_size), 1:, None])

                feed_dict = {tf_train_dataset: test_batch_data, tf_train_length_labels: test_batch_length_labels,
                     tf_train_digits_labels: test_batch_digits_labels}

                p_length, p_0, p_1, p_2, p_3, p_4 = session.run([train_length_prediction, 
                                                                 train_digits_0_prediction, 
                                                                 train_digits_1_prediction,
                                                                 train_digits_2_prediction, 
                                                                 train_digits_3_prediction, 
                                                                 train_digits_4_prediction],feed_dict=feed_dict)

                accuracy_result, numerator, denominator = self.accuracy(p_length, [p_0, p_1, p_2, p_3, p_4], 
                                                test_batch_length_labels, test_batch_digits_labels)
                test_accuracy_numerator += numerator
                test_accuracy_denominator += denominator
            accuracy_result = test_accuracy_numerator / test_accuracy_denominator * 100
            print('Test accuracy: %.1f%%' % accuracy_result)
            finish_time = time.strftime("%Y-%m-%dT%H:%M:%S%z")
            print("finish : {}".format(finish_time))

            output_graph_def = graph_util.convert_variables_to_constants(
              session, self.graph.as_graph_def(), ['p_digit_length', 'p_digit_0', 'p_digit_1', 'p_digit_2', 'p_digit_3', 'p_digit_4'])
            with gfile.FastGFile('./graph/model_{}.pb'.format(finish_time), 'wb') as f:
                f.write(output_graph_def.SerializeToString())

# %%
# Minibatch loss at step 100000: 0.601887
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-11-28T11:21:13+0900
# Test accuracy: 86.7%
# finish : 2016-11-28T11:21:15+0900
            
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,0,0,0,0,0], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 13.938466
# Minibatch accuracy_length: 3.1%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 6.5%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-28T10:06:57+0900
# Minibatch loss at step 500: 8.022201
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T10:07:18+0900
# Minibatch loss at step 1000: 6.632330
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-28T10:07:39+0900
# Minibatch loss at step 1500: 7.169613
# Minibatch accuracy_length: 78.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.6%
# finish : 2016-11-28T10:08:00+0900
# Minibatch loss at step 2000: 5.931431
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 50.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 36.7%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 5.1%
# finish : 2016-11-28T10:08:21+0900
# Minibatch loss at step 2500: 4.301026
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 65.6%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 65.5%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 28.1%
# Validation accuracy: 23.2%
# finish : 2016-11-28T10:08:43+0900
# Minibatch loss at step 3000: 3.249440
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 65.6%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 73.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 25.0%
# Validation accuracy: 41.2%
# finish : 2016-11-28T10:09:05+0900
# Minibatch loss at step 3500: 2.652176
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 85.7%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 50.0%
# finish : 2016-11-28T10:09:28+0900
# Minibatch loss at step 4000: 2.408663
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 68.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 55.1%
# finish : 2016-11-28T10:09:50+0900
# Minibatch loss at step 4500: 1.688354
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 78.6%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 59.5%
# finish : 2016-11-28T10:10:13+0900
# Minibatch loss at step 5000: 2.771491
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 75.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 62.7%
# finish : 2016-11-28T10:10:35+0900
# Minibatch loss at step 5500: 2.252657
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 78.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 65.2%
# finish : 2016-11-28T10:10:57+0900
# Minibatch loss at step 6000: 1.358788
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 86.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 65.7%
# finish : 2016-11-28T10:11:19+0900
# Minibatch loss at step 6500: 1.778998
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 69.6%
# finish : 2016-11-28T10:11:41+0900
# Minibatch loss at step 7000: 3.076769
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 68.8%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 80.8%
# Minibatch accuracy_digit_3: 77.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 69.7%
# finish : 2016-11-28T10:12:04+0900
# Minibatch loss at step 7500: 1.884229
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 68.4%
# finish : 2016-11-28T10:12:26+0900
# Minibatch loss at step 8000: 1.628046
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.4%
# finish : 2016-11-28T10:12:49+0900
# Minibatch loss at step 8500: 1.300421
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.9%
# finish : 2016-11-28T10:13:11+0900
# Minibatch loss at step 9000: 1.683227
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 74.0%
# finish : 2016-11-28T10:13:33+0900
# Minibatch loss at step 9500: 1.807962
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 75.4%
# finish : 2016-11-28T10:13:56+0900
# Minibatch loss at step 10000: 0.707061
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 75.7%
# finish : 2016-11-28T10:14:18+0900
# Minibatch loss at step 10500: 1.210841
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 77.0%
# finish : 2016-11-28T10:14:40+0900
# Minibatch loss at step 11000: 0.828714
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 77.1%
# finish : 2016-11-28T10:15:02+0900
# Minibatch loss at step 11500: 2.933798
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 76.6%
# finish : 2016-11-28T10:15:25+0900
# Minibatch loss at step 12000: 1.044843
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.0%
# finish : 2016-11-28T10:15:47+0900
# Minibatch loss at step 12500: 1.254781
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 78.8%
# finish : 2016-11-28T10:16:09+0900
# Minibatch loss at step 13000: 1.421648
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 78.4%
# finish : 2016-11-28T10:16:31+0900
# Minibatch loss at step 13500: 0.680806
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.1%
# finish : 2016-11-28T10:16:53+0900
# Minibatch loss at step 14000: 2.031778
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 78.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 79.8%
# finish : 2016-11-28T10:17:16+0900
# Minibatch loss at step 14500: 1.501456
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 82.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.9%
# finish : 2016-11-28T10:17:38+0900
# Minibatch loss at step 15000: 1.099093
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# finish : 2016-11-28T10:18:00+0900
# Minibatch loss at step 15500: 1.164539
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.6%
# finish : 2016-11-28T10:18:23+0900
# Minibatch loss at step 16000: 0.930795
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.2%
# finish : 2016-11-28T10:18:45+0900
# Minibatch loss at step 16500: 1.122020
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# finish : 2016-11-28T10:19:08+0900
# Minibatch loss at step 17000: 1.282279
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.1%
# finish : 2016-11-28T10:19:30+0900
# Minibatch loss at step 17500: 1.285043
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 82.0%
# finish : 2016-11-28T10:19:52+0900
# Minibatch loss at step 18000: 0.652283
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# finish : 2016-11-28T10:20:15+0900
# Minibatch loss at step 18500: 1.031233
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 89.3%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# finish : 2016-11-28T10:20:38+0900
# Minibatch loss at step 19000: 0.691766
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# finish : 2016-11-28T10:21:00+0900
# Minibatch loss at step 19500: 1.061133
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.6%
# finish : 2016-11-28T10:21:22+0900
# Minibatch loss at step 20000: 0.885194
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.6%
# finish : 2016-11-28T10:21:45+0900
# Minibatch loss at step 20500: 0.725828
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# finish : 2016-11-28T10:22:07+0900
# Minibatch loss at step 21000: 0.921473
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# finish : 2016-11-28T10:22:29+0900
# Minibatch loss at step 21500: 1.031259
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.2%
# finish : 2016-11-28T10:22:51+0900
# Minibatch loss at step 22000: 2.054722
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# finish : 2016-11-28T10:23:14+0900
# Minibatch loss at step 22500: 0.806737
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# finish : 2016-11-28T10:23:36+0900
# Minibatch loss at step 23000: 0.641360
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.8%
# finish : 2016-11-28T10:23:58+0900
# Minibatch loss at step 23500: 1.038736
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.0%
# finish : 2016-11-28T10:24:21+0900
# Minibatch loss at step 24000: 1.090663
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.8%
# finish : 2016-11-28T10:24:43+0900
# Minibatch loss at step 24500: 0.573191
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# finish : 2016-11-28T10:25:05+0900
# Minibatch loss at step 25000: 0.736999
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# finish : 2016-11-28T10:25:27+0900
# Minibatch loss at step 25500: 0.412242
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 83.7%
# finish : 2016-11-28T10:25:50+0900
# Minibatch loss at step 26000: 0.385811
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 83.7%
# finish : 2016-11-28T10:26:12+0900
# Minibatch loss at step 26500: 0.902351
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# finish : 2016-11-28T10:26:34+0900
# Minibatch loss at step 27000: 1.044227
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.5%
# finish : 2016-11-28T10:26:56+0900
# Minibatch loss at step 27500: 0.598008
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# finish : 2016-11-28T10:27:18+0900
# Minibatch loss at step 28000: 1.291427
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.6%
# finish : 2016-11-28T10:27:41+0900
# Minibatch loss at step 28500: 0.648908
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.4%
# finish : 2016-11-28T10:28:03+0900
# Minibatch loss at step 29000: 0.793669
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.0%
# finish : 2016-11-28T10:28:26+0900
# Minibatch loss at step 29500: 0.729027
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.5%
# finish : 2016-11-28T10:28:48+0900
# Minibatch loss at step 30000: 0.793370
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 84.6%
# finish : 2016-11-28T10:29:11+0900
# Minibatch loss at step 30500: 0.824083
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# finish : 2016-11-28T10:29:33+0900
# Minibatch loss at step 31000: 1.035165
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# finish : 2016-11-28T10:29:55+0900
# Minibatch loss at step 31500: 0.569152
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# finish : 2016-11-28T10:30:18+0900
# Minibatch loss at step 32000: 0.570010
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# finish : 2016-11-28T10:30:40+0900
# Minibatch loss at step 32500: 0.542354
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.7%
# finish : 2016-11-28T10:31:02+0900
# Minibatch loss at step 33000: 0.646472
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# finish : 2016-11-28T10:31:25+0900
# Minibatch loss at step 33500: 0.759327
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# finish : 2016-11-28T10:31:47+0900
# Minibatch loss at step 34000: 0.694536
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# finish : 2016-11-28T10:32:09+0900
# Minibatch loss at step 34500: 1.012196
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.3%
# finish : 2016-11-28T10:32:31+0900
# Minibatch loss at step 35000: 1.540003
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.9%
# finish : 2016-11-28T10:32:53+0900
# Minibatch loss at step 35500: 1.439474
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# finish : 2016-11-28T10:33:16+0900
# Minibatch loss at step 36000: 1.051057
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.7%
# finish : 2016-11-28T10:33:38+0900
# Minibatch loss at step 36500: 2.169856
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.2%
# finish : 2016-11-28T10:34:00+0900
# Minibatch loss at step 37000: 0.281089
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.5%
# finish : 2016-11-28T10:34:23+0900
# Minibatch loss at step 37500: 0.818830
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.1%
# finish : 2016-11-28T10:34:45+0900
# Minibatch loss at step 38000: 1.493148
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.1%
# finish : 2016-11-28T10:35:08+0900
# Minibatch loss at step 38500: 0.645708
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# finish : 2016-11-28T10:35:30+0900
# Minibatch loss at step 39000: 0.842552
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# finish : 2016-11-28T10:35:52+0900
# Minibatch loss at step 39500: 0.821592
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 85.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.2%
# finish : 2016-11-28T10:36:14+0900
# Minibatch loss at step 40000: 0.549853
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.3%
# finish : 2016-11-28T10:36:36+0900
# Minibatch loss at step 40500: 0.658581
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# finish : 2016-11-28T10:36:58+0900
# Minibatch loss at step 41000: 0.559087
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.9%
# finish : 2016-11-28T10:37:20+0900
# Minibatch loss at step 41500: 0.587992
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# finish : 2016-11-28T10:37:43+0900
# Minibatch loss at step 42000: 0.581088
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# finish : 2016-11-28T10:38:05+0900
# Minibatch loss at step 42500: 1.039243
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# finish : 2016-11-28T10:38:28+0900
# Minibatch loss at step 43000: 1.266312
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# finish : 2016-11-28T10:38:50+0900
# Minibatch loss at step 43500: 0.569480
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# finish : 2016-11-28T10:39:12+0900
# Minibatch loss at step 44000: 1.126046
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.9%
# finish : 2016-11-28T10:39:35+0900
# Minibatch loss at step 44500: 0.630237
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# finish : 2016-11-28T10:39:57+0900
# Minibatch loss at step 45000: 1.004215
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# finish : 2016-11-28T10:40:20+0900
# Minibatch loss at step 45500: 0.508833
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# finish : 2016-11-28T10:40:42+0900
# Minibatch loss at step 46000: 0.695465
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# finish : 2016-11-28T10:41:05+0900
# Minibatch loss at step 46500: 0.306880
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.7%
# finish : 2016-11-28T10:41:26+0900
# Minibatch loss at step 47000: 0.675102
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.9%
# finish : 2016-11-28T10:41:48+0900
# Minibatch loss at step 47500: 0.278759
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.1%
# finish : 2016-11-28T10:42:11+0900
# Minibatch loss at step 48000: 1.205312
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.1%
# finish : 2016-11-28T10:42:34+0900
# Minibatch loss at step 48500: 0.756031
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# finish : 2016-11-28T10:42:56+0900
# Minibatch loss at step 49000: 0.620409
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.1%
# finish : 2016-11-28T10:43:18+0900
# Minibatch loss at step 49500: 0.859286
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.8%
# finish : 2016-11-28T10:43:41+0900
# Minibatch loss at step 50000: 0.485663
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.9%
# finish : 2016-11-28T10:44:03+0900
# Minibatch loss at step 50500: 0.566431
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 85.5%
# finish : 2016-11-28T10:44:26+0900
# Minibatch loss at step 51000: 0.333116
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# finish : 2016-11-28T10:44:48+0900
# Minibatch loss at step 51500: 0.536768
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# finish : 2016-11-28T10:45:10+0900
# Minibatch loss at step 52000: 0.324121
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# finish : 2016-11-28T10:45:33+0900
# Minibatch loss at step 52500: 0.588329
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# finish : 2016-11-28T10:45:55+0900
# Minibatch loss at step 53000: 0.360810
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# finish : 2016-11-28T10:46:17+0900
# Minibatch loss at step 53500: 0.403722
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.1%
# finish : 2016-11-28T10:46:39+0900
# Minibatch loss at step 54000: 0.449762
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.5%
# finish : 2016-11-28T10:47:02+0900
# Minibatch loss at step 54500: 0.895997
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.3%
# finish : 2016-11-28T10:47:24+0900
# Minibatch loss at step 55000: 1.086956
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# finish : 2016-11-28T10:47:46+0900
# Minibatch loss at step 55500: 0.358286
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.1%
# finish : 2016-11-28T10:48:08+0900
# Minibatch loss at step 56000: 0.565000
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 91.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# finish : 2016-11-28T10:48:31+0900
# Minibatch loss at step 56500: 0.805078
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# finish : 2016-11-28T10:48:54+0900
# Minibatch loss at step 57000: 1.067324
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# finish : 2016-11-28T10:49:16+0900
# Minibatch loss at step 57500: 0.689575
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# finish : 2016-11-28T10:49:38+0900
# Minibatch loss at step 58000: 2.217681
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.2%
# finish : 2016-11-28T10:50:00+0900
# Minibatch loss at step 58500: 0.611504
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# finish : 2016-11-28T10:50:23+0900
# Minibatch loss at step 59000: 0.640025
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# finish : 2016-11-28T10:50:45+0900
# Minibatch loss at step 59500: 0.452178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-11-28T10:51:07+0900
# Minibatch loss at step 60000: 0.549354
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# finish : 2016-11-28T10:51:30+0900
# Minibatch loss at step 60500: 0.350333
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.3%
# finish : 2016-11-28T10:51:51+0900
# Minibatch loss at step 61000: 0.376105
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# finish : 2016-11-28T10:52:14+0900
# Minibatch loss at step 61500: 0.807429
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# finish : 2016-11-28T10:52:36+0900
# Minibatch loss at step 62000: 0.375758
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-11-28T10:52:59+0900
# Minibatch loss at step 62500: 1.063434
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# finish : 2016-11-28T10:53:21+0900
# Minibatch loss at step 63000: 0.939755
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# finish : 2016-11-28T10:53:43+0900
# Minibatch loss at step 63500: 0.484422
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# finish : 2016-11-28T10:54:06+0900
# Minibatch loss at step 64000: 0.858024
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 91.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# finish : 2016-11-28T10:54:28+0900
# Minibatch loss at step 64500: 0.337975
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.7%
# finish : 2016-11-28T10:54:50+0900
# Minibatch loss at step 65000: 1.130207
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 91.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.3%
# finish : 2016-11-28T10:55:13+0900
# Minibatch loss at step 65500: 0.473168
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-11-28T10:55:35+0900
# Minibatch loss at step 66000: 1.825576
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# finish : 2016-11-28T10:55:57+0900
# Minibatch loss at step 66500: 0.420277
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# finish : 2016-11-28T10:56:19+0900
# Minibatch loss at step 67000: 0.628859
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# finish : 2016-11-28T10:56:42+0900
# Minibatch loss at step 67500: 0.550493
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# finish : 2016-11-28T10:57:03+0900
# Minibatch loss at step 68000: 0.355423
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.1%
# finish : 2016-11-28T10:57:26+0900
# Minibatch loss at step 68500: 0.665975
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# finish : 2016-11-28T10:57:48+0900
# Minibatch loss at step 69000: 0.564081
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# finish : 2016-11-28T10:58:11+0900
# Minibatch loss at step 69500: 0.443807
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# finish : 2016-11-28T10:58:33+0900
# Minibatch loss at step 70000: 1.072455
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.5%
# finish : 2016-11-28T10:58:56+0900
# Minibatch loss at step 70500: 0.638951
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# finish : 2016-11-28T10:59:18+0900
# Minibatch loss at step 71000: 0.665947
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# finish : 2016-11-28T10:59:40+0900
# Minibatch loss at step 71500: 0.354892
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# ...
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-11-28T11:03:46+0900
# Minibatch loss at step 77000: 0.638916
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# finish : 2016-11-28T11:04:08+0900
# Minibatch loss at step 77500: 0.505850
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# finish : 2016-11-28T11:04:30+0900
# Minibatch loss at step 78000: 0.589058
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# finish : 2016-11-28T11:04:53+0900
# Minibatch loss at step 78500: 0.920126
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 95.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# finish : 2016-11-28T11:05:15+0900
# Minibatch loss at step 79000: 0.469790
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# finish : 2016-11-28T11:05:38+0900
# Minibatch loss at step 79500: 0.411613
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-11-28T11:06:00+0900
# Minibatch loss at step 80000: 0.463518
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# finish : 2016-11-28T11:06:22+0900
# Minibatch loss at step 80500: 0.387480
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# finish : 2016-11-28T11:06:45+0900
# Minibatch loss at step 81000: 0.247493
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# finish : 2016-11-28T11:07:07+0900
# Minibatch loss at step 81500: 0.276961
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.8%
# finish : 2016-11-28T11:07:30+0900
# Minibatch loss at step 82000: 0.545219
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.9%
# finish : 2016-11-28T11:07:52+0900
# Minibatch loss at step 82500: 0.501223
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# finish : 2016-11-28T11:08:14+0900
# Minibatch loss at step 83000: 0.543732
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# finish : 2016-11-28T11:08:36+0900
# Minibatch loss at step 83500: 0.259690
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.1%
# finish : 2016-11-28T11:08:58+0900
# Minibatch loss at step 84000: 0.469768
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.8%
# finish : 2016-11-28T11:09:20+0900
# Minibatch loss at step 84500: 0.472065
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# finish : 2016-11-28T11:09:43+0900
# Minibatch loss at step 85000: 0.711256
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.1%
# finish : 2016-11-28T11:10:05+0900
# Minibatch loss at step 85500: 0.248878
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.2%
# finish : 2016-11-28T11:10:27+0900
# Minibatch loss at step 86000: 0.379217
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.6%
# finish : 2016-11-28T11:10:50+0900
# Minibatch loss at step 86500: 0.884794
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 91.7%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# finish : 2016-11-28T11:11:12+0900
# Minibatch loss at step 87000: 0.283534
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.6%
# finish : 2016-11-28T11:11:34+0900
# Minibatch loss at step 87500: 0.256012
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# finish : 2016-11-28T11:11:57+0900
# Minibatch loss at step 88000: 0.309345
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.9%
# finish : 2016-11-28T11:12:19+0900
# Minibatch loss at step 88500: 0.342958
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.1%
# finish : 2016-11-28T11:12:42+0900
# Minibatch loss at step 89000: 0.332895
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# finish : 2016-11-28T11:13:04+0900
# Minibatch loss at step 89500: 0.567182
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# finish : 2016-11-28T11:13:26+0900
# Minibatch loss at step 90000: 0.320828
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.4%
# finish : 2016-11-28T11:13:49+0900
# Minibatch loss at step 90500: 0.787034
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-11-28T11:14:11+0900
# Minibatch loss at step 91000: 0.536522
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# finish : 2016-11-28T11:14:33+0900
# Minibatch loss at step 91500: 0.773159
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.7%
# finish : 2016-11-28T11:14:55+0900
# Minibatch loss at step 92000: 0.636983
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# finish : 2016-11-28T11:15:17+0900
# Minibatch loss at step 92500: 0.281116
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.4%
# finish : 2016-11-28T11:15:40+0900
# Minibatch loss at step 93000: 0.270234
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.2%
# finish : 2016-11-28T11:16:02+0900
# Minibatch loss at step 93500: 0.837845
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# finish : 2016-11-28T11:16:24+0900
# Minibatch loss at step 94000: 0.896709
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# finish : 2016-11-28T11:16:47+0900
# Minibatch loss at step 94500: 0.373015
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-11-28T11:17:09+0900
# Minibatch loss at step 95000: 0.480236
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.9%
# finish : 2016-11-28T11:17:31+0900
# Minibatch loss at step 95500: 0.292908
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.8%
# finish : 2016-11-28T11:17:53+0900
# Minibatch loss at step 96000: 0.313654
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.1%
# finish : 2016-11-28T11:18:15+0900
# Minibatch loss at step 96500: 0.386167
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# finish : 2016-11-28T11:18:38+0900
# Minibatch loss at step 97000: 0.447650
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# finish : 2016-11-28T11:19:00+0900
# Minibatch loss at step 97500: 0.407778
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.5%
# finish : 2016-11-28T11:19:23+0900
# Minibatch loss at step 98000: 0.511648
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# finish : 2016-11-28T11:19:45+0900
# Minibatch loss at step 98500: 0.582195
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.1%
# finish : 2016-11-28T11:20:07+0900
# Minibatch loss at step 99000: 0.555174
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.9%
# finish : 2016-11-28T11:20:29+0900
# Minibatch loss at step 99500: 0.338452
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# finish : 2016-11-28T11:20:51+0900
# Minibatch loss at step 100000: 0.601887
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-11-28T11:21:13+0900
# Test accuracy: 86.7%
# finish : 2016-11-28T11:21:15+0900

# %%
# Minibatch loss at step 100000: 0.657399
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-11-28T12:55:27+0900
# Test accuracy: 87.1%
# finish : 2016-11-28T12:55:29+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,0,0,0,0], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 13.478090
# Minibatch accuracy_length: 18.8%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 6.5%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-28T11:41:31+0900
# Minibatch loss at step 500: 8.021799
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T11:41:53+0900
# Minibatch loss at step 1000: 6.677716
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-28T11:42:15+0900
# Minibatch loss at step 1500: 7.544122
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-28T11:42:36+0900
# Minibatch loss at step 2000: 7.565415
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 1.4%
# finish : 2016-11-28T11:42:57+0900
# Minibatch loss at step 2500: 5.802812
# Minibatch accuracy_length: 78.1%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 55.2%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 6.4%
# finish : 2016-11-28T11:43:19+0900
# Minibatch loss at step 3000: 4.237362
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 59.4%
# Minibatch accuracy_digit_1: 46.9%
# Minibatch accuracy_digit_2: 73.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 18.2%
# finish : 2016-11-28T11:43:41+0900
# Minibatch loss at step 3500: 3.421029
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 71.4%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 35.3%
# finish : 2016-11-28T11:44:03+0900
# Minibatch loss at step 4000: 2.472686
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 68.8%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 31.2%
# Validation accuracy: 43.7%
# finish : 2016-11-28T11:44:25+0900
# Minibatch loss at step 4500: 2.240215
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 64.3%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 53.1%
# finish : 2016-11-28T11:44:47+0900
# Minibatch loss at step 5000: 2.705746
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 57.8%
# finish : 2016-11-28T11:45:09+0900
# Minibatch loss at step 5500: 2.208519
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 81.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 61.7%
# finish : 2016-11-28T11:45:32+0900
# Minibatch loss at step 6000: 1.392565
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 62.5%
# finish : 2016-11-28T11:45:53+0900
# Minibatch loss at step 6500: 1.769022
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 77.4%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 65.9%
# finish : 2016-11-28T11:46:16+0900
# Minibatch loss at step 7000: 2.439790
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 80.8%
# Minibatch accuracy_digit_3: 77.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.4%
# finish : 2016-11-28T11:46:38+0900
# Minibatch loss at step 7500: 2.126131
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 67.3%
# finish : 2016-11-28T11:47:00+0900
# Minibatch loss at step 8000: 1.511171
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 68.9%
# finish : 2016-11-28T11:47:23+0900
# Minibatch loss at step 8500: 1.747925
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 69.8%
# finish : 2016-11-28T11:47:45+0900
# Minibatch loss at step 9000: 1.607875
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.8%
# finish : 2016-11-28T11:48:08+0900
# Minibatch loss at step 9500: 1.616551
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 74.0%
# finish : 2016-11-28T11:48:30+0900
# Minibatch loss at step 10000: 0.830948
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.0%
# finish : 2016-11-28T11:48:52+0900
# Minibatch loss at step 10500: 1.294833
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 77.1%
# finish : 2016-11-28T11:49:15+0900
# Minibatch loss at step 11000: 1.162392
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.4%
# finish : 2016-11-28T11:49:37+0900
# Minibatch loss at step 11500: 2.162255
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 76.6%
# finish : 2016-11-28T11:50:00+0900
# Minibatch loss at step 12000: 0.998058
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.6%
# finish : 2016-11-28T11:50:22+0900
# Minibatch loss at step 12500: 1.154694
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.2%
# finish : 2016-11-28T11:50:45+0900
# Minibatch loss at step 13000: 1.542084
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.9%
# finish : 2016-11-28T11:51:07+0900
# Minibatch loss at step 13500: 0.761742
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.5%
# finish : 2016-11-28T11:51:29+0900
# Minibatch loss at step 14000: 1.520861
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 95.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.2%
# finish : 2016-11-28T11:51:51+0900
# Minibatch loss at step 14500: 1.496343
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 78.6%
# finish : 2016-11-28T11:52:13+0900
# Minibatch loss at step 15000: 1.062823
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# finish : 2016-11-28T11:52:35+0900
# Minibatch loss at step 15500: 1.116148
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.4%
# finish : 2016-11-28T11:52:57+0900
# Minibatch loss at step 16000: 0.689404
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.7%
# finish : 2016-11-28T11:53:20+0900
# Minibatch loss at step 16500: 1.162702
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 81.2%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# finish : 2016-11-28T11:53:41+0900
# Minibatch loss at step 17000: 1.114982
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# finish : 2016-11-28T11:54:04+0900
# Minibatch loss at step 17500: 0.989353
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.5%
# finish : 2016-11-28T11:54:26+0900
# Minibatch loss at step 18000: 0.558271
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.5%
# finish : 2016-11-28T11:54:48+0900
# Minibatch loss at step 18500: 1.132293
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# finish : 2016-11-28T11:55:11+0900
# Minibatch loss at step 19000: 0.515210
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# finish : 2016-11-28T11:55:33+0900
# Minibatch loss at step 19500: 0.887996
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 83.0%
# finish : 2016-11-28T11:55:55+0900
# Minibatch loss at step 20000: 1.126009
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# finish : 2016-11-28T11:56:17+0900
# Minibatch loss at step 20500: 0.825360
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.0%
# finish : 2016-11-28T11:56:39+0900
# Minibatch loss at step 21000: 0.696273
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.2%
# finish : 2016-11-28T11:57:01+0900
# Minibatch loss at step 21500: 1.014832
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# finish : 2016-11-28T11:57:24+0900
# Minibatch loss at step 22000: 1.874929
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# finish : 2016-11-28T11:57:46+0900
# Minibatch loss at step 22500: 0.541564
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# finish : 2016-11-28T11:58:09+0900
# Minibatch loss at step 23000: 0.509705
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.9%
# finish : 2016-11-28T11:58:31+0900
# Minibatch loss at step 23500: 0.889443
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# finish : 2016-11-28T11:58:53+0900
# Minibatch loss at step 24000: 0.836048
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.3%
# finish : 2016-11-28T11:59:15+0900
# Minibatch loss at step 24500: 0.429837
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.2%
# finish : 2016-11-28T11:59:37+0900
# Minibatch loss at step 25000: 0.664053
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# finish : 2016-11-28T11:59:59+0900
# Minibatch loss at step 25500: 0.519124
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# finish : 2016-11-28T12:00:22+0900
# Minibatch loss at step 26000: 0.310226
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 84.5%
# finish : 2016-11-28T12:00:44+0900
# Minibatch loss at step 26500: 0.610451
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.1%
# finish : 2016-11-28T12:01:07+0900
# Minibatch loss at step 27000: 0.950499
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# finish : 2016-11-28T12:01:29+0900
# Minibatch loss at step 27500: 0.516925
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# finish : 2016-11-28T12:01:51+0900
# Minibatch loss at step 28000: 1.026900
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 85.3%
# finish : 2016-11-28T12:02:13+0900
# Minibatch loss at step 28500: 0.744236
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.4%
# finish : 2016-11-28T12:02:35+0900
# Minibatch loss at step 29000: 0.520186
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# finish : 2016-11-28T12:02:57+0900
# Minibatch loss at step 29500: 0.671946
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.4%
# finish : 2016-11-28T12:03:19+0900
# Minibatch loss at step 30000: 0.523165
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.5%
# finish : 2016-11-28T12:03:41+0900
# Minibatch loss at step 30500: 0.781868
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# finish : 2016-11-28T12:04:04+0900
# Minibatch loss at step 31000: 0.892677
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# finish : 2016-11-28T12:04:25+0900
# Minibatch loss at step 31500: 0.520674
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# finish : 2016-11-28T12:04:48+0900
# Minibatch loss at step 32000: 0.566312
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.9%
# finish : 2016-11-28T12:05:10+0900
# Minibatch loss at step 32500: 0.392968
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.6%
# finish : 2016-11-28T12:05:33+0900
# Minibatch loss at step 33000: 0.628379
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.7%
# finish : 2016-11-28T12:05:55+0900
# Minibatch loss at step 33500: 0.541277
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.5%
# finish : 2016-11-28T12:06:17+0900
# Minibatch loss at step 34000: 0.604244
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.0%
# finish : 2016-11-28T12:06:40+0900
# Minibatch loss at step 34500: 0.862455
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# finish : 2016-11-28T12:07:02+0900
# Minibatch loss at step 35000: 1.433276
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# finish : 2016-11-28T12:07:25+0900
# Minibatch loss at step 35500: 1.013247
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# finish : 2016-11-28T12:07:47+0900
# Minibatch loss at step 36000: 0.939324
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# finish : 2016-11-28T12:08:09+0900
# Minibatch loss at step 36500: 2.039477
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# finish : 2016-11-28T12:08:32+0900
# Minibatch loss at step 37000: 0.214295
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.5%
# finish : 2016-11-28T12:08:54+0900
# Minibatch loss at step 37500: 0.722244
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# finish : 2016-11-28T12:09:17+0900
# Minibatch loss at step 38000: 1.288513
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# finish : 2016-11-28T12:09:39+0900
# Minibatch loss at step 38500: 0.559249
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.2%
# finish : 2016-11-28T12:10:01+0900
# Minibatch loss at step 39000: 0.761044
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# finish : 2016-11-28T12:10:23+0900
# Minibatch loss at step 39500: 0.618491
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# finish : 2016-11-28T12:10:45+0900
# Minibatch loss at step 40000: 0.447631
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.4%
# finish : 2016-11-28T12:11:07+0900
# Minibatch loss at step 40500: 0.612696
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# finish : 2016-11-28T12:11:29+0900
# Minibatch loss at step 41000: 0.466164
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# finish : 2016-11-28T12:11:52+0900
# Minibatch loss at step 41500: 0.587394
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# finish : 2016-11-28T12:12:14+0900
# Minibatch loss at step 42000: 0.770720
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.3%
# finish : 2016-11-28T12:12:36+0900
# Minibatch loss at step 42500: 0.739992
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# finish : 2016-11-28T12:12:58+0900
# Minibatch loss at step 43000: 0.929662
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# finish : 2016-11-28T12:13:20+0900
# Minibatch loss at step 43500: 0.688899
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# finish : 2016-11-28T12:13:42+0900
# Minibatch loss at step 44000: 1.115731
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# finish : 2016-11-28T12:14:04+0900
# Minibatch loss at step 44500: 0.454330
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# finish : 2016-11-28T12:14:27+0900
# Minibatch loss at step 45000: 0.814068
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# finish : 2016-11-28T12:14:48+0900
# Minibatch loss at step 45500: 0.364049
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:15:10+0900
# Minibatch loss at step 46000: 0.593657
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# finish : 2016-11-28T12:15:33+0900
# Minibatch loss at step 46500: 0.343411
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-11-28T12:15:55+0900
# Minibatch loss at step 47000: 0.718636
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# finish : 2016-11-28T12:16:17+0900
# Minibatch loss at step 47500: 0.284962
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-11-28T12:16:40+0900
# Minibatch loss at step 48000: 1.382553
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.9%
# finish : 2016-11-28T12:17:02+0900
# Minibatch loss at step 48500: 0.377460
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:17:24+0900
# Minibatch loss at step 49000: 0.472488
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.9%
# finish : 2016-11-28T12:17:46+0900
# Minibatch loss at step 49500: 0.799367
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# finish : 2016-11-28T12:18:09+0900
# Minibatch loss at step 50000: 0.404026
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.1%
# finish : 2016-11-28T12:18:31+0900
# Minibatch loss at step 50500: 0.346976
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.0%
# finish : 2016-11-28T12:18:53+0900
# Minibatch loss at step 51000: 0.364172
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.8%
# finish : 2016-11-28T12:19:15+0900
# Minibatch loss at step 51500: 0.512735
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# finish : 2016-11-28T12:19:38+0900
# Minibatch loss at step 52000: 0.303916
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:20:00+0900
# Minibatch loss at step 52500: 0.496599
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:20:23+0900
# Minibatch loss at step 53000: 0.429506
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-28T12:20:45+0900
# Minibatch loss at step 53500: 0.368677
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-11-28T12:21:07+0900
# Minibatch loss at step 54000: 0.362385
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.0%
# finish : 2016-11-28T12:21:29+0900
# Minibatch loss at step 54500: 0.641846
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# finish : 2016-11-28T12:21:51+0900
# Minibatch loss at step 55000: 1.002792
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:22:13+0900
# Minibatch loss at step 55500: 0.311770
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-11-28T12:22:35+0900
# Minibatch loss at step 56000: 0.643140
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# finish : 2016-11-28T12:22:58+0900
# Minibatch loss at step 56500: 0.639625
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# finish : 2016-11-28T12:23:20+0900
# Minibatch loss at step 57000: 0.867275
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# finish : 2016-11-28T12:23:42+0900
# Minibatch loss at step 57500: 0.738161
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-11-28T12:24:05+0900
# Minibatch loss at step 58000: 1.386948
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# finish : 2016-11-28T12:24:27+0900
# Minibatch loss at step 58500: 0.429579
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:24:49+0900
# Minibatch loss at step 59000: 0.502883
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# finish : 2016-11-28T12:25:11+0900
# Minibatch loss at step 59500: 0.355249
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# finish : 2016-11-28T12:25:33+0900
# Minibatch loss at step 60000: 0.419040
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-28T12:25:54+0900
# Minibatch loss at step 60500: 0.307071
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:26:16+0900
# Minibatch loss at step 61000: 0.255310
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-11-28T12:26:38+0900
# Minibatch loss at step 61500: 0.853494
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# finish : 2016-11-28T12:27:01+0900
# Minibatch loss at step 62000: 0.335704
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-28T12:27:23+0900
# Minibatch loss at step 62500: 0.692790
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:27:44+0900
# Minibatch loss at step 63000: 0.851548
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:28:07+0900
# Minibatch loss at step 63500: 0.538276
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# finish : 2016-11-28T12:28:29+0900
# Minibatch loss at step 64000: 0.788679
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 91.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# finish : 2016-11-28T12:28:52+0900
# Minibatch loss at step 64500: 0.252880
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# finish : 2016-11-28T12:29:14+0900
# Minibatch loss at step 65000: 0.982832
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# finish : 2016-11-28T12:29:36+0900
# Minibatch loss at step 65500: 0.340745
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.5%
# finish : 2016-11-28T12:29:58+0900
# Minibatch loss at step 66000: 1.218284
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:30:20+0900
# Minibatch loss at step 66500: 0.392178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# finish : 2016-11-28T12:30:42+0900
# Minibatch loss at step 67000: 0.537476
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# finish : 2016-11-28T12:31:04+0900
# Minibatch loss at step 67500: 0.353213
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-11-28T12:31:27+0900
# Minibatch loss at step 68000: 0.347793
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-11-28T12:31:48+0900
# Minibatch loss at step 68500: 0.390148
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.0%
# finish : 2016-11-28T12:32:11+0900
# Minibatch loss at step 69000: 0.705139
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# finish : 2016-11-28T12:32:33+0900
# Minibatch loss at step 69500: 0.311029
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# finish : 2016-11-28T12:32:55+0900
# Minibatch loss at step 70000: 0.859396
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# finish : 2016-11-28T12:33:17+0900
# Minibatch loss at step 70500: 0.559203
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# finish : 2016-11-28T12:33:39+0900
# Minibatch loss at step 71000: 0.701498
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.0%
# finish : 2016-11-28T12:34:01+0900
# Minibatch loss at step 71500: 0.279845
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# ...
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-28T12:38:05+0900
# Minibatch loss at step 77000: 0.558779
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# finish : 2016-11-28T12:38:27+0900
# Minibatch loss at step 77500: 0.396023
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# finish : 2016-11-28T12:38:49+0900
# Minibatch loss at step 78000: 0.484968
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:39:11+0900
# Minibatch loss at step 78500: 0.613066
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.0%
# finish : 2016-11-28T12:39:33+0900
# Minibatch loss at step 79000: 0.405473
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:39:55+0900
# Minibatch loss at step 79500: 0.316431
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-28T12:40:17+0900
# Minibatch loss at step 80000: 0.399337
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:40:39+0900
# Minibatch loss at step 80500: 0.388560
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.9%
# finish : 2016-11-28T12:41:01+0900
# Minibatch loss at step 81000: 0.223166
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# finish : 2016-11-28T12:41:23+0900
# Minibatch loss at step 81500: 0.190622
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# finish : 2016-11-28T12:41:45+0900
# Minibatch loss at step 82000: 0.297241
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:42:07+0900
# Minibatch loss at step 82500: 0.319799
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.8%
# finish : 2016-11-28T12:42:29+0900
# Minibatch loss at step 83000: 0.616590
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# finish : 2016-11-28T12:42:51+0900
# Minibatch loss at step 83500: 0.197386
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# finish : 2016-11-28T12:43:13+0900
# Minibatch loss at step 84000: 0.321620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# finish : 2016-11-28T12:43:36+0900
# Minibatch loss at step 84500: 0.313401
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.0%
# finish : 2016-11-28T12:43:58+0900
# Minibatch loss at step 85000: 0.462311
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# finish : 2016-11-28T12:44:21+0900
# Minibatch loss at step 85500: 0.254217
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:44:43+0900
# Minibatch loss at step 86000: 0.260931
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.4%
# finish : 2016-11-28T12:45:05+0900
# Minibatch loss at step 86500: 0.639391
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# finish : 2016-11-28T12:45:27+0900
# Minibatch loss at step 87000: 0.303072
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:45:49+0900
# Minibatch loss at step 87500: 0.241297
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# finish : 2016-11-28T12:46:11+0900
# Minibatch loss at step 88000: 0.277759
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# finish : 2016-11-28T12:46:33+0900
# Minibatch loss at step 88500: 0.368860
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.9%
# finish : 2016-11-28T12:46:56+0900
# Minibatch loss at step 89000: 0.270967
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# finish : 2016-11-28T12:47:18+0900
# Minibatch loss at step 89500: 0.351290
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# finish : 2016-11-28T12:47:40+0900
# Minibatch loss at step 90000: 0.331323
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# finish : 2016-11-28T12:48:02+0900
# Minibatch loss at step 90500: 0.565281
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-28T12:48:24+0900
# Minibatch loss at step 91000: 0.437033
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# finish : 2016-11-28T12:48:47+0900
# Minibatch loss at step 91500: 0.493112
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:49:10+0900
# Minibatch loss at step 92000: 0.635855
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# finish : 2016-11-28T12:49:32+0900
# Minibatch loss at step 92500: 0.184070
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:49:54+0900
# Minibatch loss at step 93000: 0.264929
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.1%
# finish : 2016-11-28T12:50:16+0900
# Minibatch loss at step 93500: 0.751087
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# finish : 2016-11-28T12:50:38+0900
# Minibatch loss at step 94000: 0.820086
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-28T12:51:00+0900
# Minibatch loss at step 94500: 0.275458
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.8%
# finish : 2016-11-28T12:51:22+0900
# Minibatch loss at step 95000: 0.361846
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.9%
# finish : 2016-11-28T12:51:44+0900
# Minibatch loss at step 95500: 0.273020
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# finish : 2016-11-28T12:52:06+0900
# Minibatch loss at step 96000: 0.314298
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-28T12:52:28+0900
# Minibatch loss at step 96500: 0.267984
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# finish : 2016-11-28T12:52:51+0900
# Minibatch loss at step 97000: 0.320617
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# finish : 2016-11-28T12:53:13+0900
# Minibatch loss at step 97500: 0.311588
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# finish : 2016-11-28T12:53:35+0900
# Minibatch loss at step 98000: 0.551401
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# finish : 2016-11-28T12:53:57+0900
# Minibatch loss at step 98500: 0.396676
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# finish : 2016-11-28T12:54:19+0900
# Minibatch loss at step 99000: 0.363631
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# finish : 2016-11-28T12:54:42+0900
# Minibatch loss at step 99500: 0.313935
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-28T12:55:05+0900
# Minibatch loss at step 100000: 0.657399
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-11-28T12:55:27+0900
# Test accuracy: 87.1%
# finish : 2016-11-28T12:55:29+0900

# %%
# Minibatch loss at step 100000: 0.413733
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:27:39+0900
# Test accuracy: 88.7%
# finish : 2016-11-28T14:27:42+0900

svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,0,0,0], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 14.323484
# Minibatch accuracy_length: 21.9%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 25.8%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.5%
# finish : 2016-11-28T13:12:03+0900
# Minibatch loss at step 500: 8.015701
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T13:12:25+0900
# Minibatch loss at step 1000: 6.655470
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-28T13:12:48+0900
# Minibatch loss at step 1500: 7.319536
# Minibatch accuracy_length: 78.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.8%
# finish : 2016-11-28T13:13:10+0900
# Minibatch loss at step 2000: 6.493125
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 30.0%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 2.3%
# finish : 2016-11-28T13:13:32+0900
# Minibatch loss at step 2500: 5.020501
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 46.9%
# Minibatch accuracy_digit_2: 62.1%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.7%
# finish : 2016-11-28T13:13:54+0900
# Minibatch loss at step 3000: 3.473983
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 59.4%
# Minibatch accuracy_digit_1: 62.5%
# Minibatch accuracy_digit_2: 70.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 25.0%
# Validation accuracy: 32.6%
# finish : 2016-11-28T13:14:17+0900
# Minibatch loss at step 3500: 2.752711
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 82.1%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 44.5%
# finish : 2016-11-28T13:14:39+0900
# Minibatch loss at step 4000: 1.953188
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 54.5%
# finish : 2016-11-28T13:15:01+0900
# Minibatch loss at step 4500: 1.932044
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 71.4%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 60.4%
# finish : 2016-11-28T13:15:24+0900
# Minibatch loss at step 5000: 2.430950
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 75.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 65.4%
# finish : 2016-11-28T13:15:46+0900
# Minibatch loss at step 5500: 1.695585
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 81.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.9%
# finish : 2016-11-28T13:16:08+0900
# Minibatch loss at step 6000: 1.192394
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.0%
# finish : 2016-11-28T13:16:31+0900
# Minibatch loss at step 6500: 1.480778
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.1%
# finish : 2016-11-28T13:16:53+0900
# Minibatch loss at step 7000: 2.329607
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 80.8%
# Minibatch accuracy_digit_3: 77.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 71.7%
# finish : 2016-11-28T13:17:16+0900
# Minibatch loss at step 7500: 2.006922
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.7%
# finish : 2016-11-28T13:17:38+0900
# Minibatch loss at step 8000: 1.606265
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.0%
# finish : 2016-11-28T13:18:01+0900
# Minibatch loss at step 8500: 1.352973
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 74.3%
# finish : 2016-11-28T13:18:24+0900
# Minibatch loss at step 9000: 1.627352
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.1%
# finish : 2016-11-28T13:18:47+0900
# Minibatch loss at step 9500: 1.138229
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.6%
# finish : 2016-11-28T13:19:09+0900
# Minibatch loss at step 10000: 0.668823
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 79.1%
# finish : 2016-11-28T13:19:32+0900
# Minibatch loss at step 10500: 1.107325
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.2%
# finish : 2016-11-28T13:19:55+0900
# Minibatch loss at step 11000: 0.898472
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# finish : 2016-11-28T13:20:18+0900
# Minibatch loss at step 11500: 2.036289
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 79.6%
# finish : 2016-11-28T13:20:40+0900
# Minibatch loss at step 12000: 0.788211
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# finish : 2016-11-28T13:21:03+0900
# Minibatch loss at step 12500: 0.830547
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.8%
# finish : 2016-11-28T13:21:25+0900
# Minibatch loss at step 13000: 1.821764
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# finish : 2016-11-28T13:21:48+0900
# Minibatch loss at step 13500: 0.516469
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.7%
# finish : 2016-11-28T13:22:11+0900
# Minibatch loss at step 14000: 1.724328
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 95.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.2%
# finish : 2016-11-28T13:22:33+0900
# Minibatch loss at step 14500: 1.405752
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# finish : 2016-11-28T13:22:56+0900
# Minibatch loss at step 15000: 1.119745
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.1%
# finish : 2016-11-28T13:23:19+0900
# Minibatch loss at step 15500: 0.884322
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.8%
# finish : 2016-11-28T13:23:42+0900
# Minibatch loss at step 16000: 0.937167
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# finish : 2016-11-28T13:24:04+0900
# Minibatch loss at step 16500: 1.003034
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.0%
# finish : 2016-11-28T13:24:27+0900
# Minibatch loss at step 17000: 0.792106
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.2%
# finish : 2016-11-28T13:24:50+0900
# Minibatch loss at step 17500: 1.016925
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# finish : 2016-11-28T13:25:12+0900
# Minibatch loss at step 18000: 0.523108
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# finish : 2016-11-28T13:25:35+0900
# Minibatch loss at step 18500: 0.893891
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# finish : 2016-11-28T13:25:57+0900
# Minibatch loss at step 19000: 0.478039
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# finish : 2016-11-28T13:26:20+0900
# Minibatch loss at step 19500: 0.992086
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# finish : 2016-11-28T13:26:43+0900
# Minibatch loss at step 20000: 0.926608
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# finish : 2016-11-28T13:27:06+0900
# Minibatch loss at step 20500: 0.602586
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# finish : 2016-11-28T13:27:28+0900
# Minibatch loss at step 21000: 0.612781
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# finish : 2016-11-28T13:27:51+0900
# Minibatch loss at step 21500: 0.784301
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# finish : 2016-11-28T13:28:14+0900
# Minibatch loss at step 22000: 1.818661
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 84.0%
# finish : 2016-11-28T13:28:37+0900
# Minibatch loss at step 22500: 0.372450
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.4%
# finish : 2016-11-28T13:29:00+0900
# Minibatch loss at step 23000: 0.483294
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# finish : 2016-11-28T13:29:23+0900
# Minibatch loss at step 23500: 0.781641
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.7%
# finish : 2016-11-28T13:29:45+0900
# Minibatch loss at step 24000: 0.874231
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# finish : 2016-11-28T13:30:08+0900
# Minibatch loss at step 24500: 0.455252
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-11-28T13:30:31+0900
# Minibatch loss at step 25000: 0.652952
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# finish : 2016-11-28T13:30:54+0900
# Minibatch loss at step 25500: 0.335190
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.1%
# finish : 2016-11-28T13:31:17+0900
# Minibatch loss at step 26000: 0.360504
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.4%
# finish : 2016-11-28T13:31:39+0900
# Minibatch loss at step 26500: 0.759093
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# finish : 2016-11-28T13:32:03+0900
# Minibatch loss at step 27000: 0.810961
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.6%
# finish : 2016-11-28T13:32:25+0900
# Minibatch loss at step 27500: 0.472056
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# finish : 2016-11-28T13:32:48+0900
# Minibatch loss at step 28000: 0.966106
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# finish : 2016-11-28T13:33:11+0900
# Minibatch loss at step 28500: 0.763504
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# finish : 2016-11-28T13:33:33+0900
# Minibatch loss at step 29000: 0.462548
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.6%
# finish : 2016-11-28T13:33:56+0900
# Minibatch loss at step 29500: 0.536300
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.9%
# finish : 2016-11-28T13:34:19+0900
# Minibatch loss at step 30000: 0.382494
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.8%
# finish : 2016-11-28T13:34:42+0900
# Minibatch loss at step 30500: 0.607930
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# finish : 2016-11-28T13:35:04+0900
# Minibatch loss at step 31000: 0.679604
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# finish : 2016-11-28T13:35:27+0900
# Minibatch loss at step 31500: 0.509200
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.1%
# finish : 2016-11-28T13:35:50+0900
# Minibatch loss at step 32000: 0.342486
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# finish : 2016-11-28T13:36:13+0900
# Minibatch loss at step 32500: 0.314096
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.9%
# finish : 2016-11-28T13:36:35+0900
# Minibatch loss at step 33000: 0.515812
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# finish : 2016-11-28T13:36:58+0900
# Minibatch loss at step 33500: 0.389623
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# finish : 2016-11-28T13:37:21+0900
# Minibatch loss at step 34000: 0.365135
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# finish : 2016-11-28T13:37:44+0900
# Minibatch loss at step 34500: 0.688548
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.1%
# finish : 2016-11-28T13:38:06+0900
# Minibatch loss at step 35000: 1.504749
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 84.6%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.5%
# finish : 2016-11-28T13:38:29+0900
# Minibatch loss at step 35500: 1.273661
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# finish : 2016-11-28T13:38:52+0900
# Minibatch loss at step 36000: 0.637068
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-11-28T13:39:15+0900
# Minibatch loss at step 36500: 1.838468
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# finish : 2016-11-28T13:39:38+0900
# Minibatch loss at step 37000: 0.177018
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# finish : 2016-11-28T13:40:00+0900
# Minibatch loss at step 37500: 0.530659
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# finish : 2016-11-28T13:40:23+0900
# Minibatch loss at step 38000: 1.310835
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# finish : 2016-11-28T13:40:46+0900
# Minibatch loss at step 38500: 0.425104
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-28T13:41:09+0900
# Minibatch loss at step 39000: 0.498069
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# finish : 2016-11-28T13:41:32+0900
# Minibatch loss at step 39500: 0.514871
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-11-28T13:41:54+0900
# Minibatch loss at step 40000: 0.358008
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-28T13:42:16+0900
# Minibatch loss at step 40500: 0.570926
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# finish : 2016-11-28T13:42:39+0900
# Minibatch loss at step 41000: 0.484845
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# finish : 2016-11-28T13:43:02+0900
# Minibatch loss at step 41500: 0.411658
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# finish : 2016-11-28T13:43:24+0900
# Minibatch loss at step 42000: 0.374270
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.4%
# finish : 2016-11-28T13:43:47+0900
# Minibatch loss at step 42500: 0.631705
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# finish : 2016-11-28T13:44:10+0900
# Minibatch loss at step 43000: 0.580675
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# finish : 2016-11-28T13:44:33+0900
# Minibatch loss at step 43500: 0.408527
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# finish : 2016-11-28T13:44:56+0900
# Minibatch loss at step 44000: 1.072252
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-28T13:45:18+0900
# Minibatch loss at step 44500: 0.394109
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-28T13:45:41+0900
# Minibatch loss at step 45000: 0.493889
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-28T13:46:04+0900
# Minibatch loss at step 45500: 0.242413
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T13:46:26+0900
# Minibatch loss at step 46000: 0.332125
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T13:46:49+0900
# Minibatch loss at step 46500: 0.326821
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.9%
# finish : 2016-11-28T13:47:12+0900
# Minibatch loss at step 47000: 0.711066
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-28T13:47:35+0900
# Minibatch loss at step 47500: 0.293226
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T13:47:58+0900
# Minibatch loss at step 48000: 0.769404
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# finish : 2016-11-28T13:48:20+0900
# Minibatch loss at step 48500: 0.309808
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-28T13:48:43+0900
# Minibatch loss at step 49000: 0.337550
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-28T13:49:06+0900
# Minibatch loss at step 49500: 0.535214
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# finish : 2016-11-28T13:49:28+0900
# Minibatch loss at step 50000: 0.451908
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# finish : 2016-11-28T13:49:51+0900
# Minibatch loss at step 50500: 0.282418
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.2%
# finish : 2016-11-28T13:50:14+0900
# Minibatch loss at step 51000: 0.236992
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-28T13:50:37+0900
# Minibatch loss at step 51500: 0.360550
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T13:50:59+0900
# Minibatch loss at step 52000: 0.198629
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-28T13:51:22+0900
# Minibatch loss at step 52500: 0.262558
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-28T13:51:45+0900
# Minibatch loss at step 53000: 0.283814
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T13:52:07+0900
# Minibatch loss at step 53500: 0.235527
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T13:52:30+0900
# Minibatch loss at step 54000: 0.256388
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T13:52:52+0900
# Minibatch loss at step 54500: 0.616029
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.4%
# finish : 2016-11-28T13:53:15+0900
# Minibatch loss at step 55000: 0.696906
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# finish : 2016-11-28T13:53:37+0900
# Minibatch loss at step 55500: 0.202304
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-11-28T13:54:00+0900
# Minibatch loss at step 56000: 0.536369
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 95.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-28T13:54:23+0900
# Minibatch loss at step 56500: 0.697875
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# finish : 2016-11-28T13:54:46+0900
# Minibatch loss at step 57000: 0.741106
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.3%
# finish : 2016-11-28T13:55:09+0900
# Minibatch loss at step 57500: 0.593775
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# finish : 2016-11-28T13:55:32+0900
# Minibatch loss at step 58000: 1.225198
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.9%
# finish : 2016-11-28T13:55:55+0900
# Minibatch loss at step 58500: 0.418967
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T13:56:17+0900
# Minibatch loss at step 59000: 0.444431
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-28T13:56:40+0900
# Minibatch loss at step 59500: 0.231525
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T13:57:02+0900
# Minibatch loss at step 60000: 0.309730
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T13:57:25+0900
# Minibatch loss at step 60500: 0.194868
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T13:57:48+0900
# Minibatch loss at step 61000: 0.167798
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T13:58:10+0900
# Minibatch loss at step 61500: 0.507343
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# finish : 2016-11-28T13:58:33+0900
# Minibatch loss at step 62000: 0.239225
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T13:58:55+0900
# Minibatch loss at step 62500: 0.505920
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# finish : 2016-11-28T13:59:18+0900
# Minibatch loss at step 63000: 0.809190
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# finish : 2016-11-28T13:59:41+0900
# Minibatch loss at step 63500: 0.311176
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-11-28T14:00:05+0900
# Minibatch loss at step 64000: 0.745983
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# finish : 2016-11-28T14:00:28+0900
# Minibatch loss at step 64500: 0.247631
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# finish : 2016-11-28T14:00:50+0900
# Minibatch loss at step 65000: 0.995000
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-28T14:01:13+0900
# Minibatch loss at step 65500: 0.197839
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:01:36+0900
# Minibatch loss at step 66000: 1.167596
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-28T14:01:59+0900
# Minibatch loss at step 66500: 0.272958
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:02:21+0900
# Minibatch loss at step 67000: 0.274210
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:02:44+0900
# Minibatch loss at step 67500: 0.256771
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-28T14:03:07+0900
# Minibatch loss at step 68000: 0.225907
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T14:03:29+0900
# Minibatch loss at step 68500: 0.314662
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T14:03:52+0900
# Minibatch loss at step 69000: 0.454008
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:04:14+0900
# Minibatch loss at step 69500: 0.281220
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-28T14:04:37+0900
# Minibatch loss at step 70000: 0.600003
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-28T14:05:00+0900
# Minibatch loss at step 70500: 0.650163
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# finish : 2016-11-28T14:05:23+0900
# Minibatch loss at step 71000: 0.602719
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-28T14:05:45+0900
# Minibatch loss at step 71500: 0.243575
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# ...
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T14:09:55+0900
# Minibatch loss at step 77000: 0.356891
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T14:10:18+0900
# Minibatch loss at step 77500: 0.278732
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:10:41+0900
# Minibatch loss at step 78000: 0.568863
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# finish : 2016-11-28T14:11:04+0900
# Minibatch loss at step 78500: 0.684136
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# finish : 2016-11-28T14:11:27+0900
# Minibatch loss at step 79000: 0.343183
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:11:49+0900
# Minibatch loss at step 79500: 0.339817
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:12:12+0900
# Minibatch loss at step 80000: 0.419640
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T14:12:34+0900
# Minibatch loss at step 80500: 0.198853
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:12:57+0900
# Minibatch loss at step 81000: 0.173178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T14:13:19+0900
# Minibatch loss at step 81500: 0.172040
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T14:13:42+0900
# Minibatch loss at step 82000: 0.179426
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-28T14:14:05+0900
# Minibatch loss at step 82500: 0.222871
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:14:27+0900
# Minibatch loss at step 83000: 0.323383
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# finish : 2016-11-28T14:14:50+0900
# Minibatch loss at step 83500: 0.150502
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T14:15:12+0900
# Minibatch loss at step 84000: 0.271302
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:15:35+0900
# Minibatch loss at step 84500: 0.313550
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:15:57+0900
# Minibatch loss at step 85000: 0.460307
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:16:20+0900
# Minibatch loss at step 85500: 0.191051
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.3%
# finish : 2016-11-28T14:16:43+0900
# Minibatch loss at step 86000: 0.203440
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T14:17:05+0900
# Minibatch loss at step 86500: 0.969792
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# finish : 2016-11-28T14:17:28+0900
# Minibatch loss at step 87000: 0.273385
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:17:50+0900
# Minibatch loss at step 87500: 0.238949
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T14:18:13+0900
# Minibatch loss at step 88000: 0.159022
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T14:18:36+0900
# Minibatch loss at step 88500: 0.316778
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:18:59+0900
# Minibatch loss at step 89000: 0.239171
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-28T14:19:21+0900
# Minibatch loss at step 89500: 0.323975
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-28T14:19:43+0900
# Minibatch loss at step 90000: 0.206308
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T14:20:06+0900
# Minibatch loss at step 90500: 0.230962
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:20:28+0900
# Minibatch loss at step 91000: 0.299798
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:20:51+0900
# Minibatch loss at step 91500: 0.422845
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-28T14:21:14+0900
# Minibatch loss at step 92000: 0.372456
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:21:37+0900
# Minibatch loss at step 92500: 0.178156
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:21:59+0900
# Minibatch loss at step 93000: 0.194025
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:22:22+0900
# Minibatch loss at step 93500: 0.655017
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-28T14:22:45+0900
# Minibatch loss at step 94000: 0.660164
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-28T14:23:07+0900
# Minibatch loss at step 94500: 0.229139
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T14:23:30+0900
# Minibatch loss at step 95000: 0.281852
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:23:52+0900
# Minibatch loss at step 95500: 0.187813
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T14:24:15+0900
# Minibatch loss at step 96000: 0.297370
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:24:38+0900
# Minibatch loss at step 96500: 0.174486
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T14:25:01+0900
# Minibatch loss at step 97000: 0.204807
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T14:25:23+0900
# Minibatch loss at step 97500: 0.238526
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T14:25:46+0900
# Minibatch loss at step 98000: 0.383828
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-28T14:26:08+0900
# Minibatch loss at step 98500: 0.357934
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:26:31+0900
# Minibatch loss at step 99000: 0.277824
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-28T14:26:54+0900
# Minibatch loss at step 99500: 0.290079
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:27:17+0900
# Minibatch loss at step 100000: 0.413733
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:27:39+0900
# Test accuracy: 88.7%
# finish : 2016-11-28T14:27:42+0900

# %%
# Minibatch loss at step 100000: 0.363833
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:45:28+0900
# Test accuracy: 89.7%
# finish : 2016-11-28T15:45:31+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,0,0], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 14.073882
# Minibatch accuracy_length: 3.1%
# Minibatch accuracy_digit_0: 9.4%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 6.5%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-28T14:27:53+0900
# Minibatch loss at step 500: 8.007686
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T14:28:15+0900
# Minibatch loss at step 1000: 6.650657
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-28T14:28:38+0900
# Minibatch loss at step 1500: 7.254798
# Minibatch accuracy_length: 78.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.5%
# finish : 2016-11-28T14:29:01+0900
# Minibatch loss at step 2000: 6.793263
# Minibatch accuracy_length: 78.1%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 2.6%
# finish : 2016-11-28T14:29:23+0900
# Minibatch loss at step 2500: 4.880967
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 50.0%
# Minibatch accuracy_digit_1: 56.2%
# Minibatch accuracy_digit_2: 62.1%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 11.7%
# finish : 2016-11-28T14:29:46+0900
# Minibatch loss at step 3000: 3.427339
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 62.5%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 73.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 18.8%
# Validation accuracy: 30.0%
# finish : 2016-11-28T14:30:09+0900
# Minibatch loss at step 3500: 2.855779
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 45.7%
# finish : 2016-11-28T14:30:32+0900
# Minibatch loss at step 4000: 1.836498
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 78.1%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 55.3%
# finish : 2016-11-28T14:30:55+0900
# Minibatch loss at step 4500: 1.739203
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 71.4%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 61.6%
# finish : 2016-11-28T14:31:18+0900
# Minibatch loss at step 5000: 2.253084
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 66.1%
# finish : 2016-11-28T14:31:41+0900
# Minibatch loss at step 5500: 1.926744
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.0%
# finish : 2016-11-28T14:32:04+0900
# Minibatch loss at step 6000: 1.055797
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.5%
# finish : 2016-11-28T14:32:28+0900
# Minibatch loss at step 6500: 1.552676
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 73.5%
# finish : 2016-11-28T14:32:51+0900
# Minibatch loss at step 7000: 2.455119
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 80.8%
# Minibatch accuracy_digit_3: 77.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.6%
# finish : 2016-11-28T14:33:14+0900
# Minibatch loss at step 7500: 1.890831
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 73.9%
# finish : 2016-11-28T14:33:37+0900
# Minibatch loss at step 8000: 1.354486
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 75.7%
# finish : 2016-11-28T14:34:01+0900
# Minibatch loss at step 8500: 1.269764
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 75.9%
# finish : 2016-11-28T14:34:24+0900
# Minibatch loss at step 9000: 1.465676
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.4%
# finish : 2016-11-28T14:34:47+0900
# Minibatch loss at step 9500: 1.315750
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.9%
# finish : 2016-11-28T14:35:11+0900
# Minibatch loss at step 10000: 0.572715
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.4%
# finish : 2016-11-28T14:35:34+0900
# Minibatch loss at step 10500: 1.036465
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.4%
# finish : 2016-11-28T14:35:57+0900
# Minibatch loss at step 11000: 0.860436
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.7%
# finish : 2016-11-28T14:36:20+0900
# Minibatch loss at step 11500: 2.434924
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 82.3%
# finish : 2016-11-28T14:36:43+0900
# Minibatch loss at step 12000: 0.800718
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.0%
# finish : 2016-11-28T14:37:06+0900
# Minibatch loss at step 12500: 0.820501
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.3%
# finish : 2016-11-28T14:37:29+0900
# Minibatch loss at step 13000: 1.621646
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.3%
# finish : 2016-11-28T14:37:53+0900
# Minibatch loss at step 13500: 0.468894
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.4%
# finish : 2016-11-28T14:38:16+0900
# Minibatch loss at step 14000: 1.597155
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 95.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 83.7%
# finish : 2016-11-28T14:38:40+0900
# Minibatch loss at step 14500: 1.525957
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.2%
# finish : 2016-11-28T14:39:03+0900
# Minibatch loss at step 15000: 0.758807
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# finish : 2016-11-28T14:39:26+0900
# Minibatch loss at step 15500: 0.952376
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.6%
# finish : 2016-11-28T14:39:49+0900
# Minibatch loss at step 16000: 0.469727
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.7%
# finish : 2016-11-28T14:40:13+0900
# Minibatch loss at step 16500: 1.035123
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 85.2%
# finish : 2016-11-28T14:40:37+0900
# Minibatch loss at step 17000: 0.582828
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.8%
# finish : 2016-11-28T14:41:00+0900
# Minibatch loss at step 17500: 1.123126
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# finish : 2016-11-28T14:41:23+0900
# Minibatch loss at step 18000: 0.699688
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.3%
# finish : 2016-11-28T14:41:46+0900
# Minibatch loss at step 18500: 1.075750
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.2%
# finish : 2016-11-28T14:42:09+0900
# Minibatch loss at step 19000: 0.459222
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# finish : 2016-11-28T14:42:32+0900
# Minibatch loss at step 19500: 0.680435
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.9%
# finish : 2016-11-28T14:42:56+0900
# Minibatch loss at step 20000: 0.562763
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# finish : 2016-11-28T14:43:19+0900
# Minibatch loss at step 20500: 0.555674
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# finish : 2016-11-28T14:43:43+0900
# Minibatch loss at step 21000: 0.677221
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# finish : 2016-11-28T14:44:07+0900
# Minibatch loss at step 21500: 0.646607
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.3%
# finish : 2016-11-28T14:44:30+0900
# Minibatch loss at step 22000: 1.343249
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# finish : 2016-11-28T14:44:53+0900
# Minibatch loss at step 22500: 0.450193
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# finish : 2016-11-28T14:45:17+0900
# Minibatch loss at step 23000: 0.594584
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# finish : 2016-11-28T14:45:40+0900
# Minibatch loss at step 23500: 0.658616
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# finish : 2016-11-28T14:46:03+0900
# Minibatch loss at step 24000: 0.746776
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# finish : 2016-11-28T14:46:27+0900
# Minibatch loss at step 24500: 0.416584
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# finish : 2016-11-28T14:46:50+0900
# Minibatch loss at step 25000: 0.642743
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# finish : 2016-11-28T14:47:13+0900
# Minibatch loss at step 25500: 0.274799
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-11-28T14:47:37+0900
# Minibatch loss at step 26000: 0.288040
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# finish : 2016-11-28T14:48:00+0900
# Minibatch loss at step 26500: 0.579756
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# finish : 2016-11-28T14:48:23+0900
# Minibatch loss at step 27000: 0.740527
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# finish : 2016-11-28T14:48:46+0900
# Minibatch loss at step 27500: 0.396256
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# finish : 2016-11-28T14:49:10+0900
# Minibatch loss at step 28000: 0.890870
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# finish : 2016-11-28T14:49:33+0900
# Minibatch loss at step 28500: 0.441418
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.9%
# finish : 2016-11-28T14:49:57+0900
# Minibatch loss at step 29000: 0.393662
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# finish : 2016-11-28T14:50:21+0900
# Minibatch loss at step 29500: 0.659309
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# finish : 2016-11-28T14:50:44+0900
# Minibatch loss at step 30000: 0.338434
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# finish : 2016-11-28T14:51:08+0900
# Minibatch loss at step 30500: 0.440149
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# finish : 2016-11-28T14:51:31+0900
# Minibatch loss at step 31000: 0.711998
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:51:55+0900
# Minibatch loss at step 31500: 0.394748
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.2%
# finish : 2016-11-28T14:52:18+0900
# Minibatch loss at step 32000: 0.277301
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.6%
# finish : 2016-11-28T14:52:41+0900
# Minibatch loss at step 32500: 0.301627
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-28T14:53:05+0900
# Minibatch loss at step 33000: 0.392190
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# finish : 2016-11-28T14:53:28+0900
# Minibatch loss at step 33500: 0.345197
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# finish : 2016-11-28T14:53:51+0900
# Minibatch loss at step 34000: 0.519559
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# finish : 2016-11-28T14:54:15+0900
# Minibatch loss at step 34500: 0.594762
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:54:38+0900
# Minibatch loss at step 35000: 0.700447
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# finish : 2016-11-28T14:55:01+0900
# Minibatch loss at step 35500: 1.018273
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.8%
# finish : 2016-11-28T14:55:25+0900
# Minibatch loss at step 36000: 0.599096
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# finish : 2016-11-28T14:55:48+0900
# Minibatch loss at step 36500: 1.575011
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# finish : 2016-11-28T14:56:12+0900
# Minibatch loss at step 37000: 0.184273
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:56:35+0900
# Minibatch loss at step 37500: 0.405942
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# finish : 2016-11-28T14:56:58+0900
# Minibatch loss at step 38000: 1.220472
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:57:22+0900
# Minibatch loss at step 38500: 0.329696
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# finish : 2016-11-28T14:57:45+0900
# Minibatch loss at step 39000: 0.640737
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# finish : 2016-11-28T14:58:08+0900
# Minibatch loss at step 39500: 0.533952
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-28T14:58:32+0900
# Minibatch loss at step 40000: 0.287371
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T14:58:55+0900
# Minibatch loss at step 40500: 0.589382
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.2%
# finish : 2016-11-28T14:59:19+0900
# Minibatch loss at step 41000: 0.325382
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T14:59:42+0900
# Minibatch loss at step 41500: 0.416307
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T15:00:05+0900
# Minibatch loss at step 42000: 0.511492
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T15:00:28+0900
# Minibatch loss at step 42500: 0.679929
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-28T15:00:52+0900
# Minibatch loss at step 43000: 0.623409
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# finish : 2016-11-28T15:01:15+0900
# Minibatch loss at step 43500: 0.308432
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-28T15:01:39+0900
# Minibatch loss at step 44000: 0.946476
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T15:02:03+0900
# Minibatch loss at step 44500: 0.202436
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T15:02:26+0900
# Minibatch loss at step 45000: 0.511856
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:02:49+0900
# Minibatch loss at step 45500: 0.225574
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T15:03:13+0900
# Minibatch loss at step 46000: 0.445156
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:03:36+0900
# Minibatch loss at step 46500: 0.278314
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:03:59+0900
# Minibatch loss at step 47000: 0.682083
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:04:22+0900
# Minibatch loss at step 47500: 0.249318
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T15:04:45+0900
# Minibatch loss at step 48000: 0.727406
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# finish : 2016-11-28T15:05:09+0900
# Minibatch loss at step 48500: 0.241783
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:05:32+0900
# Minibatch loss at step 49000: 0.285948
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:05:55+0900
# Minibatch loss at step 49500: 0.613869
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.1%
# finish : 2016-11-28T15:06:19+0900
# Minibatch loss at step 50000: 0.297847
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-11-28T15:06:42+0900
# Minibatch loss at step 50500: 0.281983
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T15:07:06+0900
# Minibatch loss at step 51000: 0.251313
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:07:29+0900
# Minibatch loss at step 51500: 0.331597
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:07:52+0900
# Minibatch loss at step 52000: 0.196435
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T15:08:16+0900
# Minibatch loss at step 52500: 0.248482
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T15:08:39+0900
# Minibatch loss at step 53000: 0.243296
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T15:09:02+0900
# Minibatch loss at step 53500: 0.207349
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:09:26+0900
# Minibatch loss at step 54000: 0.171396
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:09:49+0900
# Minibatch loss at step 54500: 0.600185
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-28T15:10:13+0900
# Minibatch loss at step 55000: 0.830470
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# finish : 2016-11-28T15:10:36+0900
# Minibatch loss at step 55500: 0.171289
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T15:10:59+0900
# Minibatch loss at step 56000: 0.454829
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:11:22+0900
# Minibatch loss at step 56500: 0.726202
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# finish : 2016-11-28T15:11:45+0900
# Minibatch loss at step 57000: 0.762859
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T15:12:08+0900
# Minibatch loss at step 57500: 0.711468
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:12:32+0900
# Minibatch loss at step 58000: 1.106407
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.4%
# finish : 2016-11-28T15:12:55+0900
# Minibatch loss at step 58500: 0.291511
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T15:13:18+0900
# Minibatch loss at step 59000: 0.346805
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:13:41+0900
# Minibatch loss at step 59500: 0.214899
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:14:05+0900
# Minibatch loss at step 60000: 0.298641
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:14:28+0900
# Minibatch loss at step 60500: 0.178543
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:14:51+0900
# Minibatch loss at step 61000: 0.172929
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:15:14+0900
# Minibatch loss at step 61500: 0.388596
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:15:37+0900
# Minibatch loss at step 62000: 0.164049
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T15:16:01+0900
# Minibatch loss at step 62500: 0.252508
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T15:16:24+0900
# Minibatch loss at step 63000: 0.647441
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-28T15:16:47+0900
# Minibatch loss at step 63500: 0.299545
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-28T15:17:10+0900
# Minibatch loss at step 64000: 0.465940
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:17:33+0900
# Minibatch loss at step 64500: 0.170230
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:17:57+0900
# Minibatch loss at step 65000: 0.669443
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T15:18:20+0900
# Minibatch loss at step 65500: 0.256518
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:18:44+0900
# Minibatch loss at step 66000: 1.139451
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# finish : 2016-11-28T15:19:07+0900
# Minibatch loss at step 66500: 0.235328
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-28T15:19:30+0900
# Minibatch loss at step 67000: 0.255511
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-28T15:19:53+0900
# Minibatch loss at step 67500: 0.230213
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:20:17+0900
# Minibatch loss at step 68000: 0.162772
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:20:40+0900
# Minibatch loss at step 68500: 0.310467
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:21:03+0900
# Minibatch loss at step 69000: 0.292891
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:21:26+0900
# Minibatch loss at step 69500: 0.156933
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T15:21:49+0900
# Minibatch loss at step 70000: 0.750944
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:22:13+0900
# Minibatch loss at step 70500: 0.441775
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-28T15:22:36+0900
# Minibatch loss at step 71000: 0.661402
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:23:00+0900
# Minibatch loss at step 71500: 0.184084
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# ...
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:27:16+0900
# Minibatch loss at step 77000: 0.373160
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:27:39+0900
# Minibatch loss at step 77500: 0.254625
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-28T15:28:03+0900
# Minibatch loss at step 78000: 0.319856
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:28:26+0900
# Minibatch loss at step 78500: 0.761607
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T15:28:49+0900
# Minibatch loss at step 79000: 0.212539
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:29:12+0900
# Minibatch loss at step 79500: 0.258741
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:29:36+0900
# Minibatch loss at step 80000: 0.304330
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:29:59+0900
# Minibatch loss at step 80500: 0.237821
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-28T15:30:22+0900
# Minibatch loss at step 81000: 0.171824
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T15:30:45+0900
# Minibatch loss at step 81500: 0.126966
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:31:09+0900
# Minibatch loss at step 82000: 0.237690
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T15:31:32+0900
# Minibatch loss at step 82500: 0.190515
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:31:56+0900
# Minibatch loss at step 83000: 0.273636
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-28T15:32:19+0900
# Minibatch loss at step 83500: 0.130688
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T15:32:42+0900
# Minibatch loss at step 84000: 0.184655
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:33:05+0900
# Minibatch loss at step 84500: 0.233477
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-28T15:33:28+0900
# Minibatch loss at step 85000: 0.257908
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:33:52+0900
# Minibatch loss at step 85500: 0.136037
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T15:34:15+0900
# Minibatch loss at step 86000: 0.136835
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:34:38+0900
# Minibatch loss at step 86500: 0.438881
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:35:02+0900
# Minibatch loss at step 87000: 0.132094
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T15:35:25+0900
# Minibatch loss at step 87500: 0.135646
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:35:48+0900
# Minibatch loss at step 88000: 0.142740
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:36:11+0900
# Minibatch loss at step 88500: 0.216585
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:36:34+0900
# Minibatch loss at step 89000: 0.187183
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T15:36:57+0900
# Minibatch loss at step 89500: 0.247789
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# finish : 2016-11-28T15:37:20+0900
# Minibatch loss at step 90000: 0.200141
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:37:44+0900
# Minibatch loss at step 90500: 0.154573
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:38:07+0900
# Minibatch loss at step 91000: 0.267531
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:38:30+0900
# Minibatch loss at step 91500: 0.358797
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-28T15:38:54+0900
# Minibatch loss at step 92000: 0.428891
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T15:39:17+0900
# Minibatch loss at step 92500: 0.125798
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:39:40+0900
# Minibatch loss at step 93000: 0.183283
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T15:40:03+0900
# Minibatch loss at step 93500: 0.573683
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# finish : 2016-11-28T15:40:26+0900
# Minibatch loss at step 94000: 0.593357
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:40:49+0900
# Minibatch loss at step 94500: 0.199493
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T15:41:12+0900
# Minibatch loss at step 95000: 0.178922
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-28T15:41:35+0900
# Minibatch loss at step 95500: 0.151465
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T15:41:58+0900
# Minibatch loss at step 96000: 0.152104
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:42:22+0900
# Minibatch loss at step 96500: 0.165195
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T15:42:45+0900
# Minibatch loss at step 97000: 0.234771
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:43:08+0900
# Minibatch loss at step 97500: 0.171729
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-28T15:43:32+0900
# Minibatch loss at step 98000: 0.200550
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T15:43:55+0900
# Minibatch loss at step 98500: 0.338458
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-28T15:44:18+0900
# Minibatch loss at step 99000: 0.242592
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-28T15:44:42+0900
# Minibatch loss at step 99500: 0.200238
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T15:45:05+0900
# Minibatch loss at step 100000: 0.363833
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T15:45:28+0900
# Test accuracy: 89.7%
# finish : 2016-11-28T15:45:31+0900

# %%
# Minibatch loss at step 100000: 0.323064
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T17:10:10+0900
# Test accuracy: 89.8%
# finish : 2016-11-28T17:10:13+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,64,0], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 14.700812
# Minibatch accuracy_length: 3.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 19.4%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.6%
# finish : 2016-11-28T15:45:42+0900
# Minibatch loss at step 500: 8.015172
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T15:46:07+0900
# Minibatch loss at step 1000: 6.702885
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-28T15:46:32+0900
# Minibatch loss at step 1500: 7.617788
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-28T15:46:56+0900
# Minibatch loss at step 2000: 8.416334
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T15:47:20+0900
# Minibatch loss at step 2500: 7.485530
# Minibatch accuracy_length: 65.6%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.9%
# finish : 2016-11-28T15:47:45+0900
# Minibatch loss at step 3000: 6.066069
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 1.9%
# finish : 2016-11-28T15:48:08+0900
# Minibatch loss at step 3500: 5.229297
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 50.0%
# Minibatch accuracy_digit_1: 50.0%
# Minibatch accuracy_digit_2: 57.1%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 8.4%
# finish : 2016-11-28T15:48:33+0900
# Minibatch loss at step 4000: 3.790381
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 65.6%
# Minibatch accuracy_digit_1: 59.4%
# Minibatch accuracy_digit_2: 62.5%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 28.1%
# Validation accuracy: 19.3%
# finish : 2016-11-28T15:48:57+0900
# Minibatch loss at step 4500: 2.615160
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 64.3%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 46.9%
# Validation accuracy: 35.6%
# finish : 2016-11-28T15:49:21+0900
# Minibatch loss at step 5000: 3.026850
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 72.4%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 37.5%
# Validation accuracy: 44.6%
# finish : 2016-11-28T15:49:46+0900
# Minibatch loss at step 5500: 2.026415
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 78.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 54.7%
# finish : 2016-11-28T15:50:11+0900
# Minibatch loss at step 6000: 1.373930
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 59.7%
# finish : 2016-11-28T15:50:36+0900
# Minibatch loss at step 6500: 1.884522
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 63.2%
# finish : 2016-11-28T15:51:01+0900
# Minibatch loss at step 7000: 2.662866
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 80.8%
# Minibatch accuracy_digit_3: 77.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 65.1%
# finish : 2016-11-28T15:51:25+0900
# Minibatch loss at step 7500: 1.525519
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.7%
# finish : 2016-11-28T15:51:50+0900
# Minibatch loss at step 8000: 1.734550
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.4%
# finish : 2016-11-28T15:52:15+0900
# Minibatch loss at step 8500: 1.432963
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 69.8%
# finish : 2016-11-28T15:52:40+0900
# Minibatch loss at step 9000: 1.600976
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 73.1%
# finish : 2016-11-28T15:53:05+0900
# Minibatch loss at step 9500: 1.524885
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 75.2%
# finish : 2016-11-28T15:53:30+0900
# Minibatch loss at step 10000: 0.665778
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 77.1%
# finish : 2016-11-28T15:53:55+0900
# Minibatch loss at step 10500: 1.216678
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.7%
# finish : 2016-11-28T15:54:20+0900
# Minibatch loss at step 11000: 0.933437
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.9%
# finish : 2016-11-28T15:54:45+0900
# Minibatch loss at step 11500: 2.185607
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.1%
# finish : 2016-11-28T15:55:11+0900
# Minibatch loss at step 12000: 0.993037
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# finish : 2016-11-28T15:55:36+0900
# Minibatch loss at step 12500: 0.823933
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.1%
# finish : 2016-11-28T15:56:01+0900
# Minibatch loss at step 13000: 1.838861
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# finish : 2016-11-28T15:56:26+0900
# Minibatch loss at step 13500: 0.454941
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# finish : 2016-11-28T15:56:51+0900
# Minibatch loss at step 14000: 1.611305
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 91.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 82.4%
# finish : 2016-11-28T15:57:16+0900
# Minibatch loss at step 14500: 1.567665
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 81.5%
# finish : 2016-11-28T15:57:41+0900
# Minibatch loss at step 15000: 1.059026
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.6%
# finish : 2016-11-28T15:58:06+0900
# Minibatch loss at step 15500: 1.108494
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.6%
# finish : 2016-11-28T15:58:31+0900
# Minibatch loss at step 16000: 0.957409
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# finish : 2016-11-28T15:58:56+0900
# Minibatch loss at step 16500: 0.896234
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.7%
# finish : 2016-11-28T15:59:21+0900
# Minibatch loss at step 17000: 0.703244
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.8%
# finish : 2016-11-28T15:59:46+0900
# Minibatch loss at step 17500: 0.875434
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# finish : 2016-11-28T16:00:11+0900
# Minibatch loss at step 18000: 0.389801
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.4%
# finish : 2016-11-28T16:00:36+0900
# Minibatch loss at step 18500: 0.971503
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# finish : 2016-11-28T16:01:01+0900
# Minibatch loss at step 19000: 0.358391
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# finish : 2016-11-28T16:01:26+0900
# Minibatch loss at step 19500: 0.753277
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# finish : 2016-11-28T16:01:52+0900
# Minibatch loss at step 20000: 0.532641
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.5%
# finish : 2016-11-28T16:02:17+0900
# Minibatch loss at step 20500: 0.506324
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# finish : 2016-11-28T16:02:42+0900
# Minibatch loss at step 21000: 0.695832
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# finish : 2016-11-28T16:03:07+0900
# Minibatch loss at step 21500: 0.833597
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# finish : 2016-11-28T16:03:33+0900
# Minibatch loss at step 22000: 1.681155
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# finish : 2016-11-28T16:03:58+0900
# Minibatch loss at step 22500: 0.505646
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# finish : 2016-11-28T16:04:23+0900
# Minibatch loss at step 23000: 0.250841
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
# finish : 2016-11-28T16:04:48+0900
# Minibatch loss at step 23500: 0.775874
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.3%
# finish : 2016-11-28T16:05:13+0900
# Minibatch loss at step 24000: 0.821524
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.4%
# finish : 2016-11-28T16:05:38+0900
# Minibatch loss at step 24500: 0.411941
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-11-28T16:06:04+0900
# Minibatch loss at step 25000: 0.386256
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# finish : 2016-11-28T16:06:29+0900
# Minibatch loss at step 25500: 0.284616
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-11-28T16:06:55+0900
# Minibatch loss at step 26000: 0.287398
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# finish : 2016-11-28T16:07:20+0900
# Minibatch loss at step 26500: 0.532517
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# finish : 2016-11-28T16:07:45+0900
# Minibatch loss at step 27000: 0.746203
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# finish : 2016-11-28T16:08:10+0900
# Minibatch loss at step 27500: 0.376032
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.9%
# finish : 2016-11-28T16:08:35+0900
# Minibatch loss at step 28000: 0.825074
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.9%
# finish : 2016-11-28T16:09:00+0900
# Minibatch loss at step 28500: 0.459045
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.9%
# finish : 2016-11-28T16:09:25+0900
# Minibatch loss at step 29000: 0.371097
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# finish : 2016-11-28T16:09:51+0900
# Minibatch loss at step 29500: 0.632948
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.4%
# finish : 2016-11-28T16:10:16+0900
# Minibatch loss at step 30000: 0.413198
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# finish : 2016-11-28T16:10:42+0900
# Minibatch loss at step 30500: 0.445054
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-28T16:11:07+0900
# Minibatch loss at step 31000: 0.649832
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-28T16:11:32+0900
# Minibatch loss at step 31500: 0.395505
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.7%
# finish : 2016-11-28T16:11:57+0900
# Minibatch loss at step 32000: 0.394019
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-28T16:12:22+0900
# Minibatch loss at step 32500: 0.301597
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# finish : 2016-11-28T16:12:48+0900
# Minibatch loss at step 33000: 0.502091
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# finish : 2016-11-28T16:13:13+0900
# Minibatch loss at step 33500: 0.388083
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T16:13:39+0900
# Minibatch loss at step 34000: 0.370586
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-28T16:14:04+0900
# Minibatch loss at step 34500: 0.513132
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# finish : 2016-11-28T16:14:29+0900
# Minibatch loss at step 35000: 0.994053
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# finish : 2016-11-28T16:14:55+0900
# Minibatch loss at step 35500: 1.230346
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.6%
# finish : 2016-11-28T16:15:20+0900
# Minibatch loss at step 36000: 0.583257
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# finish : 2016-11-28T16:15:46+0900
# Minibatch loss at step 36500: 1.779336
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# finish : 2016-11-28T16:16:12+0900
# Minibatch loss at step 37000: 0.109962
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-28T16:16:37+0900
# Minibatch loss at step 37500: 0.439288
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-28T16:17:03+0900
# Minibatch loss at step 38000: 0.955429
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T16:17:28+0900
# Minibatch loss at step 38500: 0.383973
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T16:17:53+0900
# Minibatch loss at step 39000: 0.525218
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T16:18:18+0900
# Minibatch loss at step 39500: 0.607029
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# finish : 2016-11-28T16:18:44+0900
# Minibatch loss at step 40000: 0.296953
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:19:09+0900
# Minibatch loss at step 40500: 0.433738
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# finish : 2016-11-28T16:19:34+0900
# Minibatch loss at step 41000: 0.297966
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T16:20:00+0900
# Minibatch loss at step 41500: 0.395254
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T16:20:25+0900
# Minibatch loss at step 42000: 0.311505
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T16:20:51+0900
# Minibatch loss at step 42500: 0.553315
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# finish : 2016-11-28T16:21:16+0900
# Minibatch loss at step 43000: 0.728725
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# finish : 2016-11-28T16:21:42+0900
# Minibatch loss at step 43500: 0.401917
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-28T16:22:07+0900
# Minibatch loss at step 44000: 1.014292
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T16:22:33+0900
# Minibatch loss at step 44500: 0.265221
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T16:22:58+0900
# Minibatch loss at step 45000: 0.331992
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:23:24+0900
# Minibatch loss at step 45500: 0.251599
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-28T16:23:49+0900
# Minibatch loss at step 46000: 0.323799
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# finish : 2016-11-28T16:24:15+0900
# Minibatch loss at step 46500: 0.158678
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T16:24:40+0900
# Minibatch loss at step 47000: 0.307430
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-28T16:25:06+0900
# Minibatch loss at step 47500: 0.170611
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T16:25:31+0900
# Minibatch loss at step 48000: 0.674308
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.5%
# finish : 2016-11-28T16:25:57+0900
# Minibatch loss at step 48500: 0.201763
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:26:22+0900
# Minibatch loss at step 49000: 0.333251
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# finish : 2016-11-28T16:26:48+0900
# Minibatch loss at step 49500: 0.460857
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.4%
# finish : 2016-11-28T16:27:13+0900
# Minibatch loss at step 50000: 0.285823
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-28T16:27:38+0900
# Minibatch loss at step 50500: 0.276514
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T16:28:04+0900
# Minibatch loss at step 51000: 0.203841
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T16:28:29+0900
# Minibatch loss at step 51500: 0.182953
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T16:28:55+0900
# Minibatch loss at step 52000: 0.140865
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T16:29:20+0900
# Minibatch loss at step 52500: 0.238600
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T16:29:45+0900
# Minibatch loss at step 53000: 0.287612
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T16:30:11+0900
# Minibatch loss at step 53500: 0.208649
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-28T16:30:37+0900
# Minibatch loss at step 54000: 0.116255
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T16:31:03+0900
# Minibatch loss at step 54500: 0.417035
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:31:28+0900
# Minibatch loss at step 55000: 0.824548
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# finish : 2016-11-28T16:31:54+0900
# Minibatch loss at step 55500: 0.178417
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T16:32:20+0900
# Minibatch loss at step 56000: 0.396116
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 95.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# finish : 2016-11-28T16:32:46+0900
# Minibatch loss at step 56500: 0.717085
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# finish : 2016-11-28T16:33:11+0900
# Minibatch loss at step 57000: 0.681071
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# finish : 2016-11-28T16:33:36+0900
# Minibatch loss at step 57500: 0.320180
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T16:34:02+0900
# Minibatch loss at step 58000: 1.318393
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# finish : 2016-11-28T16:34:27+0900
# Minibatch loss at step 58500: 0.197857
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T16:34:53+0900
# Minibatch loss at step 59000: 0.330928
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:35:19+0900
# Minibatch loss at step 59500: 0.151766
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T16:35:45+0900
# Minibatch loss at step 60000: 0.304779
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# finish : 2016-11-28T16:36:11+0900
# Minibatch loss at step 60500: 0.122026
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:36:36+0900
# Minibatch loss at step 61000: 0.160345
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# finish : 2016-11-28T16:37:02+0900
# Minibatch loss at step 61500: 0.305136
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T16:37:27+0900
# Minibatch loss at step 62000: 0.150808
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:37:53+0900
# Minibatch loss at step 62500: 0.389398
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:38:18+0900
# Minibatch loss at step 63000: 0.718592
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:38:44+0900
# Minibatch loss at step 63500: 0.315494
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-28T16:39:10+0900
# Minibatch loss at step 64000: 0.536415
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T16:39:35+0900
# Minibatch loss at step 64500: 0.178719
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T16:40:01+0900
# Minibatch loss at step 65000: 0.747376
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:40:26+0900
# Minibatch loss at step 65500: 0.158456
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T16:40:52+0900
# Minibatch loss at step 66000: 1.186610
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T16:41:17+0900
# Minibatch loss at step 66500: 0.128629
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T16:41:42+0900
# Minibatch loss at step 67000: 0.247314
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:42:08+0900
# Minibatch loss at step 67500: 0.186532
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# finish : 2016-11-28T16:42:34+0900
# Minibatch loss at step 68000: 0.142476
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-28T16:42:59+0900
# Minibatch loss at step 68500: 0.237175
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T16:43:25+0900
# Minibatch loss at step 69000: 0.280288
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# finish : 2016-11-28T16:43:51+0900
# Minibatch loss at step 69500: 0.190416
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:44:16+0900
# Minibatch loss at step 70000: 0.469216
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:44:42+0900
# Minibatch loss at step 70500: 0.378994
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# finish : 2016-11-28T16:45:08+0900
# Minibatch loss at step 71000: 0.306184
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T16:45:34+0900
# Minibatch loss at step 71500: 0.160658
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# ...
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# finish : 2016-11-28T16:50:13+0900
# Minibatch loss at step 77000: 0.470419
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# finish : 2016-11-28T16:50:39+0900
# Minibatch loss at step 77500: 0.193380
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-28T16:51:04+0900
# Minibatch loss at step 78000: 0.470691
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:51:30+0900
# Minibatch loss at step 78500: 0.608282
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:51:55+0900
# Minibatch loss at step 79000: 0.202062
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T16:52:20+0900
# Minibatch loss at step 79500: 0.187929
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-28T16:52:46+0900
# Minibatch loss at step 80000: 0.229158
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:53:11+0900
# Minibatch loss at step 80500: 0.192530
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-28T16:53:36+0900
# Minibatch loss at step 81000: 0.121914
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T16:54:01+0900
# Minibatch loss at step 81500: 0.089974
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-28T16:54:26+0900
# Minibatch loss at step 82000: 0.134169
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-28T16:54:52+0900
# Minibatch loss at step 82500: 0.148529
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-28T16:55:17+0900
# Minibatch loss at step 83000: 0.161627
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-28T16:55:43+0900
# Minibatch loss at step 83500: 0.101176
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T16:56:08+0900
# Minibatch loss at step 84000: 0.226772
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# finish : 2016-11-28T16:56:33+0900
# Minibatch loss at step 84500: 0.302058
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# finish : 2016-11-28T16:56:59+0900
# Minibatch loss at step 85000: 0.455323
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# finish : 2016-11-28T16:57:24+0900
# Minibatch loss at step 85500: 0.127310
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T16:57:50+0900
# Minibatch loss at step 86000: 0.133781
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-28T16:58:15+0900
# Minibatch loss at step 86500: 0.286710
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# finish : 2016-11-28T16:58:41+0900
# Minibatch loss at step 87000: 0.166873
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-28T16:59:06+0900
# Minibatch loss at step 87500: 0.164715
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-28T16:59:32+0900
# Minibatch loss at step 88000: 0.121075
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T16:59:57+0900
# Minibatch loss at step 88500: 0.139727
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T17:00:23+0900
# Minibatch loss at step 89000: 0.151048
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-28T17:00:48+0900
# Minibatch loss at step 89500: 0.171483
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T17:01:14+0900
# Minibatch loss at step 90000: 0.123440
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T17:01:40+0900
# Minibatch loss at step 90500: 0.245432
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T17:02:05+0900
# Minibatch loss at step 91000: 0.307216
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# finish : 2016-11-28T17:02:30+0900
# Minibatch loss at step 91500: 0.342407
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-28T17:02:56+0900
# Minibatch loss at step 92000: 0.336067
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-28T17:03:21+0900
# Minibatch loss at step 92500: 0.111563
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T17:03:47+0900
# Minibatch loss at step 93000: 0.116054
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T17:04:13+0900
# Minibatch loss at step 93500: 0.654987
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# finish : 2016-11-28T17:04:38+0900
# Minibatch loss at step 94000: 0.441257
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T17:05:04+0900
# Minibatch loss at step 94500: 0.150918
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T17:05:29+0900
# Minibatch loss at step 95000: 0.137227
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T17:05:55+0900
# Minibatch loss at step 95500: 0.121829
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T17:06:20+0900
# Minibatch loss at step 96000: 0.129149
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T17:06:46+0900
# Minibatch loss at step 96500: 0.103856
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T17:07:11+0900
# Minibatch loss at step 97000: 0.180231
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T17:07:37+0900
# Minibatch loss at step 97500: 0.125969
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T17:08:02+0900
# Minibatch loss at step 98000: 0.221333
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T17:08:28+0900
# Minibatch loss at step 98500: 0.165291
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T17:08:53+0900
# Minibatch loss at step 99000: 0.415164
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# finish : 2016-11-28T17:09:19+0900
# Minibatch loss at step 99500: 0.179744
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T17:09:44+0900
# Minibatch loss at step 100000: 0.323064
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T17:10:10+0900
# Test accuracy: 89.8%
# finish : 2016-11-28T17:10:13+0900

# %%
# Minibatch loss at step 100000: 0.160149
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:39:22+0900
# Test accuracy: 89.6%
# finish : 2016-11-28T18:39:25+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,64,64], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 14.772124
# Minibatch accuracy_length: 0.0%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 3.1%
# Minibatch accuracy_digit_2: 0.0%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-28T17:10:24+0900
# Minibatch loss at step 500: 8.031597
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T17:10:49+0900
# Minibatch loss at step 1000: 6.694897
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-28T17:11:15+0900
# Minibatch loss at step 1500: 7.610261
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-28T17:11:40+0900
# Minibatch loss at step 2000: 8.456555
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T17:12:05+0900
# Minibatch loss at step 2500: 8.087393
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T17:12:31+0900
# Minibatch loss at step 3000: 7.393323
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T17:12:56+0900
# Minibatch loss at step 3500: 6.849295
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 57.1%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 1.1%
# finish : 2016-11-28T17:13:20+0900
# Minibatch loss at step 4000: 5.683964
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 3.8%
# finish : 2016-11-28T17:13:45+0900
# Minibatch loss at step 4500: 5.027453
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 32.1%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 5.7%
# finish : 2016-11-28T17:14:10+0900
# Minibatch loss at step 5000: 5.516435
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 37.9%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 12.7%
# finish : 2016-11-28T17:14:36+0900
# Minibatch loss at step 5500: 3.504588
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 56.2%
# Minibatch accuracy_digit_1: 59.4%
# Minibatch accuracy_digit_2: 62.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 21.9%
# Validation accuracy: 25.3%
# finish : 2016-11-28T17:15:02+0900
# Minibatch loss at step 6000: 2.065077
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 86.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 38.2%
# finish : 2016-11-28T17:15:28+0900
# Minibatch loss at step 6500: 2.498438
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 37.5%
# Validation accuracy: 49.4%
# finish : 2016-11-28T17:15:54+0900
# Minibatch loss at step 7000: 2.694461
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 73.1%
# Minibatch accuracy_digit_3: 66.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 54.0%
# finish : 2016-11-28T17:16:21+0900
# Minibatch loss at step 7500: 2.003249
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 57.7%
# finish : 2016-11-28T17:16:47+0900
# Minibatch loss at step 8000: 2.381693
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 58.3%
# finish : 2016-11-28T17:17:14+0900
# Minibatch loss at step 8500: 1.844445
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 62.3%
# finish : 2016-11-28T17:17:40+0900
# Minibatch loss at step 9000: 1.936355
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 68.7%
# finish : 2016-11-28T17:18:06+0900
# Minibatch loss at step 9500: 1.401265
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.7%
# finish : 2016-11-28T17:18:32+0900
# Minibatch loss at step 10000: 0.889905
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 73.3%
# finish : 2016-11-28T17:18:59+0900
# Minibatch loss at step 10500: 1.416960
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 81.2%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.5%
# finish : 2016-11-28T17:19:25+0900
# Minibatch loss at step 11000: 0.733335
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 75.7%
# finish : 2016-11-28T17:19:51+0900
# Minibatch loss at step 11500: 2.087630
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 75.9%
# finish : 2016-11-28T17:20:18+0900
# Minibatch loss at step 12000: 1.109352
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 77.3%
# finish : 2016-11-28T17:20:44+0900
# Minibatch loss at step 12500: 1.080089
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.1%
# finish : 2016-11-28T17:21:10+0900
# Minibatch loss at step 13000: 1.915467
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.6%
# finish : 2016-11-28T17:21:36+0900
# Minibatch loss at step 13500: 0.857901
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 82.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.4%
# finish : 2016-11-28T17:22:02+0900
# Minibatch loss at step 14000: 1.701902
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 87.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 80.1%
# finish : 2016-11-28T17:22:29+0900
# Minibatch loss at step 14500: 1.508251
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.9%
# finish : 2016-11-28T17:22:55+0900
# Minibatch loss at step 15000: 0.912417
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.1%
# finish : 2016-11-28T17:23:21+0900
# Minibatch loss at step 15500: 0.951516
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.9%
# finish : 2016-11-28T17:23:48+0900
# Minibatch loss at step 16000: 0.696553
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# finish : 2016-11-28T17:24:14+0900
# Minibatch loss at step 16500: 0.770064
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# finish : 2016-11-28T17:24:41+0900
# Minibatch loss at step 17000: 0.657496
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.0%
# finish : 2016-11-28T17:25:07+0900
# Minibatch loss at step 17500: 1.000542
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# finish : 2016-11-28T17:25:34+0900
# Minibatch loss at step 18000: 0.600519
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.4%
# finish : 2016-11-28T17:26:00+0900
# Minibatch loss at step 18500: 0.951181
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# finish : 2016-11-28T17:26:26+0900
# Minibatch loss at step 19000: 0.506247
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# finish : 2016-11-28T17:26:53+0900
# Minibatch loss at step 19500: 0.715689
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# finish : 2016-11-28T17:27:19+0900
# Minibatch loss at step 20000: 0.891961
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# finish : 2016-11-28T17:27:46+0900
# Minibatch loss at step 20500: 0.494210
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# finish : 2016-11-28T17:28:12+0900
# Minibatch loss at step 21000: 0.554112
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# finish : 2016-11-28T17:28:39+0900
# Minibatch loss at step 21500: 0.887697
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# finish : 2016-11-28T17:29:06+0900
# Minibatch loss at step 22000: 1.781731
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.7%
# finish : 2016-11-28T17:29:32+0900
# Minibatch loss at step 22500: 0.556538
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# finish : 2016-11-28T17:29:59+0900
# Minibatch loss at step 23000: 0.356766
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# finish : 2016-11-28T17:30:25+0900
# Minibatch loss at step 23500: 0.938784
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# finish : 2016-11-28T17:30:52+0900
# Minibatch loss at step 24000: 0.913544
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# finish : 2016-11-28T17:31:18+0900
# Minibatch loss at step 24500: 0.453462
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# finish : 2016-11-28T17:31:45+0900
# Minibatch loss at step 25000: 0.533301
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# finish : 2016-11-28T17:32:11+0900
# Minibatch loss at step 25500: 0.351340
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.2%
# finish : 2016-11-28T17:32:38+0900
# Minibatch loss at step 26000: 0.268659
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# finish : 2016-11-28T17:33:04+0900
# Minibatch loss at step 26500: 0.420819
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# finish : 2016-11-28T17:33:31+0900
# Minibatch loss at step 27000: 0.533509
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# finish : 2016-11-28T17:33:58+0900
# Minibatch loss at step 27500: 0.309852
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.1%
# finish : 2016-11-28T17:34:24+0900
# Minibatch loss at step 28000: 0.798622
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# finish : 2016-11-28T17:34:51+0900
# Minibatch loss at step 28500: 0.598546
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# finish : 2016-11-28T17:35:18+0900
# Minibatch loss at step 29000: 0.360845
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.4%
# finish : 2016-11-28T17:35:45+0900
# Minibatch loss at step 29500: 0.589479
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-28T17:36:12+0900
# Minibatch loss at step 30000: 0.310985
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# finish : 2016-11-28T17:36:38+0900
# Minibatch loss at step 30500: 0.810052
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.9%
# finish : 2016-11-28T17:37:05+0900
# Minibatch loss at step 31000: 0.605241
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# finish : 2016-11-28T17:37:32+0900
# Minibatch loss at step 31500: 0.419994
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.6%
# finish : 2016-11-28T17:37:58+0900
# Minibatch loss at step 32000: 0.472275
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# finish : 2016-11-28T17:38:25+0900
# Minibatch loss at step 32500: 0.260338
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# finish : 2016-11-28T17:38:52+0900
# Minibatch loss at step 33000: 0.428774
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# finish : 2016-11-28T17:39:18+0900
# Minibatch loss at step 33500: 0.371793
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# finish : 2016-11-28T17:39:45+0900
# Minibatch loss at step 34000: 0.405841
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# finish : 2016-11-28T17:40:12+0900
# Minibatch loss at step 34500: 0.704865
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# finish : 2016-11-28T17:40:38+0900
# Minibatch loss at step 35000: 0.665687
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.1%
# finish : 2016-11-28T17:41:05+0900
# Minibatch loss at step 35500: 1.169574
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.3%
# finish : 2016-11-28T17:41:32+0900
# Minibatch loss at step 36000: 0.614574
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# finish : 2016-11-28T17:41:59+0900
# Minibatch loss at step 36500: 1.456914
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# finish : 2016-11-28T17:42:26+0900
# Minibatch loss at step 37000: 0.113017
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-28T17:42:53+0900
# Minibatch loss at step 37500: 0.324967
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# finish : 2016-11-28T17:43:19+0900
# Minibatch loss at step 38000: 1.266466
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# finish : 2016-11-28T17:43:46+0900
# Minibatch loss at step 38500: 0.417954
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# finish : 2016-11-28T17:44:13+0900
# Minibatch loss at step 39000: 0.596629
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.0%
# finish : 2016-11-28T17:44:40+0900
# Minibatch loss at step 39500: 0.409099
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-28T17:45:06+0900
# Minibatch loss at step 40000: 0.240695
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T17:45:33+0900
# Minibatch loss at step 40500: 0.488668
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-28T17:45:59+0900
# Minibatch loss at step 41000: 0.317314
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T17:46:26+0900
# Minibatch loss at step 41500: 0.364799
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-28T17:46:53+0900
# Minibatch loss at step 42000: 0.494564
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-28T17:47:20+0900
# Minibatch loss at step 42500: 0.847629
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# finish : 2016-11-28T17:47:46+0900
# Minibatch loss at step 43000: 0.789021
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# finish : 2016-11-28T17:48:13+0900
# Minibatch loss at step 43500: 0.330945
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# finish : 2016-11-28T17:48:40+0900
# Minibatch loss at step 44000: 1.035844
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T17:49:07+0900
# Minibatch loss at step 44500: 0.247018
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# finish : 2016-11-28T17:49:34+0900
# Minibatch loss at step 45000: 0.290388
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T17:50:00+0900
# Minibatch loss at step 45500: 0.197437
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T17:50:27+0900
# Minibatch loss at step 46000: 0.475575
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T17:50:54+0900
# Minibatch loss at step 46500: 0.163357
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T17:51:21+0900
# Minibatch loss at step 47000: 0.543055
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# finish : 2016-11-28T17:51:48+0900
# Minibatch loss at step 47500: 0.247871
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T17:52:15+0900
# Minibatch loss at step 48000: 0.903586
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T17:52:42+0900
# Minibatch loss at step 48500: 0.335969
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# finish : 2016-11-28T17:53:08+0900
# Minibatch loss at step 49000: 0.204749
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-28T17:53:35+0900
# Minibatch loss at step 49500: 0.551676
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# finish : 2016-11-28T17:54:02+0900
# Minibatch loss at step 50000: 0.223436
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.3%
# finish : 2016-11-28T17:54:29+0900
# Minibatch loss at step 50500: 0.178247
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-28T17:54:56+0900
# Minibatch loss at step 51000: 0.174935
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T17:55:23+0900
# Minibatch loss at step 51500: 0.237648
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T17:55:50+0900
# Minibatch loss at step 52000: 0.122111
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T17:56:17+0900
# Minibatch loss at step 52500: 0.220668
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T17:56:44+0900
# Minibatch loss at step 53000: 0.236135
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T17:57:11+0900
# Minibatch loss at step 53500: 0.125456
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T17:57:38+0900
# Minibatch loss at step 54000: 0.169902
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T17:58:05+0900
# Minibatch loss at step 54500: 0.620691
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 89.2%
# finish : 2016-11-28T17:58:32+0900
# Minibatch loss at step 55000: 0.487703
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# finish : 2016-11-28T17:58:59+0900
# Minibatch loss at step 55500: 0.113259
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T17:59:26+0900
# Minibatch loss at step 56000: 0.404192
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 95.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-28T17:59:53+0900
# Minibatch loss at step 56500: 0.897594
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 89.0%
# finish : 2016-11-28T18:00:20+0900
# Minibatch loss at step 57000: 0.454375
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T18:00:47+0900
# Minibatch loss at step 57500: 0.260714
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T18:01:14+0900
# Minibatch loss at step 58000: 0.581332
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# finish : 2016-11-28T18:01:41+0900
# Minibatch loss at step 58500: 0.307077
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:02:08+0900
# Minibatch loss at step 59000: 0.311646
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-28T18:02:34+0900
# Minibatch loss at step 59500: 0.186204
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T18:03:01+0900
# Minibatch loss at step 60000: 0.264762
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T18:03:28+0900
# Minibatch loss at step 60500: 0.093842
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T18:03:55+0900
# Minibatch loss at step 61000: 0.145681
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T18:04:22+0900
# Minibatch loss at step 61500: 0.339898
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T18:04:49+0900
# Minibatch loss at step 62000: 0.252563
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# finish : 2016-11-28T18:05:16+0900
# Minibatch loss at step 62500: 0.736410
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# finish : 2016-11-28T18:05:43+0900
# Minibatch loss at step 63000: 0.470604
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# finish : 2016-11-28T18:06:10+0900
# Minibatch loss at step 63500: 0.324141
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# finish : 2016-11-28T18:06:38+0900
# Minibatch loss at step 64000: 0.614514
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-28T18:07:05+0900
# Minibatch loss at step 64500: 0.131097
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-28T18:07:31+0900
# Minibatch loss at step 65000: 0.862819
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:07:58+0900
# Minibatch loss at step 65500: 0.231087
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# finish : 2016-11-28T18:08:25+0900
# Minibatch loss at step 66000: 0.894518
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T18:08:52+0900
# Minibatch loss at step 66500: 0.241655
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:09:19+0900
# Minibatch loss at step 67000: 0.429570
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:09:46+0900
# Minibatch loss at step 67500: 0.137138
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T18:10:13+0900
# Minibatch loss at step 68000: 0.125120
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:10:40+0900
# Minibatch loss at step 68500: 0.324693
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:11:07+0900
# Minibatch loss at step 69000: 0.236777
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T18:11:34+0900
# Minibatch loss at step 69500: 0.183975
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:12:00+0900
# Minibatch loss at step 70000: 0.521309
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T18:12:27+0900
# Minibatch loss at step 70500: 0.479606
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# finish : 2016-11-28T18:12:55+0900
# Minibatch loss at step 71000: 0.489185
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T18:13:22+0900
# Minibatch loss at step 71500: 0.129865
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# ...
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:18:18+0900
# Minibatch loss at step 77000: 0.382994
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:18:45+0900
# Minibatch loss at step 77500: 0.176576
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# finish : 2016-11-28T18:19:12+0900
# Minibatch loss at step 78000: 0.268079
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T18:19:39+0900
# Minibatch loss at step 78500: 0.728153
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# finish : 2016-11-28T18:20:06+0900
# Minibatch loss at step 79000: 0.229349
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T18:20:33+0900
# Minibatch loss at step 79500: 0.454383
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T18:20:59+0900
# Minibatch loss at step 80000: 0.226265
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T18:21:26+0900
# Minibatch loss at step 80500: 0.126492
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:21:53+0900
# Minibatch loss at step 81000: 0.113554
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:22:20+0900
# Minibatch loss at step 81500: 0.094255
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:22:47+0900
# Minibatch loss at step 82000: 0.176732
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:23:14+0900
# Minibatch loss at step 82500: 0.145465
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T18:23:41+0900
# Minibatch loss at step 83000: 0.189232
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-28T18:24:08+0900
# Minibatch loss at step 83500: 0.085476
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:24:34+0900
# Minibatch loss at step 84000: 0.127034
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T18:25:01+0900
# Minibatch loss at step 84500: 0.274077
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# finish : 2016-11-28T18:25:28+0900
# Minibatch loss at step 85000: 0.236039
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-28T18:25:55+0900
# Minibatch loss at step 85500: 0.114495
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T18:26:22+0900
# Minibatch loss at step 86000: 0.188816
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-28T18:26:49+0900
# Minibatch loss at step 86500: 0.331040
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# finish : 2016-11-28T18:27:16+0900
# Minibatch loss at step 87000: 0.251013
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T18:27:43+0900
# Minibatch loss at step 87500: 0.104332
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:28:10+0900
# Minibatch loss at step 88000: 0.110496
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T18:28:37+0900
# Minibatch loss at step 88500: 0.144463
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T18:29:03+0900
# Minibatch loss at step 89000: 0.153419
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:29:30+0900
# Minibatch loss at step 89500: 0.204922
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:29:57+0900
# Minibatch loss at step 90000: 0.127805
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-28T18:30:24+0900
# Minibatch loss at step 90500: 0.202025
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T18:30:50+0900
# Minibatch loss at step 91000: 0.324962
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# finish : 2016-11-28T18:31:18+0900
# Minibatch loss at step 91500: 0.318491
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-28T18:31:45+0900
# Minibatch loss at step 92000: 0.331568
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T18:32:11+0900
# Minibatch loss at step 92500: 0.076518
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T18:32:39+0900
# Minibatch loss at step 93000: 0.117830
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:33:06+0900
# Minibatch loss at step 93500: 0.449116
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-28T18:33:33+0900
# Minibatch loss at step 94000: 0.743367
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T18:33:59+0900
# Minibatch loss at step 94500: 0.126110
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T18:34:26+0900
# Minibatch loss at step 95000: 0.214495
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:34:53+0900
# Minibatch loss at step 95500: 0.093509
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-28T18:35:20+0900
# Minibatch loss at step 96000: 0.103759
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:35:47+0900
# Minibatch loss at step 96500: 0.084534
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:36:13+0900
# Minibatch loss at step 97000: 0.118507
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T18:36:40+0900
# Minibatch loss at step 97500: 0.142867
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-28T18:37:07+0900
# Minibatch loss at step 98000: 0.272494
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T18:37:34+0900
# Minibatch loss at step 98500: 0.174101
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T18:38:01+0900
# Minibatch loss at step 99000: 0.181895
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T18:38:28+0900
# Minibatch loss at step 99500: 0.163231
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T18:38:55+0900
# Minibatch loss at step 100000: 0.160149
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T18:39:22+0900
# Test accuracy: 89.6%
# finish : 2016-11-28T18:39:25+0900

# %%
# Minibatch loss at step 100000: 0.270255
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T20:41:24+0900
# Test accuracy: 89.5%
# finish : 2016-11-28T20:41:27+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,64,64], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 14.113474
# Minibatch accuracy_length: 34.4%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 0.0%
# Minibatch accuracy_digit_2: 3.2%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T18:39:37+0900
# Minibatch loss at step 500: 8.592757
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T18:40:12+0900
# Minibatch loss at step 1000: 7.215502
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-28T18:40:46+0900
# Minibatch loss at step 1500: 8.090764
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-28T18:41:21+0900
# Minibatch loss at step 2000: 8.861453
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T18:41:56+0900
# Minibatch loss at step 2500: 8.437123
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T18:42:31+0900
# Minibatch loss at step 3000: 7.710177
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T18:43:05+0900
# Minibatch loss at step 3500: 8.230992
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T18:43:39+0900
# Minibatch loss at step 4000: 7.114099
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.8%
# finish : 2016-11-28T18:44:12+0900
# Minibatch loss at step 4500: 7.033211
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 35.7%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 1.9%
# finish : 2016-11-28T18:44:46+0900
# Minibatch loss at step 5000: 6.814203
# Minibatch accuracy_length: 81.2%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 34.5%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 3.3%
# finish : 2016-11-28T18:45:21+0900
# Minibatch loss at step 5500: 4.378727
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 62.5%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 53.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 12.3%
# finish : 2016-11-28T18:45:56+0900
# Minibatch loss at step 6000: 3.500649
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 50.0%
# Minibatch accuracy_digit_2: 76.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 28.1%
# Validation accuracy: 22.4%
# finish : 2016-11-28T18:46:31+0900
# Minibatch loss at step 6500: 3.517577
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 68.8%
# Minibatch accuracy_digit_1: 50.0%
# Minibatch accuracy_digit_2: 67.7%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 18.8%
# Validation accuracy: 36.1%
# finish : 2016-11-28T18:47:06+0900
# Minibatch loss at step 7000: 3.563380
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 62.5%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 65.4%
# Minibatch accuracy_digit_3: 66.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 40.6%
# Validation accuracy: 43.1%
# finish : 2016-11-28T18:47:42+0900
# Minibatch loss at step 7500: 2.083192
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 49.2%
# finish : 2016-11-28T18:48:17+0900
# Minibatch loss at step 8000: 2.131412
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 53.3%
# finish : 2016-11-28T18:48:53+0900
# Minibatch loss at step 8500: 2.253957
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 56.9%
# finish : 2016-11-28T18:49:29+0900
# Minibatch loss at step 9000: 2.147380
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 81.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 63.4%
# finish : 2016-11-28T18:50:05+0900
# Minibatch loss at step 9500: 1.512657
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 68.4%
# finish : 2016-11-28T18:50:41+0900
# Minibatch loss at step 10000: 1.010250
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 70.1%
# finish : 2016-11-28T18:51:17+0900
# Minibatch loss at step 10500: 1.441071
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 81.2%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.7%
# finish : 2016-11-28T18:51:52+0900
# Minibatch loss at step 11000: 0.858028
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.4%
# finish : 2016-11-28T18:52:29+0900
# Minibatch loss at step 11500: 2.309027
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 77.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 74.6%
# finish : 2016-11-28T18:53:04+0900
# Minibatch loss at step 12000: 1.200567
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 83.3%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 74.8%
# finish : 2016-11-28T18:53:41+0900
# Minibatch loss at step 12500: 1.117060
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 77.3%
# finish : 2016-11-28T18:54:16+0900
# Minibatch loss at step 13000: 1.631257
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.1%
# finish : 2016-11-28T18:54:53+0900
# Minibatch loss at step 13500: 1.085360
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.3%
# finish : 2016-11-28T18:55:29+0900
# Minibatch loss at step 14000: 1.531005
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 82.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.9%
# finish : 2016-11-28T18:56:05+0900
# Minibatch loss at step 14500: 1.564457
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 78.5%
# finish : 2016-11-28T18:56:41+0900
# Minibatch loss at step 15000: 1.207736
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.5%
# finish : 2016-11-28T18:57:17+0900
# Minibatch loss at step 15500: 1.347053
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.1%
# finish : 2016-11-28T18:57:53+0900
# Minibatch loss at step 16000: 0.563816
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.7%
# finish : 2016-11-28T18:58:29+0900
# Minibatch loss at step 16500: 1.064523
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# finish : 2016-11-28T18:59:05+0900
# Minibatch loss at step 17000: 0.913514
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 85.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.3%
# finish : 2016-11-28T18:59:41+0900
# Minibatch loss at step 17500: 1.031686
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# finish : 2016-11-28T19:00:18+0900
# Minibatch loss at step 18000: 0.512587
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# finish : 2016-11-28T19:00:54+0900
# Minibatch loss at step 18500: 1.127812
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.6%
# finish : 2016-11-28T19:01:30+0900
# Minibatch loss at step 19000: 0.553220
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# finish : 2016-11-28T19:02:06+0900
# Minibatch loss at step 19500: 0.795737
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# finish : 2016-11-28T19:02:42+0900
# Minibatch loss at step 20000: 1.029586
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.1%
# finish : 2016-11-28T19:03:18+0900
# Minibatch loss at step 20500: 0.469782
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# finish : 2016-11-28T19:03:54+0900
# Minibatch loss at step 21000: 0.592796
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.5%
# finish : 2016-11-28T19:04:31+0900
# Minibatch loss at step 21500: 0.830565
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 89.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# finish : 2016-11-28T19:05:07+0900
# Minibatch loss at step 22000: 1.672504
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.4%
# finish : 2016-11-28T19:05:43+0900
# Minibatch loss at step 22500: 0.388360
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.3%
# finish : 2016-11-28T19:06:19+0900
# Minibatch loss at step 23000: 0.297127
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.7%
# finish : 2016-11-28T19:06:56+0900
# Minibatch loss at step 23500: 1.051722
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# finish : 2016-11-28T19:07:32+0900
# Minibatch loss at step 24000: 0.869555
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.7%
# finish : 2016-11-28T19:08:09+0900
# Minibatch loss at step 24500: 0.271757
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# finish : 2016-11-28T19:08:45+0900
# Minibatch loss at step 25000: 0.555117
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# finish : 2016-11-28T19:09:22+0900
# Minibatch loss at step 25500: 0.333517
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# finish : 2016-11-28T19:09:59+0900
# Minibatch loss at step 26000: 0.439772
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# finish : 2016-11-28T19:10:35+0900
# Minibatch loss at step 26500: 0.649880
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# finish : 2016-11-28T19:11:11+0900
# Minibatch loss at step 27000: 0.780186
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# finish : 2016-11-28T19:11:47+0900
# Minibatch loss at step 27500: 0.443750
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# finish : 2016-11-28T19:12:24+0900
# Minibatch loss at step 28000: 1.140744
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# finish : 2016-11-28T19:13:01+0900
# Minibatch loss at step 28500: 0.513189
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# finish : 2016-11-28T19:13:37+0900
# Minibatch loss at step 29000: 0.499855
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.1%
# finish : 2016-11-28T19:14:14+0900
# Minibatch loss at step 29500: 0.877577
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# finish : 2016-11-28T19:14:50+0900
# Minibatch loss at step 30000: 0.441607
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.6%
# finish : 2016-11-28T19:15:26+0900
# Minibatch loss at step 30500: 0.522109
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# finish : 2016-11-28T19:16:03+0900
# Minibatch loss at step 31000: 1.056820
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.5%
# finish : 2016-11-28T19:16:40+0900
# Minibatch loss at step 31500: 0.349961
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# finish : 2016-11-28T19:17:16+0900
# Minibatch loss at step 32000: 0.492191
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.8%
# finish : 2016-11-28T19:17:54+0900
# Minibatch loss at step 32500: 0.280478
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# finish : 2016-11-28T19:18:30+0900
# Minibatch loss at step 33000: 0.285266
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# finish : 2016-11-28T19:19:07+0900
# Minibatch loss at step 33500: 0.387601
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# finish : 2016-11-28T19:19:44+0900
# Minibatch loss at step 34000: 0.476501
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# finish : 2016-11-28T19:20:21+0900
# Minibatch loss at step 34500: 0.708832
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# finish : 2016-11-28T19:20:58+0900
# Minibatch loss at step 35000: 0.983107
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.3%
# finish : 2016-11-28T19:21:35+0900
# Minibatch loss at step 35500: 0.827815
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.2%
# finish : 2016-11-28T19:22:11+0900
# Minibatch loss at step 36000: 0.651940
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# finish : 2016-11-28T19:22:48+0900
# Minibatch loss at step 36500: 1.473636
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.7%
# finish : 2016-11-28T19:23:24+0900
# Minibatch loss at step 37000: 0.137503
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# finish : 2016-11-28T19:24:02+0900
# Minibatch loss at step 37500: 0.354331
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# finish : 2016-11-28T19:24:39+0900
# Minibatch loss at step 38000: 1.033884
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-28T19:25:16+0900
# Minibatch loss at step 38500: 0.422674
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# finish : 2016-11-28T19:25:53+0900
# Minibatch loss at step 39000: 0.633276
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# finish : 2016-11-28T19:26:29+0900
# Minibatch loss at step 39500: 0.453867
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-11-28T19:27:06+0900
# Minibatch loss at step 40000: 0.298308
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.9%
# finish : 2016-11-28T19:27:44+0900
# Minibatch loss at step 40500: 0.583409
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-28T19:28:20+0900
# Minibatch loss at step 41000: 0.372001
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-28T19:28:57+0900
# Minibatch loss at step 41500: 0.460040
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-28T19:29:34+0900
# Minibatch loss at step 42000: 0.412161
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# finish : 2016-11-28T19:30:11+0900
# Minibatch loss at step 42500: 0.676653
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# finish : 2016-11-28T19:30:48+0900
# Minibatch loss at step 43000: 0.656856
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# finish : 2016-11-28T19:31:25+0900
# Minibatch loss at step 43500: 0.287175
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.0%
# finish : 2016-11-28T19:32:02+0900
# Minibatch loss at step 44000: 1.050456
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T19:32:39+0900
# Minibatch loss at step 44500: 0.400149
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# finish : 2016-11-28T19:33:16+0900
# Minibatch loss at step 45000: 0.384361
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T19:33:53+0900
# Minibatch loss at step 45500: 0.262078
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# finish : 2016-11-28T19:34:30+0900
# Minibatch loss at step 46000: 0.393205
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.1%
# finish : 2016-11-28T19:35:08+0900
# Minibatch loss at step 46500: 0.163440
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T19:35:45+0900
# Minibatch loss at step 47000: 0.491993
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-11-28T19:36:21+0900
# Minibatch loss at step 47500: 0.233797
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T19:36:58+0900
# Minibatch loss at step 48000: 0.995583
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# finish : 2016-11-28T19:37:35+0900
# Minibatch loss at step 48500: 0.171725
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-28T19:38:12+0900
# Minibatch loss at step 49000: 0.320415
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.9%
# finish : 2016-11-28T19:38:49+0900
# Minibatch loss at step 49500: 0.627924
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# finish : 2016-11-28T19:39:25+0900
# Minibatch loss at step 50000: 0.226631
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.1%
# finish : 2016-11-28T19:40:02+0900
# Minibatch loss at step 50500: 0.259948
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# finish : 2016-11-28T19:40:40+0900
# Minibatch loss at step 51000: 0.232602
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T19:41:16+0900
# Minibatch loss at step 51500: 0.367806
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T19:41:53+0900
# Minibatch loss at step 52000: 0.119480
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T19:42:30+0900
# Minibatch loss at step 52500: 0.309246
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# finish : 2016-11-28T19:43:06+0900
# Minibatch loss at step 53000: 0.147519
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-28T19:43:43+0900
# Minibatch loss at step 53500: 0.237088
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T19:44:20+0900
# Minibatch loss at step 54000: 0.159918
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T19:44:56+0900
# Minibatch loss at step 54500: 0.653790
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# finish : 2016-11-28T19:45:33+0900
# Minibatch loss at step 55000: 0.811803
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T19:46:11+0900
# Minibatch loss at step 55500: 0.176763
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.9%
# finish : 2016-11-28T19:46:47+0900
# Minibatch loss at step 56000: 0.434190
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 95.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# finish : 2016-11-28T19:47:24+0900
# Minibatch loss at step 56500: 0.603142
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# finish : 2016-11-28T19:48:01+0900
# Minibatch loss at step 57000: 0.666772
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# finish : 2016-11-28T19:48:39+0900
# Minibatch loss at step 57500: 0.571931
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-28T19:49:15+0900
# Minibatch loss at step 58000: 0.958998
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.3%
# finish : 2016-11-28T19:49:52+0900
# Minibatch loss at step 58500: 0.362199
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T19:50:29+0900
# Minibatch loss at step 59000: 0.340105
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T19:51:05+0900
# Minibatch loss at step 59500: 0.174556
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T19:51:42+0900
# Minibatch loss at step 60000: 0.202916
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T19:52:19+0900
# Minibatch loss at step 60500: 0.138083
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T19:52:56+0900
# Minibatch loss at step 61000: 0.115079
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T19:53:33+0900
# Minibatch loss at step 61500: 0.330831
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# finish : 2016-11-28T19:54:10+0900
# Minibatch loss at step 62000: 0.134710
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-28T19:54:47+0900
# Minibatch loss at step 62500: 0.429490
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T19:55:24+0900
# Minibatch loss at step 63000: 0.619426
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# finish : 2016-11-28T19:56:00+0900
# Minibatch loss at step 63500: 0.149844
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-28T19:56:37+0900
# Minibatch loss at step 64000: 0.568496
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# finish : 2016-11-28T19:57:14+0900
# Minibatch loss at step 64500: 0.230807
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-28T19:57:51+0900
# Minibatch loss at step 65000: 0.698903
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T19:58:28+0900
# Minibatch loss at step 65500: 0.239725
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-28T19:59:05+0900
# Minibatch loss at step 66000: 0.722545
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T19:59:42+0900
# Minibatch loss at step 66500: 0.182525
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T20:00:19+0900
# Minibatch loss at step 67000: 0.353228
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# finish : 2016-11-28T20:00:56+0900
# Minibatch loss at step 67500: 0.176924
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T20:01:32+0900
# Minibatch loss at step 68000: 0.229934
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# finish : 2016-11-28T20:02:09+0900
# Minibatch loss at step 68500: 0.197857
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T20:02:46+0900
# Minibatch loss at step 69000: 0.194843
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T20:03:22+0900
# Minibatch loss at step 69500: 0.227526
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T20:03:59+0900
# Minibatch loss at step 70000: 0.513152
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# finish : 2016-11-28T20:04:36+0900
# Minibatch loss at step 70500: 0.497940
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# finish : 2016-11-28T20:05:13+0900
# Minibatch loss at step 71000: 0.371872
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-28T20:05:50+0900
# Minibatch loss at step 71500: 0.145420
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# ...
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T20:12:33+0900
# Minibatch loss at step 77000: 0.492200
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-28T20:13:10+0900
# Minibatch loss at step 77500: 0.253864
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# finish : 2016-11-28T20:13:47+0900
# Minibatch loss at step 78000: 0.292923
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-28T20:14:24+0900
# Minibatch loss at step 78500: 0.484832
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-28T20:15:02+0900
# Minibatch loss at step 79000: 0.204547
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T20:15:38+0900
# Minibatch loss at step 79500: 0.269537
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T20:16:15+0900
# Minibatch loss at step 80000: 0.204187
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T20:16:51+0900
# Minibatch loss at step 80500: 0.116258
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T20:17:27+0900
# Minibatch loss at step 81000: 0.109051
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T20:18:04+0900
# Minibatch loss at step 81500: 0.112881
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T20:18:41+0900
# Minibatch loss at step 82000: 0.130016
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T20:19:18+0900
# Minibatch loss at step 82500: 0.304493
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T20:19:55+0900
# Minibatch loss at step 83000: 0.204929
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-28T20:20:32+0900
# Minibatch loss at step 83500: 0.101186
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T20:21:08+0900
# Minibatch loss at step 84000: 0.151442
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T20:21:45+0900
# Minibatch loss at step 84500: 0.172713
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# finish : 2016-11-28T20:22:22+0900
# Minibatch loss at step 85000: 0.349313
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-28T20:22:59+0900
# Minibatch loss at step 85500: 0.113139
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T20:23:36+0900
# Minibatch loss at step 86000: 0.152893
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T20:24:12+0900
# Minibatch loss at step 86500: 0.209193
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T20:24:49+0900
# Minibatch loss at step 87000: 0.147556
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T20:25:25+0900
# Minibatch loss at step 87500: 0.126187
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-28T20:26:02+0900
# Minibatch loss at step 88000: 0.094417
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T20:26:40+0900
# Minibatch loss at step 88500: 0.180079
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-28T20:27:17+0900
# Minibatch loss at step 89000: 0.131078
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-28T20:27:54+0900
# Minibatch loss at step 89500: 0.166502
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T20:28:30+0900
# Minibatch loss at step 90000: 0.109470
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T20:29:07+0900
# Minibatch loss at step 90500: 0.229495
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T20:29:44+0900
# Minibatch loss at step 91000: 0.251151
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T20:30:21+0900
# Minibatch loss at step 91500: 0.431509
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-28T20:30:57+0900
# Minibatch loss at step 92000: 0.334903
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-28T20:31:34+0900
# Minibatch loss at step 92500: 0.106740
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T20:32:11+0900
# Minibatch loss at step 93000: 0.128832
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T20:32:49+0900
# Minibatch loss at step 93500: 0.554526
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T20:33:25+0900
# Minibatch loss at step 94000: 0.444265
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-28T20:34:02+0900
# Minibatch loss at step 94500: 0.139905
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T20:34:39+0900
# Minibatch loss at step 95000: 0.115183
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T20:35:16+0900
# Minibatch loss at step 95500: 0.110566
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T20:35:53+0900
# Minibatch loss at step 96000: 0.146249
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T20:36:30+0900
# Minibatch loss at step 96500: 0.116289
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T20:37:06+0900
# Minibatch loss at step 97000: 0.120691
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-28T20:37:43+0900
# Minibatch loss at step 97500: 0.194901
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-28T20:38:20+0900
# Minibatch loss at step 98000: 0.264946
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T20:38:56+0900
# Minibatch loss at step 98500: 0.292398
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-28T20:39:33+0900
# Minibatch loss at step 99000: 0.160855
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-28T20:40:10+0900
# Minibatch loss at step 99500: 0.228510
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T20:40:47+0900
# Minibatch loss at step 100000: 0.270255
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T20:41:24+0900
# Test accuracy: 89.5%
# finish : 2016-11-28T20:41:27+0900

# %%
# Minibatch loss at step 100000: 0.137252
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T03:36:36+0900
# Test accuracy: 89.7%
# finish : 2016-11-29T03:36:40+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,128,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 18.937731
# Minibatch accuracy_length: 3.1%
# Minibatch accuracy_digit_0: 9.4%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 0.0%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T00:08:46+0900
# Minibatch loss at step 500: 9.751569
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-29T00:09:43+0900
# Minibatch loss at step 1000: 8.233493
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-29T00:10:41+0900
# Minibatch loss at step 1500: 8.979883
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-29T00:11:38+0900
# Minibatch loss at step 2000: 9.659987
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T00:12:35+0900
# Minibatch loss at step 2500: 8.599910
# Minibatch accuracy_length: 65.6%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.9%
# finish : 2016-11-29T00:13:32+0900
# Minibatch loss at step 3000: 6.832656
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 43.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 2.5%
# finish : 2016-11-29T00:14:29+0900
# Minibatch loss at step 3500: 6.060237
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 50.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 57.1%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 8.4%
# finish : 2016-11-29T00:15:27+0900
# Minibatch loss at step 4000: 4.407569
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 59.4%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 19.9%
# finish : 2016-11-29T00:16:25+0900
# Minibatch loss at step 4500: 3.760278
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 53.6%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 34.4%
# Validation accuracy: 32.2%
# finish : 2016-11-29T00:17:24+0900
# Minibatch loss at step 5000: 3.691534
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 75.9%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 31.2%
# Validation accuracy: 41.9%
# finish : 2016-11-29T00:18:24+0900
# Minibatch loss at step 5500: 2.520469
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 53.4%
# finish : 2016-11-29T00:19:24+0900
# Minibatch loss at step 6000: 1.736438
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 58.0%
# finish : 2016-11-29T00:20:25+0900
# Minibatch loss at step 6500: 2.295256
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 64.0%
# finish : 2016-11-29T00:21:25+0900
# Minibatch loss at step 7000: 2.990286
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 76.9%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 66.3%
# finish : 2016-11-29T00:22:25+0900
# Minibatch loss at step 7500: 2.171412
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 65.4%
# finish : 2016-11-29T00:23:26+0900
# Minibatch loss at step 8000: 2.192836
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 68.3%
# finish : 2016-11-29T00:24:26+0900
# Minibatch loss at step 8500: 1.918643
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.8%
# finish : 2016-11-29T00:25:27+0900
# Minibatch loss at step 9000: 2.135363
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 74.6%
# finish : 2016-11-29T00:26:27+0900
# Minibatch loss at step 9500: 1.740411
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.4%
# finish : 2016-11-29T00:27:27+0900
# Minibatch loss at step 10000: 0.797510
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 76.9%
# finish : 2016-11-29T00:28:27+0900
# Minibatch loss at step 10500: 1.445818
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.3%
# finish : 2016-11-29T00:29:28+0900
# Minibatch loss at step 11000: 1.227896
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 78.3%
# finish : 2016-11-29T00:30:28+0900
# Minibatch loss at step 11500: 2.034292
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.1%
# finish : 2016-11-29T00:31:28+0900
# Minibatch loss at step 12000: 0.917802
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.2%
# finish : 2016-11-29T00:32:29+0900
# Minibatch loss at step 12500: 1.274890
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.6%
# finish : 2016-11-29T00:33:30+0900
# Minibatch loss at step 13000: 1.565763
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.1%
# finish : 2016-11-29T00:34:30+0900
# Minibatch loss at step 13500: 0.729201
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.8%
# finish : 2016-11-29T00:35:31+0900
# Minibatch loss at step 14000: 1.591328
# Minibatch accuracy_length: 81.2%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 91.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 83.4%
# finish : 2016-11-29T00:36:31+0900
# Minibatch loss at step 14500: 1.159226
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# finish : 2016-11-29T00:37:32+0900
# Minibatch loss at step 15000: 0.772600
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.0%
# finish : 2016-11-29T00:38:33+0900
# Minibatch loss at step 15500: 1.061511
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# finish : 2016-11-29T00:39:33+0900
# Minibatch loss at step 16000: 0.973047
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.2%
# finish : 2016-11-29T00:40:33+0900
# Minibatch loss at step 16500: 0.815254
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# finish : 2016-11-29T00:41:34+0900
# Minibatch loss at step 17000: 0.590974
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# finish : 2016-11-29T00:42:34+0900
# Minibatch loss at step 17500: 0.911002
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.7%
# finish : 2016-11-29T00:43:35+0900
# Minibatch loss at step 18000: 0.484136
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# finish : 2016-11-29T00:44:36+0900
# Minibatch loss at step 18500: 0.911934
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# finish : 2016-11-29T00:45:37+0900
# Minibatch loss at step 19000: 0.557924
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.6%
# finish : 2016-11-29T00:46:38+0900
# Minibatch loss at step 19500: 0.743797
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# finish : 2016-11-29T00:47:39+0900
# Minibatch loss at step 20000: 0.961733
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# finish : 2016-11-29T00:48:40+0900
# Minibatch loss at step 20500: 0.360273
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.0%
# finish : 2016-11-29T00:49:41+0900
# Minibatch loss at step 21000: 0.517191
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# finish : 2016-11-29T00:50:42+0900
# Minibatch loss at step 21500: 0.536403
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# finish : 2016-11-29T00:51:43+0900
# Minibatch loss at step 22000: 1.268217
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.1%
# finish : 2016-11-29T00:52:45+0900
# Minibatch loss at step 22500: 0.423220
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-11-29T00:53:46+0900
# Minibatch loss at step 23000: 0.448444
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# finish : 2016-11-29T00:54:47+0900
# Minibatch loss at step 23500: 0.639390
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# finish : 2016-11-29T00:55:48+0900
# Minibatch loss at step 24000: 0.831719
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# finish : 2016-11-29T00:56:50+0900
# Minibatch loss at step 24500: 0.260283
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.4%
# finish : 2016-11-29T00:57:51+0900
# Minibatch loss at step 25000: 0.401333
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-29T00:58:53+0900
# Minibatch loss at step 25500: 0.311266
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# finish : 2016-11-29T00:59:54+0900
# Minibatch loss at step 26000: 0.275113
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# finish : 2016-11-29T01:00:56+0900
# Minibatch loss at step 26500: 0.510999
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# finish : 2016-11-29T01:01:58+0900
# Minibatch loss at step 27000: 0.907956
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.0%
# finish : 2016-11-29T01:03:00+0900
# Minibatch loss at step 27500: 0.292485
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-29T01:04:01+0900
# Minibatch loss at step 28000: 0.904313
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# finish : 2016-11-29T01:05:03+0900
# Minibatch loss at step 28500: 0.622664
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# finish : 2016-11-29T01:06:05+0900
# Minibatch loss at step 29000: 0.409108
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-11-29T01:07:08+0900
# Minibatch loss at step 29500: 0.731629
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# finish : 2016-11-29T01:08:10+0900
# Minibatch loss at step 30000: 0.421975
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# finish : 2016-11-29T01:09:12+0900
# Minibatch loss at step 30500: 0.542608
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# finish : 2016-11-29T01:10:14+0900
# Minibatch loss at step 31000: 0.645482
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# finish : 2016-11-29T01:11:16+0900
# Minibatch loss at step 31500: 0.189862
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-11-29T01:12:18+0900
# Minibatch loss at step 32000: 0.430525
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# finish : 2016-11-29T01:13:20+0900
# Minibatch loss at step 32500: 0.259201
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.3%
# finish : 2016-11-29T01:14:22+0900
# Minibatch loss at step 33000: 0.491350
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# finish : 2016-11-29T01:15:24+0900
# Minibatch loss at step 33500: 0.383524
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# finish : 2016-11-29T01:16:26+0900
# Minibatch loss at step 34000: 0.411371
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# finish : 2016-11-29T01:17:28+0900
# Minibatch loss at step 34500: 0.648577
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.8%
# finish : 2016-11-29T01:18:30+0900
# Minibatch loss at step 35000: 0.808665
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# finish : 2016-11-29T01:19:32+0900
# Minibatch loss at step 35500: 0.528693
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# finish : 2016-11-29T01:20:35+0900
# Minibatch loss at step 36000: 0.608115
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# finish : 2016-11-29T01:21:38+0900
# Minibatch loss at step 36500: 1.344178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# finish : 2016-11-29T01:22:41+0900
# Minibatch loss at step 37000: 0.127432
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-29T01:23:43+0900
# Minibatch loss at step 37500: 0.320945
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.2%
# finish : 2016-11-29T01:24:46+0900
# Minibatch loss at step 38000: 0.894658
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T01:25:48+0900
# Minibatch loss at step 38500: 0.355326
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# finish : 2016-11-29T01:26:51+0900
# Minibatch loss at step 39000: 0.500870
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# finish : 2016-11-29T01:27:53+0900
# Minibatch loss at step 39500: 0.499372
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-29T01:28:56+0900
# Minibatch loss at step 40000: 0.295320
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-29T01:29:59+0900
# Minibatch loss at step 40500: 0.543046
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# finish : 2016-11-29T01:31:02+0900
# Minibatch loss at step 41000: 0.281237
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-29T01:32:04+0900
# Minibatch loss at step 41500: 0.232876
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T01:33:07+0900
# Minibatch loss at step 42000: 0.379026
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T01:34:10+0900
# Minibatch loss at step 42500: 0.651589
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# finish : 2016-11-29T01:35:13+0900
# Minibatch loss at step 43000: 0.674712
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-29T01:36:16+0900
# Minibatch loss at step 43500: 0.258967
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-29T01:37:18+0900
# Minibatch loss at step 44000: 1.087181
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T01:38:21+0900
# Minibatch loss at step 44500: 0.278467
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-29T01:39:24+0900
# Minibatch loss at step 45000: 0.410474
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# finish : 2016-11-29T01:40:27+0900
# Minibatch loss at step 45500: 0.231796
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T01:41:30+0900
# Minibatch loss at step 46000: 0.377421
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-29T01:42:33+0900
# Minibatch loss at step 46500: 0.222557
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-29T01:43:36+0900
# Minibatch loss at step 47000: 0.488398
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# finish : 2016-11-29T01:44:39+0900
# Minibatch loss at step 47500: 0.183680
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-29T01:45:43+0900
# Minibatch loss at step 48000: 0.483736
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.6%
# finish : 2016-11-29T01:46:46+0900
# Minibatch loss at step 48500: 0.197362
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T01:47:48+0900
# Minibatch loss at step 49000: 0.223264
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T01:48:51+0900
# Minibatch loss at step 49500: 0.325565
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# finish : 2016-11-29T01:49:54+0900
# Minibatch loss at step 50000: 0.236287
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-11-29T01:50:58+0900
# Minibatch loss at step 50500: 0.244214
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T01:52:01+0900
# Minibatch loss at step 51000: 0.195628
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-29T01:53:04+0900
# Minibatch loss at step 51500: 0.305988
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# finish : 2016-11-29T01:54:08+0900
# Minibatch loss at step 52000: 0.129378
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-29T01:55:11+0900
# Minibatch loss at step 52500: 0.230810
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T01:56:14+0900
# Minibatch loss at step 53000: 0.211748
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-29T01:57:18+0900
# Minibatch loss at step 53500: 0.153083
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T01:58:21+0900
# Minibatch loss at step 54000: 0.158579
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-29T01:59:24+0900
# Minibatch loss at step 54500: 0.552613
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# finish : 2016-11-29T02:00:27+0900
# Minibatch loss at step 55000: 0.536241
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-29T02:01:31+0900
# Minibatch loss at step 55500: 0.148300
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T02:02:33+0900
# Minibatch loss at step 56000: 0.254035
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 95.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-29T02:03:37+0900
# Minibatch loss at step 56500: 0.496340
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-29T02:04:41+0900
# Minibatch loss at step 57000: 0.765035
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# finish : 2016-11-29T02:05:44+0900
# Minibatch loss at step 57500: 0.239636
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T02:06:48+0900
# Minibatch loss at step 58000: 0.696546
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# finish : 2016-11-29T02:07:51+0900
# Minibatch loss at step 58500: 0.230617
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-29T02:08:54+0900
# Minibatch loss at step 59000: 0.214257
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-29T02:09:57+0900
# Minibatch loss at step 59500: 0.214628
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-29T02:11:01+0900
# Minibatch loss at step 60000: 0.206479
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T02:12:04+0900
# Minibatch loss at step 60500: 0.121374
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-29T02:13:07+0900
# Minibatch loss at step 61000: 0.127303
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-29T02:14:11+0900
# Minibatch loss at step 61500: 0.241979
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.1%
# finish : 2016-11-29T02:15:14+0900
# Minibatch loss at step 62000: 0.256487
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-29T02:16:17+0900
# Minibatch loss at step 62500: 0.400455
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-29T02:17:21+0900
# Minibatch loss at step 63000: 0.591552
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# finish : 2016-11-29T02:18:24+0900
# Minibatch loss at step 63500: 0.191426
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-11-29T02:19:28+0900
# Minibatch loss at step 64000: 0.525879
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-29T02:20:31+0900
# Minibatch loss at step 64500: 0.141380
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T02:21:35+0900
# Minibatch loss at step 65000: 0.665114
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T02:22:38+0900
# Minibatch loss at step 65500: 0.164900
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T02:23:41+0900
# Minibatch loss at step 66000: 0.748905
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-29T02:24:45+0900
# Minibatch loss at step 66500: 0.146505
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T02:25:48+0900
# Minibatch loss at step 67000: 0.182871
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T02:26:52+0900
# Minibatch loss at step 67500: 0.143981
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-29T02:27:55+0900
# Minibatch loss at step 68000: 0.169558
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-29T02:28:58+0900
# Minibatch loss at step 68500: 0.234916
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-29T02:30:02+0900
# Minibatch loss at step 69000: 0.394099
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-29T02:31:06+0900
# Minibatch loss at step 69500: 0.184014
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T02:32:09+0900
# Minibatch loss at step 70000: 0.456067
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# finish : 2016-11-29T02:33:13+0900
# Minibatch loss at step 70500: 0.260430
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-29T02:34:17+0900
# Minibatch loss at step 71000: 0.327307
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T02:35:21+0900
# Minibatch loss at step 71500: 0.145250
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# ...
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T02:46:58+0900
# Minibatch loss at step 77000: 0.291060
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-29T02:48:01+0900
# Minibatch loss at step 77500: 0.181653
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-29T02:49:05+0900
# Minibatch loss at step 78000: 0.204230
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-11-29T02:50:09+0900
# Minibatch loss at step 78500: 0.408605
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-29T02:51:12+0900
# Minibatch loss at step 79000: 0.158100
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T02:52:16+0900
# Minibatch loss at step 79500: 0.141693
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T02:53:19+0900
# Minibatch loss at step 80000: 0.255783
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-29T02:54:22+0900
# Minibatch loss at step 80500: 0.124366
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T02:55:25+0900
# Minibatch loss at step 81000: 0.110520
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T02:56:29+0900
# Minibatch loss at step 81500: 0.112574
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-29T02:57:32+0900
# Minibatch loss at step 82000: 0.153506
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T02:58:36+0900
# Minibatch loss at step 82500: 0.154244
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-29T02:59:39+0900
# Minibatch loss at step 83000: 0.164181
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-29T03:00:42+0900
# Minibatch loss at step 83500: 0.126463
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-29T03:01:46+0900
# Minibatch loss at step 84000: 0.224435
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-29T03:02:49+0900
# Minibatch loss at step 84500: 0.156790
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-29T03:03:53+0900
# Minibatch loss at step 85000: 0.235540
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T03:04:56+0900
# Minibatch loss at step 85500: 0.102775
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T03:06:00+0900
# Minibatch loss at step 86000: 0.116570
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T03:07:03+0900
# Minibatch loss at step 86500: 0.200993
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T03:08:06+0900
# Minibatch loss at step 87000: 0.120729
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-29T03:09:09+0900
# Minibatch loss at step 87500: 0.106377
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T03:10:13+0900
# Minibatch loss at step 88000: 0.116398
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T03:11:16+0900
# Minibatch loss at step 88500: 0.121994
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-29T03:12:20+0900
# Minibatch loss at step 89000: 0.145810
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-29T03:13:23+0900
# Minibatch loss at step 89500: 0.168124
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-29T03:14:26+0900
# Minibatch loss at step 90000: 0.116273
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-29T03:15:29+0900
# Minibatch loss at step 90500: 0.157371
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T03:16:32+0900
# Minibatch loss at step 91000: 0.192325
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-29T03:17:35+0900
# Minibatch loss at step 91500: 0.148292
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-29T03:18:39+0900
# Minibatch loss at step 92000: 0.226384
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T03:19:42+0900
# Minibatch loss at step 92500: 0.107003
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T03:20:45+0900
# Minibatch loss at step 93000: 0.113601
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T03:21:49+0900
# Minibatch loss at step 93500: 0.306271
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-29T03:22:52+0900
# Minibatch loss at step 94000: 0.222218
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-29T03:23:55+0900
# Minibatch loss at step 94500: 0.111306
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T03:24:59+0900
# Minibatch loss at step 95000: 0.118708
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-29T03:26:02+0900
# Minibatch loss at step 95500: 0.099688
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-29T03:27:06+0900
# Minibatch loss at step 96000: 0.113003
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-29T03:28:09+0900
# Minibatch loss at step 96500: 0.114471
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-29T03:29:13+0900
# Minibatch loss at step 97000: 0.101099
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-29T03:30:16+0900
# Minibatch loss at step 97500: 0.126108
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T03:31:19+0900
# Minibatch loss at step 98000: 0.163403
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T03:32:23+0900
# Minibatch loss at step 98500: 0.150953
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T03:33:26+0900
# Minibatch loss at step 99000: 0.152246
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T03:34:30+0900
# Minibatch loss at step 99500: 0.130805
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T03:35:33+0900
# Minibatch loss at step 100000: 0.137252
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T03:36:36+0900
# Test accuracy: 89.7%
# finish : 2016-11-29T03:36:40+0900

# %%
# Minibatch loss at step 200000: 0.061928
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:34:08+0900
# Test accuracy: 89.1%
# finish : 2016-11-29T11:34:12+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=200001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,64,64], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 13.509753
# Minibatch accuracy_length: 75.0%
# Minibatch accuracy_digit_0: 6.2%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 3.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-29T08:45:21+0900
# Minibatch loss at step 500: 8.016180
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-29T08:45:45+0900
# Minibatch loss at step 1000: 6.703472
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-29T08:46:09+0900
# Minibatch loss at step 1500: 7.603532
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-29T08:46:33+0900
# Minibatch loss at step 2000: 8.434341
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T08:46:58+0900
# Minibatch loss at step 2500: 7.069183
# Minibatch accuracy_length: 75.0%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 1.1%
# finish : 2016-11-29T08:47:21+0900
# Minibatch loss at step 3000: 5.678803
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 53.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 3.2%
# finish : 2016-11-29T08:47:45+0900
# Minibatch loss at step 3500: 5.624478
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 50.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 57.1%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 12.5%
# Validation accuracy: 4.9%
# finish : 2016-11-29T08:48:09+0900
# Minibatch loss at step 4000: 4.215102
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 62.5%
# Minibatch accuracy_digit_1: 50.0%
# Minibatch accuracy_digit_2: 53.1%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 12.5%
# Validation accuracy: 15.6%
# finish : 2016-11-29T08:48:34+0900
# Minibatch loss at step 4500: 3.456767
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 60.7%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 34.4%
# Validation accuracy: 23.8%
# finish : 2016-11-29T08:48:59+0900
# Minibatch loss at step 5000: 3.730651
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 65.6%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 58.6%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 28.1%
# Validation accuracy: 40.9%
# finish : 2016-11-29T08:49:23+0900
# Minibatch loss at step 5500: 2.412245
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 46.9%
# Validation accuracy: 48.9%
# finish : 2016-11-29T08:49:48+0900
# Minibatch loss at step 6000: 1.602062
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 55.4%
# finish : 2016-11-29T08:50:13+0900
# Minibatch loss at step 6500: 2.163552
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 62.0%
# finish : 2016-11-29T08:50:38+0900
# Minibatch loss at step 7000: 2.804415
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 76.9%
# Minibatch accuracy_digit_3: 77.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 61.7%
# finish : 2016-11-29T08:51:03+0900
# Minibatch loss at step 7500: 1.999464
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 63.9%
# finish : 2016-11-29T08:51:28+0900
# Minibatch loss at step 8000: 1.931248
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 65.5%
# finish : 2016-11-29T08:51:53+0900
# Minibatch loss at step 8500: 1.746029
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 65.0%
# finish : 2016-11-29T08:52:18+0900
# Minibatch loss at step 9000: 1.872848
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.3%
# finish : 2016-11-29T08:52:44+0900
# Minibatch loss at step 9500: 1.629247
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 82.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.7%
# finish : 2016-11-29T08:53:09+0900
# Minibatch loss at step 10000: 0.810677
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.8%
# finish : 2016-11-29T08:53:34+0900
# Minibatch loss at step 10500: 1.339869
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.2%
# finish : 2016-11-29T08:53:59+0900
# Minibatch loss at step 11000: 0.955087
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 77.2%
# finish : 2016-11-29T08:54:25+0900
# Minibatch loss at step 11500: 2.436274
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.4%
# finish : 2016-11-29T08:54:50+0900
# Minibatch loss at step 12000: 0.944517
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.6%
# finish : 2016-11-29T08:55:15+0900
# Minibatch loss at step 12500: 1.136329
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.1%
# finish : 2016-11-29T08:55:40+0900
# Minibatch loss at step 13000: 1.452784
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.9%
# finish : 2016-11-29T08:56:05+0900
# Minibatch loss at step 13500: 0.591603
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.9%
# finish : 2016-11-29T08:56:30+0900
# Minibatch loss at step 14000: 1.888747
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 91.3%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.9%
# finish : 2016-11-29T08:56:56+0900
# Minibatch loss at step 14500: 1.495389
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 79.6%
# finish : 2016-11-29T08:57:21+0900
# Minibatch loss at step 15000: 0.698413
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.7%
# finish : 2016-11-29T08:57:46+0900
# Minibatch loss at step 15500: 1.129238
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.8%
# finish : 2016-11-29T08:58:11+0900
# Minibatch loss at step 16000: 0.596316
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.0%
# finish : 2016-11-29T08:58:37+0900
# Minibatch loss at step 16500: 0.903245
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# finish : 2016-11-29T08:59:02+0900
# Minibatch loss at step 17000: 0.716293
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# finish : 2016-11-29T08:59:27+0900
# Minibatch loss at step 17500: 0.869641
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# finish : 2016-11-29T08:59:52+0900
# Minibatch loss at step 18000: 0.410363
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.1%
# finish : 2016-11-29T09:00:17+0900
# Minibatch loss at step 18500: 1.015106
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# finish : 2016-11-29T09:00:42+0900
# Minibatch loss at step 19000: 0.371433
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 84.6%
# finish : 2016-11-29T09:01:08+0900
# Minibatch loss at step 19500: 0.699331
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# finish : 2016-11-29T09:01:33+0900
# Minibatch loss at step 20000: 0.699827
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# finish : 2016-11-29T09:01:59+0900
# Minibatch loss at step 20500: 0.449079
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.9%
# finish : 2016-11-29T09:02:24+0900
# Minibatch loss at step 21000: 0.711721
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# finish : 2016-11-29T09:02:49+0900
# Minibatch loss at step 21500: 0.736719
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# finish : 2016-11-29T09:03:15+0900
# Minibatch loss at step 22000: 1.549469
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.4%
# finish : 2016-11-29T09:03:40+0900
# Minibatch loss at step 22500: 0.414253
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.0%
# finish : 2016-11-29T09:04:05+0900
# Minibatch loss at step 23000: 0.253212
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.7%
# finish : 2016-11-29T09:04:30+0900
# Minibatch loss at step 23500: 0.671283
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# finish : 2016-11-29T09:04:55+0900
# Minibatch loss at step 24000: 0.854227
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# finish : 2016-11-29T09:05:21+0900
# Minibatch loss at step 24500: 0.576042
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# finish : 2016-11-29T09:05:46+0900
# Minibatch loss at step 25000: 0.515999
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# finish : 2016-11-29T09:06:11+0900
# Minibatch loss at step 25500: 0.391006
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.8%
# finish : 2016-11-29T09:06:36+0900
# Minibatch loss at step 26000: 0.310999
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.9%
# finish : 2016-11-29T09:07:02+0900
# Minibatch loss at step 26500: 0.530364
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.1%
# finish : 2016-11-29T09:07:27+0900
# Minibatch loss at step 27000: 0.808968
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# finish : 2016-11-29T09:07:52+0900
# Minibatch loss at step 27500: 0.326719
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# finish : 2016-11-29T09:08:17+0900
# Minibatch loss at step 28000: 0.824080
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# finish : 2016-11-29T09:08:43+0900
# Minibatch loss at step 28500: 0.551232
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# finish : 2016-11-29T09:09:08+0900
# Minibatch loss at step 29000: 0.320292
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.6%
# finish : 2016-11-29T09:09:33+0900
# Minibatch loss at step 29500: 0.561148
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.2%
# finish : 2016-11-29T09:09:58+0900
# Minibatch loss at step 30000: 0.447167
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# finish : 2016-11-29T09:10:23+0900
# Minibatch loss at step 30500: 0.542655
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# finish : 2016-11-29T09:10:49+0900
# Minibatch loss at step 31000: 0.531750
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# finish : 2016-11-29T09:11:14+0900
# Minibatch loss at step 31500: 0.395631
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# finish : 2016-11-29T09:11:39+0900
# Minibatch loss at step 32000: 0.510801
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# finish : 2016-11-29T09:12:05+0900
# Minibatch loss at step 32500: 0.266252
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.3%
# finish : 2016-11-29T09:12:30+0900
# Minibatch loss at step 33000: 0.407296
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# finish : 2016-11-29T09:12:55+0900
# Minibatch loss at step 33500: 0.473510
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# finish : 2016-11-29T09:13:21+0900
# Minibatch loss at step 34000: 0.440715
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# finish : 2016-11-29T09:13:46+0900
# Minibatch loss at step 34500: 0.559364
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# finish : 2016-11-29T09:14:11+0900
# Minibatch loss at step 35000: 0.692030
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# finish : 2016-11-29T09:14:37+0900
# Minibatch loss at step 35500: 0.846783
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.3%
# finish : 2016-11-29T09:15:02+0900
# Minibatch loss at step 36000: 0.784362
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# finish : 2016-11-29T09:15:28+0900
# Minibatch loss at step 36500: 1.639747
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.5%
# finish : 2016-11-29T09:15:53+0900
# Minibatch loss at step 37000: 0.104161
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-11-29T09:16:18+0900
# Minibatch loss at step 37500: 0.348458
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# finish : 2016-11-29T09:16:44+0900
# Minibatch loss at step 38000: 1.211136
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# finish : 2016-11-29T09:17:09+0900
# Minibatch loss at step 38500: 0.403369
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# finish : 2016-11-29T09:17:34+0900
# Minibatch loss at step 39000: 0.751904
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.0%
# finish : 2016-11-29T09:18:00+0900
# Minibatch loss at step 39500: 0.478833
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# finish : 2016-11-29T09:18:26+0900
# Minibatch loss at step 40000: 0.233675
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-11-29T09:18:51+0900
# Minibatch loss at step 40500: 0.574316
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# finish : 2016-11-29T09:19:16+0900
# Minibatch loss at step 41000: 0.300312
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T09:19:42+0900
# Minibatch loss at step 41500: 0.264751
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-29T09:20:07+0900
# Minibatch loss at step 42000: 0.437053
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.7%
# finish : 2016-11-29T09:20:32+0900
# Minibatch loss at step 42500: 0.770091
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# finish : 2016-11-29T09:20:58+0900
# Minibatch loss at step 43000: 0.676395
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# finish : 2016-11-29T09:21:24+0900
# Minibatch loss at step 43500: 0.296944
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.8%
# finish : 2016-11-29T09:21:49+0900
# Minibatch loss at step 44000: 0.882668
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-11-29T09:22:14+0900
# Minibatch loss at step 44500: 0.372064
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-29T09:22:40+0900
# Minibatch loss at step 45000: 0.355026
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-29T09:23:05+0900
# Minibatch loss at step 45500: 0.235705
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-29T09:23:31+0900
# Minibatch loss at step 46000: 0.349880
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# finish : 2016-11-29T09:23:56+0900
# Minibatch loss at step 46500: 0.189898
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T09:24:22+0900
# Minibatch loss at step 47000: 0.592755
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# finish : 2016-11-29T09:24:47+0900
# Minibatch loss at step 47500: 0.266519
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-29T09:25:13+0900
# Minibatch loss at step 48000: 0.835798
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# finish : 2016-11-29T09:25:38+0900
# Minibatch loss at step 48500: 0.155189
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T09:26:04+0900
# Minibatch loss at step 49000: 0.207818
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-11-29T09:26:29+0900
# Minibatch loss at step 49500: 0.575085
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# finish : 2016-11-29T09:26:55+0900
# Minibatch loss at step 50000: 0.246356
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# finish : 2016-11-29T09:27:20+0900
# Minibatch loss at step 50500: 0.353367
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# finish : 2016-11-29T09:27:46+0900
# Minibatch loss at step 51000: 0.184442
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-29T09:28:11+0900
# Minibatch loss at step 51500: 0.211498
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-29T09:28:37+0900
# Minibatch loss at step 52000: 0.117914
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T09:29:02+0900
# Minibatch loss at step 52500: 0.345731
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-29T09:29:28+0900
# Minibatch loss at step 53000: 0.185180
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T09:29:53+0900
# Minibatch loss at step 53500: 0.185006
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T09:30:19+0900
# Minibatch loss at step 54000: 0.318215
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-29T09:30:45+0900
# Minibatch loss at step 54500: 0.477543
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-29T09:31:10+0900
# Minibatch loss at step 55000: 0.692890
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# finish : 2016-11-29T09:31:35+0900
# Minibatch loss at step 55500: 0.161610
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-29T09:32:01+0900
# Minibatch loss at step 56000: 0.354877
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 95.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# finish : 2016-11-29T09:32:26+0900
# Minibatch loss at step 56500: 0.702391
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-29T09:32:51+0900
# Minibatch loss at step 57000: 0.686927
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# finish : 2016-11-29T09:33:17+0900
# Minibatch loss at step 57500: 0.331502
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-29T09:33:42+0900
# Minibatch loss at step 58000: 0.786295
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.1%
# finish : 2016-11-29T09:34:08+0900
# Minibatch loss at step 58500: 0.168897
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T09:34:34+0900
# Minibatch loss at step 59000: 0.298854
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-29T09:35:00+0900
# Minibatch loss at step 59500: 0.304572
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-29T09:35:25+0900
# Minibatch loss at step 60000: 0.235674
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T09:35:50+0900
# Minibatch loss at step 60500: 0.109874
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T09:36:16+0900
# Minibatch loss at step 61000: 0.140727
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-29T09:36:41+0900
# Minibatch loss at step 61500: 0.525016
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-29T09:37:07+0900
# Minibatch loss at step 62000: 0.132569
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T09:37:32+0900
# Minibatch loss at step 62500: 0.591494
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-29T09:37:58+0900
# Minibatch loss at step 63000: 0.732016
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-29T09:38:24+0900
# Minibatch loss at step 63500: 0.279477
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-11-29T09:38:50+0900
# Minibatch loss at step 64000: 0.622963
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# finish : 2016-11-29T09:39:15+0900
# Minibatch loss at step 64500: 0.166938
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-29T09:39:41+0900
# Minibatch loss at step 65000: 0.675333
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-29T09:40:06+0900
# Minibatch loss at step 65500: 0.180886
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-29T09:40:32+0900
# Minibatch loss at step 66000: 1.199999
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# finish : 2016-11-29T09:40:57+0900
# Minibatch loss at step 66500: 0.154856
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T09:41:22+0900
# Minibatch loss at step 67000: 0.289185
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# finish : 2016-11-29T09:41:48+0900
# Minibatch loss at step 67500: 0.173633
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-29T09:42:14+0900
# Minibatch loss at step 68000: 0.129546
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T09:42:39+0900
# Minibatch loss at step 68500: 0.373746
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-29T09:43:05+0900
# Minibatch loss at step 69000: 0.284214
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-29T09:43:30+0900
# Minibatch loss at step 69500: 0.208937
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-29T09:43:56+0900
# Minibatch loss at step 70000: 0.735892
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# finish : 2016-11-29T09:44:21+0900
# Minibatch loss at step 70500: 0.411574
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# finish : 2016-11-29T09:44:47+0900
# Minibatch loss at step 71000: 0.425488
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# finish : 2016-11-29T09:45:12+0900
# Minibatch loss at step 71500: 0.297189
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.1%
# ...
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-11-29T11:14:20+0900
# Minibatch loss at step 177000: 0.063934
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T11:14:45+0900
# Minibatch loss at step 177500: 0.077718
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T11:15:10+0900
# Minibatch loss at step 178000: 0.084473
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-11-29T11:15:35+0900
# Minibatch loss at step 178500: 0.335664
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:16:01+0900
# Minibatch loss at step 179000: 0.066306
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:16:26+0900
# Minibatch loss at step 179500: 0.135125
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T11:16:52+0900
# Minibatch loss at step 180000: 0.088117
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T11:17:17+0900
# Minibatch loss at step 180500: 0.067658
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T11:17:43+0900
# Minibatch loss at step 181000: 0.074184
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T11:18:08+0900
# Minibatch loss at step 181500: 0.061872
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T11:18:34+0900
# Minibatch loss at step 182000: 0.086261
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-29T11:18:59+0900
# Minibatch loss at step 182500: 0.079253
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-29T11:19:24+0900
# Minibatch loss at step 183000: 0.091038
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-11-29T11:19:50+0900
# Minibatch loss at step 183500: 0.061380
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-29T11:20:15+0900
# Minibatch loss at step 184000: 0.126060
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T11:20:40+0900
# Minibatch loss at step 184500: 0.071977
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T11:21:05+0900
# Minibatch loss at step 185000: 0.068970
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T11:21:31+0900
# Minibatch loss at step 185500: 0.069644
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:21:56+0900
# Minibatch loss at step 186000: 0.072305
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:22:21+0900
# Minibatch loss at step 186500: 0.076145
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T11:22:46+0900
# Minibatch loss at step 187000: 0.070393
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T11:23:12+0900
# Minibatch loss at step 187500: 0.066911
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T11:23:37+0900
# Minibatch loss at step 188000: 0.071862
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T11:24:02+0900
# Minibatch loss at step 188500: 0.071060
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-29T11:24:27+0900
# Minibatch loss at step 189000: 0.120963
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T11:24:52+0900
# Minibatch loss at step 189500: 0.097994
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T11:25:18+0900
# Minibatch loss at step 190000: 0.060605
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-11-29T11:25:43+0900
# Minibatch loss at step 190500: 0.081479
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-11-29T11:26:08+0900
# Minibatch loss at step 191000: 0.077408
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T11:26:33+0900
# Minibatch loss at step 191500: 0.258501
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:26:59+0900
# Minibatch loss at step 192000: 0.067905
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T11:27:24+0900
# Minibatch loss at step 192500: 0.070903
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:27:49+0900
# Minibatch loss at step 193000: 0.064298
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:28:14+0900
# Minibatch loss at step 193500: 0.120608
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T11:28:40+0900
# Minibatch loss at step 194000: 0.068159
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T11:29:06+0900
# Minibatch loss at step 194500: 0.060157
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T11:29:31+0900
# Minibatch loss at step 195000: 0.068288
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T11:29:57+0900
# Minibatch loss at step 195500: 0.063555
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T11:30:22+0900
# Minibatch loss at step 196000: 0.084529
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T11:30:47+0900
# Minibatch loss at step 196500: 0.121889
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T11:31:12+0900
# Minibatch loss at step 197000: 0.059690
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T11:31:37+0900
# Minibatch loss at step 197500: 0.078472
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-29T11:32:02+0900
# Minibatch loss at step 198000: 0.067220
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T11:32:28+0900
# Minibatch loss at step 198500: 0.079098
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T11:32:53+0900
# Minibatch loss at step 199000: 0.084018
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T11:33:18+0900
# Minibatch loss at step 199500: 0.058061
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:33:43+0900
# Minibatch loss at step 200000: 0.061928
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T11:34:08+0900
# Test accuracy: 89.1%
# finish : 2016-11-29T11:34:12+0900

# %%
# Minibatch loss at step 100000: 0.076815
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T15:14:29+0900
# Test accuracy: 89.1%
# finish : 2016-11-29T15:14:31+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=64,  
                        num_convs=[16,32,64,64,64,64,64,64], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(64, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(64, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(64, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 13.844358
# Minibatch accuracy_length: 20.3%
# Minibatch accuracy_digit_0: 4.7%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 51.7%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.5%
# finish : 2016-11-29T13:44:23+0900
# Minibatch loss at step 500: 7.050818
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 29.7%
# Minibatch accuracy_digit_1: 32.8%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-29T13:44:48+0900
# Minibatch loss at step 1000: 8.269038
# Minibatch accuracy_length: 57.8%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 41.9%
# Minibatch accuracy_digit_3: 88.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T13:45:13+0900
# Minibatch loss at step 1500: 7.458803
# Minibatch accuracy_length: 48.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 57.4%
# Minibatch accuracy_digit_3: 96.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T13:45:38+0900
# Minibatch loss at step 2000: 7.361517
# Minibatch accuracy_length: 68.8%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 14.1%
# Minibatch accuracy_digit_2: 53.1%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.8%
# finish : 2016-11-29T13:46:03+0900
# Minibatch loss at step 2500: 6.908812
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 20.3%
# Minibatch accuracy_digit_2: 35.0%
# Minibatch accuracy_digit_3: 95.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 1.1%
# finish : 2016-11-29T13:46:28+0900
# Minibatch loss at step 3000: 4.458411
# Minibatch accuracy_length: 92.2%
# Minibatch accuracy_digit_0: 67.2%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 62.3%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 10.2%
# finish : 2016-11-29T13:46:54+0900
# Minibatch loss at step 3500: 6.405129
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 48.4%
# Minibatch accuracy_digit_1: 32.8%
# Minibatch accuracy_digit_2: 66.0%
# Minibatch accuracy_digit_3: 78.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 17.6%
# finish : 2016-11-29T13:47:20+0900
# Minibatch loss at step 4000: 2.245631
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 79.7%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 85.7%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 42.5%
# finish : 2016-11-29T13:47:47+0900
# Minibatch loss at step 4500: 3.323902
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 68.8%
# Minibatch accuracy_digit_1: 70.3%
# Minibatch accuracy_digit_2: 72.4%
# Minibatch accuracy_digit_3: 97.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 48.5%
# finish : 2016-11-29T13:48:14+0900
# Minibatch loss at step 5000: 2.174761
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 85.9%
# Minibatch accuracy_digit_1: 82.8%
# Minibatch accuracy_digit_2: 77.4%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 57.8%
# Validation accuracy: 61.4%
# finish : 2016-11-29T13:48:41+0900
# Minibatch loss at step 5500: 1.553816
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 89.1%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 84.7%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 67.2%
# Validation accuracy: 68.3%
# finish : 2016-11-29T13:49:09+0900
# Minibatch loss at step 6000: 1.522993
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 85.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 96.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.6%
# finish : 2016-11-29T13:49:36+0900
# Minibatch loss at step 6500: 1.741841
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.3%
# finish : 2016-11-29T13:50:03+0900
# Minibatch loss at step 7000: 2.065740
# Minibatch accuracy_length: 92.2%
# Minibatch accuracy_digit_0: 82.8%
# Minibatch accuracy_digit_1: 82.8%
# Minibatch accuracy_digit_2: 91.2%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.2%
# finish : 2016-11-29T13:50:30+0900
# Minibatch loss at step 7500: 1.462744
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 85.9%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 76.6%
# Validation accuracy: 74.9%
# finish : 2016-11-29T13:50:56+0900
# Minibatch loss at step 8000: 1.148139
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 89.1%
# Minibatch accuracy_digit_2: 92.1%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.0%
# finish : 2016-11-29T13:51:23+0900
# Minibatch loss at step 8500: 1.197100
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 85.9%
# Minibatch accuracy_digit_2: 86.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 70.3%
# Validation accuracy: 78.5%
# finish : 2016-11-29T13:51:50+0900
# Minibatch loss at step 9000: 1.219914
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 89.1%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.0%
# Minibatch accuracy_digit_4: 75.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.2%
# finish : 2016-11-29T13:52:17+0900
# Minibatch loss at step 9500: 0.673136
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.5%
# finish : 2016-11-29T13:52:44+0900
# Minibatch loss at step 10000: 0.980762
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.9%
# finish : 2016-11-29T13:53:10+0900
# Minibatch loss at step 10500: 1.425121
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 84.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 82.0%
# finish : 2016-11-29T13:53:37+0900
# Minibatch loss at step 11000: 1.172630
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 94.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# finish : 2016-11-29T13:54:04+0900
# Minibatch loss at step 11500: 0.545594
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.7%
# Minibatch accuracy_digit_3: 95.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.7%
# finish : 2016-11-29T13:54:31+0900
# Minibatch loss at step 12000: 1.093928
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 95.0%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# finish : 2016-11-29T13:54:57+0900
# Minibatch loss at step 12500: 0.694689
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.0%
# finish : 2016-11-29T13:55:24+0900
# Minibatch loss at step 13000: 0.931753
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.2%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.2%
# finish : 2016-11-29T13:55:51+0900
# Minibatch loss at step 13500: 0.733342
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.7%
# finish : 2016-11-29T13:56:18+0900
# Minibatch loss at step 14000: 1.482016
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.3%
# finish : 2016-11-29T13:56:45+0900
# Minibatch loss at step 14500: 0.790867
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 94.3%
# Minibatch accuracy_digit_3: 95.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.0%
# finish : 2016-11-29T13:57:12+0900
# Minibatch loss at step 15000: 0.532918
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.7%
# Minibatch accuracy_digit_3: 97.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.2%
# finish : 2016-11-29T13:57:39+0900
# Minibatch loss at step 15500: 0.596120
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.1%
# finish : 2016-11-29T13:58:06+0900
# Minibatch loss at step 16000: 0.424902
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.6%
# finish : 2016-11-29T13:58:33+0900
# Minibatch loss at step 16500: 0.402782
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# finish : 2016-11-29T13:59:00+0900
# Minibatch loss at step 17000: 0.732193
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 95.2%
# Minibatch accuracy_digit_3: 97.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.1%
# finish : 2016-11-29T13:59:27+0900
# Minibatch loss at step 17500: 0.885659
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 89.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# finish : 2016-11-29T13:59:54+0900
# Minibatch loss at step 18000: 0.531201
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.9%
# finish : 2016-11-29T14:00:21+0900
# Minibatch loss at step 18500: 0.520618
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.6%
# finish : 2016-11-29T14:00:47+0900
# Minibatch loss at step 19000: 0.250086
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.7%
# finish : 2016-11-29T14:01:14+0900
# Minibatch loss at step 19500: 0.335218
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.8%
# finish : 2016-11-29T14:01:41+0900
# Minibatch loss at step 20000: 0.698918
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 95.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# finish : 2016-11-29T14:02:08+0900
# Minibatch loss at step 20500: 0.724306
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.5%
# Minibatch accuracy_digit_3: 92.7%
# Minibatch accuracy_digit_4: 75.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.2%
# finish : 2016-11-29T14:02:35+0900
# Minibatch loss at step 21000: 0.383781
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.9%
# finish : 2016-11-29T14:03:02+0900
# Minibatch loss at step 21500: 0.543160
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.0%
# finish : 2016-11-29T14:03:30+0900
# Minibatch loss at step 22000: 0.794192
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 91.8%
# Minibatch accuracy_digit_3: 94.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.9%
# finish : 2016-11-29T14:03:57+0900
# Minibatch loss at step 22500: 0.520581
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.4%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.2%
# finish : 2016-11-29T14:04:24+0900
# Minibatch loss at step 23000: 0.430441
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# finish : 2016-11-29T14:04:50+0900
# Minibatch loss at step 23500: 0.157239
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-11-29T14:05:17+0900
# Minibatch loss at step 24000: 0.434885
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 95.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.5%
# finish : 2016-11-29T14:05:45+0900
# Minibatch loss at step 24500: 0.787131
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.5%
# finish : 2016-11-29T14:06:12+0900
# Minibatch loss at step 25000: 0.743496
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 94.8%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.5%
# finish : 2016-11-29T14:06:38+0900
# Minibatch loss at step 25500: 0.357842
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 97.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# finish : 2016-11-29T14:07:06+0900
# Minibatch loss at step 26000: 0.214802
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.4%
# finish : 2016-11-29T14:07:32+0900
# Minibatch loss at step 26500: 0.330524
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:07:59+0900
# Minibatch loss at step 27000: 0.884524
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-29T14:08:26+0900
# Minibatch loss at step 27500: 0.265325
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.7%
# finish : 2016-11-29T14:08:53+0900
# Minibatch loss at step 28000: 0.402975
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:09:20+0900
# Minibatch loss at step 28500: 0.556664
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.0%
# finish : 2016-11-29T14:09:46+0900
# Minibatch loss at step 29000: 0.458389
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 97.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-29T14:10:14+0900
# Minibatch loss at step 29500: 0.460081
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:10:41+0900
# Minibatch loss at step 30000: 0.753850
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:11:08+0900
# Minibatch loss at step 30500: 0.470509
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.8%
# finish : 2016-11-29T14:11:35+0900
# Minibatch loss at step 31000: 0.252056
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-29T14:12:02+0900
# Minibatch loss at step 31500: 0.510051
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-29T14:12:30+0900
# Minibatch loss at step 32000: 0.504197
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-29T14:12:57+0900
# Minibatch loss at step 32500: 0.572010
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-29T14:13:24+0900
# Minibatch loss at step 33000: 0.172096
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T14:13:51+0900
# Minibatch loss at step 33500: 0.166799
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-11-29T14:14:18+0900
# Minibatch loss at step 34000: 0.223337
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:14:45+0900
# Minibatch loss at step 34500: 0.265621
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:15:12+0900
# Minibatch loss at step 35000: 1.564460
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# finish : 2016-11-29T14:15:40+0900
# Minibatch loss at step 35500: 0.823370
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 89.1%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 94.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# finish : 2016-11-29T14:16:07+0900
# Minibatch loss at step 36000: 0.449224
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:16:33+0900
# Minibatch loss at step 36500: 0.303004
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.8%
# finish : 2016-11-29T14:17:01+0900
# Minibatch loss at step 37000: 0.296677
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 95.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-29T14:17:28+0900
# Minibatch loss at step 37500: 0.211869
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-11-29T14:17:55+0900
# Minibatch loss at step 38000: 0.226394
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:18:22+0900
# Minibatch loss at step 38500: 0.629308
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-29T14:18:49+0900
# Minibatch loss at step 39000: 0.368340
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:19:17+0900
# Minibatch loss at step 39500: 0.556697
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:19:45+0900
# Minibatch loss at step 40000: 0.201517
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.1%
# finish : 2016-11-29T14:20:12+0900
# Minibatch loss at step 40500: 0.540937
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:20:39+0900
# Minibatch loss at step 41000: 0.209396
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:21:06+0900
# Minibatch loss at step 41500: 0.173870
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:21:34+0900
# Minibatch loss at step 42000: 0.548724
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.4%
# finish : 2016-11-29T14:22:01+0900
# Minibatch loss at step 42500: 0.471547
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-29T14:22:29+0900
# Minibatch loss at step 43000: 0.351313
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:22:56+0900
# Minibatch loss at step 43500: 0.182243
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.1%
# finish : 2016-11-29T14:23:23+0900
# Minibatch loss at step 44000: 0.193239
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:23:50+0900
# Minibatch loss at step 44500: 0.137113
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T14:24:17+0900
# Minibatch loss at step 45000: 0.148773
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:24:44+0900
# Minibatch loss at step 45500: 0.480404
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 95.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# finish : 2016-11-29T14:25:11+0900
# Minibatch loss at step 46000: 0.247733
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.7%
# finish : 2016-11-29T14:25:38+0900
# Minibatch loss at step 46500: 0.290918
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.0%
# finish : 2016-11-29T14:26:05+0900
# Minibatch loss at step 47000: 0.113535
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:26:32+0900
# Minibatch loss at step 47500: 0.161065
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-11-29T14:26:59+0900
# Minibatch loss at step 48000: 0.146844
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T14:27:26+0900
# Minibatch loss at step 48500: 0.181125
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:27:54+0900
# Minibatch loss at step 49000: 0.316574
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:28:21+0900
# Minibatch loss at step 49500: 0.284469
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:28:49+0900
# Minibatch loss at step 50000: 0.210755
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.1%
# finish : 2016-11-29T14:29:16+0900
# Minibatch loss at step 50500: 0.218213
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T14:29:43+0900
# Minibatch loss at step 51000: 0.225063
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-29T14:30:10+0900
# Minibatch loss at step 51500: 0.149535
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.5%
# finish : 2016-11-29T14:30:37+0900
# Minibatch loss at step 52000: 0.125542
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:31:04+0900
# Minibatch loss at step 52500: 0.247361
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.1%
# finish : 2016-11-29T14:31:31+0900
# Minibatch loss at step 53000: 0.224096
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.8%
# finish : 2016-11-29T14:31:58+0900
# Minibatch loss at step 53500: 0.118697
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T14:32:25+0900
# Minibatch loss at step 54000: 0.241398
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:32:52+0900
# Minibatch loss at step 54500: 0.164868
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T14:33:19+0900
# Minibatch loss at step 55000: 0.210031
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:33:47+0900
# Minibatch loss at step 55500: 0.299258
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:34:14+0900
# Minibatch loss at step 56000: 0.180774
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:34:41+0900
# Minibatch loss at step 56500: 0.133951
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:35:08+0900
# Minibatch loss at step 57000: 0.496914
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# finish : 2016-11-29T14:35:35+0900
# Minibatch loss at step 57500: 0.143912
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T14:36:02+0900
# Minibatch loss at step 58000: 0.183551
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T14:36:30+0900
# Minibatch loss at step 58500: 0.318340
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.5%
# finish : 2016-11-29T14:36:57+0900
# Minibatch loss at step 59000: 0.124890
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:37:24+0900
# Minibatch loss at step 59500: 0.199093
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:37:52+0900
# Minibatch loss at step 60000: 0.236784
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.5%
# finish : 2016-11-29T14:38:19+0900
# Minibatch loss at step 60500: 0.141516
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-11-29T14:38:46+0900
# Minibatch loss at step 61000: 0.457508
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 95.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:39:13+0900
# Minibatch loss at step 61500: 0.115125
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T14:39:40+0900
# Minibatch loss at step 62000: 0.163665
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:40:07+0900
# Minibatch loss at step 62500: 0.101284
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T14:40:35+0900
# Minibatch loss at step 63000: 0.276816
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:41:02+0900
# Minibatch loss at step 63500: 0.130221
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.6%
# finish : 2016-11-29T14:41:30+0900
# Minibatch loss at step 64000: 0.160793
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T14:41:57+0900
# Minibatch loss at step 64500: 0.186333
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.9%
# finish : 2016-11-29T14:42:24+0900
# Minibatch loss at step 65000: 0.173271
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:42:52+0900
# Minibatch loss at step 65500: 0.109963
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:43:18+0900
# Minibatch loss at step 66000: 0.094888
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T14:43:46+0900
# Minibatch loss at step 66500: 0.258764
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-29T14:44:13+0900
# Minibatch loss at step 67000: 0.204863
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.5%
# finish : 2016-11-29T14:44:41+0900
# Minibatch loss at step 67500: 0.194563
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T14:45:07+0900
# Minibatch loss at step 68000: 0.151106
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.1%
# finish : 2016-11-29T14:45:35+0900
# Minibatch loss at step 68500: 0.106653
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:46:01+0900
# Minibatch loss at step 69000: 0.148166
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T14:46:29+0900
# Minibatch loss at step 69500: 0.113943
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T14:46:56+0900
# Minibatch loss at step 70000: 0.215701
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.1%
# finish : 2016-11-29T14:47:23+0900
# Minibatch loss at step 70500: 0.122876
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T14:47:51+0900
# Minibatch loss at step 71000: 0.123953
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:48:18+0900
# Minibatch loss at step 71500: 0.109414
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# ...
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T14:53:15+0900
# Minibatch loss at step 77000: 0.142596
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:53:42+0900
# Minibatch loss at step 77500: 0.143684
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.8%
# finish : 2016-11-29T14:54:09+0900
# Minibatch loss at step 78000: 0.100483
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T14:54:36+0900
# Minibatch loss at step 78500: 0.113693
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:55:04+0900
# Minibatch loss at step 79000: 0.185103
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:55:30+0900
# Minibatch loss at step 79500: 0.116127
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:55:57+0900
# Minibatch loss at step 80000: 0.156549
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.6%
# finish : 2016-11-29T14:56:24+0900
# Minibatch loss at step 80500: 0.183769
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:56:51+0900
# Minibatch loss at step 81000: 0.124969
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T14:57:18+0900
# Minibatch loss at step 81500: 0.087305
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T14:57:46+0900
# Minibatch loss at step 82000: 0.095576
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T14:58:12+0900
# Minibatch loss at step 82500: 0.103751
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:58:40+0900
# Minibatch loss at step 83000: 0.090197
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T14:59:07+0900
# Minibatch loss at step 83500: 0.114237
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.5%
# finish : 2016-11-29T14:59:34+0900
# Minibatch loss at step 84000: 0.126709
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T15:00:01+0900
# Minibatch loss at step 84500: 0.126543
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-29T15:00:28+0900
# Minibatch loss at step 85000: 0.197106
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 85.7%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-11-29T15:00:55+0900
# Minibatch loss at step 85500: 0.100575
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T15:01:22+0900
# Minibatch loss at step 86000: 0.099097
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T15:01:49+0900
# Minibatch loss at step 86500: 0.093424
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T15:02:16+0900
# Minibatch loss at step 87000: 0.100554
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T15:02:44+0900
# Minibatch loss at step 87500: 0.204742
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.9%
# finish : 2016-11-29T15:03:12+0900
# Minibatch loss at step 88000: 0.105140
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# finish : 2016-11-29T15:03:39+0900
# Minibatch loss at step 88500: 0.090109
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T15:04:06+0900
# Minibatch loss at step 89000: 0.136130
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-11-29T15:04:33+0900
# Minibatch loss at step 89500: 0.167631
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.2%
# finish : 2016-11-29T15:05:00+0900
# Minibatch loss at step 90000: 0.097964
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T15:05:28+0900
# Minibatch loss at step 90500: 0.085261
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T15:05:54+0900
# Minibatch loss at step 91000: 0.110146
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T15:06:21+0900
# Minibatch loss at step 91500: 0.105053
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# finish : 2016-11-29T15:06:48+0900
# Minibatch loss at step 92000: 0.085492
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T15:07:15+0900
# Minibatch loss at step 92500: 0.088439
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T15:07:42+0900
# Minibatch loss at step 93000: 0.089304
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T15:08:09+0900
# Minibatch loss at step 93500: 0.116283
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T15:08:35+0900
# Minibatch loss at step 94000: 0.105241
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T15:09:03+0900
# Minibatch loss at step 94500: 0.124284
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T15:09:30+0900
# Minibatch loss at step 95000: 0.123522
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.6%
# finish : 2016-11-29T15:09:57+0900
# Minibatch loss at step 95500: 0.080389
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T15:10:25+0900
# Minibatch loss at step 96000: 0.083347
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T15:10:52+0900
# Minibatch loss at step 96500: 0.163560
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T15:11:19+0900
# Minibatch loss at step 97000: 0.077676
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T15:11:46+0900
# Minibatch loss at step 97500: 0.078812
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T15:12:13+0900
# Minibatch loss at step 98000: 0.085109
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-29T15:12:41+0900
# Minibatch loss at step 98500: 0.077716
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T15:13:08+0900
# Minibatch loss at step 99000: 0.074727
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T15:13:35+0900
# Minibatch loss at step 99500: 0.093289
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T15:14:02+0900
# Minibatch loss at step 100000: 0.076815
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T15:14:29+0900
# Test accuracy: 89.1%
# finish : 2016-11-29T15:14:31+0900

# %%
# Minibatch loss at step 100000: 0.086014
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T18:27:38+0900
# Test accuracy: 89.5%
# finish : 2016-11-29T18:27:41+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=64,  
                        num_convs=[32,32,32,64,64,64,64,64], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(64, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(64, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(64, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 13.715680
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 3.1%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 11.7%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-29T15:43:03+0900
# Minibatch loss at step 500: 7.048334
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 29.7%
# Minibatch accuracy_digit_1: 32.8%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-29T15:43:59+0900
# Minibatch loss at step 1000: 8.263910
# Minibatch accuracy_length: 57.8%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 41.9%
# Minibatch accuracy_digit_3: 88.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T15:44:54+0900
# Minibatch loss at step 1500: 7.015138
# Minibatch accuracy_length: 81.2%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 57.4%
# Minibatch accuracy_digit_3: 96.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-29T15:45:45+0900
# Minibatch loss at step 2000: 6.309704
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 46.9%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 2.7%
# finish : 2016-11-29T15:46:33+0900
# Minibatch loss at step 2500: 4.808761
# Minibatch accuracy_length: 92.2%
# Minibatch accuracy_digit_0: 65.6%
# Minibatch accuracy_digit_1: 48.4%
# Minibatch accuracy_digit_2: 51.7%
# Minibatch accuracy_digit_3: 95.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 17.2%
# Validation accuracy: 12.6%
# finish : 2016-11-29T15:47:22+0900
# Minibatch loss at step 3000: 2.581695
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 85.9%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 75.4%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 42.2%
# Validation accuracy: 32.8%
# finish : 2016-11-29T15:48:10+0900
# Minibatch loss at step 3500: 3.289210
# Minibatch accuracy_length: 89.1%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 76.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 40.6%
# Validation accuracy: 44.6%
# finish : 2016-11-29T15:48:59+0900
# Minibatch loss at step 4000: 1.952577
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 79.7%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 60.9%
# Validation accuracy: 53.9%
# finish : 2016-11-29T15:49:48+0900
# Minibatch loss at step 4500: 2.617138
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 81.0%
# Minibatch accuracy_digit_3: 97.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 54.7%
# Validation accuracy: 61.0%
# finish : 2016-11-29T15:50:37+0900
# Minibatch loss at step 5000: 2.190768
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 82.8%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 79.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 57.8%
# Validation accuracy: 64.5%
# finish : 2016-11-29T15:51:26+0900
# Minibatch loss at step 5500: 1.382484
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 89.1%
# Minibatch accuracy_digit_2: 86.4%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.6%
# finish : 2016-11-29T15:52:15+0900
# Minibatch loss at step 6000: 1.449824
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 89.1%
# Minibatch accuracy_digit_2: 87.9%
# Minibatch accuracy_digit_3: 90.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 73.4%
# Validation accuracy: 73.6%
# finish : 2016-11-29T15:53:04+0900
# Minibatch loss at step 6500: 1.841654
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 91.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 75.1%
# finish : 2016-11-29T15:53:52+0900
# Minibatch loss at step 7000: 1.987476
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 89.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 75.9%
# finish : 2016-11-29T15:54:41+0900
# Minibatch loss at step 7500: 1.478301
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 89.1%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 94.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 77.2%
# finish : 2016-11-29T15:55:29+0900
# Minibatch loss at step 8000: 0.983495
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.7%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.8%
# finish : 2016-11-29T15:56:18+0900
# Minibatch loss at step 8500: 1.149106
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.6%
# finish : 2016-11-29T15:57:07+0900
# Minibatch loss at step 9000: 1.290109
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 89.1%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.0%
# Minibatch accuracy_digit_4: 75.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# finish : 2016-11-29T15:57:57+0900
# Minibatch loss at step 9500: 0.693410
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.1%
# finish : 2016-11-29T15:58:46+0900
# Minibatch loss at step 10000: 0.911214
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 88.3%
# Minibatch accuracy_digit_3: 95.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 76.6%
# Validation accuracy: 83.3%
# finish : 2016-11-29T15:59:34+0900
# Minibatch loss at step 10500: 1.135786
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 90.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.4%
# finish : 2016-11-29T16:00:23+0900
# Minibatch loss at step 11000: 1.035880
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 89.1%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.8%
# finish : 2016-11-29T16:01:12+0900
# Minibatch loss at step 11500: 0.555620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.4%
# finish : 2016-11-29T16:02:02+0900
# Minibatch loss at step 12000: 0.881583
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.0%
# finish : 2016-11-29T16:02:51+0900
# Minibatch loss at step 12500: 0.685685
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 94.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.9%
# finish : 2016-11-29T16:03:40+0900
# Minibatch loss at step 13000: 0.888955
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.0%
# finish : 2016-11-29T16:04:28+0900
# Minibatch loss at step 13500: 0.652751
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.4%
# finish : 2016-11-29T16:05:17+0900
# Minibatch loss at step 14000: 1.640996
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 89.1%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.7%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# finish : 2016-11-29T16:06:05+0900
# Minibatch loss at step 14500: 0.833326
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.1%
# Minibatch accuracy_digit_3: 95.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# finish : 2016-11-29T16:06:55+0900
# Minibatch loss at step 15000: 0.420281
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 97.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.6%
# finish : 2016-11-29T16:07:45+0900
# Minibatch loss at step 15500: 0.542035
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# finish : 2016-11-29T16:08:35+0900
# Minibatch loss at step 16000: 0.451278
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.0%
# finish : 2016-11-29T16:09:23+0900
# Minibatch loss at step 16500: 0.493946
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# finish : 2016-11-29T16:10:12+0900
# Minibatch loss at step 17000: 0.653808
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 97.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.4%
# finish : 2016-11-29T16:11:01+0900
# Minibatch loss at step 17500: 0.795585
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# finish : 2016-11-29T16:11:51+0900
# Minibatch loss at step 18000: 0.594916
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.3%
# finish : 2016-11-29T16:12:40+0900
# Minibatch loss at step 18500: 0.514094
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 95.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.7%
# finish : 2016-11-29T16:13:29+0900
# Minibatch loss at step 19000: 0.251568
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# finish : 2016-11-29T16:14:19+0900
# Minibatch loss at step 19500: 0.295686
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# finish : 2016-11-29T16:15:08+0900
# Minibatch loss at step 20000: 0.599613
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 97.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.1%
# finish : 2016-11-29T16:15:57+0900
# Minibatch loss at step 20500: 0.564357
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 95.1%
# Minibatch accuracy_digit_4: 75.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# finish : 2016-11-29T16:16:46+0900
# Minibatch loss at step 21000: 0.409873
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.2%
# finish : 2016-11-29T16:17:35+0900
# Minibatch loss at step 21500: 0.641053
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.9%
# finish : 2016-11-29T16:18:24+0900
# Minibatch loss at step 22000: 0.859756
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 95.1%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.7%
# finish : 2016-11-29T16:19:14+0900
# Minibatch loss at step 22500: 0.517950
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.2%
# finish : 2016-11-29T16:20:03+0900
# Minibatch loss at step 23000: 0.438074
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 91.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# finish : 2016-11-29T16:20:53+0900
# Minibatch loss at step 23500: 0.245304
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.6%
# finish : 2016-11-29T16:21:42+0900
# Minibatch loss at step 24000: 0.465323
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 95.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# finish : 2016-11-29T16:22:31+0900
# Minibatch loss at step 24500: 0.724145
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.2%
# finish : 2016-11-29T16:23:20+0900
# Minibatch loss at step 25000: 0.898146
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 94.8%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.6%
# finish : 2016-11-29T16:24:09+0900
# Minibatch loss at step 25500: 0.449722
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 94.6%
# Minibatch accuracy_digit_3: 97.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.2%
# finish : 2016-11-29T16:24:59+0900
# Minibatch loss at step 26000: 0.236549
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-29T16:25:48+0900
# Minibatch loss at step 26500: 0.431838
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 97.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# finish : 2016-11-29T16:26:38+0900
# Minibatch loss at step 27000: 0.826751
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-29T16:27:26+0900
# Minibatch loss at step 27500: 0.327178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-29T16:28:15+0900
# Minibatch loss at step 28000: 0.526375
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 94.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# finish : 2016-11-29T16:29:05+0900
# Minibatch loss at step 28500: 0.604224
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.9%
# finish : 2016-11-29T16:29:54+0900
# Minibatch loss at step 29000: 0.441856
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 97.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.5%
# finish : 2016-11-29T16:30:44+0900
# Minibatch loss at step 29500: 0.497309
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.8%
# finish : 2016-11-29T16:31:33+0900
# Minibatch loss at step 30000: 0.742788
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# finish : 2016-11-29T16:32:21+0900
# Minibatch loss at step 30500: 0.510706
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T16:33:11+0900
# Minibatch loss at step 31000: 0.379146
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-29T16:33:59+0900
# Minibatch loss at step 31500: 0.445008
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-29T16:34:48+0900
# Minibatch loss at step 32000: 0.540577
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.8%
# finish : 2016-11-29T16:35:37+0900
# Minibatch loss at step 32500: 0.460560
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.6%
# finish : 2016-11-29T16:36:26+0900
# Minibatch loss at step 33000: 0.214078
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.0%
# finish : 2016-11-29T16:37:15+0900
# Minibatch loss at step 33500: 0.250163
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.0%
# finish : 2016-11-29T16:38:04+0900
# Minibatch loss at step 34000: 0.292221
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-29T16:38:54+0900
# Minibatch loss at step 34500: 0.261173
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-29T16:39:43+0900
# Minibatch loss at step 35000: 1.328458
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# finish : 2016-11-29T16:40:32+0900
# Minibatch loss at step 35500: 0.711634
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 96.1%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# finish : 2016-11-29T16:41:21+0900
# Minibatch loss at step 36000: 0.486182
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# finish : 2016-11-29T16:42:10+0900
# Minibatch loss at step 36500: 0.296202
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-29T16:43:00+0900
# Minibatch loss at step 37000: 0.246219
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-29T16:43:50+0900
# Minibatch loss at step 37500: 0.168478
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T16:44:39+0900
# Minibatch loss at step 38000: 0.234939
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T16:45:29+0900
# Minibatch loss at step 38500: 0.803283
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-29T16:46:19+0900
# Minibatch loss at step 39000: 0.467532
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.8%
# finish : 2016-11-29T16:47:08+0900
# Minibatch loss at step 39500: 0.451292
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 95.1%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.0%
# finish : 2016-11-29T16:47:58+0900
# Minibatch loss at step 40000: 0.275628
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.4%
# finish : 2016-11-29T16:48:47+0900
# Minibatch loss at step 40500: 0.483166
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# finish : 2016-11-29T16:49:36+0900
# Minibatch loss at step 41000: 0.338292
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 97.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# finish : 2016-11-29T16:50:26+0900
# Minibatch loss at step 41500: 0.203043
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T16:51:15+0900
# Minibatch loss at step 42000: 0.485767
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-29T16:52:04+0900
# Minibatch loss at step 42500: 0.316833
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.0%
# finish : 2016-11-29T16:52:54+0900
# Minibatch loss at step 43000: 0.359183
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-29T16:53:43+0900
# Minibatch loss at step 43500: 0.182195
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T16:54:32+0900
# Minibatch loss at step 44000: 0.207013
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-29T16:55:22+0900
# Minibatch loss at step 44500: 0.170989
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-11-29T16:56:11+0900
# Minibatch loss at step 45000: 0.206071
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-29T16:57:00+0900
# Minibatch loss at step 45500: 0.522851
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.8%
# finish : 2016-11-29T16:57:50+0900
# Minibatch loss at step 46000: 0.400635
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.3%
# finish : 2016-11-29T16:58:39+0900
# Minibatch loss at step 46500: 0.291466
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T16:59:28+0900
# Minibatch loss at step 47000: 0.181089
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-11-29T17:00:17+0900
# Minibatch loss at step 47500: 0.170783
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.6%
# finish : 2016-11-29T17:01:05+0900
# Minibatch loss at step 48000: 0.190565
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-11-29T17:01:55+0900
# Minibatch loss at step 48500: 0.154997
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T17:02:44+0900
# Minibatch loss at step 49000: 0.292797
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.2%
# finish : 2016-11-29T17:03:34+0900
# Minibatch loss at step 49500: 0.260607
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-29T17:04:23+0900
# Minibatch loss at step 50000: 0.197918
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T17:05:13+0900
# Minibatch loss at step 50500: 0.394215
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-29T17:06:02+0900
# Minibatch loss at step 51000: 0.171605
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.9%
# finish : 2016-11-29T17:06:52+0900
# Minibatch loss at step 51500: 0.166503
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-11-29T17:07:42+0900
# Minibatch loss at step 52000: 0.144950
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T17:08:32+0900
# Minibatch loss at step 52500: 0.357250
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.4%
# finish : 2016-11-29T17:09:22+0900
# Minibatch loss at step 53000: 0.265042
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.8%
# finish : 2016-11-29T17:10:12+0900
# Minibatch loss at step 53500: 0.141349
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T17:11:01+0900
# Minibatch loss at step 54000: 0.197987
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.8%
# finish : 2016-11-29T17:11:49+0900
# Minibatch loss at step 54500: 0.159426
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-29T17:12:38+0900
# Minibatch loss at step 55000: 0.179073
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T17:13:27+0900
# Minibatch loss at step 55500: 0.367200
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 95.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-29T17:14:17+0900
# Minibatch loss at step 56000: 0.169131
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T17:15:06+0900
# Minibatch loss at step 56500: 0.140586
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# finish : 2016-11-29T17:15:55+0900
# Minibatch loss at step 57000: 0.358738
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.4%
# finish : 2016-11-29T17:16:45+0900
# Minibatch loss at step 57500: 0.165038
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.9%
# finish : 2016-11-29T17:17:34+0900
# Minibatch loss at step 58000: 0.146046
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T17:18:23+0900
# Minibatch loss at step 58500: 0.435913
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-29T17:19:13+0900
# Minibatch loss at step 59000: 0.128948
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.8%
# finish : 2016-11-29T17:20:03+0900
# Minibatch loss at step 59500: 0.192039
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T17:20:52+0900
# Minibatch loss at step 60000: 0.210401
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.3%
# finish : 2016-11-29T17:21:42+0900
# Minibatch loss at step 60500: 0.148004
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T17:22:31+0900
# Minibatch loss at step 61000: 0.463426
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-29T17:23:20+0900
# Minibatch loss at step 61500: 0.117735
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T17:24:09+0900
# Minibatch loss at step 62000: 0.147290
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T17:24:58+0900
# Minibatch loss at step 62500: 0.137935
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T17:25:47+0900
# Minibatch loss at step 63000: 0.322537
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.8%
# finish : 2016-11-29T17:26:36+0900
# Minibatch loss at step 63500: 0.182806
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-29T17:27:27+0900
# Minibatch loss at step 64000: 0.161188
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T17:28:16+0900
# Minibatch loss at step 64500: 0.170451
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T17:29:05+0900
# Minibatch loss at step 65000: 0.190003
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-29T17:29:55+0900
# Minibatch loss at step 65500: 0.157442
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 90.1%
# finish : 2016-11-29T17:30:44+0900
# Minibatch loss at step 66000: 0.110273
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T17:31:33+0900
# Minibatch loss at step 66500: 0.248312
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T17:32:22+0900
# Minibatch loss at step 67000: 0.195910
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.5%
# finish : 2016-11-29T17:33:12+0900
# Minibatch loss at step 67500: 0.193754
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-11-29T17:34:02+0900
# Minibatch loss at step 68000: 0.167382
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.5%
# finish : 2016-11-29T17:34:50+0900
# Minibatch loss at step 68500: 0.136324
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T17:35:40+0900
# Minibatch loss at step 69000: 0.164817
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T17:36:29+0900
# Minibatch loss at step 69500: 0.121084
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-29T17:37:18+0900
# Minibatch loss at step 70000: 0.211600
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T17:38:08+0900
# Minibatch loss at step 70500: 0.130533
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-11-29T17:38:58+0900
# Minibatch loss at step 71000: 0.119406
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T17:39:49+0900
# Minibatch loss at step 71500: 0.139007
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# ...
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T17:48:52+0900
# Minibatch loss at step 77000: 0.153583
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-29T17:49:42+0900
# Minibatch loss at step 77500: 0.125136
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T17:50:32+0900
# Minibatch loss at step 78000: 0.137620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-29T17:51:21+0900
# Minibatch loss at step 78500: 0.125635
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T17:52:11+0900
# Minibatch loss at step 79000: 0.196608
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.8%
# finish : 2016-11-29T17:53:00+0900
# Minibatch loss at step 79500: 0.115258
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T17:53:49+0900
# Minibatch loss at step 80000: 0.138698
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.8%
# finish : 2016-11-29T17:54:38+0900
# Minibatch loss at step 80500: 0.222025
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.5%
# finish : 2016-11-29T17:55:28+0900
# Minibatch loss at step 81000: 0.194894
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.7%
# finish : 2016-11-29T17:56:18+0900
# Minibatch loss at step 81500: 0.110872
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T17:57:07+0900
# Minibatch loss at step 82000: 0.108469
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T17:57:56+0900
# Minibatch loss at step 82500: 0.104957
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T17:58:46+0900
# Minibatch loss at step 83000: 0.100816
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T17:59:35+0900
# Minibatch loss at step 83500: 0.109586
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T18:00:24+0900
# Minibatch loss at step 84000: 0.143621
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T18:01:14+0900
# Minibatch loss at step 84500: 0.132325
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-29T18:02:03+0900
# Minibatch loss at step 85000: 0.181473
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 85.7%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T18:02:53+0900
# Minibatch loss at step 85500: 0.134675
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.6%
# finish : 2016-11-29T18:03:42+0900
# Minibatch loss at step 86000: 0.130834
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T18:04:32+0900
# Minibatch loss at step 86500: 0.111681
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T18:05:21+0900
# Minibatch loss at step 87000: 0.108435
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T18:06:10+0900
# Minibatch loss at step 87500: 0.154657
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T18:07:00+0900
# Minibatch loss at step 88000: 0.115226
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T18:07:50+0900
# Minibatch loss at step 88500: 0.098427
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T18:08:40+0900
# Minibatch loss at step 89000: 0.135682
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.6%
# finish : 2016-11-29T18:09:30+0900
# Minibatch loss at step 89500: 0.176445
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T18:10:19+0900
# Minibatch loss at step 90000: 0.130243
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T18:11:08+0900
# Minibatch loss at step 90500: 0.094008
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-29T18:11:58+0900
# Minibatch loss at step 91000: 0.125830
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T18:12:47+0900
# Minibatch loss at step 91500: 0.110499
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T18:13:37+0900
# Minibatch loss at step 92000: 0.095797
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T18:14:27+0900
# Minibatch loss at step 92500: 0.116693
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T18:15:16+0900
# Minibatch loss at step 93000: 0.096144
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-29T18:16:06+0900
# Minibatch loss at step 93500: 0.120721
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T18:16:56+0900
# Minibatch loss at step 94000: 0.123660
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T18:17:45+0900
# Minibatch loss at step 94500: 0.157738
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-29T18:18:34+0900
# Minibatch loss at step 95000: 0.186004
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.4%
# finish : 2016-11-29T18:19:24+0900
# Minibatch loss at step 95500: 0.102945
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T18:20:13+0900
# Minibatch loss at step 96000: 0.091205
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T18:21:03+0900
# Minibatch loss at step 96500: 0.208924
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T18:21:52+0900
# Minibatch loss at step 97000: 0.088050
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-29T18:22:42+0900
# Minibatch loss at step 97500: 0.091448
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-29T18:23:31+0900
# Minibatch loss at step 98000: 0.107784
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-11-29T18:24:21+0900
# Minibatch loss at step 98500: 0.100322
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-11-29T18:25:11+0900
# Minibatch loss at step 99000: 0.080923
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T18:26:00+0900
# Minibatch loss at step 99500: 0.099064
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-29T18:26:49+0900
# Minibatch loss at step 100000: 0.086014
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-29T18:27:38+0900
# Test accuracy: 89.5%
# finish : 2016-11-29T18:27:41+0900

# %%
# Minibatch loss at step 100000: 0.432907
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-30T00:33:23+0900
# Test accuracy: 89.8%
# finish : 2016-11-30T00:33:27+0900
# more complex conv net
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,128,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 19.339659
# Minibatch accuracy_length: 3.1%
# Minibatch accuracy_digit_0: 9.4%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 3.2%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.2%
# finish : 2016-11-29T21:10:51+0900
# Minibatch loss at step 500: 9.754180
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-29T21:11:48+0900
# Minibatch loss at step 1000: 8.240347
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-29T21:12:44+0900
# Minibatch loss at step 1500: 9.004229
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:13:41+0900
# Minibatch loss at step 2000: 9.671268
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:14:37+0900
# Minibatch loss at step 2500: 9.167704
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:15:32+0900
# Minibatch loss at step 3000: 8.352421
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:16:28+0900
# Minibatch loss at step 3500: 8.896187
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:17:24+0900
# Minibatch loss at step 4000: 8.051915
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:18:19+0900
# Minibatch loss at step 4500: 8.753716
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 35.7%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:19:15+0900
# Minibatch loss at step 5000: 8.506031
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 31.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:20:10+0900
# Minibatch loss at step 5500: 7.512980
# Minibatch accuracy_length: 68.8%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:21:06+0900
# Minibatch loss at step 6000: 7.911807
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 56.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:22:01+0900
# Minibatch loss at step 6500: 8.444895
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:22:57+0900
# Minibatch loss at step 7000: 7.845359
# Minibatch accuracy_length: 18.8%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 69.2%
# Minibatch accuracy_digit_3: 66.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:23:53+0900
# Minibatch loss at step 7500: 6.462686
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-29T21:24:49+0900
# Minibatch loss at step 8000: 7.288937
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 70.4%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-29T21:25:45+0900
# Minibatch loss at step 8500: 7.374136
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 64.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:26:41+0900
# Minibatch loss at step 9000: 7.883081
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 34.4%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-29T21:27:37+0900
# Minibatch loss at step 9500: 7.529088
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 34.5%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-29T21:28:33+0900
# Minibatch loss at step 10000: 6.715005
# Minibatch accuracy_length: 75.0%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 58.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 1.1%
# finish : 2016-11-29T21:29:29+0900
# Minibatch loss at step 10500: 6.941263
# Minibatch accuracy_length: 81.2%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 1.7%
# finish : 2016-11-29T21:30:25+0900
# Minibatch loss at step 11000: 5.757666
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 68.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 2.3%
# finish : 2016-11-29T21:31:21+0900
# Minibatch loss at step 11500: 6.903762
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 32.3%
# Minibatch accuracy_digit_3: 92.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 2.4%
# finish : 2016-11-29T21:32:17+0900
# Minibatch loss at step 12000: 5.335814
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 3.2%
# finish : 2016-11-29T21:33:13+0900
# Minibatch loss at step 12500: 5.280363
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 55.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 4.0%
# finish : 2016-11-29T21:34:10+0900
# Minibatch loss at step 13000: 4.995878
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 37.5%
# Minibatch accuracy_digit_2: 71.9%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 12.5%
# Validation accuracy: 6.2%
# finish : 2016-11-29T21:35:06+0900
# Minibatch loss at step 13500: 5.156514
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 50.0%
# Minibatch accuracy_digit_1: 37.5%
# Minibatch accuracy_digit_2: 55.2%
# Minibatch accuracy_digit_3: 76.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 6.5%
# finish : 2016-11-29T21:36:03+0900
# Minibatch loss at step 14000: 4.032044
# Minibatch accuracy_length: 81.2%
# Minibatch accuracy_digit_0: 59.4%
# Minibatch accuracy_digit_1: 46.9%
# Minibatch accuracy_digit_2: 60.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 12.0%
# finish : 2016-11-29T21:37:00+0900
# Minibatch loss at step 14500: 3.671033
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 43.8%
# Minibatch accuracy_digit_2: 75.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 21.9%
# Validation accuracy: 19.3%
# finish : 2016-11-29T21:37:57+0900
# Minibatch loss at step 15000: 2.231455
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 24.8%
# finish : 2016-11-29T21:38:55+0900
# Minibatch loss at step 15500: 3.583707
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 50.0%
# Minibatch accuracy_digit_2: 71.0%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 31.2%
# Validation accuracy: 30.3%
# finish : 2016-11-29T21:39:53+0900
# Minibatch loss at step 16000: 2.006336
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 38.2%
# finish : 2016-11-29T21:40:50+0900
# Minibatch loss at step 16500: 2.322678
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 43.8%
# Validation accuracy: 48.6%
# finish : 2016-11-29T21:41:48+0900
# Minibatch loss at step 17000: 2.782766
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 78.1%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 51.1%
# finish : 2016-11-29T21:42:46+0900
# Minibatch loss at step 17500: 2.507368
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 60.5%
# finish : 2016-11-29T21:43:45+0900
# Minibatch loss at step 18000: 1.213764
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 82.8%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 63.1%
# finish : 2016-11-29T21:44:44+0900
# Minibatch loss at step 18500: 2.196845
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 78.6%
# Minibatch accuracy_digit_3: 77.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 66.6%
# finish : 2016-11-29T21:45:44+0900
# Minibatch loss at step 19000: 1.209973
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 67.0%
# finish : 2016-11-29T21:46:42+0900
# Minibatch loss at step 19500: 1.809536
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.1%
# finish : 2016-11-29T21:47:42+0900
# Minibatch loss at step 20000: 1.635615
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 76.7%
# Minibatch accuracy_digit_3: 91.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 71.2%
# finish : 2016-11-29T21:48:41+0900
# Minibatch loss at step 20500: 1.775301
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 70.3%
# finish : 2016-11-29T21:49:40+0900
# Minibatch loss at step 21000: 1.061966
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.2%
# finish : 2016-11-29T21:50:40+0900
# Minibatch loss at step 21500: 1.136301
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 85.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.1%
# finish : 2016-11-29T21:51:39+0900
# Minibatch loss at step 22000: 1.741231
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.7%
# finish : 2016-11-29T21:52:38+0900
# Minibatch loss at step 22500: 0.860713
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 75.9%
# finish : 2016-11-29T21:53:37+0900
# Minibatch loss at step 23000: 1.106962
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 77.3%
# finish : 2016-11-29T21:54:36+0900
# Minibatch loss at step 23500: 1.358601
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 79.0%
# finish : 2016-11-29T21:55:34+0900
# Minibatch loss at step 24000: 0.965057
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.9%
# finish : 2016-11-29T21:56:33+0900
# Minibatch loss at step 24500: 0.604600
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.5%
# finish : 2016-11-29T21:57:32+0900
# Minibatch loss at step 25000: 0.679018
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# finish : 2016-11-29T21:58:31+0900
# Minibatch loss at step 25500: 0.660117
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# finish : 2016-11-29T21:59:31+0900
# Minibatch loss at step 26000: 0.597540
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# finish : 2016-11-29T22:00:30+0900
# Minibatch loss at step 26500: 1.032420
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 82.3%
# finish : 2016-11-29T22:01:29+0900
# Minibatch loss at step 27000: 1.388521
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.2%
# finish : 2016-11-29T22:02:28+0900
# Minibatch loss at step 27500: 0.526591
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.2%
# finish : 2016-11-29T22:03:28+0900
# Minibatch loss at step 28000: 1.327466
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 83.5%
# finish : 2016-11-29T22:04:28+0900
# Minibatch loss at step 28500: 0.840783
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# finish : 2016-11-29T22:05:27+0900
# Minibatch loss at step 29000: 0.653469
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.2%
# finish : 2016-11-29T22:06:25+0900
# Minibatch loss at step 29500: 0.787460
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.0%
# finish : 2016-11-29T22:07:24+0900
# Minibatch loss at step 30000: 0.764866
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.7%
# finish : 2016-11-29T22:08:24+0900
# Minibatch loss at step 30500: 0.704171
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.1%
# finish : 2016-11-29T22:09:24+0900
# Minibatch loss at step 31000: 1.103516
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.1%
# finish : 2016-11-29T22:10:23+0900
# Minibatch loss at step 31500: 0.545791
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.6%
# finish : 2016-11-29T22:11:23+0900
# Minibatch loss at step 32000: 0.489093
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# finish : 2016-11-29T22:12:22+0900
# Minibatch loss at step 32500: 0.420383
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# finish : 2016-11-29T22:13:22+0900
# Minibatch loss at step 33000: 0.350858
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# finish : 2016-11-29T22:14:21+0900
# Minibatch loss at step 33500: 0.552848
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# finish : 2016-11-29T22:15:21+0900
# Minibatch loss at step 34000: 0.708286
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.9%
# finish : 2016-11-29T22:16:21+0900
# Minibatch loss at step 34500: 1.089324
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.5%
# finish : 2016-11-29T22:17:21+0900
# Minibatch loss at step 35000: 1.259049
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.1%
# finish : 2016-11-29T22:18:21+0900
# Minibatch loss at step 35500: 1.264195
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# finish : 2016-11-29T22:19:21+0900
# Minibatch loss at step 36000: 0.649349
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.3%
# finish : 2016-11-29T22:20:21+0900
# Minibatch loss at step 36500: 1.946642
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# finish : 2016-11-29T22:21:21+0900
# Minibatch loss at step 37000: 0.170848
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.8%
# finish : 2016-11-29T22:22:21+0900
# Minibatch loss at step 37500: 0.572046
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# finish : 2016-11-29T22:23:22+0900
# Minibatch loss at step 38000: 1.326270
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-11-29T22:24:22+0900
# Minibatch loss at step 38500: 0.474693
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# finish : 2016-11-29T22:25:22+0900
# Minibatch loss at step 39000: 0.745334
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# finish : 2016-11-29T22:26:22+0900
# Minibatch loss at step 39500: 0.661246
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# finish : 2016-11-29T22:27:23+0900
# Minibatch loss at step 40000: 0.465969
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# finish : 2016-11-29T22:28:25+0900
# Minibatch loss at step 40500: 0.534963
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# finish : 2016-11-29T22:29:25+0900
# Minibatch loss at step 41000: 0.427483
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# finish : 2016-11-29T22:30:26+0900
# Minibatch loss at step 41500: 0.197595
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.3%
# finish : 2016-11-29T22:31:27+0900
# Minibatch loss at step 42000: 0.450302
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-11-29T22:32:28+0900
# Minibatch loss at step 42500: 0.945023
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.7%
# finish : 2016-11-29T22:33:29+0900
# Minibatch loss at step 43000: 0.882640
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# finish : 2016-11-29T22:34:31+0900
# Minibatch loss at step 43500: 0.482542
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# finish : 2016-11-29T22:35:32+0900
# Minibatch loss at step 44000: 1.028425
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# finish : 2016-11-29T22:36:32+0900
# Minibatch loss at step 44500: 0.342388
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# finish : 2016-11-29T22:37:34+0900
# Minibatch loss at step 45000: 0.610913
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# finish : 2016-11-29T22:38:35+0900
# Minibatch loss at step 45500: 0.241458
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-29T22:39:36+0900
# Minibatch loss at step 46000: 0.387849
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# finish : 2016-11-29T22:40:37+0900
# Minibatch loss at step 46500: 0.159555
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-29T22:41:38+0900
# Minibatch loss at step 47000: 0.467215
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-11-29T22:42:39+0900
# Minibatch loss at step 47500: 0.136978
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-11-29T22:43:41+0900
# Minibatch loss at step 48000: 0.991173
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# finish : 2016-11-29T22:44:43+0900
# Minibatch loss at step 48500: 0.444263
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.9%
# finish : 2016-11-29T22:45:44+0900
# Minibatch loss at step 49000: 0.251262
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-29T22:46:46+0900
# Minibatch loss at step 49500: 0.719330
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.5%
# finish : 2016-11-29T22:47:48+0900
# Minibatch loss at step 50000: 0.275123
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# finish : 2016-11-29T22:48:49+0900
# Minibatch loss at step 50500: 0.447870
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# finish : 2016-11-29T22:49:51+0900
# Minibatch loss at step 51000: 0.242080
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# finish : 2016-11-29T22:50:52+0900
# Minibatch loss at step 51500: 0.229082
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-29T22:51:54+0900
# Minibatch loss at step 52000: 0.101359
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T22:52:56+0900
# Minibatch loss at step 52500: 0.307824
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-29T22:53:57+0900
# Minibatch loss at step 53000: 0.207380
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T22:54:59+0900
# Minibatch loss at step 53500: 0.163441
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-29T22:56:01+0900
# Minibatch loss at step 54000: 0.290485
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-29T22:57:02+0900
# Minibatch loss at step 54500: 0.697630
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# finish : 2016-11-29T22:58:04+0900
# Minibatch loss at step 55000: 0.823743
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-29T22:59:07+0900
# Minibatch loss at step 55500: 0.163671
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-29T23:00:09+0900
# Minibatch loss at step 56000: 0.279818
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-11-29T23:01:11+0900
# Minibatch loss at step 56500: 0.727474
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.4%
# finish : 2016-11-29T23:02:13+0900
# Minibatch loss at step 57000: 0.609807
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-29T23:03:15+0900
# Minibatch loss at step 57500: 0.455732
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-29T23:04:18+0900
# Minibatch loss at step 58000: 1.053171
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.8%
# finish : 2016-11-29T23:05:20+0900
# Minibatch loss at step 58500: 0.563533
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-29T23:06:23+0900
# Minibatch loss at step 59000: 0.492999
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# finish : 2016-11-29T23:07:25+0900
# Minibatch loss at step 59500: 0.198983
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-29T23:08:28+0900
# Minibatch loss at step 60000: 0.262653
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# finish : 2016-11-29T23:09:30+0900
# Minibatch loss at step 60500: 0.182844
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-29T23:10:33+0900
# Minibatch loss at step 61000: 0.184542
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-29T23:11:35+0900
# Minibatch loss at step 61500: 0.520721
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-29T23:12:38+0900
# Minibatch loss at step 62000: 0.132405
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-29T23:13:41+0900
# Minibatch loss at step 62500: 0.259282
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T23:14:44+0900
# Minibatch loss at step 63000: 0.963334
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 77.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.5%
# finish : 2016-11-29T23:15:47+0900
# Minibatch loss at step 63500: 0.576113
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# finish : 2016-11-29T23:16:49+0900
# Minibatch loss at step 64000: 0.749178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 91.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.8%
# finish : 2016-11-29T23:17:52+0900
# Minibatch loss at step 64500: 0.232704
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T23:18:54+0900
# Minibatch loss at step 65000: 0.747543
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-11-29T23:19:57+0900
# Minibatch loss at step 65500: 0.176900
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-29T23:21:00+0900
# Minibatch loss at step 66000: 0.938748
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-29T23:22:02+0900
# Minibatch loss at step 66500: 0.181912
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-29T23:23:05+0900
# Minibatch loss at step 67000: 0.534723
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# finish : 2016-11-29T23:24:08+0900
# Minibatch loss at step 67500: 0.215574
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-29T23:25:11+0900
# Minibatch loss at step 68000: 0.222906
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# finish : 2016-11-29T23:26:13+0900
# Minibatch loss at step 68500: 0.291138
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-29T23:27:16+0900
# Minibatch loss at step 69000: 0.442126
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# finish : 2016-11-29T23:28:19+0900
# Minibatch loss at step 69500: 0.364215
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-29T23:29:22+0900
# Minibatch loss at step 70000: 0.701555
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# finish : 2016-11-29T23:30:25+0900
# Minibatch loss at step 70500: 0.487158
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-29T23:31:28+0900
# Minibatch loss at step 71000: 0.645362
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# finish : 2016-11-29T23:32:31+0900
# Minibatch loss at step 71500: 0.139904
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# ...
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-29T23:44:02+0900
# Minibatch loss at step 77000: 0.645749
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# finish : 2016-11-29T23:45:05+0900
# Minibatch loss at step 77500: 0.292041
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-29T23:46:09+0900
# Minibatch loss at step 78000: 0.268462
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-29T23:47:12+0900
# Minibatch loss at step 78500: 0.659497
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# finish : 2016-11-29T23:48:14+0900
# Minibatch loss at step 79000: 0.326144
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# finish : 2016-11-29T23:49:17+0900
# Minibatch loss at step 79500: 0.192270
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# finish : 2016-11-29T23:50:20+0900
# Minibatch loss at step 80000: 0.331521
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# finish : 2016-11-29T23:51:23+0900
# Minibatch loss at step 80500: 0.158460
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-29T23:52:26+0900
# Minibatch loss at step 81000: 0.173021
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-29T23:53:29+0900
# Minibatch loss at step 81500: 0.120638
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-29T23:54:32+0900
# Minibatch loss at step 82000: 0.141793
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.9%
# finish : 2016-11-29T23:55:34+0900
# Minibatch loss at step 82500: 0.109420
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-29T23:56:37+0900
# Minibatch loss at step 83000: 0.637420
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# finish : 2016-11-29T23:57:40+0900
# Minibatch loss at step 83500: 0.088144
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-29T23:58:44+0900
# Minibatch loss at step 84000: 0.345676
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# finish : 2016-11-29T23:59:46+0900
# Minibatch loss at step 84500: 0.178129
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-30T00:00:49+0900
# Minibatch loss at step 85000: 0.373413
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# finish : 2016-11-30T00:01:52+0900
# Minibatch loss at step 85500: 0.119105
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-30T00:02:55+0900
# Minibatch loss at step 86000: 0.186333
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-30T00:03:59+0900
# Minibatch loss at step 86500: 0.382617
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.6%
# finish : 2016-11-30T00:05:02+0900
# Minibatch loss at step 87000: 0.176900
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-30T00:06:05+0900
# Minibatch loss at step 87500: 0.136846
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# finish : 2016-11-30T00:07:08+0900
# Minibatch loss at step 88000: 0.108787
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-30T00:08:11+0900
# Minibatch loss at step 88500: 0.117748
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-30T00:09:13+0900
# Minibatch loss at step 89000: 0.137034
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.1%
# finish : 2016-11-30T00:10:16+0900
# Minibatch loss at step 89500: 0.244735
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# finish : 2016-11-30T00:11:19+0900
# Minibatch loss at step 90000: 0.097456
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-30T00:12:23+0900
# Minibatch loss at step 90500: 0.476326
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-30T00:13:26+0900
# Minibatch loss at step 91000: 0.305275
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# finish : 2016-11-30T00:14:29+0900
# Minibatch loss at step 91500: 0.556943
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# finish : 2016-11-30T00:15:32+0900
# Minibatch loss at step 92000: 0.502905
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-30T00:16:36+0900
# Minibatch loss at step 92500: 0.111216
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-30T00:17:39+0900
# Minibatch loss at step 93000: 0.122183
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-30T00:18:42+0900
# Minibatch loss at step 93500: 0.812712
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# finish : 2016-11-30T00:19:44+0900
# Minibatch loss at step 94000: 0.539164
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# finish : 2016-11-30T00:20:47+0900
# Minibatch loss at step 94500: 0.118979
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-30T00:21:49+0900
# Minibatch loss at step 95000: 0.159196
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-30T00:22:53+0900
# Minibatch loss at step 95500: 0.158532
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-30T00:23:56+0900
# Minibatch loss at step 96000: 0.103350
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-30T00:24:58+0900
# Minibatch loss at step 96500: 0.161552
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.7%
# finish : 2016-11-30T00:26:01+0900
# Minibatch loss at step 97000: 0.134677
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.8%
# finish : 2016-11-30T00:27:05+0900
# Minibatch loss at step 97500: 0.163837
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-30T00:28:07+0900
# Minibatch loss at step 98000: 0.393289
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.4%
# finish : 2016-11-30T00:29:11+0900
# Minibatch loss at step 98500: 0.279693
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-30T00:30:14+0900
# Minibatch loss at step 99000: 0.184063
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-30T00:31:17+0900
# Minibatch loss at step 99500: 0.187697
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-30T00:32:20+0900
# Minibatch loss at step 100000: 0.432907
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-30T00:33:23+0900
# Test accuracy: 89.8%
# finish : 2016-11-30T00:33:27+0900

# %%
# Minibatch loss at step 100000: 0.437522
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-30T03:52:08+0900
# Test accuracy: 89.0%
# finish : 2016-11-30T03:52:12+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,128,128,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 18.294018
# Minibatch accuracy_length: 46.9%
# Minibatch accuracy_digit_0: 6.2%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 0.0%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-30T00:33:39+0900
# Minibatch loss at step 500: 9.840426
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T00:34:37+0900
# Minibatch loss at step 1000: 8.231583
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-30T00:35:33+0900
# Minibatch loss at step 1500: 8.992169
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:36:30+0900
# Minibatch loss at step 2000: 9.665369
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:37:26+0900
# Minibatch loss at step 2500: 9.165138
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:38:23+0900
# Minibatch loss at step 3000: 8.352623
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:39:19+0900
# Minibatch loss at step 3500: 8.900310
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:40:15+0900
# Minibatch loss at step 4000: 8.055553
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:41:11+0900
# Minibatch loss at step 4500: 8.750436
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 35.7%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:42:07+0900
# Minibatch loss at step 5000: 8.507767
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 31.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:43:04+0900
# Minibatch loss at step 5500: 7.512950
# Minibatch accuracy_length: 68.8%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:44:00+0900
# Minibatch loss at step 6000: 7.908237
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 56.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:44:56+0900
# Minibatch loss at step 6500: 8.442066
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:45:52+0900
# Minibatch loss at step 7000: 7.838640
# Minibatch accuracy_length: 18.8%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 69.2%
# Minibatch accuracy_digit_3: 66.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:46:49+0900
# Minibatch loss at step 7500: 6.455317
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-30T00:47:45+0900
# Minibatch loss at step 8000: 7.286482
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 70.4%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T00:48:42+0900
# Minibatch loss at step 8500: 7.388459
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 64.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:49:39+0900
# Minibatch loss at step 9000: 7.902486
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 34.4%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:50:36+0900
# Minibatch loss at step 9500: 7.801384
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 34.5%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:51:33+0900
# Minibatch loss at step 10000: 7.278113
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 58.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:52:29+0900
# Minibatch loss at step 10500: 7.469469
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:53:25+0900
# Minibatch loss at step 11000: 6.881602
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 68.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:54:22+0900
# Minibatch loss at step 11500: 7.977912
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 32.3%
# Minibatch accuracy_digit_3: 92.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:55:19+0900
# Minibatch loss at step 12000: 7.374450
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 43.3%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:56:15+0900
# Minibatch loss at step 12500: 7.229524
# Minibatch accuracy_length: 50.0%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 58.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:57:12+0900
# Minibatch loss at step 13000: 7.178948
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 65.6%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:58:08+0900
# Minibatch loss at step 13500: 8.068736
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 51.7%
# Minibatch accuracy_digit_3: 76.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T00:59:05+0900
# Minibatch loss at step 14000: 6.927450
# Minibatch accuracy_length: 31.2%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 37.5%
# Minibatch accuracy_digit_2: 60.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:00:02+0900
# Minibatch loss at step 14500: 6.829921
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 69.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T01:00:58+0900
# Minibatch loss at step 15000: 6.631725
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 68.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T01:01:55+0900
# Minibatch loss at step 15500: 7.427223
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 58.1%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:02:51+0900
# Minibatch loss at step 16000: 6.708873
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 61.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:03:47+0900
# Minibatch loss at step 16500: 7.575738
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 46.9%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:04:44+0900
# Minibatch loss at step 17000: 7.811557
# Minibatch accuracy_length: 46.9%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 46.9%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:05:40+0900
# Minibatch loss at step 17500: 7.825987
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 48.4%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:06:37+0900
# Minibatch loss at step 18000: 7.601236
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 37.9%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:07:34+0900
# Minibatch loss at step 18500: 8.728776
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 28.6%
# Minibatch accuracy_digit_3: 77.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:08:30+0900
# Minibatch loss at step 19000: 7.330348
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 3.1%
# Minibatch accuracy_digit_2: 48.4%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:09:27+0900
# Minibatch loss at step 19500: 7.207605
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 48.4%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:10:24+0900
# Minibatch loss at step 20000: 8.085003
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 26.7%
# Minibatch accuracy_digit_3: 87.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:11:21+0900
# Minibatch loss at step 20500: 7.851295
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 76.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:12:17+0900
# Minibatch loss at step 21000: 6.552379
# Minibatch accuracy_length: 25.0%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 71.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:13:14+0900
# Minibatch loss at step 21500: 6.375220
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 71.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 0.7%
# finish : 2016-11-30T01:14:11+0900
# Minibatch loss at step 22000: 6.559989
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 74.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T01:15:07+0900
# Minibatch loss at step 22500: 8.036209
# Minibatch accuracy_length: 50.0%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 40.0%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:16:04+0900
# Minibatch loss at step 23000: 6.894542
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:17:01+0900
# Minibatch loss at step 23500: 8.135470
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 35.5%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:17:57+0900
# Minibatch loss at step 24000: 7.688664
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 34.5%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:18:54+0900
# Minibatch loss at step 24500: 7.211137
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T01:19:51+0900
# Minibatch loss at step 25000: 7.191964
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.8%
# finish : 2016-11-30T01:20:47+0900
# Minibatch loss at step 25500: 7.083753
# Minibatch accuracy_length: 78.1%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 40.6%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.9%
# finish : 2016-11-30T01:21:44+0900
# Minibatch loss at step 26000: 5.619460
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 59.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 1.6%
# finish : 2016-11-30T01:22:40+0900
# Minibatch loss at step 26500: 6.176765
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 40.0%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 1.5%
# finish : 2016-11-30T01:23:37+0900
# Minibatch loss at step 27000: 7.100890
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 27.6%
# Minibatch accuracy_digit_3: 84.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 1.9%
# finish : 2016-11-30T01:24:34+0900
# Minibatch loss at step 27500: 5.710259
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 40.6%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 2.9%
# finish : 2016-11-30T01:25:31+0900
# Minibatch loss at step 28000: 5.554379
# Minibatch accuracy_length: 75.0%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 55.6%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 3.0%
# finish : 2016-11-30T01:26:29+0900
# Minibatch loss at step 28500: 3.838382
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 69.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 4.8%
# finish : 2016-11-30T01:27:27+0900
# Minibatch loss at step 29000: 4.107425
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 62.5%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 68.0%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 21.9%
# Validation accuracy: 6.7%
# finish : 2016-11-30T01:28:24+0900
# Minibatch loss at step 29500: 4.448817
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 31.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.7%
# finish : 2016-11-30T01:29:22+0900
# Minibatch loss at step 30000: 4.074946
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 56.2%
# Minibatch accuracy_digit_2: 40.6%
# Minibatch accuracy_digit_3: 91.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 17.5%
# finish : 2016-11-30T01:30:21+0900
# Minibatch loss at step 30500: 3.397398
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 43.8%
# Minibatch accuracy_digit_2: 72.4%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 25.0%
# Validation accuracy: 26.5%
# finish : 2016-11-30T01:31:19+0900
# Minibatch loss at step 31000: 3.692968
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 43.8%
# Minibatch accuracy_digit_2: 55.2%
# Minibatch accuracy_digit_3: 84.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 28.1%
# Validation accuracy: 34.1%
# finish : 2016-11-30T01:32:17+0900
# Minibatch loss at step 31500: 3.285767
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 71.9%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 71.0%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 34.4%
# Validation accuracy: 45.8%
# finish : 2016-11-30T01:33:16+0900
# Minibatch loss at step 32000: 1.723471
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 51.8%
# finish : 2016-11-30T01:34:15+0900
# Minibatch loss at step 32500: 1.885657
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 53.3%
# finish : 2016-11-30T01:35:14+0900
# Minibatch loss at step 33000: 1.845103
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 61.3%
# finish : 2016-11-30T01:36:13+0900
# Minibatch loss at step 33500: 1.402338
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 64.4%
# finish : 2016-11-30T01:37:12+0900
# Minibatch loss at step 34000: 1.739673
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.6%
# finish : 2016-11-30T01:38:11+0900
# Minibatch loss at step 34500: 1.573149
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.7%
# finish : 2016-11-30T01:39:10+0900
# Minibatch loss at step 35000: 2.069407
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 80.8%
# Minibatch accuracy_digit_3: 72.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 68.0%
# finish : 2016-11-30T01:40:09+0900
# Minibatch loss at step 35500: 2.308916
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.7%
# finish : 2016-11-30T01:41:09+0900
# Minibatch loss at step 36000: 1.642029
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.2%
# finish : 2016-11-30T01:42:08+0900
# Minibatch loss at step 36500: 2.847574
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 73.4%
# finish : 2016-11-30T01:43:08+0900
# Minibatch loss at step 37000: 0.414559
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 76.1%
# finish : 2016-11-30T01:44:07+0900
# Minibatch loss at step 37500: 1.460708
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 82.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.8%
# finish : 2016-11-30T01:45:07+0900
# Minibatch loss at step 38000: 2.001846
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 78.2%
# finish : 2016-11-30T01:46:07+0900
# Minibatch loss at step 38500: 0.719385
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.3%
# finish : 2016-11-30T01:47:06+0900
# Minibatch loss at step 39000: 1.268388
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.8%
# finish : 2016-11-30T01:48:06+0900
# Minibatch loss at step 39500: 1.200335
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 85.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.5%
# finish : 2016-11-30T01:49:06+0900
# Minibatch loss at step 40000: 0.745511
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.0%
# finish : 2016-11-30T01:50:06+0900
# Minibatch loss at step 40500: 1.096405
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.0%
# finish : 2016-11-30T01:51:06+0900
# Minibatch loss at step 41000: 0.731484
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# finish : 2016-11-30T01:52:05+0900
# Minibatch loss at step 41500: 0.744821
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# finish : 2016-11-30T01:53:05+0900
# Minibatch loss at step 42000: 0.716525
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# finish : 2016-11-30T01:54:04+0900
# Minibatch loss at step 42500: 1.571294
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.4%
# finish : 2016-11-30T01:55:04+0900
# Minibatch loss at step 43000: 1.160511
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.6%
# finish : 2016-11-30T01:56:04+0900
# Minibatch loss at step 43500: 0.685826
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.4%
# finish : 2016-11-30T01:57:03+0900
# Minibatch loss at step 44000: 1.482349
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.7%
# finish : 2016-11-30T01:58:03+0900
# Minibatch loss at step 44500: 0.837272
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# finish : 2016-11-30T01:59:03+0900
# Minibatch loss at step 45000: 0.967124
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.1%
# finish : 2016-11-30T02:00:02+0900
# Minibatch loss at step 45500: 0.303337
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# finish : 2016-11-30T02:01:02+0900
# Minibatch loss at step 46000: 0.972815
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# finish : 2016-11-30T02:02:03+0900
# Minibatch loss at step 46500: 0.559952
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# finish : 2016-11-30T02:03:03+0900
# Minibatch loss at step 47000: 1.009161
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# finish : 2016-11-30T02:04:02+0900
# Minibatch loss at step 47500: 0.198338
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.7%
# finish : 2016-11-30T02:05:03+0900
# Minibatch loss at step 48000: 1.284562
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# finish : 2016-11-30T02:06:03+0900
# Minibatch loss at step 48500: 0.713277
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# finish : 2016-11-30T02:07:02+0900
# Minibatch loss at step 49000: 0.360087
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.3%
# finish : 2016-11-30T02:08:03+0900
# Minibatch loss at step 49500: 1.005009
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# finish : 2016-11-30T02:09:03+0900
# Minibatch loss at step 50000: 0.426989
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# finish : 2016-11-30T02:10:03+0900
# Minibatch loss at step 50500: 0.672182
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# finish : 2016-11-30T02:11:04+0900
# Minibatch loss at step 51000: 0.677507
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.4%
# finish : 2016-11-30T02:12:04+0900
# Minibatch loss at step 51500: 0.451477
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.1%
# finish : 2016-11-30T02:13:04+0900
# Minibatch loss at step 52000: 0.125260
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
# finish : 2016-11-30T02:14:04+0900
# Minibatch loss at step 52500: 0.562382
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.1%
# finish : 2016-11-30T02:15:05+0900
# Minibatch loss at step 53000: 0.275743
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.3%
# finish : 2016-11-30T02:16:05+0900
# Minibatch loss at step 53500: 0.333253
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# finish : 2016-11-30T02:17:06+0900
# Minibatch loss at step 54000: 0.321081
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# finish : 2016-11-30T02:18:06+0900
# Minibatch loss at step 54500: 1.009961
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.7%
# finish : 2016-11-30T02:19:07+0900
# Minibatch loss at step 55000: 0.950902
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# finish : 2016-11-30T02:20:07+0900
# Minibatch loss at step 55500: 0.255429
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# finish : 2016-11-30T02:21:08+0900
# Minibatch loss at step 56000: 0.404316
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 95.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# finish : 2016-11-30T02:22:09+0900
# Minibatch loss at step 56500: 0.992227
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# finish : 2016-11-30T02:23:09+0900
# Minibatch loss at step 57000: 0.955220
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.6%
# finish : 2016-11-30T02:24:10+0900
# Minibatch loss at step 57500: 0.882311
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# finish : 2016-11-30T02:25:11+0900
# Minibatch loss at step 58000: 1.357199
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.3%
# finish : 2016-11-30T02:26:12+0900
# Minibatch loss at step 58500: 0.597746
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# finish : 2016-11-30T02:27:12+0900
# Minibatch loss at step 59000: 0.600051
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.7%
# finish : 2016-11-30T02:28:14+0900
# Minibatch loss at step 59500: 0.282703
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# finish : 2016-11-30T02:29:14+0900
# Minibatch loss at step 60000: 0.501450
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# finish : 2016-11-30T02:30:15+0900
# Minibatch loss at step 60500: 0.275268
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# finish : 2016-11-30T02:31:16+0900
# Minibatch loss at step 61000: 0.186855
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.8%
# finish : 2016-11-30T02:32:18+0900
# Minibatch loss at step 61500: 0.520330
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# finish : 2016-11-30T02:33:19+0900
# Minibatch loss at step 62000: 0.282430
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.1%
# finish : 2016-11-30T02:34:20+0900
# Minibatch loss at step 62500: 1.022304
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.4%
# finish : 2016-11-30T02:35:21+0900
# Minibatch loss at step 63000: 1.034899
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# finish : 2016-11-30T02:36:22+0900
# Minibatch loss at step 63500: 0.837122
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 91.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# finish : 2016-11-30T02:37:23+0900
# Minibatch loss at step 64000: 0.772327
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 91.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# finish : 2016-11-30T02:38:25+0900
# Minibatch loss at step 64500: 0.202546
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# finish : 2016-11-30T02:39:26+0900
# Minibatch loss at step 65000: 1.046834
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.3%
# finish : 2016-11-30T02:40:27+0900
# Minibatch loss at step 65500: 0.167195
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# finish : 2016-11-30T02:41:27+0900
# Minibatch loss at step 66000: 1.209071
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# finish : 2016-11-30T02:42:28+0900
# Minibatch loss at step 66500: 0.307755
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-30T02:43:29+0900
# Minibatch loss at step 67000: 0.558753
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# finish : 2016-11-30T02:44:30+0900
# Minibatch loss at step 67500: 0.266943
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# finish : 2016-11-30T02:45:31+0900
# Minibatch loss at step 68000: 0.224367
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-11-30T02:46:32+0900
# Minibatch loss at step 68500: 0.633620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# finish : 2016-11-30T02:47:34+0900
# Minibatch loss at step 69000: 0.529891
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-30T02:48:35+0900
# Minibatch loss at step 69500: 0.420144
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# finish : 2016-11-30T02:49:36+0900
# Minibatch loss at step 70000: 0.893305
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.8%
# finish : 2016-11-30T02:50:38+0900
# Minibatch loss at step 70500: 0.605063
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# finish : 2016-11-30T02:51:39+0900
# Minibatch loss at step 71000: 0.770512
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.9%
# finish : 2016-11-30T02:52:41+0900
# Minibatch loss at step 71500: 0.188088
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-11-30T02:53:42+0900
# Minibatch loss at step 72000: 0.402866
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# ...
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-30T03:03:54+0900
# Minibatch loss at step 77000: 0.586031
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# finish : 2016-11-30T03:04:55+0900
# Minibatch loss at step 77500: 0.252969
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.0%
# finish : 2016-11-30T03:05:57+0900
# Minibatch loss at step 78000: 0.374849
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# finish : 2016-11-30T03:06:59+0900
# Minibatch loss at step 78500: 0.698612
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-11-30T03:08:00+0900
# Minibatch loss at step 79000: 0.292615
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-30T03:09:02+0900
# Minibatch loss at step 79500: 0.700741
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-30T03:10:03+0900
# Minibatch loss at step 80000: 0.458637
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-30T03:11:05+0900
# Minibatch loss at step 80500: 0.175913
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-30T03:12:06+0900
# Minibatch loss at step 81000: 0.133373
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-30T03:13:07+0900
# Minibatch loss at step 81500: 0.146670
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# finish : 2016-11-30T03:14:08+0900
# Minibatch loss at step 82000: 0.129328
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-30T03:15:10+0900
# Minibatch loss at step 82500: 0.359807
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# finish : 2016-11-30T03:16:11+0900
# Minibatch loss at step 83000: 0.555196
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# finish : 2016-11-30T03:17:13+0900
# Minibatch loss at step 83500: 0.132824
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-30T03:18:15+0900
# Minibatch loss at step 84000: 0.141870
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-30T03:19:16+0900
# Minibatch loss at step 84500: 0.296292
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# finish : 2016-11-30T03:20:18+0900
# Minibatch loss at step 85000: 0.474098
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# finish : 2016-11-30T03:21:20+0900
# Minibatch loss at step 85500: 0.115099
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-30T03:22:22+0900
# Minibatch loss at step 86000: 0.265899
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-30T03:23:23+0900
# Minibatch loss at step 86500: 0.826910
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-30T03:24:25+0900
# Minibatch loss at step 87000: 0.354592
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-30T03:25:26+0900
# Minibatch loss at step 87500: 0.100108
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-30T03:26:28+0900
# Minibatch loss at step 88000: 0.099309
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-11-30T03:27:30+0900
# Minibatch loss at step 88500: 0.238000
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-30T03:28:32+0900
# Minibatch loss at step 89000: 0.194976
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-30T03:29:33+0900
# Minibatch loss at step 89500: 0.240130
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-30T03:30:35+0900
# Minibatch loss at step 90000: 0.246477
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-30T03:31:36+0900
# Minibatch loss at step 90500: 0.333519
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-30T03:32:38+0900
# Minibatch loss at step 91000: 0.468074
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# finish : 2016-11-30T03:33:40+0900
# Minibatch loss at step 91500: 0.417617
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.3%
# finish : 2016-11-30T03:34:41+0900
# Minibatch loss at step 92000: 0.396167
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-11-30T03:35:42+0900
# Minibatch loss at step 92500: 0.147543
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-30T03:36:44+0900
# Minibatch loss at step 93000: 0.156039
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-30T03:37:46+0900
# Minibatch loss at step 93500: 0.814427
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# finish : 2016-11-30T03:38:47+0900
# Minibatch loss at step 94000: 0.688547
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# finish : 2016-11-30T03:39:49+0900
# Minibatch loss at step 94500: 0.154196
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-30T03:40:50+0900
# Minibatch loss at step 95000: 0.153530
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-11-30T03:41:52+0900
# Minibatch loss at step 95500: 0.256532
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-30T03:42:53+0900
# Minibatch loss at step 96000: 0.157818
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-30T03:43:55+0900
# Minibatch loss at step 96500: 0.135085
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-30T03:44:56+0900
# Minibatch loss at step 97000: 0.121522
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-11-30T03:45:58+0900
# Minibatch loss at step 97500: 0.321799
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-30T03:46:59+0900
# Minibatch loss at step 98000: 0.387695
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# finish : 2016-11-30T03:48:01+0900
# Minibatch loss at step 98500: 0.355687
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-11-30T03:49:03+0900
# Minibatch loss at step 99000: 0.168280
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# finish : 2016-11-30T03:50:04+0900
# Minibatch loss at step 99500: 0.219962
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-30T03:51:06+0900
# Minibatch loss at step 100000: 0.437522
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-30T03:52:08+0900
# Test accuracy: 89.0%
# finish : 2016-11-30T03:52:12+0900

# %%
# Minibatch loss at step 100000: 0.258780
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-30T07:10:31+0900
# Test accuracy: 87.7%
# finish : 2016-11-30T07:10:36+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,128,128,128,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 21.581238
# Minibatch accuracy_length: 0.0%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 3.1%
# Minibatch accuracy_digit_2: 6.5%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-30T03:52:24+0900
# Minibatch loss at step 500: 9.767053
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T03:53:21+0900
# Minibatch loss at step 1000: 8.248741
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-30T03:54:17+0900
# Minibatch loss at step 1500: 8.983968
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T03:55:13+0900
# Minibatch loss at step 2000: 9.688792
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T03:56:09+0900
# Minibatch loss at step 2500: 9.168427
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T03:57:05+0900
# Minibatch loss at step 3000: 8.363778
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T03:58:01+0900
# Minibatch loss at step 3500: 8.904301
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T03:58:57+0900
# Minibatch loss at step 4000: 8.068970
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T03:59:53+0900
# Minibatch loss at step 4500: 8.753407
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 35.7%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:00:49+0900
# Minibatch loss at step 5000: 8.517529
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 31.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:01:44+0900
# Minibatch loss at step 5500: 7.519949
# Minibatch accuracy_length: 68.8%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:02:40+0900
# Minibatch loss at step 6000: 7.916101
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 56.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:03:35+0900
# Minibatch loss at step 6500: 8.451786
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:04:31+0900
# Minibatch loss at step 7000: 7.859621
# Minibatch accuracy_length: 18.8%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 69.2%
# Minibatch accuracy_digit_3: 66.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:05:27+0900
# Minibatch loss at step 7500: 6.468339
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-30T04:06:22+0900
# Minibatch loss at step 8000: 7.299791
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 70.4%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T04:07:18+0900
# Minibatch loss at step 8500: 7.406149
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 64.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:08:14+0900
# Minibatch loss at step 9000: 7.915846
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 34.4%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:09:11+0900
# Minibatch loss at step 9500: 7.805241
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 34.5%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:10:07+0900
# Minibatch loss at step 10000: 7.282773
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 58.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:11:04+0900
# Minibatch loss at step 10500: 7.467909
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:12:01+0900
# Minibatch loss at step 11000: 6.896175
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 68.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:12:57+0900
# Minibatch loss at step 11500: 7.976736
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 32.3%
# Minibatch accuracy_digit_3: 92.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:13:53+0900
# Minibatch loss at step 12000: 7.379251
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 43.3%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:14:49+0900
# Minibatch loss at step 12500: 7.240214
# Minibatch accuracy_length: 50.0%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 58.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:15:45+0900
# Minibatch loss at step 13000: 7.195041
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 65.6%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:16:41+0900
# Minibatch loss at step 13500: 8.064695
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 51.7%
# Minibatch accuracy_digit_3: 76.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:17:37+0900
# Minibatch loss at step 14000: 6.965488
# Minibatch accuracy_length: 31.2%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 37.5%
# Minibatch accuracy_digit_2: 60.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:18:33+0900
# Minibatch loss at step 14500: 6.833127
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 69.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T04:19:28+0900
# Minibatch loss at step 15000: 6.633929
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 68.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T04:20:24+0900
# Minibatch loss at step 15500: 7.427831
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 58.1%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:21:20+0900
# Minibatch loss at step 16000: 6.713574
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 61.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:22:16+0900
# Minibatch loss at step 16500: 7.578205
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 46.9%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:23:11+0900
# Minibatch loss at step 17000: 7.813869
# Minibatch accuracy_length: 46.9%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 46.9%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:24:07+0900
# Minibatch loss at step 17500: 7.826568
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 48.4%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:25:04+0900
# Minibatch loss at step 18000: 7.607417
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 37.9%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:26:00+0900
# Minibatch loss at step 18500: 8.735612
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 28.6%
# Minibatch accuracy_digit_3: 77.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:26:57+0900
# Minibatch loss at step 19000: 7.334134
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 3.1%
# Minibatch accuracy_digit_2: 48.4%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:27:52+0900
# Minibatch loss at step 19500: 7.211098
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 48.4%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:28:49+0900
# Minibatch loss at step 20000: 8.097256
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 26.7%
# Minibatch accuracy_digit_3: 87.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:29:45+0900
# Minibatch loss at step 20500: 7.851088
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 76.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:30:41+0900
# Minibatch loss at step 21000: 6.516584
# Minibatch accuracy_length: 25.0%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 71.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:31:38+0900
# Minibatch loss at step 21500: 6.376921
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 71.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 0.7%
# finish : 2016-11-30T04:32:34+0900
# Minibatch loss at step 22000: 6.559435
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 74.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-30T04:33:31+0900
# Minibatch loss at step 22500: 8.014198
# Minibatch accuracy_length: 50.0%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 40.0%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:34:27+0900
# Minibatch loss at step 23000: 6.896434
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:35:24+0900
# Minibatch loss at step 23500: 8.136490
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 35.5%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:36:20+0900
# Minibatch loss at step 24000: 7.693097
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 34.5%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:37:16+0900
# Minibatch loss at step 24500: 7.216405
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:38:12+0900
# Minibatch loss at step 25000: 7.355194
# Minibatch accuracy_length: 46.9%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:39:08+0900
# Minibatch loss at step 25500: 7.849047
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 40.6%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:40:05+0900
# Minibatch loss at step 26000: 6.713258
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 59.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:41:01+0900
# Minibatch loss at step 26500: 7.885639
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 40.0%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:41:57+0900
# Minibatch loss at step 27000: 8.182067
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 27.6%
# Minibatch accuracy_digit_3: 84.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-30T04:42:53+0900
# Minibatch loss at step 27500: 6.975207
# Minibatch accuracy_length: 81.2%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 40.6%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.8%
# finish : 2016-11-30T04:43:49+0900
# Minibatch loss at step 28000: 7.004838
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 55.6%
# Minibatch accuracy_digit_3: 92.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.9%
# finish : 2016-11-30T04:44:45+0900
# Minibatch loss at step 28500: 4.911679
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 73.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 1.7%
# finish : 2016-11-30T04:45:41+0900
# Minibatch loss at step 29000: 4.962520
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 64.0%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 1.7%
# finish : 2016-11-30T04:46:37+0900
# Minibatch loss at step 29500: 5.762069
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 28.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 2.4%
# finish : 2016-11-30T04:47:34+0900
# Minibatch loss at step 30000: 5.693832
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 40.6%
# Minibatch accuracy_digit_3: 91.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 3.3%
# finish : 2016-11-30T04:48:31+0900
# Minibatch loss at step 30500: 4.939138
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 72.4%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 4.0%
# finish : 2016-11-30T04:49:28+0900
# Minibatch loss at step 31000: 5.069952
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 55.2%
# Minibatch accuracy_digit_3: 84.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 5.3%
# finish : 2016-11-30T04:50:24+0900
# Minibatch loss at step 31500: 5.201906
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 53.1%
# Minibatch accuracy_digit_2: 45.2%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 8.7%
# finish : 2016-11-30T04:51:21+0900
# Minibatch loss at step 32000: 3.667367
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 56.2%
# Minibatch accuracy_digit_2: 55.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.1%
# finish : 2016-11-30T04:52:18+0900
# Minibatch loss at step 32500: 3.616262
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 59.4%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 18.8%
# Validation accuracy: 14.6%
# finish : 2016-11-30T04:53:16+0900
# Minibatch loss at step 33000: 3.741194
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 65.6%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 19.1%
# finish : 2016-11-30T04:54:13+0900
# Minibatch loss at step 33500: 3.024188
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 68.8%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 67.7%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 31.2%
# Validation accuracy: 29.8%
# finish : 2016-11-30T04:55:11+0900
# Minibatch loss at step 34000: 2.755426
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 65.6%
# Minibatch accuracy_digit_2: 59.4%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 37.5%
# Validation accuracy: 38.3%
# finish : 2016-11-30T04:56:09+0900
# Minibatch loss at step 34500: 2.522240
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 77.4%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 44.6%
# finish : 2016-11-30T04:57:07+0900
# Minibatch loss at step 35000: 3.165985
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 69.2%
# Minibatch accuracy_digit_3: 63.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 43.9%
# finish : 2016-11-30T04:58:06+0900
# Minibatch loss at step 35500: 2.711256
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 49.6%
# finish : 2016-11-30T04:59:05+0900
# Minibatch loss at step 36000: 2.568137
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 80.8%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 50.5%
# finish : 2016-11-30T05:00:03+0900
# Minibatch loss at step 36500: 3.435926
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 71.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 37.5%
# Validation accuracy: 55.5%
# finish : 2016-11-30T05:01:02+0900
# Minibatch loss at step 37000: 0.929658
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 82.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 61.4%
# finish : 2016-11-30T05:02:02+0900
# Minibatch loss at step 37500: 2.015061
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 63.8%
# finish : 2016-11-30T05:03:00+0900
# Minibatch loss at step 38000: 2.835361
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 83.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 65.5%
# finish : 2016-11-30T05:03:59+0900
# Minibatch loss at step 38500: 1.534272
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 77.4%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 65.6%
# finish : 2016-11-30T05:04:59+0900
# Minibatch loss at step 39000: 1.617178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 83.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 68.7%
# finish : 2016-11-30T05:05:58+0900
# Minibatch loss at step 39500: 1.488490
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 82.1%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 71.1%
# finish : 2016-11-30T05:06:57+0900
# Minibatch loss at step 40000: 1.429940
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.9%
# finish : 2016-11-30T05:07:56+0900
# Minibatch loss at step 40500: 1.325620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.1%
# finish : 2016-11-30T05:08:55+0900
# Minibatch loss at step 41000: 1.441608
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 74.1%
# finish : 2016-11-30T05:09:55+0900
# Minibatch loss at step 41500: 1.331862
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.4%
# finish : 2016-11-30T05:10:54+0900
# Minibatch loss at step 42000: 1.134536
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 75.6%
# finish : 2016-11-30T05:11:53+0900
# Minibatch loss at step 42500: 1.051628
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.6%
# finish : 2016-11-30T05:12:51+0900
# Minibatch loss at step 43000: 1.395138
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.6%
# finish : 2016-11-30T05:13:51+0900
# Minibatch loss at step 43500: 1.029186
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 92.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.6%
# finish : 2016-11-30T05:14:50+0900
# Minibatch loss at step 44000: 1.719685
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 77.4%
# finish : 2016-11-30T05:15:50+0900
# Minibatch loss at step 44500: 0.952227
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 78.4%
# finish : 2016-11-30T05:16:49+0900
# Minibatch loss at step 45000: 1.597672
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.7%
# finish : 2016-11-30T05:17:48+0900
# Minibatch loss at step 45500: 0.522514
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# finish : 2016-11-30T05:18:48+0900
# Minibatch loss at step 46000: 1.054072
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 80.1%
# finish : 2016-11-30T05:19:48+0900
# Minibatch loss at step 46500: 0.787946
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.2%
# finish : 2016-11-30T05:20:47+0900
# Minibatch loss at step 47000: 1.351766
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 84.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.1%
# finish : 2016-11-30T05:21:48+0900
# Minibatch loss at step 47500: 0.288208
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 81.4%
# finish : 2016-11-30T05:22:48+0900
# Minibatch loss at step 48000: 1.532724
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.9%
# finish : 2016-11-30T05:23:48+0900
# Minibatch loss at step 48500: 0.519220
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# finish : 2016-11-30T05:24:48+0900
# Minibatch loss at step 49000: 0.542245
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.0%
# finish : 2016-11-30T05:25:48+0900
# Minibatch loss at step 49500: 1.119771
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# finish : 2016-11-30T05:26:49+0900
# Minibatch loss at step 50000: 0.521314
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 81.1%
# finish : 2016-11-30T05:27:50+0900
# Minibatch loss at step 50500: 0.534538
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.2%
# finish : 2016-11-30T05:28:51+0900
# Minibatch loss at step 51000: 0.515734
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.0%
# finish : 2016-11-30T05:29:51+0900
# Minibatch loss at step 51500: 0.802433
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.6%
# finish : 2016-11-30T05:30:51+0900
# Minibatch loss at step 52000: 0.235876
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.6%
# finish : 2016-11-30T05:31:52+0900
# Minibatch loss at step 52500: 0.909452
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# finish : 2016-11-30T05:32:53+0900
# Minibatch loss at step 53000: 0.329051
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# finish : 2016-11-30T05:33:53+0900
# Minibatch loss at step 53500: 0.356999
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.9%
# finish : 2016-11-30T05:34:54+0900
# Minibatch loss at step 54000: 0.463022
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.1%
# finish : 2016-11-30T05:35:54+0900
# Minibatch loss at step 54500: 0.920737
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# finish : 2016-11-30T05:36:55+0900
# Minibatch loss at step 55000: 1.381544
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.1%
# finish : 2016-11-30T05:37:56+0900
# Minibatch loss at step 55500: 0.204601
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.4%
# finish : 2016-11-30T05:38:57+0900
# Minibatch loss at step 56000: 0.866276
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 91.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# finish : 2016-11-30T05:39:58+0900
# Minibatch loss at step 56500: 0.997846
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# finish : 2016-11-30T05:40:59+0900
# Minibatch loss at step 57000: 0.890690
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.0%
# finish : 2016-11-30T05:42:01+0900
# Minibatch loss at step 57500: 1.220907
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# finish : 2016-11-30T05:43:02+0900
# Minibatch loss at step 58000: 1.652997
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# finish : 2016-11-30T05:44:02+0900
# Minibatch loss at step 58500: 0.508159
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# finish : 2016-11-30T05:45:04+0900
# Minibatch loss at step 59000: 0.792911
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.7%
# finish : 2016-11-30T05:46:05+0900
# Minibatch loss at step 59500: 0.489950
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# finish : 2016-11-30T05:47:06+0900
# Minibatch loss at step 60000: 0.401506
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.3%
# finish : 2016-11-30T05:48:07+0900
# Minibatch loss at step 60500: 0.269649
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.1%
# finish : 2016-11-30T05:49:07+0900
# Minibatch loss at step 61000: 0.154017
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.5%
# finish : 2016-11-30T05:50:08+0900
# Minibatch loss at step 61500: 0.691936
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.3%
# finish : 2016-11-30T05:51:09+0900
# Minibatch loss at step 62000: 0.387569
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# finish : 2016-11-30T05:52:11+0900
# Minibatch loss at step 62500: 1.097768
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.5%
# finish : 2016-11-30T05:53:11+0900
# Minibatch loss at step 63000: 0.753147
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.2%
# finish : 2016-11-30T05:54:12+0900
# Minibatch loss at step 63500: 0.650121
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# finish : 2016-11-30T05:55:13+0900
# Minibatch loss at step 64000: 0.727722
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# finish : 2016-11-30T05:56:15+0900
# Minibatch loss at step 64500: 0.326057
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 84.6%
# finish : 2016-11-30T05:57:17+0900
# Minibatch loss at step 65000: 0.777247
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.4%
# finish : 2016-11-30T05:58:19+0900
# Minibatch loss at step 65500: 0.256058
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
# finish : 2016-11-30T05:59:20+0900
# Minibatch loss at step 66000: 1.332804
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# finish : 2016-11-30T06:00:22+0900
# Minibatch loss at step 66500: 0.178180
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# finish : 2016-11-30T06:01:23+0900
# Minibatch loss at step 67000: 0.548828
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# finish : 2016-11-30T06:02:25+0900
# Minibatch loss at step 67500: 0.349940
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# finish : 2016-11-30T06:03:27+0900
# Minibatch loss at step 68000: 0.339040
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# finish : 2016-11-30T06:04:28+0900
# Minibatch loss at step 68500: 0.468673
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# finish : 2016-11-30T06:05:30+0900
# Minibatch loss at step 69000: 0.664517
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# finish : 2016-11-30T06:06:32+0900
# Minibatch loss at step 69500: 0.520932
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# finish : 2016-11-30T06:07:33+0900
# Minibatch loss at step 70000: 0.907272
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.4%
# finish : 2016-11-30T06:08:35+0900
# Minibatch loss at step 70500: 0.486948
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# finish : 2016-11-30T06:09:37+0900
# Minibatch loss at step 71000: 0.801232
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.5%
# finish : 2016-11-30T06:10:38+0900
# Minibatch loss at step 71500: 0.260852
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.9%
# finish : 2016-11-30T06:11:40+0900
# Minibatch loss at step 72000: 0.428838
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.3%
# ...
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-11-30T06:21:59+0900
# Minibatch loss at step 77000: 0.549826
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# finish : 2016-11-30T06:23:01+0900
# Minibatch loss at step 77500: 0.416439
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# finish : 2016-11-30T06:24:03+0900
# Minibatch loss at step 78000: 0.549136
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# finish : 2016-11-30T06:25:05+0900
# Minibatch loss at step 78500: 0.749460
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# finish : 2016-11-30T06:26:07+0900
# Minibatch loss at step 79000: 0.328045
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# finish : 2016-11-30T06:27:09+0900
# Minibatch loss at step 79500: 0.285765
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-11-30T06:28:12+0900
# Minibatch loss at step 80000: 0.351979
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# finish : 2016-11-30T06:29:13+0900
# Minibatch loss at step 80500: 0.207215
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.4%
# finish : 2016-11-30T06:30:15+0900
# Minibatch loss at step 81000: 0.232999
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-11-30T06:31:17+0900
# Minibatch loss at step 81500: 0.088263
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-11-30T06:32:18+0900
# Minibatch loss at step 82000: 0.191113
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# finish : 2016-11-30T06:33:20+0900
# Minibatch loss at step 82500: 0.203757
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.0%
# finish : 2016-11-30T06:34:22+0900
# Minibatch loss at step 83000: 0.275668
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-30T06:35:24+0900
# Minibatch loss at step 83500: 0.120243
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# finish : 2016-11-30T06:36:26+0900
# Minibatch loss at step 84000: 0.176719
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.4%
# finish : 2016-11-30T06:37:28+0900
# Minibatch loss at step 84500: 0.260699
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# finish : 2016-11-30T06:38:29+0900
# Minibatch loss at step 85000: 0.736312
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# finish : 2016-11-30T06:39:31+0900
# Minibatch loss at step 85500: 0.101000
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.9%
# finish : 2016-11-30T06:40:34+0900
# Minibatch loss at step 86000: 0.203522
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# finish : 2016-11-30T06:41:35+0900
# Minibatch loss at step 86500: 0.968736
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# finish : 2016-11-30T06:42:37+0900
# Minibatch loss at step 87000: 0.188549
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-11-30T06:43:39+0900
# Minibatch loss at step 87500: 0.145174
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# finish : 2016-11-30T06:44:41+0900
# Minibatch loss at step 88000: 0.167994
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# finish : 2016-11-30T06:45:43+0900
# Minibatch loss at step 88500: 0.202822
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-11-30T06:46:44+0900
# Minibatch loss at step 89000: 0.128519
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-11-30T06:47:46+0900
# Minibatch loss at step 89500: 0.238851
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# finish : 2016-11-30T06:48:48+0900
# Minibatch loss at step 90000: 0.127977
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# finish : 2016-11-30T06:49:50+0900
# Minibatch loss at step 90500: 0.242715
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# finish : 2016-11-30T06:50:51+0900
# Minibatch loss at step 91000: 0.298452
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-30T06:51:53+0900
# Minibatch loss at step 91500: 0.329947
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# finish : 2016-11-30T06:52:55+0900
# Minibatch loss at step 92000: 0.445500
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# finish : 2016-11-30T06:53:58+0900
# Minibatch loss at step 92500: 0.166289
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# finish : 2016-11-30T06:55:00+0900
# Minibatch loss at step 93000: 0.149863
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# finish : 2016-11-30T06:56:03+0900
# Minibatch loss at step 93500: 0.757219
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-30T06:57:04+0900
# Minibatch loss at step 94000: 0.486906
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# finish : 2016-11-30T06:58:06+0900
# Minibatch loss at step 94500: 0.202552
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.8%
# finish : 2016-11-30T06:59:08+0900
# Minibatch loss at step 95000: 0.170629
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.6%
# finish : 2016-11-30T07:00:10+0900
# Minibatch loss at step 95500: 0.155977
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.9%
# finish : 2016-11-30T07:01:12+0900
# Minibatch loss at step 96000: 0.154903
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.4%
# finish : 2016-11-30T07:02:13+0900
# Minibatch loss at step 96500: 0.113379
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-11-30T07:03:16+0900
# Minibatch loss at step 97000: 0.147036
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# finish : 2016-11-30T07:04:18+0900
# Minibatch loss at step 97500: 0.239252
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-11-30T07:05:20+0900
# Minibatch loss at step 98000: 0.207768
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-11-30T07:06:22+0900
# Minibatch loss at step 98500: 0.276239
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# finish : 2016-11-30T07:07:25+0900
# Minibatch loss at step 99000: 0.218072
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# finish : 2016-11-30T07:08:27+0900
# Minibatch loss at step 99500: 0.195273
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-11-30T07:09:29+0900
# Minibatch loss at step 100000: 0.258780
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-30T07:10:31+0900
# Test accuracy: 87.7%
# finish : 2016-11-30T07:10:36+0900

# %%
# best model.

# finish : 2016-11-28T20:41:39+0900
# Minibatch loss at step 100000: 0.648583
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# finish : 2016-11-29T00:08:29+0900
# Test accuracy: 90.1%
# finish : 2016-11-29T00:08:33+0900
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,64,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("Placeholder:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder_1:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_2:0", shape=(32, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 16.426882
# Minibatch accuracy_length: 75.0%
# Minibatch accuracy_digit_0: 0.0%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 3.2%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-28T20:41:39+0900
# Minibatch loss at step 500: 9.739598
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 34.4%
# Minibatch accuracy_digit_2: 63.6%
# Minibatch accuracy_digit_3: 60.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-11-28T20:42:37+0900
# Minibatch loss at step 1000: 8.228830
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.7%
# finish : 2016-11-28T20:43:34+0900
# Minibatch loss at step 1500: 8.952175
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 0.3%
# finish : 2016-11-28T20:44:31+0900
# Minibatch loss at step 2000: 9.661255
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 33.3%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T20:45:28+0900
# Minibatch loss at step 2500: 9.140995
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T20:46:25+0900
# Minibatch loss at step 3000: 8.322756
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T20:47:22+0900
# Minibatch loss at step 3500: 8.869891
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T20:48:19+0900
# Minibatch loss at step 4000: 8.022766
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T20:49:15+0900
# Minibatch loss at step 4500: 8.703549
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 35.7%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-11-28T20:50:12+0900
# Minibatch loss at step 5000: 8.123390
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 31.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-11-28T20:51:08+0900
# Minibatch loss at step 5500: 7.103561
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 1.1%
# finish : 2016-11-28T20:52:05+0900
# Minibatch loss at step 6000: 6.176687
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 56.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 1.9%
# finish : 2016-11-28T20:53:02+0900
# Minibatch loss at step 6500: 6.203335
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 48.4%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 3.8%
# finish : 2016-11-28T20:53:59+0900
# Minibatch loss at step 7000: 6.859140
# Minibatch accuracy_length: 68.8%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 69.2%
# Minibatch accuracy_digit_3: 66.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 5.4%
# finish : 2016-11-28T20:54:57+0900
# Minibatch loss at step 7500: 3.808895
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 53.1%
# Minibatch accuracy_digit_1: 56.2%
# Minibatch accuracy_digit_2: 75.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 13.0%
# finish : 2016-11-28T20:55:56+0900
# Minibatch loss at step 8000: 3.518923
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 68.8%
# Minibatch accuracy_digit_1: 62.5%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 40.6%
# Validation accuracy: 23.1%
# finish : 2016-11-28T20:56:54+0900
# Minibatch loss at step 8500: 3.078578
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 59.4%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 34.6%
# finish : 2016-11-28T20:57:54+0900
# Minibatch loss at step 9000: 3.027915
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 62.5%
# Minibatch accuracy_digit_2: 68.8%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 47.4%
# finish : 2016-11-28T20:58:54+0900
# Minibatch loss at step 9500: 2.088218
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 57.9%
# finish : 2016-11-28T20:59:54+0900
# Minibatch loss at step 10000: 1.123297
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 62.6%
# finish : 2016-11-28T21:00:54+0900
# Minibatch loss at step 10500: 1.871007
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 75.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 67.9%
# finish : 2016-11-28T21:01:55+0900
# Minibatch loss at step 11000: 1.436286
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.6%
# finish : 2016-11-28T21:02:55+0900
# Minibatch loss at step 11500: 2.313260
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.1%
# finish : 2016-11-28T21:03:55+0900
# Minibatch loss at step 12000: 1.297848
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 74.2%
# finish : 2016-11-28T21:04:55+0900
# Minibatch loss at step 12500: 1.323246
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 76.9%
# finish : 2016-11-28T21:05:56+0900
# Minibatch loss at step 13000: 1.955213
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.8%
# finish : 2016-11-28T21:06:57+0900
# Minibatch loss at step 13500: 1.163045
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.9%
# finish : 2016-11-28T21:07:57+0900
# Minibatch loss at step 14000: 1.917701
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 62.5%
# Minibatch accuracy_digit_2: 87.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.9%
# finish : 2016-11-28T21:08:57+0900
# Minibatch loss at step 14500: 1.809527
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.6%
# finish : 2016-11-28T21:09:58+0900
# Minibatch loss at step 15000: 0.970775
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.6%
# finish : 2016-11-28T21:10:58+0900
# Minibatch loss at step 15500: 1.114266
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.1%
# finish : 2016-11-28T21:11:59+0900
# Minibatch loss at step 16000: 1.057565
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# finish : 2016-11-28T21:12:59+0900
# Minibatch loss at step 16500: 1.170700
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 82.5%
# finish : 2016-11-28T21:14:00+0900
# Minibatch loss at step 17000: 0.775663
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.4%
# finish : 2016-11-28T21:15:01+0900
# Minibatch loss at step 17500: 1.046302
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# finish : 2016-11-28T21:16:01+0900
# Minibatch loss at step 18000: 0.576619
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# finish : 2016-11-28T21:17:02+0900
# Minibatch loss at step 18500: 1.006120
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# finish : 2016-11-28T21:18:03+0900
# Minibatch loss at step 19000: 0.463442
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# finish : 2016-11-28T21:19:03+0900
# Minibatch loss at step 19500: 0.757465
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# finish : 2016-11-28T21:20:04+0900
# Minibatch loss at step 20000: 0.974965
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# finish : 2016-11-28T21:21:05+0900
# Minibatch loss at step 20500: 0.531000
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.1%
# finish : 2016-11-28T21:22:06+0900
# Minibatch loss at step 21000: 0.598675
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# finish : 2016-11-28T21:23:07+0900
# Minibatch loss at step 21500: 0.592551
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.4%
# finish : 2016-11-28T21:24:08+0900
# Minibatch loss at step 22000: 1.456360
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.6%
# finish : 2016-11-28T21:25:10+0900
# Minibatch loss at step 22500: 0.328206
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# finish : 2016-11-28T21:26:11+0900
# Minibatch loss at step 23000: 0.513304
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# finish : 2016-11-28T21:27:12+0900
# Minibatch loss at step 23500: 0.745231
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# finish : 2016-11-28T21:28:14+0900
# Minibatch loss at step 24000: 0.866309
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.1%
# finish : 2016-11-28T21:29:15+0900
# Minibatch loss at step 24500: 0.262137
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.0%
# finish : 2016-11-28T21:30:16+0900
# Minibatch loss at step 25000: 0.717726
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# finish : 2016-11-28T21:31:17+0900
# Minibatch loss at step 25500: 0.396799
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.3%
# finish : 2016-11-28T21:32:18+0900
# Minibatch loss at step 26000: 0.372498
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.9%
# finish : 2016-11-28T21:33:20+0900
# Minibatch loss at step 26500: 0.594137
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# finish : 2016-11-28T21:34:22+0900
# Minibatch loss at step 27000: 0.718883
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# finish : 2016-11-28T21:35:23+0900
# Minibatch loss at step 27500: 0.327960
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-11-28T21:36:25+0900
# Minibatch loss at step 28000: 0.643023
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.8%
# finish : 2016-11-28T21:37:27+0900
# Minibatch loss at step 28500: 0.425874
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# finish : 2016-11-28T21:38:29+0900
# Minibatch loss at step 29000: 0.393818
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# finish : 2016-11-28T21:39:30+0900
# Minibatch loss at step 29500: 0.343334
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-11-28T21:40:32+0900
# Minibatch loss at step 30000: 0.425685
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.2%
# finish : 2016-11-28T21:41:33+0900
# Minibatch loss at step 30500: 0.523035
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.5%
# finish : 2016-11-28T21:42:35+0900
# Minibatch loss at step 31000: 0.542575
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# finish : 2016-11-28T21:43:37+0900
# Minibatch loss at step 31500: 0.387150
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# finish : 2016-11-28T21:44:39+0900
# Minibatch loss at step 32000: 0.377722
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# finish : 2016-11-28T21:45:40+0900
# Minibatch loss at step 32500: 0.240131
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# finish : 2016-11-28T21:46:42+0900
# Minibatch loss at step 33000: 0.384954
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-11-28T21:47:44+0900
# Minibatch loss at step 33500: 0.301208
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-11-28T21:48:46+0900
# Minibatch loss at step 34000: 0.399427
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.6%
# finish : 2016-11-28T21:49:48+0900
# Minibatch loss at step 34500: 0.701762
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 90.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 88.8%
# finish : 2016-11-28T21:50:50+0900
# Minibatch loss at step 35000: 0.765889
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 84.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# finish : 2016-11-28T21:51:53+0900
# Minibatch loss at step 35500: 0.942367
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# finish : 2016-11-28T21:52:55+0900
# Minibatch loss at step 36000: 0.829260
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# finish : 2016-11-28T21:53:57+0900
# Minibatch loss at step 36500: 1.566388
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# finish : 2016-11-28T21:55:00+0900
# Minibatch loss at step 37000: 0.123233
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-11-28T21:56:02+0900
# Minibatch loss at step 37500: 0.271036
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-11-28T21:57:04+0900
# Minibatch loss at step 38000: 1.108428
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T21:58:06+0900
# Minibatch loss at step 38500: 0.561673
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# finish : 2016-11-28T21:59:09+0900
# Minibatch loss at step 39000: 0.341233
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T22:00:12+0900
# Minibatch loss at step 39500: 0.488578
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# finish : 2016-11-28T22:01:14+0900
# Minibatch loss at step 40000: 0.362889
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-11-28T22:02:17+0900
# Minibatch loss at step 40500: 0.416311
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T22:03:19+0900
# Minibatch loss at step 41000: 0.329550
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T22:04:21+0900
# Minibatch loss at step 41500: 0.205684
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-11-28T22:05:24+0900
# Minibatch loss at step 42000: 0.477507
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T22:06:27+0900
# Minibatch loss at step 42500: 0.535994
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# finish : 2016-11-28T22:07:29+0900
# Minibatch loss at step 43000: 0.650104
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# finish : 2016-11-28T22:08:32+0900
# Minibatch loss at step 43500: 0.231001
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-28T22:09:35+0900
# Minibatch loss at step 44000: 1.049778
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# finish : 2016-11-28T22:10:37+0900
# Minibatch loss at step 44500: 0.329335
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-28T22:11:40+0900
# Minibatch loss at step 45000: 0.410509
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# finish : 2016-11-28T22:12:42+0900
# Minibatch loss at step 45500: 0.264303
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-11-28T22:13:45+0900
# Minibatch loss at step 46000: 0.311819
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# finish : 2016-11-28T22:14:48+0900
# Minibatch loss at step 46500: 0.215088
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T22:15:51+0900
# Minibatch loss at step 47000: 0.635100
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# finish : 2016-11-28T22:16:54+0900
# Minibatch loss at step 47500: 0.183787
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T22:17:57+0900
# Minibatch loss at step 48000: 0.775424
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.9%
# finish : 2016-11-28T22:18:59+0900
# Minibatch loss at step 48500: 0.287855
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T22:20:02+0900
# Minibatch loss at step 49000: 0.309304
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# finish : 2016-11-28T22:21:05+0900
# Minibatch loss at step 49500: 0.618971
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.5%
# finish : 2016-11-28T22:22:09+0900
# Minibatch loss at step 50000: 0.297865
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# finish : 2016-11-28T22:23:12+0900
# Minibatch loss at step 50500: 0.275152
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T22:24:15+0900
# Minibatch loss at step 51000: 0.145137
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T22:25:18+0900
# Minibatch loss at step 51500: 0.300697
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T22:26:21+0900
# Minibatch loss at step 52000: 0.113699
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T22:27:23+0900
# Minibatch loss at step 52500: 0.208269
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-11-28T22:28:26+0900
# Minibatch loss at step 53000: 0.232039
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-28T22:29:29+0900
# Minibatch loss at step 53500: 0.167107
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T22:30:32+0900
# Minibatch loss at step 54000: 0.117609
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-11-28T22:31:35+0900
# Minibatch loss at step 54500: 0.550526
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# finish : 2016-11-28T22:32:38+0900
# Minibatch loss at step 55000: 0.480241
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T22:33:42+0900
# Minibatch loss at step 55500: 0.143304
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-11-28T22:34:45+0900
# Minibatch loss at step 56000: 0.396824
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 91.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# finish : 2016-11-28T22:35:48+0900
# Minibatch loss at step 56500: 0.708353
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.4%
# finish : 2016-11-28T22:36:51+0900
# Minibatch loss at step 57000: 0.681545
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T22:37:55+0900
# Minibatch loss at step 57500: 0.302012
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T22:38:58+0900
# Minibatch loss at step 58000: 0.720085
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# finish : 2016-11-28T22:40:01+0900
# Minibatch loss at step 58500: 0.423485
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.2%
# finish : 2016-11-28T22:41:04+0900
# Minibatch loss at step 59000: 0.380825
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# finish : 2016-11-28T22:42:07+0900
# Minibatch loss at step 59500: 0.160255
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T22:43:10+0900
# Minibatch loss at step 60000: 0.277270
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# finish : 2016-11-28T22:44:13+0900
# Minibatch loss at step 60500: 0.142665
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T22:45:16+0900
# Minibatch loss at step 61000: 0.149875
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T22:46:20+0900
# Minibatch loss at step 61500: 0.449186
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# finish : 2016-11-28T22:47:23+0900
# Minibatch loss at step 62000: 0.120491
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T22:48:27+0900
# Minibatch loss at step 62500: 1.042788
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.1%
# finish : 2016-11-28T22:49:30+0900
# Minibatch loss at step 63000: 0.353347
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# finish : 2016-11-28T22:50:33+0900
# Minibatch loss at step 63500: 0.782519
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T22:51:37+0900
# Minibatch loss at step 64000: 0.450788
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-28T22:52:40+0900
# Minibatch loss at step 64500: 0.199649
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-11-28T22:53:44+0900
# Minibatch loss at step 65000: 0.549997
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.1%
# finish : 2016-11-28T22:54:47+0900
# Minibatch loss at step 65500: 0.183009
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-28T22:55:50+0900
# Minibatch loss at step 66000: 0.943236
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# finish : 2016-11-28T22:56:53+0900
# Minibatch loss at step 66500: 0.199606
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.4%
# finish : 2016-11-28T22:57:56+0900
# Minibatch loss at step 67000: 0.340320
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
# finish : 2016-11-28T22:58:59+0900
# Minibatch loss at step 67500: 0.131770
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T23:00:02+0900
# Minibatch loss at step 68000: 0.158876
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T23:01:05+0900
# Minibatch loss at step 68500: 0.191069
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-28T23:02:08+0900
# Minibatch loss at step 69000: 0.465175
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.7%
# finish : 2016-11-28T23:03:11+0900
# Minibatch loss at step 69500: 0.176705
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-11-28T23:04:15+0900
# Minibatch loss at step 70000: 0.702390
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 90.2%
# finish : 2016-11-28T23:05:18+0900
# Minibatch loss at step 70500: 0.367732
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# finish : 2016-11-28T23:06:21+0900
# Minibatch loss at step 71000: 0.410798
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# finish : 2016-11-28T23:07:25+0900
# Minibatch loss at step 71500: 0.150208
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# ...
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T23:19:01+0900
# Minibatch loss at step 77000: 0.349524
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# finish : 2016-11-28T23:20:04+0900
# Minibatch loss at step 77500: 0.221610
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# finish : 2016-11-28T23:21:07+0900
# Minibatch loss at step 78000: 0.517113
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.5%
# finish : 2016-11-28T23:22:11+0900
# Minibatch loss at step 78500: 0.441576
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T23:23:14+0900
# Minibatch loss at step 79000: 0.245324
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.3%
# finish : 2016-11-28T23:24:17+0900
# Minibatch loss at step 79500: 0.296291
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# finish : 2016-11-28T23:25:20+0900
# Minibatch loss at step 80000: 0.191988
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# finish : 2016-11-28T23:26:23+0900
# Minibatch loss at step 80500: 0.109445
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T23:27:26+0900
# Minibatch loss at step 81000: 0.154312
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# finish : 2016-11-28T23:28:30+0900
# Minibatch loss at step 81500: 0.087968
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-28T23:29:33+0900
# Minibatch loss at step 82000: 0.120144
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-28T23:30:36+0900
# Minibatch loss at step 82500: 0.104575
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.8%
# finish : 2016-11-28T23:31:39+0900
# Minibatch loss at step 83000: 0.178167
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.9%
# finish : 2016-11-28T23:32:42+0900
# Minibatch loss at step 83500: 0.113766
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-28T23:33:45+0900
# Minibatch loss at step 84000: 0.229614
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# finish : 2016-11-28T23:34:49+0900
# Minibatch loss at step 84500: 0.204248
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-28T23:35:52+0900
# Minibatch loss at step 85000: 0.249856
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# finish : 2016-11-28T23:36:55+0900
# Minibatch loss at step 85500: 0.110106
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-28T23:37:58+0900
# Minibatch loss at step 86000: 0.136732
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-11-28T23:39:02+0900
# Minibatch loss at step 86500: 0.383971
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 80.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# finish : 2016-11-28T23:40:05+0900
# Minibatch loss at step 87000: 0.155760
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.8%
# finish : 2016-11-28T23:41:08+0900
# Minibatch loss at step 87500: 0.109648
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-11-28T23:42:11+0900
# Minibatch loss at step 88000: 0.120452
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-28T23:43:15+0900
# Minibatch loss at step 88500: 0.165798
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-11-28T23:44:18+0900
# Minibatch loss at step 89000: 0.116339
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-28T23:45:21+0900
# Minibatch loss at step 89500: 0.181626
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.9%
# finish : 2016-11-28T23:46:24+0900
# Minibatch loss at step 90000: 0.106723
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.9%
# finish : 2016-11-28T23:47:27+0900
# Minibatch loss at step 90500: 0.208136
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-11-28T23:48:30+0900
# Minibatch loss at step 91000: 0.229346
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
# finish : 2016-11-28T23:49:33+0900
# Minibatch loss at step 91500: 0.251075
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# finish : 2016-11-28T23:50:36+0900
# Minibatch loss at step 92000: 0.320953
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 83.3%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-11-28T23:51:40+0900
# Minibatch loss at step 92500: 0.103655
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T23:52:43+0900
# Minibatch loss at step 93000: 0.093717
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-28T23:53:46+0900
# Minibatch loss at step 93500: 0.710404
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.7%
# finish : 2016-11-28T23:54:49+0900
# Minibatch loss at step 94000: 0.210225
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.9%
# finish : 2016-11-28T23:55:52+0900
# Minibatch loss at step 94500: 0.121013
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-11-28T23:56:55+0900
# Minibatch loss at step 95000: 0.109379
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-11-28T23:57:58+0900
# Minibatch loss at step 95500: 0.122707
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-11-28T23:59:01+0900
# Minibatch loss at step 96000: 0.153812
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.6%
# finish : 2016-11-29T00:00:04+0900
# Minibatch loss at step 96500: 0.133826
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.9%
# finish : 2016-11-29T00:01:08+0900
# Minibatch loss at step 97000: 0.132228
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.8%
# finish : 2016-11-29T00:02:10+0900
# Minibatch loss at step 97500: 0.234565
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-11-29T00:03:13+0900
# Minibatch loss at step 98000: 0.140767
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-11-29T00:04:16+0900
# Minibatch loss at step 98500: 0.154680
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-11-29T00:05:19+0900
# Minibatch loss at step 99000: 0.221829
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# finish : 2016-11-29T00:06:23+0900
# Minibatch loss at step 99500: 0.168040
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.2%
# finish : 2016-11-29T00:07:26+0900
# Minibatch loss at step 100000: 0.648583
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.6%
# finish : 2016-11-29T00:08:29+0900
# Test accuracy: 90.1%
# finish : 2016-11-29T00:08:33+0900

# %%
# best model + batch size * 4
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=128,  
                        num_convs=[16,32,64,64,64,64,64,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("tf_train_dataset:0", shape=(128, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder:0", shape=(128, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_1:0", shape=(128, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 17.586027
# Minibatch accuracy_length: 12.5%
# Minibatch accuracy_digit_0: 0.0%
# Minibatch accuracy_digit_1: 10.2%
# Minibatch accuracy_digit_2: 0.9%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 83.3%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.5%
# finish : 2016-12-09T09:17:10+0900
# Minibatch loss at step 500: 9.765965
# Minibatch accuracy_length: 57.0%
# Minibatch accuracy_digit_0: 28.9%
# Minibatch accuracy_digit_1: 16.4%
# Minibatch accuracy_digit_2: 44.0%
# Minibatch accuracy_digit_3: 91.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-12-09T09:18:06+0900
# Minibatch loss at step 1000: 9.160644
# Minibatch accuracy_length: 49.2%
# Minibatch accuracy_digit_0: 29.7%
# Minibatch accuracy_digit_1: 18.0%
# Minibatch accuracy_digit_2: 57.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-12-09T09:19:03+0900
# Minibatch loss at step 1500: 7.944941
# Minibatch accuracy_length: 83.6%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 55.3%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 1.6%
# Validation accuracy: 1.1%
# finish : 2016-12-09T09:19:58+0900
# Minibatch loss at step 2000: 5.376550
# Minibatch accuracy_length: 89.1%
# Minibatch accuracy_digit_0: 54.7%
# Minibatch accuracy_digit_1: 50.8%
# Minibatch accuracy_digit_2: 74.5%
# Minibatch accuracy_digit_3: 91.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 22.7%
# Validation accuracy: 9.6%
# finish : 2016-12-09T09:20:54+0900
# Minibatch loss at step 2500: 4.766538
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 73.4%
# Minibatch accuracy_digit_1: 60.9%
# Minibatch accuracy_digit_2: 66.9%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 35.9%
# Validation accuracy: 32.9%
# finish : 2016-12-09T09:21:51+0900
# Minibatch loss at step 3000: 3.201708
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 82.0%
# Minibatch accuracy_digit_1: 75.8%
# Minibatch accuracy_digit_2: 81.3%
# Minibatch accuracy_digit_3: 95.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 53.9%
# Validation accuracy: 49.9%
# finish : 2016-12-09T09:22:49+0900
# Minibatch loss at step 3500: 4.071604
# Minibatch accuracy_length: 89.8%
# Minibatch accuracy_digit_0: 73.4%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 80.2%
# Minibatch accuracy_digit_3: 81.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 51.6%
# Validation accuracy: 56.7%
# finish : 2016-12-09T09:23:46+0900
# Minibatch loss at step 4000: 2.105563
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.6%
# Minibatch accuracy_digit_3: 96.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 76.6%
# Validation accuracy: 68.7%
# finish : 2016-12-09T09:24:42+0900
# Minibatch loss at step 4500: 2.209020
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 85.9%
# Minibatch accuracy_digit_1: 89.8%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 73.4%
# Validation accuracy: 72.9%
# finish : 2016-12-09T09:25:40+0900
# Minibatch loss at step 5000: 1.831987
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 88.3%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 89.4%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 73.4%
# Validation accuracy: 76.4%
# finish : 2016-12-09T09:26:37+0900
# Minibatch loss at step 5500: 2.018942
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 85.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 91.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.0%
# finish : 2016-12-09T09:27:35+0900
# Minibatch loss at step 6000: 1.284135
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 94.5%
# Minibatch accuracy_digit_2: 93.7%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 88.3%
# Validation accuracy: 80.1%
# finish : 2016-12-09T09:28:32+0900
# Minibatch loss at step 6500: 1.571138
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.7%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.8%
# finish : 2016-12-09T09:29:30+0900
# Minibatch loss at step 7000: 1.482504
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 91.4%
# Minibatch accuracy_digit_1: 85.9%
# Minibatch accuracy_digit_2: 93.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.8%
# Validation accuracy: 81.9%
# finish : 2016-12-09T09:30:27+0900
# Minibatch loss at step 7500: 1.555646
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 89.8%
# Minibatch accuracy_digit_2: 92.5%
# Minibatch accuracy_digit_3: 94.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.8%
# Validation accuracy: 82.0%
# finish : 2016-12-09T09:31:25+0900
# Minibatch loss at step 8000: 1.023523
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 94.5%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 94.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.2%
# finish : 2016-12-09T09:32:22+0900
# Minibatch loss at step 8500: 1.035657
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 94.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.4%
# finish : 2016-12-09T09:33:19+0900
# Minibatch loss at step 9000: 1.156020
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.0%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 94.8%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 82.0%
# Validation accuracy: 83.7%
# finish : 2016-12-09T09:34:17+0900
# Minibatch loss at step 9500: 0.769436
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 91.4%
# Validation accuracy: 85.4%
# finish : 2016-12-09T09:35:15+0900
# Minibatch loss at step 10000: 0.793645
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 97.6%
# Minibatch accuracy_digit_3: 94.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.3%
# finish : 2016-12-09T09:36:12+0900
# Minibatch loss at step 10500: 1.062452
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 91.4%
# Minibatch accuracy_digit_1: 91.4%
# Minibatch accuracy_digit_2: 93.2%
# Minibatch accuracy_digit_3: 97.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# finish : 2016-12-09T09:37:09+0900
# Minibatch loss at step 11000: 0.981554
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 97.4%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 87.5%
# Minibatch accuracy: 88.3%
# Validation accuracy: 86.4%
# finish : 2016-12-09T09:38:07+0900
# Minibatch loss at step 11500: 0.637227
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.0%
# Validation accuracy: 86.4%
# finish : 2016-12-09T09:39:05+0900
# Minibatch loss at step 12000: 0.592420
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.7%
# finish : 2016-12-09T09:40:03+0900
# Minibatch loss at step 12500: 0.964117
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 89.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# finish : 2016-12-09T09:41:00+0900
# Minibatch loss at step 13000: 0.582963
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.0%
# Validation accuracy: 87.3%
# finish : 2016-12-09T09:41:58+0900
# Minibatch loss at step 13500: 0.518301
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 94.5%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 91.4%
# Validation accuracy: 87.8%
# finish : 2016-12-09T09:42:56+0900
# Minibatch loss at step 14000: 1.017532
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 89.1%
# Minibatch accuracy_digit_1: 92.2%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.5%
# finish : 2016-12-09T09:43:54+0900
# Minibatch loss at step 14500: 0.511913
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 97.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 87.8%
# finish : 2016-12-09T09:44:51+0900
# Minibatch loss at step 15000: 0.468699
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# finish : 2016-12-09T09:45:49+0900
# Minibatch loss at step 15500: 0.431905
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 97.6%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.5%
# finish : 2016-12-09T09:46:46+0900
# Minibatch loss at step 16000: 0.648418
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 93.0%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 97.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.3%
# finish : 2016-12-09T09:47:43+0900
# Minibatch loss at step 16500: 0.418830
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 97.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.4%
# finish : 2016-12-09T09:48:42+0900
# Minibatch loss at step 17000: 0.381392
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.0%
# finish : 2016-12-09T09:49:39+0900
# Minibatch loss at step 17500: 0.734593
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 94.5%
# Minibatch accuracy_digit_2: 98.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.9%
# finish : 2016-12-09T09:50:37+0900
# Minibatch loss at step 18000: 0.506820
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.9%
# finish : 2016-12-09T09:51:35+0900
# Minibatch loss at step 18500: 0.741560
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 97.5%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.3%
# finish : 2016-12-09T09:52:33+0900
# Minibatch loss at step 19000: 0.491311
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# finish : 2016-12-09T09:53:31+0900
# Minibatch loss at step 19500: 0.761277
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 94.5%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.1%
# finish : 2016-12-09T09:54:29+0900
# Minibatch loss at step 20000: 0.579091
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 97.6%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.7%
# finish : 2016-12-09T09:55:27+0900
# Minibatch loss at step 20500: 0.345530
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.9%
# finish : 2016-12-09T09:56:24+0900
# Minibatch loss at step 21000: 0.584161
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 94.7%
# Minibatch accuracy_digit_3: 97.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# finish : 2016-12-09T09:57:23+0900
# Minibatch loss at step 21500: 0.239097
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.0%
# finish : 2016-12-09T09:58:21+0900
# Minibatch loss at step 22000: 0.336482
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.4%
# finish : 2016-12-09T09:59:18+0900
# Minibatch loss at step 22500: 0.307097
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.3%
# finish : 2016-12-09T10:00:16+0900
# Minibatch loss at step 23000: 0.436720
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 87.8%
# finish : 2016-12-09T10:01:14+0900
# Minibatch loss at step 23500: 0.233365
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.7%
# finish : 2016-12-09T10:02:11+0900
# Minibatch loss at step 24000: 0.279470
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-12-09T10:03:09+0900
# Minibatch loss at step 24500: 0.395688
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 98.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# finish : 2016-12-09T10:04:07+0900
# Minibatch loss at step 25000: 0.428630
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.9%
# finish : 2016-12-09T10:05:05+0900
# Minibatch loss at step 25500: 0.394746
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:06:03+0900
# Minibatch loss at step 26000: 0.391056
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 97.6%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-12-09T10:07:01+0900
# Minibatch loss at step 26500: 0.308189
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 99.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.5%
# finish : 2016-12-09T10:07:59+0900
# Minibatch loss at step 27000: 0.207107
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.7%
# finish : 2016-12-09T10:08:57+0900
# Minibatch loss at step 27500: 0.219415
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.3%
# finish : 2016-12-09T10:09:55+0900
# Minibatch loss at step 28000: 0.442295
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 91.4%
# Validation accuracy: 87.7%
# finish : 2016-12-09T10:10:53+0900
# Minibatch loss at step 28500: 0.283570
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 88.9%
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.3%
# finish : 2016-12-09T10:11:51+0900
# Minibatch loss at step 29000: 0.668518
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 98.8%
# Minibatch accuracy_digit_4: 88.9%
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.5%
# finish : 2016-12-09T10:12:49+0900
# Minibatch loss at step 29500: 0.237720
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-12-09T10:13:46+0900
# Minibatch loss at step 30000: 0.276105
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.1%
# finish : 2016-12-09T10:14:44+0900
# Minibatch loss at step 30500: 0.224306
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:15:42+0900
# Minibatch loss at step 31000: 0.320019
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:16:40+0900
# Minibatch loss at step 31500: 0.353960
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 96.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.9%
# finish : 2016-12-09T10:17:38+0900
# Minibatch loss at step 32000: 0.173716
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.2%
# finish : 2016-12-09T10:18:36+0900
# Minibatch loss at step 32500: 0.405213
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.2%
# finish : 2016-12-09T10:19:33+0900
# Minibatch loss at step 33000: 0.158887
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.4%
# finish : 2016-12-09T10:20:32+0900
# Minibatch loss at step 33500: 0.353006
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 99.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 87.9%
# finish : 2016-12-09T10:21:29+0900
# Minibatch loss at step 34000: 0.168493
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:22:27+0900
# Minibatch loss at step 34500: 0.183809
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:23:25+0900
# Minibatch loss at step 35000: 0.270970
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.0%
# finish : 2016-12-09T10:24:23+0900
# Minibatch loss at step 35500: 0.201178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# finish : 2016-12-09T10:25:20+0900
# Minibatch loss at step 36000: 0.172246
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 75.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.0%
# finish : 2016-12-09T10:26:18+0900
# Minibatch loss at step 36500: 0.160275
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T10:27:15+0900
# Minibatch loss at step 37000: 0.189074
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.4%
# finish : 2016-12-09T10:28:12+0900
# Minibatch loss at step 37500: 0.132444
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-12-09T10:29:10+0900
# Minibatch loss at step 38000: 0.154161
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-09T10:30:08+0900
# Minibatch loss at step 38500: 0.245300
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.2%
# finish : 2016-12-09T10:31:05+0900
# Minibatch loss at step 39000: 0.157096
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.8%
# finish : 2016-12-09T10:32:03+0900
# Minibatch loss at step 39500: 0.131496
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:33:00+0900
# Minibatch loss at step 40000: 0.155554
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:33:57+0900
# Minibatch loss at step 40500: 0.240658
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.2%
# finish : 2016-12-09T10:34:54+0900
# Minibatch loss at step 41000: 0.140067
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:35:51+0900
# Minibatch loss at step 41500: 0.147636
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.2%
# finish : 2016-12-09T10:36:48+0900
# Minibatch loss at step 42000: 0.229260
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.8%
# finish : 2016-12-09T10:37:46+0900
# Minibatch loss at step 42500: 0.159877
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.8%
# finish : 2016-12-09T10:38:43+0900
# Minibatch loss at step 43000: 0.116520
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-09T10:39:41+0900
# Minibatch loss at step 43500: 0.132367
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T10:40:38+0900
# Minibatch loss at step 44000: 0.170546
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.4%
# finish : 2016-12-09T10:41:35+0900
# Minibatch loss at step 44500: 0.150332
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:42:32+0900
# Minibatch loss at step 45000: 0.114292
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-09T10:43:29+0900
# Minibatch loss at step 45500: 0.142590
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-12-09T10:44:27+0900
# Minibatch loss at step 46000: 0.137280
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-12-09T10:45:24+0900
# Minibatch loss at step 46500: 0.113731
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-12-09T10:46:22+0900
# Minibatch loss at step 47000: 0.110236
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T10:47:20+0900
# Minibatch loss at step 47500: 0.126619
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# finish : 2016-12-09T10:48:17+0900
# Minibatch loss at step 48000: 0.112178
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-09T10:49:14+0900
# Minibatch loss at step 48500: 0.114714
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T10:50:12+0900
# Minibatch loss at step 49000: 0.126786
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# finish : 2016-12-09T10:51:09+0900
# Minibatch loss at step 49500: 0.588139
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 87.5%
# Minibatch accuracy: 91.4%
# Validation accuracy: 87.9%
# finish : 2016-12-09T10:52:07+0900
# Minibatch loss at step 50000: 0.287255
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 97.5%
# Minibatch accuracy_digit_3: 98.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.8%
# finish : 2016-12-09T10:53:06+0900
# Minibatch loss at step 50500: 0.179562
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 97.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:54:05+0900
# Minibatch loss at step 51000: 0.474820
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 98.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.2%
# finish : 2016-12-09T10:55:04+0900
# Minibatch loss at step 51500: 0.119987
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T10:56:02+0900
# Minibatch loss at step 52000: 0.118920
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T10:57:00+0900
# Minibatch loss at step 52500: 0.248893
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.6%
# finish : 2016-12-09T10:57:58+0900
# Minibatch loss at step 53000: 0.140623
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.8%
# finish : 2016-12-09T10:58:55+0900
# Minibatch loss at step 53500: 0.138933
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.2%
# finish : 2016-12-09T10:59:53+0900
# Minibatch loss at step 54000: 0.124531
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:00:51+0900
# Minibatch loss at step 54500: 0.122713
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# finish : 2016-12-09T11:01:48+0900
# Minibatch loss at step 55000: 0.114892
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T11:02:46+0900
# Minibatch loss at step 55500: 0.114853
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T11:03:44+0900
# Minibatch loss at step 56000: 0.124731
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T11:04:42+0900
# Minibatch loss at step 56500: 0.103432
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T11:05:40+0900
# Minibatch loss at step 57000: 0.117862
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:06:38+0900
# Minibatch loss at step 57500: 0.116667
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:07:36+0900
# Minibatch loss at step 58000: 0.119875
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# finish : 2016-12-09T11:08:33+0900
# Minibatch loss at step 58500: 0.105519
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:09:31+0900
# Minibatch loss at step 59000: 0.111332
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:10:29+0900
# Minibatch loss at step 59500: 0.118816
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T11:11:27+0900
# Minibatch loss at step 60000: 0.102059
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-09T11:12:24+0900
# Minibatch loss at step 60500: 0.095074
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:13:22+0900
# Minibatch loss at step 61000: 0.092701
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:14:20+0900
# Minibatch loss at step 61500: 0.119365
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.8%
# finish : 2016-12-09T11:15:18+0900
# Minibatch loss at step 62000: 0.104191
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:16:16+0900
# Minibatch loss at step 62500: 0.109108
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:17:14+0900
# Minibatch loss at step 63000: 0.096895
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-09T11:18:12+0900
# Minibatch loss at step 63500: 0.103841
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:19:10+0900
# Minibatch loss at step 64000: 0.088424
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T11:20:08+0900
# Minibatch loss at step 64500: 0.089643
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:21:06+0900
# Minibatch loss at step 65000: 0.098710
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-12-09T11:22:05+0900
# Minibatch loss at step 65500: 0.088084
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:23:03+0900
# Minibatch loss at step 66000: 0.083068
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T11:24:01+0900
# Minibatch loss at step 66500: 0.104704
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-09T11:25:00+0900
# Minibatch loss at step 67000: 0.090953
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:25:57+0900
# Minibatch loss at step 67500: 0.084444
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:26:55+0900
# Minibatch loss at step 68000: 0.088792
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:27:53+0900
# Minibatch loss at step 68500: 0.088794
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-12-09T11:28:51+0900
# Minibatch loss at step 69000: 0.085158
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:29:50+0900
# Minibatch loss at step 69500: 0.089868
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:30:47+0900
# Minibatch loss at step 70000: 0.104620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-09T11:31:46+0900
# Minibatch loss at step 70500: 0.082423
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:32:45+0900
# Minibatch loss at step 71000: 0.090380
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:33:42+0900
# Minibatch loss at step 71500: 0.076450
# ...
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-09T11:44:24+0900
# Minibatch loss at step 77000: 0.082364
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-09T11:45:22+0900
# Minibatch loss at step 77500: 0.074802
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T11:46:21+0900
# Minibatch loss at step 78000: 0.069181
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T11:47:19+0900
# Minibatch loss at step 78500: 0.071048
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-12-09T11:48:17+0900
# Minibatch loss at step 79000: 0.075327
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-12-09T11:49:15+0900
# Minibatch loss at step 79500: 0.075656
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:50:14+0900
# Minibatch loss at step 80000: 0.070969
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:51:11+0900
# Minibatch loss at step 80500: 0.078755
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-09T11:52:10+0900
# Minibatch loss at step 81000: 0.072231
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T11:53:08+0900
# Minibatch loss at step 81500: 0.072503
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T11:54:07+0900
# Minibatch loss at step 82000: 0.066084
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-12-09T11:55:05+0900
# Minibatch loss at step 82500: 0.070664
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T11:56:04+0900
# Minibatch loss at step 83000: 0.067575
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:57:02+0900
# Minibatch loss at step 83500: 0.065033
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T11:58:00+0900
# Minibatch loss at step 84000: 0.092101
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T11:58:59+0900
# Minibatch loss at step 84500: 0.074044
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T11:59:57+0900
# Minibatch loss at step 85000: 0.068174
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T12:00:55+0900
# Minibatch loss at step 85500: 0.069185
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T12:01:54+0900
# Minibatch loss at step 86000: 0.075604
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T12:02:52+0900
# Minibatch loss at step 86500: 0.068650
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T12:03:50+0900
# Minibatch loss at step 87000: 0.062940
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T12:04:48+0900
# Minibatch loss at step 87500: 0.076966
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T12:05:46+0900
# Minibatch loss at step 88000: 0.064122
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T12:06:45+0900
# Minibatch loss at step 88500: 0.065620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T12:07:43+0900
# Minibatch loss at step 89000: 0.066531
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T12:08:42+0900
# Minibatch loss at step 89500: 0.064406
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.0%
# finish : 2016-12-09T12:09:40+0900
# Minibatch loss at step 90000: 0.063192
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T12:10:38+0900
# Minibatch loss at step 90500: 0.066287
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T12:11:36+0900
# Minibatch loss at step 91000: 0.075203
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T12:12:35+0900
# Minibatch loss at step 91500: 0.064004
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T12:13:33+0900
# Minibatch loss at step 92000: 0.074489
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T12:14:31+0900
# Minibatch loss at step 92500: 0.058230
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T12:15:29+0900
# Minibatch loss at step 93000: 0.235947
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# finish : 2016-12-09T12:16:28+0900
# Minibatch loss at step 93500: 0.184417
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.4%
# finish : 2016-12-09T12:17:27+0900
# Minibatch loss at step 94000: 0.162667
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.4%
# finish : 2016-12-09T12:18:26+0900
# Minibatch loss at step 94500: 0.239489
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.3%
# finish : 2016-12-09T12:19:26+0900
# Minibatch loss at step 95000: 0.080922
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-09T12:20:25+0900
# Minibatch loss at step 95500: 0.099943
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.3%
# finish : 2016-12-09T12:21:24+0900
# Minibatch loss at step 96000: 0.097723
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.4%
# finish : 2016-12-09T12:22:23+0900
# Minibatch loss at step 96500: 0.082199
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-12-09T12:23:22+0900
# Minibatch loss at step 97000: 0.073983
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T12:24:21+0900
# Minibatch loss at step 97500: 0.082947
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-09T12:25:20+0900
# Minibatch loss at step 98000: 0.109244
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.2%
# finish : 2016-12-09T12:26:19+0900
# Minibatch loss at step 98500: 0.083403
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.5%
# finish : 2016-12-09T12:27:18+0900
# Minibatch loss at step 99000: 0.068012
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T12:28:16+0900
# Minibatch loss at step 99500: 0.073013
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-09T12:29:14+0900
# Minibatch loss at step 100000: 0.072916
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T12:30:13+0900
# Test accuracy: 89.3%
# finish : 2016-12-09T12:30:15+0900
# Converted 32 variables to const ops.

# %%
# best model + batch size * 2
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=100001, 
                        batch_size=64,  
                        num_convs=[16,32,64,64,64,64,64,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("tf_train_dataset:0", shape=(128, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder:0", shape=(128, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_1:0", shape=(128, 5, 10), dtype=float32)
# Initialized
# Minibatch loss at step 0: 15.580715
# Minibatch accuracy_length: 0.8%
# Minibatch accuracy_digit_0: 7.0%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 2.6%
# Minibatch accuracy_digit_3: 80.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.5%
# finish : 2016-12-09T12:30:25+0900
# Minibatch loss at step 500: 9.758377
# Minibatch accuracy_length: 57.0%
# Minibatch accuracy_digit_0: 28.9%
# Minibatch accuracy_digit_1: 16.4%
# Minibatch accuracy_digit_2: 44.0%
# Minibatch accuracy_digit_3: 91.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-12-09T12:31:22+0900
# Minibatch loss at step 1000: 9.144231
# Minibatch accuracy_length: 49.2%
# Minibatch accuracy_digit_0: 29.7%
# Minibatch accuracy_digit_1: 18.0%
# Minibatch accuracy_digit_2: 57.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.3%
# finish : 2016-12-09T12:32:19+0900
# Minibatch loss at step 1500: 8.287293
# Minibatch accuracy_length: 69.5%
# Minibatch accuracy_digit_0: 35.2%
# Minibatch accuracy_digit_1: 20.3%
# Minibatch accuracy_digit_2: 55.3%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 2.3%
# Validation accuracy: 0.9%
# finish : 2016-12-09T12:33:16+0900
# Minibatch loss at step 2000: 5.734995
# Minibatch accuracy_length: 85.9%
# Minibatch accuracy_digit_0: 54.7%
# Minibatch accuracy_digit_1: 44.5%
# Minibatch accuracy_digit_2: 70.6%
# Minibatch accuracy_digit_3: 91.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 16.4%
# Validation accuracy: 8.8%
# finish : 2016-12-09T12:34:13+0900
# Minibatch loss at step 2500: 4.830159
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 74.2%
# Minibatch accuracy_digit_1: 60.2%
# Minibatch accuracy_digit_2: 66.9%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 32.8%
# Validation accuracy: 35.0%
# finish : 2016-12-09T12:35:11+0900
# Minibatch loss at step 3000: 2.982689
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 85.9%
# Minibatch accuracy_digit_1: 78.9%
# Minibatch accuracy_digit_2: 81.3%
# Minibatch accuracy_digit_3: 95.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 55.5%
# finish : 2016-12-09T12:36:10+0900
# Minibatch loss at step 3500: 3.821368
# Minibatch accuracy_length: 91.4%
# Minibatch accuracy_digit_0: 75.8%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 82.0%
# Minibatch accuracy_digit_3: 85.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 61.0%
# finish : 2016-12-09T12:37:08+0900
# Minibatch loss at step 4000: 2.017835
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 89.1%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 87.8%
# Minibatch accuracy_digit_3: 92.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 70.5%
# finish : 2016-12-09T12:38:06+0900
# Minibatch loss at step 4500: 1.996592
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 88.3%
# Minibatch accuracy_digit_1: 85.9%
# Minibatch accuracy_digit_2: 88.8%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.1%
# Validation accuracy: 75.0%
# finish : 2016-12-09T12:39:04+0900
# Minibatch loss at step 5000: 1.847772
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 91.4%
# Minibatch accuracy_digit_2: 87.0%
# Minibatch accuracy_digit_3: 96.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.1%
# Validation accuracy: 78.6%
# finish : 2016-12-09T12:40:03+0900
# Minibatch loss at step 5500: 1.909984
# Minibatch accuracy_length: 94.5%
# Minibatch accuracy_digit_0: 91.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 91.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 73.4%
# Validation accuracy: 78.6%
# finish : 2016-12-09T12:41:01+0900
# Minibatch loss at step 6000: 1.225323
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 88.3%
# Validation accuracy: 81.8%
# finish : 2016-12-09T12:41:59+0900
# Minibatch loss at step 6500: 1.511422
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.0%
# Minibatch accuracy_digit_2: 89.8%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.6%
# finish : 2016-12-09T12:42:57+0900
# Minibatch loss at step 7000: 1.361098
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 89.1%
# Minibatch accuracy_digit_2: 93.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.9%
# Validation accuracy: 83.9%
# finish : 2016-12-09T12:43:56+0900
# Minibatch loss at step 7500: 1.404706
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.0%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 93.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 80.5%
# Validation accuracy: 83.8%
# finish : 2016-12-09T12:44:55+0900
# Minibatch loss at step 8000: 1.026580
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 93.0%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.2%
# finish : 2016-12-09T12:45:54+0900
# Minibatch loss at step 8500: 1.047648
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 86.7%
# Validation accuracy: 85.2%
# finish : 2016-12-09T12:46:53+0900
# Minibatch loss at step 9000: 1.036891
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 94.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.8%
# finish : 2016-12-09T12:47:52+0900
# Minibatch loss at step 9500: 0.757979
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 91.4%
# Validation accuracy: 86.4%
# finish : 2016-12-09T12:48:51+0900
# Minibatch loss at step 10000: 0.877408
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 94.4%
# Minibatch accuracy_digit_3: 96.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 91.4%
# Validation accuracy: 85.8%
# finish : 2016-12-09T12:49:49+0900
# Minibatch loss at step 10500: 1.065078
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 91.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.2%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# finish : 2016-12-09T12:50:48+0900
# Minibatch loss at step 11000: 0.844466
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 97.4%
# Minibatch accuracy_digit_3: 98.5%
# Minibatch accuracy_digit_4: 87.5%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-12-09T12:51:47+0900
# Minibatch loss at step 11500: 0.633512
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 97.5%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 91.4%
# Validation accuracy: 87.6%
# finish : 2016-12-09T12:52:46+0900
# Minibatch loss at step 12000: 0.596207
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 97.6%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.1%
# finish : 2016-12-09T12:53:45+0900
# Minibatch loss at step 12500: 0.941905
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 92.2%
# Minibatch accuracy_digit_1: 89.1%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 96.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.6%
# finish : 2016-12-09T12:54:44+0900
# Minibatch loss at step 13000: 0.510479
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 94.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.3%
# finish : 2016-12-09T12:55:43+0900
# Minibatch loss at step 13500: 0.488172
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 98.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.2%
# finish : 2016-12-09T12:56:42+0900
# Minibatch loss at step 14000: 1.076874
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 94.6%
# Minibatch accuracy_digit_3: 97.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.9%
# finish : 2016-12-09T12:57:40+0900
# Minibatch loss at step 14500: 0.517016
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 97.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.5%
# finish : 2016-12-09T12:58:39+0900
# Minibatch loss at step 15000: 0.367409
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.7%
# finish : 2016-12-09T12:59:37+0900
# Minibatch loss at step 15500: 0.343571
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.2%
# finish : 2016-12-09T13:00:37+0900
# Minibatch loss at step 16000: 0.616799
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 94.5%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 98.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# finish : 2016-12-09T13:01:36+0900
# Minibatch loss at step 16500: 0.443906
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.3%
# finish : 2016-12-09T13:02:34+0900
# Minibatch loss at step 17000: 0.333561
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.8%
# finish : 2016-12-09T13:03:33+0900
# Minibatch loss at step 17500: 0.684237
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 94.5%
# Minibatch accuracy_digit_2: 99.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-12-09T13:04:31+0900
# Minibatch loss at step 18000: 0.531480
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 97.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.1%
# finish : 2016-12-09T13:05:30+0900
# Minibatch loss at step 18500: 0.693334
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 97.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.0%
# finish : 2016-12-09T13:06:29+0900
# Minibatch loss at step 19000: 0.480987
# Minibatch accuracy_length: 97.7%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 89.1%
# finish : 2016-12-09T13:07:28+0900
# Minibatch loss at step 19500: 0.642731
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 97.2%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.7%
# finish : 2016-12-09T13:08:27+0900
# Minibatch loss at step 20000: 0.657227
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-12-09T13:09:26+0900
# Minibatch loss at step 20500: 0.390106
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 94.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-12-09T13:10:25+0900
# Minibatch loss at step 21000: 0.521023
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 94.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.0%
# finish : 2016-12-09T13:11:24+0900
# Minibatch loss at step 21500: 0.266492
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-12-09T13:12:22+0900
# Minibatch loss at step 22000: 0.307172
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.7%
# finish : 2016-12-09T13:13:22+0900
# Minibatch loss at step 22500: 0.274355
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 89.0%
# finish : 2016-12-09T13:14:21+0900
# Minibatch loss at step 23000: 0.321984
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.6%
# finish : 2016-12-09T13:15:20+0900
# Minibatch loss at step 23500: 0.256878
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.2%
# finish : 2016-12-09T13:16:19+0900
# Minibatch loss at step 24000: 0.301266
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 97.6%
# Minibatch accuracy_digit_3: 98.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.5%
# finish : 2016-12-09T13:17:17+0900
# Minibatch loss at step 24500: 0.359011
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 97.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.3%
# finish : 2016-12-09T13:18:16+0900
# Minibatch loss at step 25000: 0.334106
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.3%
# finish : 2016-12-09T13:19:15+0900
# Minibatch loss at step 25500: 0.429689
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.3%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.6%
# finish : 2016-12-09T13:20:14+0900
# Minibatch loss at step 26000: 0.412973
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.3%
# finish : 2016-12-09T13:21:14+0900
# Minibatch loss at step 26500: 0.264291
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 99.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# finish : 2016-12-09T13:22:13+0900
# Minibatch loss at step 27000: 0.227483
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-12-09T13:23:12+0900
# Minibatch loss at step 27500: 0.208213
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.6%
# finish : 2016-12-09T13:24:11+0900
# Minibatch loss at step 28000: 0.427785
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 95.3%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.0%
# finish : 2016-12-09T13:25:10+0900
# Minibatch loss at step 28500: 0.284372
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 97.7%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 88.9%
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.5%
# finish : 2016-12-09T13:26:08+0900
# Minibatch loss at step 29000: 0.631730
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 98.8%
# Minibatch accuracy_digit_4: 88.9%
# Minibatch accuracy: 96.1%
# Validation accuracy: 88.8%
# finish : 2016-12-09T13:27:07+0900
# Minibatch loss at step 29500: 0.229580
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-12-09T13:28:07+0900
# Minibatch loss at step 30000: 0.221611
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.3%
# finish : 2016-12-09T13:29:06+0900
# Minibatch loss at step 30500: 0.287805
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 97.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.9%
# finish : 2016-12-09T13:30:05+0900
# Minibatch loss at step 31000: 0.321908
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.3%
# finish : 2016-12-09T13:31:04+0900
# Minibatch loss at step 31500: 0.390453
# Minibatch accuracy_length: 98.4%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 98.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 89.2%
# finish : 2016-12-09T13:32:03+0900
# Minibatch loss at step 32000: 0.171879
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.7%
# finish : 2016-12-09T13:33:02+0900
# Minibatch loss at step 32500: 0.371871
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.0%
# finish : 2016-12-09T13:34:02+0900
# Minibatch loss at step 33000: 0.164924
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T13:35:01+0900
# Minibatch loss at step 33500: 0.258772
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-12-09T13:36:00+0900
# Minibatch loss at step 34000: 0.186383
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-12-09T13:36:58+0900
# Minibatch loss at step 34500: 0.182639
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.5%
# finish : 2016-12-09T13:37:57+0900
# Minibatch loss at step 35000: 0.256546
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 99.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.3%
# finish : 2016-12-09T13:38:56+0900
# Minibatch loss at step 35500: 0.708663
# Minibatch accuracy_length: 95.3%
# Minibatch accuracy_digit_0: 96.1%
# Minibatch accuracy_digit_1: 96.1%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 93.4%
# Minibatch accuracy_digit_4: 93.3%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# finish : 2016-12-09T13:39:55+0900
# Minibatch loss at step 36000: 0.296326
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 75.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.8%
# finish : 2016-12-09T13:40:55+0900
# Minibatch loss at step 36500: 0.237392
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 98.6%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# finish : 2016-12-09T13:41:55+0900
# Minibatch loss at step 37000: 0.266528
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 95.3%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.9%
# finish : 2016-12-09T13:42:54+0900
# Minibatch loss at step 37500: 0.180087
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.3%
# finish : 2016-12-09T13:43:53+0900
# Minibatch loss at step 38000: 0.192002
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.7%
# finish : 2016-12-09T13:44:53+0900
# Minibatch loss at step 38500: 0.262891
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 97.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.9%
# finish : 2016-12-09T13:45:52+0900
# Minibatch loss at step 39000: 0.192854
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.2%
# finish : 2016-12-09T13:46:52+0900
# Minibatch loss at step 39500: 0.140651
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T13:47:51+0900
# Minibatch loss at step 40000: 0.164729
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 90.0%
# finish : 2016-12-09T13:48:50+0900
# Minibatch loss at step 40500: 0.279922
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.1%
# finish : 2016-12-09T13:49:50+0900
# Minibatch loss at step 41000: 0.144043
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T13:50:49+0900
# Minibatch loss at step 41500: 0.165671
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.4%
# finish : 2016-12-09T13:51:49+0900
# Minibatch loss at step 42000: 0.235550
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# finish : 2016-12-09T13:52:47+0900
# Minibatch loss at step 42500: 0.201597
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-12-09T13:53:46+0900
# Minibatch loss at step 43000: 0.134678
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T13:54:46+0900
# Minibatch loss at step 43500: 0.165461
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.5%
# finish : 2016-12-09T13:55:45+0900
# Minibatch loss at step 44000: 0.176120
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.2%
# finish : 2016-12-09T13:56:44+0900
# Minibatch loss at step 44500: 0.155701
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T13:57:43+0900
# Minibatch loss at step 45000: 0.130013
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.7%
# finish : 2016-12-09T13:58:43+0900
# Minibatch loss at step 45500: 0.147536
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T13:59:42+0900
# Minibatch loss at step 46000: 0.137421
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-09T14:00:41+0900
# Minibatch loss at step 46500: 0.118823
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T14:01:41+0900
# Minibatch loss at step 47000: 0.120213
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T14:02:41+0900
# Minibatch loss at step 47500: 0.127706
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-09T14:03:40+0900
# Minibatch loss at step 48000: 0.113972
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T14:04:39+0900
# Minibatch loss at step 48500: 0.126567
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-09T14:05:38+0900
# Minibatch loss at step 49000: 0.121214
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T14:06:37+0900
# Minibatch loss at step 49500: 0.209623
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 87.5%
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.4%
# finish : 2016-12-09T14:07:36+0900
# Minibatch loss at step 50000: 0.121968
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T14:08:35+0900
# Minibatch loss at step 50500: 0.104662
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T14:09:33+0900
# Minibatch loss at step 51000: 0.209717
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 88.8%
# finish : 2016-12-09T14:10:33+0900
# Minibatch loss at step 51500: 0.104242
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-12-09T14:11:31+0900
# Minibatch loss at step 52000: 0.106734
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T14:12:30+0900
# Minibatch loss at step 52500: 0.181897
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 99.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 89.6%
# finish : 2016-12-09T14:13:29+0900
# Minibatch loss at step 53000: 0.105947
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T14:14:28+0900
# Minibatch loss at step 53500: 0.120186
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 90.1%
# finish : 2016-12-09T14:15:26+0900
# Minibatch loss at step 54000: 0.111801
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T14:16:25+0900
# Minibatch loss at step 54500: 0.111735
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-09T14:17:24+0900
# Minibatch loss at step 55000: 0.097284
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T14:18:24+0900
# Minibatch loss at step 55500: 0.098159
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T14:19:23+0900
# Minibatch loss at step 56000: 1.071276
# Minibatch accuracy_length: 96.1%
# Minibatch accuracy_digit_0: 88.3%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 87.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 76.6%
# Validation accuracy: 82.2%
# finish : 2016-12-09T14:20:22+0900
# Minibatch loss at step 56500: 0.144275
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.2%
# finish : 2016-12-09T14:21:22+0900
# Minibatch loss at step 57000: 0.151630
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 98.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.6%
# finish : 2016-12-09T14:22:22+0900
# Minibatch loss at step 57500: 0.177158
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 97.7%
# Minibatch accuracy_digit_2: 99.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.0%
# finish : 2016-12-09T14:23:22+0900
# Minibatch loss at step 58000: 0.201660
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 97.7%
# Validation accuracy: 88.8%
# finish : 2016-12-09T14:24:21+0900
# Minibatch loss at step 58500: 0.172913
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.6%
# finish : 2016-12-09T14:25:21+0900
# Minibatch loss at step 59000: 0.182524
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 98.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 90.0%
# finish : 2016-12-09T14:26:21+0900
# Minibatch loss at step 59500: 0.163412
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.5%
# finish : 2016-12-09T14:27:21+0900
# Minibatch loss at step 60000: 0.111109
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-09T14:28:21+0900
# Minibatch loss at step 60500: 0.102243
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T14:29:20+0900
# Minibatch loss at step 61000: 0.107335
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T14:30:20+0900
# Minibatch loss at step 61500: 0.114929
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-09T14:31:20+0900
# Minibatch loss at step 62000: 0.114355
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T14:32:20+0900
# Minibatch loss at step 62500: 0.116537
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 98.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 90.4%
# finish : 2016-12-09T14:33:20+0900
# Minibatch loss at step 63000: 0.111550
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T14:34:19+0900
# Minibatch loss at step 63500: 0.106905
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T14:35:19+0900
# Minibatch loss at step 64000: 0.093381
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T14:36:18+0900
# Minibatch loss at step 64500: 0.095509
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-12-09T14:37:18+0900
# Minibatch loss at step 65000: 0.098033
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-09T14:38:17+0900
# Minibatch loss at step 65500: 0.089918
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T14:39:17+0900
# Minibatch loss at step 66000: 0.090593
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T14:40:17+0900
# Minibatch loss at step 66500: 0.122567
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T14:41:17+0900
# Minibatch loss at step 67000: 0.090658
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T14:42:16+0900
# Minibatch loss at step 67500: 0.088730
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T14:43:16+0900
# Minibatch loss at step 68000: 0.091092
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-12-09T14:44:15+0900
# Minibatch loss at step 68500: 0.097781
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 99.2%
# Validation accuracy: 89.3%
# finish : 2016-12-09T14:45:15+0900
# Minibatch loss at step 69000: 0.088336
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T14:46:14+0900
# Minibatch loss at step 69500: 0.095328
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T14:47:14+0900
# Minibatch loss at step 70000: 0.105558
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T14:48:13+0900
# Minibatch loss at step 70500: 0.085659
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T14:49:13+0900
# Minibatch loss at step 71000: 0.093920
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T14:50:12+0900
# Minibatch loss at step 71500: 0.079802
# Minibatch accuracy_length: 100.0%
# ...
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T15:01:07+0900
# Minibatch loss at step 77000: 0.091268
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T15:02:07+0900
# Minibatch loss at step 77500: 0.076034
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T15:03:06+0900
# Minibatch loss at step 78000: 0.070402
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T15:04:05+0900
# Minibatch loss at step 78500: 0.075548
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-12-09T15:05:04+0900
# Minibatch loss at step 79000: 0.077982
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-09T15:06:03+0900
# Minibatch loss at step 79500: 0.075112
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T15:07:03+0900
# Minibatch loss at step 80000: 0.074025
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T15:08:02+0900
# Minibatch loss at step 80500: 0.081519
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T15:09:02+0900
# Minibatch loss at step 81000: 0.076701
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T15:10:01+0900
# Minibatch loss at step 81500: 0.072374
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-12-09T15:11:02+0900
# Minibatch loss at step 82000: 0.065133
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.7%
# finish : 2016-12-09T15:12:01+0900
# Minibatch loss at step 82500: 0.072643
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T15:13:01+0900
# Minibatch loss at step 83000: 0.070713
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T15:14:00+0900
# Minibatch loss at step 83500: 0.067933
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T15:14:59+0900
# Minibatch loss at step 84000: 0.099973
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T15:15:58+0900
# Minibatch loss at step 84500: 0.082153
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T15:16:58+0900
# Minibatch loss at step 85000: 0.070976
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T15:17:57+0900
# Minibatch loss at step 85500: 0.071322
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-12-09T15:18:57+0900
# Minibatch loss at step 86000: 0.085389
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T15:19:56+0900
# Minibatch loss at step 86500: 0.067580
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T15:20:55+0900
# Minibatch loss at step 87000: 0.066966
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T15:21:54+0900
# Minibatch loss at step 87500: 0.077660
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T15:22:54+0900
# Minibatch loss at step 88000: 0.065865
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T15:23:53+0900
# Minibatch loss at step 88500: 0.068133
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-12-09T15:24:53+0900
# Minibatch loss at step 89000: 0.067546
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-12-09T15:25:53+0900
# Minibatch loss at step 89500: 0.063715
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T15:26:53+0900
# Minibatch loss at step 90000: 0.066300
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T15:27:52+0900
# Minibatch loss at step 90500: 0.067096
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T15:28:52+0900
# Minibatch loss at step 91000: 0.073254
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T15:29:52+0900
# Minibatch loss at step 91500: 0.069817
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T15:30:52+0900
# Minibatch loss at step 92000: 0.074962
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T15:31:51+0900
# Minibatch loss at step 92500: 0.059428
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.6%
# finish : 2016-12-09T15:32:51+0900
# Minibatch loss at step 93000: 0.121370
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 98.4%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 88.6%
# finish : 2016-12-09T15:33:51+0900
# Minibatch loss at step 93500: 0.118760
# Minibatch accuracy_length: 99.2%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 98.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.5%
# finish : 2016-12-09T15:34:51+0900
# Minibatch loss at step 94000: 0.100516
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 99.2%
# Minibatch accuracy_digit_1: 99.2%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 98.4%
# Validation accuracy: 89.8%
# finish : 2016-12-09T15:35:52+0900
# Minibatch loss at step 94500: 0.085561
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T15:36:52+0900
# Minibatch loss at step 95000: 0.077153
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-09T15:37:52+0900
# Minibatch loss at step 95500: 0.080913
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-09T15:38:52+0900
# Minibatch loss at step 96000: 0.075920
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-12-09T15:39:53+0900
# Minibatch loss at step 96500: 0.077172
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
# finish : 2016-12-09T15:40:53+0900
# Minibatch loss at step 97000: 0.067165
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T15:41:53+0900
# Minibatch loss at step 97500: 0.071282
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.4%
# finish : 2016-12-09T15:42:53+0900
# Minibatch loss at step 98000: 0.074703
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-09T15:43:52+0900
# Minibatch loss at step 98500: 0.068960
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
# finish : 2016-12-09T15:44:52+0900
# Minibatch loss at step 99000: 0.066368
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-09T15:45:52+0900
# Minibatch loss at step 99500: 0.066476
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.5%
# finish : 2016-12-09T15:46:51+0900
# Minibatch loss at step 100000: 0.066191
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-09T15:47:52+0900
# Test accuracy: 89.5%
# finish : 2016-12-09T15:47:54+0900
# Converted 32 variables to const ops.
