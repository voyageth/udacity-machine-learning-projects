# %% [markdown]
# change 0-9 -> 0-9 + unknown

# %%
import os

if not os.path.exists('svhn'):
    os.makedirs('svhn')
if not os.path.exists('svhn/raw'):
    os.makedirs('svhn/raw')
if not os.path.exists('svhn/converted'):
    os.makedirs('svhn/converted')
if not os.path.exists('svhn/reader'):
    os.makedirs('svhn/reader')
if not os.path.exists('svhn/reader/v2'):
    os.makedirs('svhn/reader/v2')
if not os.path.exists('graph'):
    os.makedirs('graph')
if not os.path.exists('graph/v2'):
    os.makedirs('graph/v2')

# %%
import gc
import os
import os.path
import time
import random

import PIL.Image as Image
import matplotlib.pyplot as plt
import numpy as np
from six.moves import cPickle as pickle
from skimage.transform import resize
from skimage.transform import rotate
from scipy.ndimage import gaussian_filter


class MultiDigitSVHNData(object):
    def __init__(self, digit_count=5, input_total_data_count=1, 
                image_size=32, use_standard_score=False, add_margin=False, margin_ratio=0.1,
                random_position_count=0, random_rotate_count=0, apply_gaussian_filter=False
                ):
        random.seed(42)
        self.use_standard_score = use_standard_score
        self.add_margin = add_margin
        self.margin_ratio = margin_ratio
        self.random_position_count = random_position_count
        self.random_rotate_count = random_rotate_count
        self.apply_gaussian_filter = apply_gaussian_filter
        self.digit_count = digit_count
        self.image_width = image_size
        self.image_height = image_size
        self.target_digit_num_labels = 11
        self.num_channels = 3

        self.input_total_data_count = input_total_data_count
        self.total_data_count = input_total_data_count  # ds.num_examples
        self.update_data_counts()

        self.train_data = None
        self.train_label_length = None
        self.train_label_digits = None
        self.validation_data = None
        self.validation_label_length = None
        self.validation_label_digits = None
        self.test_data = None
        self.test_label_length = None
        self.test_label_digits = None

    def update_data_counts(self):
        self.train_data_count = int(0.9 * self.total_data_count)
        self.validation_data_count = int(0.05 * self.total_data_count)
        self.test_data_count = self.total_data_count - self.train_data_count - self.validation_data_count

    def print_image(self, image):
        sample_image = image
        plt.figure()
        plt.imshow(sample_image)  # display it
        gc.collect()

    @staticmethod
    def maybe_pickle(digit_count, total_data_count, image_size=54, force=False, 
                     use_standard_score=False, add_margin=False, margin_ratio=0.1,
                     random_position_count=0, random_rotate_count=0, 
                     apply_gaussian_filter=False):
        filename = 'svhn/reader/v2/svhn_' + str(digit_count) \
            + '_' + str(image_size) \
            + '_' + str(total_data_count) \
            + '_' + str(use_standard_score) \
            + '_' + str(add_margin) \
            + '_' + str(margin_ratio) \
            + '_' + str(apply_gaussian_filter) \
        
        if random_position_count > 0:
            filename += '_position' + str(random_position_count) \
        
        if random_rotate_count > 0:
            filename += '_rotate' + str(random_rotate_count) \
            
        filename += '.pickle'

        if os.path.exists(filename) and not force:
            # You may override by setting force=True.
            print('%s already present - Skipping pickling.' % filename)
            svhn_data = MultiDigitSVHNData.load_pickle(filename)
        else:
            print('Pickling %s.' % filename)
            svhn_data = MultiDigitSVHNData(digit_count=digit_count, input_total_data_count=total_data_count,
                                            image_size=image_size, use_standard_score=use_standard_score, add_margin=add_margin,
                                            random_position_count=random_position_count, random_rotate_count=random_rotate_count,
                                            margin_ratio=margin_ratio, apply_gaussian_filter=apply_gaussian_filter)
            svhn_data.load_data()
            try:
                MultiDigitSVHNData.write_pickle(filename, svhn_data)
            except Exception as e:
                print('Unable to save data to', filename, ':', e)
        return svhn_data

    @staticmethod
    def write_pickle(filename, data):
        with open(filename, 'wb') as f:
            pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)

    @staticmethod
    def load_pickle(filename):
        with open(filename, 'rb') as f:
            return pickle.load(f)

    def reformat_target_length(self, target_length):
        return (np.arange(self.digit_count + 1) == target_length).astype(np.float32)

    def reformat_target_digits(self, target_digits):
        return (np.arange(11) == target_digits).astype(np.float32)
    
    def generate_data(self, rows, total_data_index, target_image_length, data_index, target_image,top,bottom,left,right,rotate_rand=False):
        self.total_label[total_data_index][0] = target_image_length

        for digit_index in range(0, target_image_length):
            self.total_label[total_data_index][1 + digit_index] = rows[1][data_index][digit_index][0]
            
        rand_rotate_angle = 0
        if rotate_rand:
            if random.choice([True, False]):
                rand_rotate_angle = random.randrange(1,91)
            else:
                rand_rotate_angle = random.randrange(-91, -1)

        for channel_index in range(0, self.num_channels):
            if self.use_standard_score:
                mean = np.mean(target_image[:][:][channel_index], dtype='float32')
                std = np.std(target_image[:][:][channel_index], dtype='float32', ddof=1)
                if std < 1e-4:std = 1
                target_image[:][:][channel_index] = ((target_image[:][:][channel_index] - mean) / std).astype('uint8')
            
            croped = target_image[channel_index][top:bottom, left:right]
            if rotate_rand:
                croped = rotate(croped, rand_rotate_angle)
            resized_image = resize(croped,output_shape=[self.image_width, self.image_height])
            for image_height_index in range(0, self.image_height):
                for image_width_index in range(0, self.image_width):
                    self.total_data[total_data_index][image_height_index][image_width_index][channel_index] = \
                        resized_image[image_height_index][image_width_index] * 255

        if self.apply_gaussian_filter:
            self.total_data[total_data_index] = gaussian_filter(self.total_data[total_data_index], 1)
        total_data_index += 1
        
        return total_data_index

    def load_data(self):
        from fuel.config_parser import config
        from fuel.datasets.svhn import SVHN
        config.data_path = './svhn/converted'
        ds = SVHN(which_format=1, which_sets=('train', 'test', 'extra'))
        fetched_total_data_count = min(ds.num_examples, self.input_total_data_count)
        rows = np.array(ds.get_data(state=ds.open(), request=range(0, fetched_total_data_count)))
        rows_len = len(rows)
        print("rows[5][0]", rows[5][0].shape, rows[5][0].dtype)

        new_cnt = 0
        for data_index in range(0, fetched_total_data_count):
            target_image = rows[5][data_index]
            target_image_length = len(rows[1][data_index])
            if target_image_length <= self.digit_count:
                new_cnt += 1
                if self.add_margin:
                    if self.random_position_count > 0:
                        new_cnt += self.random_position_count
                    if self.random_rotate_count > 0:
                        new_cnt += self.random_rotate_count
        self.total_data_count = new_cnt
        self.update_data_counts()

        self.total_data = np.zeros((self.total_data_count, self.image_height, self.image_width, self.num_channels), dtype='uint8')
        self.total_label = np.ones((self.total_data_count, self.digit_count + 1), dtype=int) * 10
        print("total_data", self.total_data.shape)
        print("total_label", self.total_label.shape)

        print("start : {}".format(time.strftime("%Y-%m-%dT%H:%M:%S%z")))
        total_data_index = 0
        for data_index in range(0, fetched_total_data_count):
            target_image = rows[5][data_index]
            target_image_length = len(rows[1][data_index])
            top = int(np.min(rows[3][data_index]))
            bottom = int(np.max(rows[0][data_index] + rows[3][data_index]))
            left = int(np.min(rows[2][data_index]))
            right = int(np.max(rows[2][data_index] + rows[4][data_index]))
            
            rand_max_width = 0
            rand_max_height = 0

            if self.add_margin:
                width = right - left
                height = bottom - top
                top = max(0, int(top - height * self.margin_ratio))
                bottom = min(len(target_image[0]), int(bottom + height * self.margin_ratio))
                left = max(0, int(left - width * self.margin_ratio))
                right = min(len(target_image[0][0]), int(right + width * self.margin_ratio))
                rand_max_width = int(width * self.margin_ratio)
                rand_max_height = int(height * self.margin_ratio)

            if target_image_length <= self.digit_count:
                #def generate_data(self, total_data_index, target_image_length, data_index, target_image,top,bottom,left,right):
                total_data_index = self.generate_data(rows,total_data_index,target_image_length,data_index,target_image,top,bottom,left,right)
                if self.add_margin:
                    if self.random_position_count > 0:
                        for rand_i in range(0, self.random_position_count):
                            rand_width = random.randrange(-rand_max_width, rand_max_width)
                            rand_height = random.randrange(-rand_max_height, rand_max_height)
                            rand_top = max(0, top + rand_height)
                            rand_bottom = min(len(target_image[0]), bottom + rand_height)
                            rand_left = max(0, left + rand_width)
                            rand_right = min(len(target_image[0][0]), right + rand_width)
                            
                            total_data_index = self.generate_data(rows,total_data_index,target_image_length,data_index,target_image,
                                                                  rand_top,rand_bottom,rand_left,rand_right)
                    if self.random_rotate_count > 0:
                        for rand_i in range(0, self.random_rotate_count):
                            total_data_index = self.generate_data(rows,total_data_index,target_image_length,data_index,target_image
                                                                  ,top,bottom,left,right, rotate_rand=True)
                    
        print("end : {}".format(time.strftime("%Y-%m-%dT%H:%M:%S%z")))

        self.train_data = self.total_data[:self.train_data_count]
        self.train_label = self.total_label[:self.train_data_count]
        print("train_data", self.train_data.shape)
        print("train_label", self.train_label.shape)
        
        self.validation_data = self.total_data[self.train_data_count:self.train_data_count + self.validation_data_count]
        self.validation_label = self.total_label[
                                       self.train_data_count:self.train_data_count + self.validation_data_count]
        print("validation_data", self.validation_data.shape)
        print("validation_label", self.validation_label.shape)

        self.test_data = self.total_data[self.train_data_count + self.validation_data_count:]
        self.test_label = self.total_label[self.train_data_count + self.validation_data_count:]
        print("test_data", self.test_data.shape)
        print("test_label", self.test_label.shape)

# %%
import re

import numpy as np
import tensorflow as tf

from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat



class MultiDigitModel(object):
    def __init__(self, multi_digit_dataset, digit_count=1, num_channels=1, pooling_stride=2, num_steps=10001,
                 batch_size=128, patch_size=5, num_convs=None, num_fc_1=3072, num_fc_2=3072, beta=0.001,
                 use_drop_out=False, drop_out_rate=0.5, use_norm=False, use_LCN=False,
                 learning_rate_start=0.1, learning_rate_decay_rate=0.1, add_l2_loss=False):
        if num_convs is None:
            # The number of units at each spatial location in each layer is [48, 64, 128, 160] for the first four layers and 192 for all other locally connected layers.
            num_convs = [48, 64, 128, 160, 192, 192, 192, 192]

        # The fully connected layers contain 3,072 units each.
        self.num_channels = num_channels
        self.pooling_stride = pooling_stride

        self.num_steps = num_steps
        self.batch_size = batch_size
        self.patch_size = patch_size
        self.num_conv_1 = num_convs[0]
        self.num_conv_2 = num_convs[1]
        self.num_conv_3 = num_convs[2]
        self.num_conv_4 = num_convs[3]
        self.num_conv_5 = num_convs[4]
        self.num_conv_6 = num_convs[5]
        self.num_conv_7 = num_convs[6]
        self.num_conv_8 = num_convs[7]

        self.last_num_conv = 0
        for i in range(7, -1, -1):
            if num_convs[i] > 0:
                self.last_num_conv = num_convs[i]
                break

        self.num_fc_1 = num_fc_1
        self.num_fc_2 = num_fc_2

        self.beta = beta
        self.learning_rate_start = learning_rate_start
        self.learning_rate_decay_rate = learning_rate_decay_rate

        self.digit_count = digit_count
        self.multi_digit_dataset = multi_digit_dataset
        self.graph = tf.Graph()

        self.add_l2_loss = add_l2_loss
        self.NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN = 50000
        self.NUM_EXAMPLES_PER_EPOCH_FOR_EVAL = 10000

        # Constants describing the training process.
        self.MOVING_AVERAGE_DECAY = 0.9999     # The decay to use for the moving average.
        self.NUM_EPOCHS_PER_DECAY = 350.0      # Epochs after which learning rate decays.
        
        self.use_norm = use_norm
        self.use_drop_out = use_drop_out
        self.drop_out_rate = drop_out_rate
        self.use_LCN = use_LCN


    @staticmethod
    def accuracy_digit(p_length, p_digits,
                       batch_length_labels, batch_digits_labels, digit):
        eq_count = 0.0
        total_count = 0.0
        for i in range(0, len(p_digits[digit])):
            if np.argmax(batch_length_labels[i]) >= digit:
                total_count += 1.0
                if np.argmax(p_digits[digit][i]) == np.argmax(batch_digits_labels[i][digit]):
                    eq_count += 1.0

        if total_count == 0:
            return 0
        return eq_count / total_count * 100

    @staticmethod
    def accuracy_length(p_length, p_0, p_1, p_2, p_3, p_4,
                        batch_length_labels, batch_digits_labels):
        eq_count = 0.0
        for i in range(0, len(p_length)):
            if np.argmax(p_length[i]) == np.argmax(batch_length_labels[i]):
                eq_count += 1.0
        return eq_count / len(p_length) * 100

    @staticmethod
    def accuracy(p_length, p_digits,
                 batch_length_labels, batch_digits_labels):
        eq_count = 0.0
        for row_index in range(0, len(p_length)):
            one_based_length_predicted = np.argmax(p_length[row_index])
            one_based_length_real = np.argmax(batch_length_labels[row_index])

            if one_based_length_predicted == one_based_length_real:
                is_equal = True
                for digit_index in range(0, one_based_length_real):
                    if np.argmax(p_digits[digit_index][row_index]) != np.argmax(
                            batch_digits_labels[row_index][digit_index]):
                        is_equal = False
                        break
                if is_equal:
                    eq_count += 1.0

        return eq_count / len(p_length) * 100, eq_count, len(p_length)
    
    
    def _activation_summary(self, x):
        tf.histogram_summary(x.op.name + '/activations', x)
        tf.scalar_summary(x.op.name + '/sparsity', tf.nn.zero_fraction(x))

    def _add_loss_summaries(self, total_loss):
        # Compute the moving average of all individual losses and the total loss.
        loss_averages = tf.train.ExponentialMovingAverage(0.9, name='avg')
        losses = tf.get_collection('losses')
        loss_averages_op = loss_averages.apply(losses + [total_loss])

        # Attach a scalar summary to all individual losses and the total loss; do the
        # same for the averaged version of the losses.
        for l in losses + [total_loss]:
        # Name each loss as '(raw)' and name the moving average version of the loss
        # as the original loss name.
            tf.scalar_summary(l.op.name +' (raw)', l)
            tf.scalar_summary(l.op.name, loss_averages.average(l))

        return loss_averages_op

        
    def _variable_on_cpu(self, name, shape, initializer):
        return tf.get_variable(name, shape, initializer=initializer, dtype=tf.float32)
        
        
    def _variable_with_weight_decay(self, name, shape, stddev, wd):
        var = self._variable_on_cpu(
            name,
            shape,
            tf.truncated_normal_initializer(stddev=stddev, dtype=tf.float32))
        if wd is not None:
            weight_decay = tf.mul(tf.nn.l2_loss(var), wd, name='weight_loss')
            tf.add_to_collection('losses', weight_decay)
        return var
    
    def conv_layer(self, number, input_data, input_num, output_num):
        with tf.variable_scope('conv_' + str(number)) as scope:
            kernel = self._variable_with_weight_decay('weights',
                             shape=[self.patch_size, self.patch_size, input_num, output_num],
                             stddev=5e-2,
                             wd=0.0)
            conv = tf.nn.conv2d(input_data, kernel, [1, 1, 1, 1], padding='SAME')
            biases = self._variable_on_cpu('biases', [output_num], tf.constant_initializer(0.0))
            pre_activation = tf.nn.bias_add(conv, biases)
            conv = tf.nn.relu(pre_activation, name=scope.name)
            self._activation_summary(conv)
        if self.use_norm:
            conv = tf.nn.lrn(conv, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm' + str(number))
        return conv
    
    # inference.
    def inference(self, data, is_training=True):
        stride = 2
        conv = None
        with tf.variable_scope('conv_1') as scope:
            kernel = self._variable_with_weight_decay('weights',
                             shape=[self.patch_size, self.patch_size, self.num_channels, self.num_conv_1],
                             stddev=5e-2,
                             wd=0.0)
            conv = tf.nn.conv2d(data, kernel, [1, 1, 1, 1], padding='SAME')
            biases = self._variable_on_cpu('biases', [self.num_conv_1], tf.constant_initializer(0.0))
            pre_activation = tf.nn.bias_add(conv, biases)
            conv1 = tf.nn.relu(pre_activation, name=scope.name)
            self._activation_summary(conv1)
        pool1 = tf.nn.max_pool(conv1, [1, 2, 2, 1], [1, stride, stride, 1], padding='SAME', name='pool1')
        
        if self.use_norm:
            conv = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm1')
        else:
            conv = pool1

        with tf.variable_scope('conv_2') as scope:
            kernel = self._variable_with_weight_decay('weights',
                             shape=[self.patch_size, self.patch_size, self.num_conv_1, self.num_conv_2],
                             stddev=5e-2,
                             wd=0.0)
            conv = tf.nn.conv2d(conv, kernel, [1, 1, 1, 1], padding='SAME')
            biases = self._variable_on_cpu('biases', [self.num_conv_2], tf.constant_initializer(0.0))
            pre_activation = tf.nn.bias_add(conv, biases)
            conv2 = tf.nn.relu(pre_activation, name=scope.name)
            self._activation_summary(conv2)
        if self.use_norm:
            conv2 = tf.nn.lrn(conv2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name='norm2')
        pool2 = tf.nn.max_pool(conv2, [1, 2, 2, 1], [1, stride, stride, 1], padding='SAME', name='pool2')
        conv = pool2
        
        if self.num_conv_3 > 0:
            conv = self.conv_layer(3, conv, self.num_conv_2, self.num_conv_3)
        if self.num_conv_4 > 0:
            conv = self.conv_layer(4, conv, self.num_conv_3, self.num_conv_4)
        if self.num_conv_5 > 0:
            conv = self.conv_layer(5, conv, self.num_conv_4, self.num_conv_5)
        if self.num_conv_6 > 0:
            conv = self.conv_layer(6, conv, self.num_conv_5, self.num_conv_6)
        if self.num_conv_7 > 0:
            conv = self.conv_layer(7, conv, self.num_conv_6, self.num_conv_7)
        if self.num_conv_8 > 0:
            conv = self.conv_layer(8, conv, self.num_conv_7, self.num_conv_8)
        
        if self.use_drop_out:
            conv = tf.nn.dropout(conv, self.drop_out_rate)
        
        with tf.variable_scope('local_1') as scope:
            shape = conv.get_shape().as_list()
            reshape = tf.reshape(conv, [shape[0], -1])
            dim = reshape.get_shape()[1].value
            weights = self._variable_with_weight_decay('weights', shape=[dim, self.num_fc_1],stddev=0.04, wd=0.004)
            biases = self._variable_on_cpu('biases', [self.num_fc_1], tf.constant_initializer(0.1))
            local3 = tf.nn.relu(tf.matmul(reshape, weights) + biases, name=scope.name)
            self._activation_summary(local3)

        with tf.variable_scope('local_2') as scope:
            weights = self._variable_with_weight_decay('weights', shape=[self.num_fc_1, self.num_fc_2],stddev=0.04, wd=0.004)
            biases = self._variable_on_cpu('biases', [self.num_fc_2], tf.constant_initializer(0.1))
            local4 = tf.nn.relu(tf.matmul(local3, weights) + biases, name=scope.name)
            self._activation_summary(local4)

        with tf.variable_scope('digit_length') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, self.multi_digit_dataset.digit_count + 1],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [self.multi_digit_dataset.digit_count + 1],tf.constant_initializer(0.0))
            digit_length_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digit_length_logit)

        with tf.variable_scope('digit_0') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, self.multi_digit_dataset.target_digit_num_labels],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [self.multi_digit_dataset.target_digit_num_labels],tf.constant_initializer(0.0))
            digits_0_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_0_logit)
        with tf.variable_scope('digit_1') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, self.multi_digit_dataset.target_digit_num_labels],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [self.multi_digit_dataset.target_digit_num_labels],tf.constant_initializer(0.0))
            digits_1_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_1_logit)
        with tf.variable_scope('digit_2') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, self.multi_digit_dataset.target_digit_num_labels],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [self.multi_digit_dataset.target_digit_num_labels],tf.constant_initializer(0.0))
            digits_2_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_2_logit)
        with tf.variable_scope('digit_3') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, self.multi_digit_dataset.target_digit_num_labels],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [self.multi_digit_dataset.target_digit_num_labels],tf.constant_initializer(0.0))
            digits_3_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_3_logit)
        with tf.variable_scope('digit_4') as scope:
            weights = self._variable_with_weight_decay('weights', [self.num_fc_2, self.multi_digit_dataset.target_digit_num_labels],stddev=1.0/self.num_fc_2, wd=0.0)
            biases = self._variable_on_cpu('biases', [self.multi_digit_dataset.target_digit_num_labels],tf.constant_initializer(0.0))
            digits_4_logit = tf.add(tf.matmul(local4, weights), biases, name=scope.name)
            self._activation_summary(digits_4_logit)

        return digit_length_logit, digits_0_logit, digits_1_logit, digits_2_logit, digits_3_logit, digits_4_logit

    
    def loss_(self, logits, length_label, digit_labels):
        # Calculate the average cross entropy loss across the batch.
        length_label = tf.cast(length_label, tf.int64)
        digit_labels = tf.cast(digit_labels, tf.int64)
        cross_entropy_sum = tf.nn.softmax_cross_entropy_with_logits(logits[0], length_label, name='cross_entropy_for_length')
        for i in range(0, self.digit_count):
            cross_entropy_sum += tf.nn.softmax_cross_entropy_with_logits(logits[i + 1], digit_labels[:, i], name='cross_entropy_for_digit' + str(i))
        cross_entropy_mean = tf.reduce_mean(cross_entropy_sum, name='cross_entropy')
        tf.add_to_collection('losses', cross_entropy_mean)

        # The total loss is defined as the cross entropy loss plus all of the weight
        # decay terms (L2 loss).
        return tf.add_n(tf.get_collection('losses'), name='total_loss')

    
    def train(self, total_loss, global_step):
        # Variables that affect learning rate.
        num_batches_per_epoch = self.NUM_EXAMPLES_PER_EPOCH_FOR_TRAIN / self.batch_size
        decay_steps = int(num_batches_per_epoch * self.NUM_EPOCHS_PER_DECAY)

        # Decay the learning rate exponentially based on the number of steps.
        lr = tf.train.exponential_decay(self.learning_rate_start,
                                      global_step,
                                      decay_steps,
                                      self.learning_rate_decay_rate,
                                      staircase=True)
        tf.scalar_summary('learning_rate', lr)

        # Generate moving averages of all losses and associated summaries.
        loss_averages_op = self._add_loss_summaries(total_loss)

        # Compute gradients.
        with tf.control_dependencies([loss_averages_op]):
            #opt = tf.train.GradientDescentOptimizer(lr)
            opt = tf.train.AdagradOptimizer(lr)
            grads = opt.compute_gradients(total_loss)

        # Apply gradients.
        apply_gradient_op = opt.apply_gradients(grads, global_step=global_step)

        # Add histograms for trainable variables.
        for var in tf.trainable_variables():
            tf.histogram_summary(var.op.name, var)

        # Add histograms for gradients.
        for grad, var in grads:
            if grad is not None:
                tf.histogram_summary(var.op.name + '/gradients', grad)

        # Track the moving averages of all trainable variables.
        variable_averages = tf.train.ExponentialMovingAverage(self.MOVING_AVERAGE_DECAY, global_step)
        variables_averages_op = variable_averages.apply(tf.trainable_variables())

        with tf.control_dependencies([apply_gradient_op, variables_averages_op]):
            train_op = tf.no_op(name='train')

        return train_op
    
    def run(self):
        import time
        
        with self.graph.as_default():
            # Input data.
            tf_train_dataset = tf.placeholder(tf.float32, shape=(
                self.batch_size, self.multi_digit_dataset.image_width, self.multi_digit_dataset.image_height,
                self.multi_digit_dataset.num_channels), name="tf_train_dataset")
            print("tf_train_dataset : {}".format(tf_train_dataset))
            tf_train_length_labels = tf.placeholder(tf.float32,
                                                    shape=(self.batch_size, self.multi_digit_dataset.digit_count + 1))
            print("tf_train_length_labels : {}".format(tf_train_length_labels))
            tf_train_digits_labels = tf.placeholder(tf.float32,
                                                    shape=(self.batch_size, self.multi_digit_dataset.digit_count, 11))
            print("tf_train_digits_labels : {}".format(tf_train_digits_labels))

            # Training computation.
            logits = self.inference(tf_train_dataset, True)
            loss = self.loss_(logits, tf_train_length_labels, tf_train_digits_labels)

            global_step = tf.Variable(0, trainable=False)
            train_op = self.train(loss, global_step)

            # Predictions for the training, validation, and test data.
            train_length_prediction = tf.nn.softmax(logits[0], name='p_digit_length')
            train_digits_0_prediction = tf.nn.softmax(logits[1], name='p_digit_0')
            train_digits_1_prediction = tf.nn.softmax(logits[2], name='p_digit_1')
            train_digits_2_prediction = tf.nn.softmax(logits[3], name='p_digit_2')
            train_digits_3_prediction = tf.nn.softmax(logits[4], name='p_digit_3')
            train_digits_4_prediction = tf.nn.softmax(logits[5], name='p_digit_4')
            
            summary_op = tf.merge_all_summaries()
            init = tf.initialize_all_variables()
            session = tf.Session()
            session.run(init)
            summary_writer = tf.train.SummaryWriter('logs/tensorboard/voyageth/svhn/v2/' + time.strftime("%Y-%m-%dT%H:%M:%S%z"), session.graph)

            saver = tf.train.Saver()
            
            print('Initialized')
            for step in range(self.num_steps):
                offset = (step * self.batch_size) % (self.multi_digit_dataset.train_data.shape[0] - self.batch_size)
                batch_data = self.multi_digit_dataset.train_data[offset:(offset + self.batch_size), :, :, :]
                batch_length_labels = self.multi_digit_dataset.reformat_target_length(self.multi_digit_dataset.train_label[offset:(offset + self.batch_size), 0, None])
                batch_digits_labels = self.multi_digit_dataset.reformat_target_digits(self.multi_digit_dataset.train_label[offset:(offset + self.batch_size), 1:, None])

                feed_dict = {tf_train_dataset: batch_data, tf_train_length_labels: batch_length_labels,
                             tf_train_digits_labels: batch_digits_labels}

                _, summary_str, l, p_length, p_0, p_1, p_2, p_3, p_4 = session.run([train_op, summary_op, loss, train_length_prediction, train_digits_0_prediction, train_digits_1_prediction,
                     train_digits_2_prediction, train_digits_3_prediction, train_digits_4_prediction],feed_dict=feed_dict)
                if step % 100 == 0:
                    summary_writer.add_summary(summary_str, step)

                if step % 500 == 0:
                    print('Minibatch loss at step %d: %f' % (step, l))
                    accuracy_result = self.accuracy_length(p_length, p_0, p_1, p_2, p_3, p_4, batch_length_labels,
                                                           batch_digits_labels)
                    print('Minibatch accuracy_length: %.1f%%' % accuracy_result)
                    for k in range(0, self.digit_count):
                        accuracy_result = self.accuracy_digit(p_length, [p_0, p_1, p_2, p_3, p_4], batch_length_labels,
                                                              batch_digits_labels, k)
                        print("Minibatch accuracy_digit_{}".format(k) + ": %.1f%%" % accuracy_result)
                    accuracy_result, _, _ = self.accuracy(p_length, [p_0, p_1, p_2, p_3, p_4], batch_length_labels,
                                                    batch_digits_labels)
                    print('Minibatch accuracy: %.1f%%' % accuracy_result)

                    validation_accuracy_numerator = 0
                    validation_accuracy_denominator = 0
                    for step in range(0, len(self.multi_digit_dataset.validation_label) / self.batch_size):
                        valid_offset = (step * self.batch_size) % (self.multi_digit_dataset.validation_data.shape[0] - self.batch_size)
                        valid_batch_data = self.multi_digit_dataset.validation_data[valid_offset:(valid_offset + self.batch_size), :, :, :]
                        valid_batch_length_labels = self.multi_digit_dataset.reformat_target_length(self.multi_digit_dataset.validation_label[valid_offset:(valid_offset + self.batch_size), 0, None])
                        valid_batch_digits_labels = self.multi_digit_dataset.reformat_target_digits(self.multi_digit_dataset.validation_label[valid_offset:(valid_offset + self.batch_size), 1:, None])

                        feed_dict = {tf_train_dataset: valid_batch_data, tf_train_length_labels: valid_batch_length_labels,
                             tf_train_digits_labels: valid_batch_digits_labels}

                        p_length, p_0, p_1, p_2, p_3, p_4 = session.run([train_length_prediction, 
                                                                         train_digits_0_prediction, 
                                                                         train_digits_1_prediction,
                                                                         train_digits_2_prediction, 
                                                                         train_digits_3_prediction, 
                                                                         train_digits_4_prediction],feed_dict=feed_dict)

                        accuracy_result, numerator, denominator = self.accuracy(p_length, [p_0, p_1, p_2, p_3, p_4], 
                                                        valid_batch_length_labels, valid_batch_digits_labels)
                        validation_accuracy_numerator += numerator
                        validation_accuracy_denominator += denominator
                    accuracy_result = validation_accuracy_numerator / validation_accuracy_denominator * 100
                    print('Validation accuracy: %.1f%%' % accuracy_result)
                    print("finish : {}".format(time.strftime("%Y-%m-%dT%H:%M:%S%z")))

            test_accuracy_numerator = 0
            test_accuracy_denominator = 0
            for step in range(0, len(self.multi_digit_dataset.test_label) / self.batch_size):
                test_offset = (step * self.batch_size) % (self.multi_digit_dataset.test_data.shape[0] - self.batch_size)
                test_batch_data = self.multi_digit_dataset.test_data[test_offset:(test_offset + self.batch_size), :, :, :]
                test_batch_length_labels = self.multi_digit_dataset.reformat_target_length(self.multi_digit_dataset.test_label[test_offset:(test_offset + self.batch_size), 0, None])
                test_batch_digits_labels = self.multi_digit_dataset.reformat_target_digits(self.multi_digit_dataset.test_label[test_offset:(test_offset + self.batch_size), 1:, None])

                feed_dict = {tf_train_dataset: test_batch_data, tf_train_length_labels: test_batch_length_labels,
                     tf_train_digits_labels: test_batch_digits_labels}

                p_length, p_0, p_1, p_2, p_3, p_4 = session.run([train_length_prediction, 
                                                                 train_digits_0_prediction, 
                                                                 train_digits_1_prediction,
                                                                 train_digits_2_prediction, 
                                                                 train_digits_3_prediction, 
                                                                 train_digits_4_prediction],feed_dict=feed_dict)

                accuracy_result, numerator, denominator = self.accuracy(p_length, [p_0, p_1, p_2, p_3, p_4], 
                                                test_batch_length_labels, test_batch_digits_labels)
                test_accuracy_numerator += numerator
                test_accuracy_denominator += denominator
            accuracy_result = test_accuracy_numerator / test_accuracy_denominator * 100
            print('Test accuracy: %.1f%%' % accuracy_result)
            finish_time = time.strftime("%Y-%m-%dT%H:%M:%S%z")
            print("finish : {}".format(finish_time))

            output_graph_def = graph_util.convert_variables_to_constants(
              session, self.graph.as_graph_def(), ['p_digit_length', 'p_digit_0', 'p_digit_1', 'p_digit_2', 'p_digit_3', 'p_digit_4'])
            with gfile.FastGFile('./graph/v2/model_{}.pb'.format(finish_time), 'wb') as f:
                f.write(output_graph_def.SerializeToString())

# %%
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=10000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        learning_rate_start=0.001,
                        digit_count=5,
                        num_channels=3,
                        num_steps=1001, 
                        batch_size=32, 
                        num_convs=[16,32,64,0,0,0,0,0], 
                        num_fc_1=64, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/v2/svhn_5_32_10000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("tf_train_dataset:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_1:0", shape=(32, 5, 11), dtype=float32)
# Initialized
# Minibatch loss at step 0: 13.873264
# Minibatch accuracy_length: 3.1%
# Minibatch accuracy_digit_0: 0.0%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 32.3%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.2%
# finish : 2016-12-02T08:00:23+0900
# Minibatch loss at step 500: 7.123955
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 64.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-02T08:00:40+0900
# Minibatch loss at step 1000: 6.989372
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 68.0%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-02T08:00:58+0900
# Test accuracy: 0.0%
# finish : 2016-12-02T08:00:58+0900
# Converted 22 variables to const ops.

# %%
# Minibatch loss at step 100000: 0.381631
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-12-01T18:49:56+0900

# Minibatch loss at step 200000: 0.066869
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-01T22:21:34+0900
# Test accuracy: 89.4%
# finish : 2016-12-01T22:21:38+0900
# Converted 32 variables to const ops.
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=200001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,64,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/v2/svhn_5_32_300000_False_False_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("tf_train_dataset:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_1:0", shape=(32, 5, 11), dtype=float32)
# Initialized
# Minibatch loss at step 0: 15.831378
# Minibatch accuracy_length: 3.1%
# Minibatch accuracy_digit_0: 6.2%
# Minibatch accuracy_digit_1: 0.0%
# Minibatch accuracy_digit_2: 0.0%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-12-01T15:24:14+0900
# Minibatch loss at step 500: 10.372810
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 54.5%
# Minibatch accuracy_digit_3: 50.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:25:11+0900
# Minibatch loss at step 1000: 8.564592
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:26:08+0900
# Minibatch loss at step 1500: 9.369090
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 41.9%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:27:05+0900
# Minibatch loss at step 2000: 10.062678
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 30.0%
# Minibatch accuracy_digit_3: 81.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:28:02+0900
# Minibatch loss at step 2500: 9.593604
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 41.4%
# Minibatch accuracy_digit_3: 82.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:28:59+0900
# Minibatch loss at step 3000: 8.723700
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 36.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:29:55+0900
# Minibatch loss at step 3500: 9.314724
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 42.9%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:30:52+0900
# Minibatch loss at step 4000: 8.497701
# Minibatch accuracy_length: 59.4%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 37.5%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:31:48+0900
# Minibatch loss at step 4500: 9.256210
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 28.6%
# Minibatch accuracy_digit_3: 85.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:32:45+0900
# Minibatch loss at step 5000: 8.760596
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 3.1%
# Minibatch accuracy_digit_2: 27.6%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:33:41+0900
# Minibatch loss at step 5500: 7.987597
# Minibatch accuracy_length: 68.8%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 31.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:34:37+0900
# Minibatch loss at step 6000: 8.246243
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:35:33+0900
# Minibatch loss at step 6500: 8.879463
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 3.1%
# Minibatch accuracy_digit_2: 41.9%
# Minibatch accuracy_digit_3: 77.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:36:30+0900
# Minibatch loss at step 7000: 8.336157
# Minibatch accuracy_length: 18.8%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 65.4%
# Minibatch accuracy_digit_3: 66.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:37:26+0900
# Minibatch loss at step 7500: 6.637744
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:38:22+0900
# Minibatch loss at step 8000: 7.641261
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 63.0%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:39:19+0900
# Minibatch loss at step 8500: 7.806349
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 48.4%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:40:16+0900
# Minibatch loss at step 9000: 8.288368
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 34.4%
# Minibatch accuracy_digit_3: 81.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:41:13+0900
# Minibatch loss at step 9500: 8.322504
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 24.1%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:42:10+0900
# Minibatch loss at step 10000: 7.487823
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 3.1%
# Minibatch accuracy_digit_2: 54.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:43:07+0900
# Minibatch loss at step 10500: 7.748488
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 40.6%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:44:04+0900
# Minibatch loss at step 11000: 7.286341
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 34.4%
# Minibatch accuracy_digit_1: 25.0%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:45:01+0900
# Minibatch loss at step 11500: 8.310988
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 19.4%
# Minibatch accuracy_digit_3: 92.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:45:58+0900
# Minibatch loss at step 12000: 7.667744
# Minibatch accuracy_length: 56.2%
# Minibatch accuracy_digit_0: 28.1%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 36.7%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:46:54+0900
# Minibatch loss at step 12500: 7.688792
# Minibatch accuracy_length: 50.0%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 44.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:47:51+0900
# Minibatch loss at step 13000: 7.522054
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 12.5%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:48:48+0900
# Minibatch loss at step 13500: 8.459963
# Minibatch accuracy_length: 40.6%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 41.4%
# Minibatch accuracy_digit_3: 76.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:49:45+0900
# Minibatch loss at step 14000: 6.796632
# Minibatch accuracy_length: 50.0%
# Minibatch accuracy_digit_0: 31.2%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 56.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T15:50:42+0900
# Minibatch loss at step 14500: 6.661101
# Minibatch accuracy_length: 71.9%
# Minibatch accuracy_digit_0: 9.4%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 65.5%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.5%
# finish : 2016-12-01T15:51:39+0900
# Minibatch loss at step 15000: 4.969178
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 68.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 0.8%
# finish : 2016-12-01T15:52:36+0900
# Minibatch loss at step 15500: 6.551665
# Minibatch accuracy_length: 84.4%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 18.8%
# Minibatch accuracy_digit_2: 51.6%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 2.2%
# finish : 2016-12-01T15:53:33+0900
# Minibatch loss at step 16000: 4.989489
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 43.8%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 61.3%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 12.5%
# Validation accuracy: 3.9%
# finish : 2016-12-01T15:54:30+0900
# Minibatch loss at step 16500: 5.568227
# Minibatch accuracy_length: 81.2%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 59.4%
# Minibatch accuracy_digit_3: 89.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 3.1%
# Validation accuracy: 5.4%
# finish : 2016-12-01T15:55:28+0900
# Minibatch loss at step 17000: 4.984577
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 65.6%
# Minibatch accuracy_digit_1: 37.5%
# Minibatch accuracy_digit_2: 56.2%
# Minibatch accuracy_digit_3: 75.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 12.5%
# Validation accuracy: 8.0%
# finish : 2016-12-01T15:56:26+0900
# Minibatch loss at step 17500: 4.532754
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 59.4%
# Minibatch accuracy_digit_1: 56.2%
# Minibatch accuracy_digit_2: 54.8%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 21.9%
# Validation accuracy: 14.1%
# finish : 2016-12-01T15:57:25+0900
# Minibatch loss at step 18000: 3.212769
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 68.8%
# Minibatch accuracy_digit_1: 56.2%
# Minibatch accuracy_digit_2: 65.5%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 15.6%
# Validation accuracy: 23.8%
# finish : 2016-12-01T15:58:25+0900
# Minibatch loss at step 18500: 3.766838
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 56.2%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 42.9%
# Minibatch accuracy_digit_3: 77.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 12.5%
# Validation accuracy: 33.4%
# finish : 2016-12-01T15:59:25+0900
# Minibatch loss at step 19000: 2.304930
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 64.5%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 46.9%
# Validation accuracy: 44.2%
# finish : 2016-12-01T16:00:24+0900
# Minibatch loss at step 19500: 2.373586
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 71.0%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 50.0%
# Validation accuracy: 50.0%
# finish : 2016-12-01T16:01:25+0900
# Minibatch loss at step 20000: 2.133872
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 91.3%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 57.3%
# finish : 2016-12-01T16:02:25+0900
# Minibatch loss at step 20500: 2.654922
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 78.6%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 40.6%
# Validation accuracy: 58.5%
# finish : 2016-12-01T16:03:26+0900
# Minibatch loss at step 21000: 1.246824
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 63.0%
# finish : 2016-12-01T16:04:27+0900
# Minibatch loss at step 21500: 2.406786
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 78.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 63.6%
# finish : 2016-12-01T16:05:28+0900
# Minibatch loss at step 22000: 1.773886
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 65.6%
# Validation accuracy: 63.4%
# finish : 2016-12-01T16:06:29+0900
# Minibatch loss at step 22500: 1.061933
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.9%
# finish : 2016-12-01T16:07:29+0900
# Minibatch loss at step 23000: 1.030345
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 72.4%
# finish : 2016-12-01T16:08:31+0900
# Minibatch loss at step 23500: 1.702611
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.1%
# finish : 2016-12-01T16:09:32+0900
# Minibatch loss at step 24000: 1.119770
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 89.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 74.9%
# finish : 2016-12-01T16:10:33+0900
# Minibatch loss at step 24500: 0.716526
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 76.4%
# finish : 2016-12-01T16:11:34+0900
# Minibatch loss at step 25000: 1.038658
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 77.6%
# finish : 2016-12-01T16:12:34+0900
# Minibatch loss at step 25500: 0.876922
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 87.5%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# finish : 2016-12-01T16:13:35+0900
# Minibatch loss at step 26000: 0.765800
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.4%
# finish : 2016-12-01T16:14:36+0900
# Minibatch loss at step 26500: 1.131371
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.8%
# finish : 2016-12-01T16:15:38+0900
# Minibatch loss at step 27000: 1.205135
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 79.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 80.5%
# finish : 2016-12-01T16:16:39+0900
# Minibatch loss at step 27500: 0.876600
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# finish : 2016-12-01T16:17:40+0900
# Minibatch loss at step 28000: 1.205835
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.5%
# finish : 2016-12-01T16:18:41+0900
# Minibatch loss at step 28500: 0.663913
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.4%
# finish : 2016-12-01T16:19:43+0900
# Minibatch loss at step 29000: 0.524003
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# finish : 2016-12-01T16:20:44+0900
# Minibatch loss at step 29500: 0.594414
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.7%
# finish : 2016-12-01T16:21:45+0900
# Minibatch loss at step 30000: 0.879147
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.7%
# finish : 2016-12-01T16:22:46+0900
# Minibatch loss at step 30500: 0.883757
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.5%
# finish : 2016-12-01T16:23:48+0900
# Minibatch loss at step 31000: 0.971383
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# finish : 2016-12-01T16:24:50+0900
# Minibatch loss at step 31500: 0.943630
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.9%
# finish : 2016-12-01T16:25:51+0900
# Minibatch loss at step 32000: 0.707577
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# finish : 2016-12-01T16:26:53+0900
# Minibatch loss at step 32500: 0.440925
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.5%
# finish : 2016-12-01T16:27:54+0900
# Minibatch loss at step 33000: 0.670077
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# finish : 2016-12-01T16:28:56+0900
# Minibatch loss at step 33500: 0.718049
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# finish : 2016-12-01T16:29:57+0900
# Minibatch loss at step 34000: 1.049049
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# finish : 2016-12-01T16:30:59+0900
# Minibatch loss at step 34500: 0.920623
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 85.1%
# finish : 2016-12-01T16:32:01+0900
# Minibatch loss at step 35000: 1.007272
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 84.6%
# Minibatch accuracy_digit_3: 72.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# finish : 2016-12-01T16:33:03+0900
# Minibatch loss at step 35500: 1.076213
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 84.5%
# finish : 2016-12-01T16:34:05+0900
# Minibatch loss at step 36000: 1.017159
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.2%
# finish : 2016-12-01T16:35:07+0900
# Minibatch loss at step 36500: 1.735538
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.1%
# finish : 2016-12-01T16:36:08+0900
# Minibatch loss at step 37000: 0.161248
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.6%
# finish : 2016-12-01T16:37:10+0900
# Minibatch loss at step 37500: 0.484132
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# finish : 2016-12-01T16:38:12+0900
# Minibatch loss at step 38000: 1.326347
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# finish : 2016-12-01T16:39:14+0900
# Minibatch loss at step 38500: 0.455885
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.6%
# finish : 2016-12-01T16:40:17+0900
# Minibatch loss at step 39000: 0.845827
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 86.6%
# finish : 2016-12-01T16:41:19+0900
# Minibatch loss at step 39500: 0.811412
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# finish : 2016-12-01T16:42:21+0900
# Minibatch loss at step 40000: 0.464013
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# finish : 2016-12-01T16:43:24+0900
# Minibatch loss at step 40500: 0.683122
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# finish : 2016-12-01T16:44:26+0900
# Minibatch loss at step 41000: 0.641577
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# finish : 2016-12-01T16:45:29+0900
# Minibatch loss at step 41500: 0.423750
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-12-01T16:46:32+0900
# Minibatch loss at step 42000: 0.454273
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# finish : 2016-12-01T16:47:34+0900
# Minibatch loss at step 42500: 0.882687
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# finish : 2016-12-01T16:48:37+0900
# Minibatch loss at step 43000: 0.869782
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# finish : 2016-12-01T16:49:40+0900
# Minibatch loss at step 43500: 0.336139
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# finish : 2016-12-01T16:50:43+0900
# Minibatch loss at step 44000: 1.107553
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# finish : 2016-12-01T16:51:45+0900
# Minibatch loss at step 44500: 0.496261
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# finish : 2016-12-01T16:52:48+0900
# Minibatch loss at step 45000: 0.970350
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# finish : 2016-12-01T16:53:51+0900
# Minibatch loss at step 45500: 0.316003
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# finish : 2016-12-01T16:54:54+0900
# Minibatch loss at step 46000: 0.626246
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# finish : 2016-12-01T16:55:57+0900
# Minibatch loss at step 46500: 0.345073
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.3%
# finish : 2016-12-01T16:57:00+0900
# Minibatch loss at step 47000: 0.614728
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# finish : 2016-12-01T16:58:03+0900
# Minibatch loss at step 47500: 0.172838
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# finish : 2016-12-01T16:59:06+0900
# Minibatch loss at step 48000: 0.959792
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.0%
# finish : 2016-12-01T17:00:09+0900
# Minibatch loss at step 48500: 0.255690
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# finish : 2016-12-01T17:01:12+0900
# Minibatch loss at step 49000: 0.378211
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# finish : 2016-12-01T17:02:15+0900
# Minibatch loss at step 49500: 0.683288
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.9%
# finish : 2016-12-01T17:03:18+0900
# Minibatch loss at step 50000: 0.408645
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.4%
# finish : 2016-12-01T17:04:21+0900
# Minibatch loss at step 50500: 0.249794
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-12-01T17:05:24+0900
# Minibatch loss at step 51000: 0.248055
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# finish : 2016-12-01T17:06:27+0900
# Minibatch loss at step 51500: 0.362883
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# finish : 2016-12-01T17:07:29+0900
# Minibatch loss at step 52000: 0.253011
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# finish : 2016-12-01T17:08:32+0900
# Minibatch loss at step 52500: 0.397933
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# finish : 2016-12-01T17:09:35+0900
# Minibatch loss at step 53000: 0.220012
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.6%
# finish : 2016-12-01T17:10:38+0900
# Minibatch loss at step 53500: 0.239016
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.8%
# finish : 2016-12-01T17:11:41+0900
# Minibatch loss at step 54000: 0.184518
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# finish : 2016-12-01T17:12:44+0900
# Minibatch loss at step 54500: 0.815137
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# finish : 2016-12-01T17:13:48+0900
# Minibatch loss at step 55000: 0.964954
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.7%
# finish : 2016-12-01T17:14:51+0900
# Minibatch loss at step 55500: 0.182302
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-12-01T17:15:54+0900
# Minibatch loss at step 56000: 0.750795
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 91.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# finish : 2016-12-01T17:16:57+0900
# Minibatch loss at step 56500: 0.743983
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.0%
# finish : 2016-12-01T17:18:01+0900
# Minibatch loss at step 57000: 0.664027
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# finish : 2016-12-01T17:19:04+0900
# Minibatch loss at step 57500: 0.484169
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# finish : 2016-12-01T17:20:07+0900
# Minibatch loss at step 58000: 1.396807
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# finish : 2016-12-01T17:21:10+0900
# Minibatch loss at step 58500: 0.464903
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# finish : 2016-12-01T17:22:14+0900
# Minibatch loss at step 59000: 0.491787
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-12-01T17:23:17+0900
# Minibatch loss at step 59500: 0.426528
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# finish : 2016-12-01T17:24:20+0900
# Minibatch loss at step 60000: 0.482329
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# finish : 2016-12-01T17:25:24+0900
# Minibatch loss at step 60500: 0.198467
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-01T17:26:27+0900
# Minibatch loss at step 61000: 0.142192
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# finish : 2016-12-01T17:27:31+0900
# Minibatch loss at step 61500: 0.726797
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.0%
# finish : 2016-12-01T17:28:34+0900
# Minibatch loss at step 62000: 0.176484
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.1%
# finish : 2016-12-01T17:29:38+0900
# Minibatch loss at step 62500: 0.886969
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# finish : 2016-12-01T17:30:41+0900
# Minibatch loss at step 63000: 0.824703
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# finish : 2016-12-01T17:31:44+0900
# Minibatch loss at step 63500: 0.403380
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# finish : 2016-12-01T17:32:48+0900
# Minibatch loss at step 64000: 0.779711
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.5%
# finish : 2016-12-01T17:33:51+0900
# Minibatch loss at step 64500: 0.219205
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.6%
# finish : 2016-12-01T17:34:55+0900
# Minibatch loss at step 65000: 0.613798
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# finish : 2016-12-01T17:35:58+0900
# Minibatch loss at step 65500: 0.267336
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-12-01T17:37:02+0900
# Minibatch loss at step 66000: 1.152722
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# finish : 2016-12-01T17:38:05+0900
# Minibatch loss at step 66500: 0.348125
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# finish : 2016-12-01T17:39:09+0900
# Minibatch loss at step 67000: 0.204022
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-01T17:40:12+0900
# Minibatch loss at step 67500: 0.143968
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-01T17:41:15+0900
# Minibatch loss at step 68000: 0.239813
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# finish : 2016-12-01T17:42:19+0900
# Minibatch loss at step 68500: 0.495811
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# finish : 2016-12-01T17:43:22+0900
# Minibatch loss at step 69000: 0.467613
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# finish : 2016-12-01T17:44:26+0900
# Minibatch loss at step 69500: 0.241836
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# finish : 2016-12-01T17:45:29+0900
# Minibatch loss at step 70000: 0.497970
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# finish : 2016-12-01T17:46:32+0900
# Minibatch loss at step 70500: 0.610463
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.2%
# finish : 2016-12-01T17:47:36+0900
# Minibatch loss at step 71000: 0.521786
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# finish : 2016-12-01T17:48:39+0900
# Minibatch loss at step 71500: 0.204747
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# finish : 2016-12-01T17:49:43+0900
# ...
# Validation accuracy: 89.4%
# finish : 2016-12-01T21:31:51+0900
# Minibatch loss at step 177000: 0.082442
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-01T21:32:54+0900
# Minibatch loss at step 177500: 0.086503
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# finish : 2016-12-01T21:33:57+0900
# Minibatch loss at step 178000: 0.078666
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-01T21:35:01+0900
# Minibatch loss at step 178500: 0.156842
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# finish : 2016-12-01T21:36:04+0900
# Minibatch loss at step 179000: 0.068477
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T21:37:08+0900
# Minibatch loss at step 179500: 0.077620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T21:38:12+0900
# Minibatch loss at step 180000: 0.116211
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-01T21:39:15+0900
# Minibatch loss at step 180500: 0.085528
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-12-01T21:40:19+0900
# Minibatch loss at step 181000: 0.081277
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T21:41:23+0900
# Minibatch loss at step 181500: 0.083453
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-01T21:42:26+0900
# Minibatch loss at step 182000: 0.083916
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-01T21:43:29+0900
# Minibatch loss at step 182500: 0.096082
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-01T21:44:33+0900
# Minibatch loss at step 183000: 0.080425
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# finish : 2016-12-01T21:45:37+0900
# Minibatch loss at step 183500: 0.071986
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-01T21:46:40+0900
# Minibatch loss at step 184000: 0.105383
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-01T21:47:44+0900
# Minibatch loss at step 184500: 0.093991
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-01T21:48:48+0900
# Minibatch loss at step 185000: 0.065747
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-01T21:49:51+0900
# Minibatch loss at step 185500: 0.080997
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-01T21:50:54+0900
# Minibatch loss at step 186000: 0.066176
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-01T21:51:57+0900
# Minibatch loss at step 186500: 0.076285
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T21:53:01+0900
# Minibatch loss at step 187000: 0.074883
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-12-01T21:54:04+0900
# Minibatch loss at step 187500: 0.076199
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-01T21:55:08+0900
# Minibatch loss at step 188000: 0.081218
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T21:56:11+0900
# Minibatch loss at step 188500: 0.077022
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-12-01T21:57:15+0900
# Minibatch loss at step 189000: 0.142708
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# finish : 2016-12-01T21:58:18+0900
# Minibatch loss at step 189500: 0.093704
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-01T21:59:22+0900
# Minibatch loss at step 190000: 0.080047
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.1%
# finish : 2016-12-01T22:00:25+0900
# Minibatch loss at step 190500: 0.079338
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-01T22:01:29+0900
# Minibatch loss at step 191000: 0.079979
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-01T22:02:32+0900
# Minibatch loss at step 191500: 0.104388
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T22:03:36+0900
# Minibatch loss at step 192000: 0.075313
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-01T22:04:39+0900
# Minibatch loss at step 192500: 0.072721
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T22:05:43+0900
# Minibatch loss at step 193000: 0.063988
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-01T22:06:46+0900
# Minibatch loss at step 193500: 0.089649
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-01T22:07:50+0900
# Minibatch loss at step 194000: 0.066207
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T22:08:53+0900
# Minibatch loss at step 194500: 0.070146
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T22:09:56+0900
# Minibatch loss at step 195000: 0.092217
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# finish : 2016-12-01T22:11:00+0900
# Minibatch loss at step 195500: 0.061267
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-01T22:12:03+0900
# Minibatch loss at step 196000: 0.079870
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-01T22:13:06+0900
# Minibatch loss at step 196500: 0.086272
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# finish : 2016-12-01T22:14:10+0900
# Minibatch loss at step 197000: 0.074505
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# finish : 2016-12-01T22:15:13+0900
# Minibatch loss at step 197500: 0.078787
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# finish : 2016-12-01T22:16:17+0900
# Minibatch loss at step 198000: 0.068771
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# finish : 2016-12-01T22:17:20+0900
# Minibatch loss at step 198500: 0.078445
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-01T22:18:24+0900
# Minibatch loss at step 199000: 0.092700
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.6%
# finish : 2016-12-01T22:19:27+0900
# Minibatch loss at step 199500: 0.069930
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# finish : 2016-12-01T22:20:31+0900
# Minibatch loss at step 200000: 0.066869
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.1%
# finish : 2016-12-01T22:21:34+0900
# Test accuracy: 89.4%
# finish : 2016-12-01T22:21:38+0900
# Converted 32 variables to const ops.

# %%
# Minibatch loss at step 100000: 0.348260
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.1%
# finish : 2016-12-02T01:47:06+0900

# Minibatch loss at step 200000: 0.074711
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-12-02T05:14:25+0900
# Test accuracy: 88.1%
# finish : 2016-12-02T05:14:29+0900
# Converted 32 variables to const ops.
svhn_data = MultiDigitSVHNData.maybe_pickle(digit_count=5, total_data_count=300000, image_size=32, add_margin=True, margin_ratio=0.1)
MultiDigitModel(multi_digit_dataset=svhn_data,
                        use_norm=True,
                        learning_rate_start=0.01,
                        digit_count=5,
                        num_channels=3,
                        num_steps=200001, 
                        batch_size=32,  
                        num_convs=[16,32,64,64,64,64,64,128], 
                        num_fc_1=128, 
                        num_fc_2=64,
                       ).run()
# Out:
# svhn/reader/v2/svhn_5_32_300000_False_True_0.1_False.pickle already present - Skipping pickling.
# tf_train_dataset : Tensor("tf_train_dataset:0", shape=(32, 32, 32, 3), dtype=float32)
# tf_train_length_labels : Tensor("Placeholder:0", shape=(32, 6), dtype=float32)
# tf_train_digits_labels : Tensor("Placeholder_1:0", shape=(32, 5, 11), dtype=float32)
# Initialized
# Minibatch loss at step 0: 18.639942
# Minibatch accuracy_length: 0.0%
# Minibatch accuracy_digit_0: 3.1%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 0.0%
# Minibatch accuracy_digit_3: 0.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.6%
# finish : 2016-12-01T22:21:51+0900
# Minibatch loss at step 500: 10.365401
# Minibatch accuracy_length: 37.5%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 31.2%
# Minibatch accuracy_digit_2: 54.5%
# Minibatch accuracy_digit_3: 50.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T22:22:48+0900
# Minibatch loss at step 1000: 8.568232
# Minibatch accuracy_length: 62.5%
# Minibatch accuracy_digit_0: 25.0%
# Minibatch accuracy_digit_1: 21.9%
# Minibatch accuracy_digit_2: 80.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T22:23:46+0900
# Minibatch loss at step 1500: 9.344976
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 6.2%
# Minibatch accuracy_digit_2: 41.9%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T22:24:42+0900
# Minibatch loss at step 2000: 10.037421
# Minibatch accuracy_length: 53.1%
# Minibatch accuracy_digit_0: 18.8%
# Minibatch accuracy_digit_1: 12.5%
# Minibatch accuracy_digit_2: 30.0%
# Minibatch accuracy_digit_3: 81.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T22:25:39+0900
# Minibatch loss at step 2500: 9.589893
# Minibatch accuracy_length: 43.8%
# Minibatch accuracy_digit_0: 15.6%
# Minibatch accuracy_digit_1: 9.4%
# Minibatch accuracy_digit_2: 41.4%
# Minibatch accuracy_digit_3: 82.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.0%
# finish : 2016-12-01T22:26:37+0900
# Minibatch loss at step 3000: 7.991276
# Minibatch accuracy_length: 78.1%
# Minibatch accuracy_digit_0: 21.9%
# Minibatch accuracy_digit_1: 15.6%
# Minibatch accuracy_digit_2: 46.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 0.0%
# Validation accuracy: 0.7%
# finish : 2016-12-01T22:27:34+0900
# Minibatch loss at step 3500: 7.472128
# Minibatch accuracy_length: 81.2%
# Minibatch accuracy_digit_0: 37.5%
# Minibatch accuracy_digit_1: 28.1%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 81.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 6.2%
# Validation accuracy: 1.1%
# finish : 2016-12-01T22:28:30+0900
# Minibatch loss at step 4000: 6.324757
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 40.6%
# Minibatch accuracy_digit_1: 40.6%
# Minibatch accuracy_digit_2: 50.0%
# Minibatch accuracy_digit_3: 95.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 4.9%
# finish : 2016-12-01T22:29:28+0900
# Minibatch loss at step 4500: 5.410353
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 56.2%
# Minibatch accuracy_digit_1: 50.0%
# Minibatch accuracy_digit_2: 53.6%
# Minibatch accuracy_digit_3: 85.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.3%
# finish : 2016-12-01T22:30:26+0900
# Minibatch loss at step 5000: 5.233078
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 46.9%
# Minibatch accuracy_digit_1: 43.8%
# Minibatch accuracy_digit_2: 55.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 9.4%
# Validation accuracy: 18.3%
# finish : 2016-12-01T22:31:24+0900
# Minibatch loss at step 5500: 3.814639
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 65.6%
# Minibatch accuracy_digit_1: 46.9%
# Minibatch accuracy_digit_2: 71.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 25.0%
# Validation accuracy: 28.3%
# finish : 2016-12-01T22:32:23+0900
# Minibatch loss at step 6000: 2.888689
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 62.5%
# Minibatch accuracy_digit_2: 86.7%
# Minibatch accuracy_digit_3: 86.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 46.9%
# Validation accuracy: 37.0%
# finish : 2016-12-01T22:33:23+0900
# Minibatch loss at step 6500: 3.328969
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 77.4%
# Minibatch accuracy_digit_3: 88.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 37.5%
# Validation accuracy: 46.0%
# finish : 2016-12-01T22:34:23+0900
# Minibatch loss at step 7000: 4.415136
# Minibatch accuracy_length: 78.1%
# Minibatch accuracy_digit_0: 62.5%
# Minibatch accuracy_digit_1: 53.1%
# Minibatch accuracy_digit_2: 80.8%
# Minibatch accuracy_digit_3: 66.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 34.4%
# Validation accuracy: 43.2%
# finish : 2016-12-01T22:35:23+0900
# Minibatch loss at step 7500: 2.298637
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 53.1%
# Validation accuracy: 52.5%
# finish : 2016-12-01T22:36:23+0900
# Minibatch loss at step 8000: 2.625398
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 88.9%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 51.1%
# finish : 2016-12-01T22:37:23+0900
# Minibatch loss at step 8500: 2.179703
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 83.9%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 55.4%
# finish : 2016-12-01T22:38:23+0900
# Minibatch loss at step 9000: 2.357239
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 81.2%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 62.5%
# Validation accuracy: 63.1%
# finish : 2016-12-01T22:39:23+0900
# Minibatch loss at step 9500: 2.305709
# Minibatch accuracy_length: 90.6%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 75.0%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 64.7%
# finish : 2016-12-01T22:40:23+0900
# Minibatch loss at step 10000: 1.186690
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 67.8%
# finish : 2016-12-01T22:41:24+0900
# Minibatch loss at step 10500: 1.541409
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 70.7%
# finish : 2016-12-01T22:42:24+0900
# Minibatch loss at step 11000: 1.654352
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 69.3%
# finish : 2016-12-01T22:43:25+0900
# Minibatch loss at step 11500: 2.365225
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 71.9%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 71.2%
# finish : 2016-12-01T22:44:25+0900
# Minibatch loss at step 12000: 1.250620
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 73.1%
# finish : 2016-12-01T22:45:26+0900
# Minibatch loss at step 12500: 1.428935
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.9%
# finish : 2016-12-01T22:46:27+0900
# Minibatch loss at step 13000: 1.887606
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 78.1%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 74.5%
# finish : 2016-12-01T22:47:27+0900
# Minibatch loss at step 13500: 1.009714
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 76.5%
# finish : 2016-12-01T22:48:27+0900
# Minibatch loss at step 14000: 2.112095
# Minibatch accuracy_length: 87.5%
# Minibatch accuracy_digit_0: 78.1%
# Minibatch accuracy_digit_1: 68.8%
# Minibatch accuracy_digit_2: 91.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 59.4%
# Validation accuracy: 77.1%
# finish : 2016-12-01T22:49:27+0900
# Minibatch loss at step 14500: 1.556257
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 75.0%
# Minibatch accuracy_digit_1: 81.2%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.7%
# finish : 2016-12-01T22:50:28+0900
# Minibatch loss at step 15000: 1.032433
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 77.2%
# finish : 2016-12-01T22:51:28+0900
# Minibatch loss at step 15500: 1.264774
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.7%
# finish : 2016-12-01T22:52:28+0900
# Minibatch loss at step 16000: 0.725005
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# finish : 2016-12-01T22:53:29+0900
# Minibatch loss at step 16500: 1.294684
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 84.4%
# Minibatch accuracy_digit_2: 90.6%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# finish : 2016-12-01T22:54:29+0900
# Minibatch loss at step 17000: 0.985986
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 80.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# finish : 2016-12-01T22:55:30+0900
# Minibatch loss at step 17500: 1.491546
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 87.1%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.2%
# finish : 2016-12-01T22:56:31+0900
# Minibatch loss at step 18000: 0.553466
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.0%
# finish : 2016-12-01T22:57:31+0900
# Minibatch loss at step 18500: 1.176652
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 89.3%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.3%
# finish : 2016-12-01T22:58:32+0900
# Minibatch loss at step 19000: 0.835705
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 80.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# finish : 2016-12-01T22:59:33+0900
# Minibatch loss at step 19500: 0.863584
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# finish : 2016-12-01T23:00:34+0900
# Minibatch loss at step 20000: 0.879546
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 86.7%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# finish : 2016-12-01T23:01:34+0900
# Minibatch loss at step 20500: 0.601624
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.4%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 81.9%
# finish : 2016-12-01T23:02:35+0900
# Minibatch loss at step 21000: 0.971546
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# finish : 2016-12-01T23:03:36+0900
# Minibatch loss at step 21500: 0.762169
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# finish : 2016-12-01T23:04:37+0900
# Minibatch loss at step 22000: 1.667795
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 92.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# finish : 2016-12-01T23:05:38+0900
# Minibatch loss at step 22500: 0.572026
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.9%
# finish : 2016-12-01T23:06:39+0900
# Minibatch loss at step 23000: 0.503656
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# finish : 2016-12-01T23:07:40+0900
# Minibatch loss at step 23500: 0.959094
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# finish : 2016-12-01T23:08:41+0900
# Minibatch loss at step 24000: 1.021995
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 84.4%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.2%
# finish : 2016-12-01T23:09:42+0900
# Minibatch loss at step 24500: 0.468257
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# finish : 2016-12-01T23:10:44+0900
# Minibatch loss at step 25000: 0.526031
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# finish : 2016-12-01T23:11:45+0900
# Minibatch loss at step 25500: 0.288120
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 84.1%
# finish : 2016-12-01T23:12:46+0900
# Minibatch loss at step 26000: 0.613656
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.5%
# finish : 2016-12-01T23:13:47+0900
# Minibatch loss at step 26500: 0.781279
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.2%
# finish : 2016-12-01T23:14:48+0900
# Minibatch loss at step 27000: 0.696288
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 86.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# finish : 2016-12-01T23:15:50+0900
# Minibatch loss at step 27500: 0.468015
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# finish : 2016-12-01T23:16:51+0900
# Minibatch loss at step 28000: 0.900283
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 81.2%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# finish : 2016-12-01T23:17:53+0900
# Minibatch loss at step 28500: 0.724978
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.8%
# finish : 2016-12-01T23:18:54+0900
# Minibatch loss at step 29000: 0.545856
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 92.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.7%
# finish : 2016-12-01T23:19:56+0900
# Minibatch loss at step 29500: 0.606502
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# finish : 2016-12-01T23:20:58+0900
# Minibatch loss at step 30000: 0.456762
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.1%
# finish : 2016-12-01T23:21:59+0900
# Minibatch loss at step 30500: 0.604544
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.5%
# finish : 2016-12-01T23:23:01+0900
# Minibatch loss at step 31000: 0.853364
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# finish : 2016-12-01T23:24:02+0900
# Minibatch loss at step 31500: 0.405002
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# finish : 2016-12-01T23:25:04+0900
# Minibatch loss at step 32000: 0.371530
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# finish : 2016-12-01T23:26:05+0900
# Minibatch loss at step 32500: 0.345050
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# finish : 2016-12-01T23:27:07+0900
# Minibatch loss at step 33000: 0.376346
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.1%
# finish : 2016-12-01T23:28:08+0900
# Minibatch loss at step 33500: 0.595543
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# finish : 2016-12-01T23:29:10+0900
# Minibatch loss at step 34000: 0.702119
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# finish : 2016-12-01T23:30:12+0900
# Minibatch loss at step 34500: 0.765077
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.7%
# finish : 2016-12-01T23:31:14+0900
# Minibatch loss at step 35000: 1.216291
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 87.5%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 88.5%
# Minibatch accuracy_digit_3: 81.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 71.9%
# Validation accuracy: 85.7%
# finish : 2016-12-01T23:32:15+0900
# Minibatch loss at step 35500: 0.893255
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 87.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# finish : 2016-12-01T23:33:17+0900
# Minibatch loss at step 36000: 0.645838
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 92.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.2%
# finish : 2016-12-01T23:34:19+0900
# Minibatch loss at step 36500: 1.707397
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# finish : 2016-12-01T23:35:21+0900
# Minibatch loss at step 37000: 0.138945
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# finish : 2016-12-01T23:36:24+0900
# Minibatch loss at step 37500: 0.436820
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.2%
# finish : 2016-12-01T23:37:25+0900
# Minibatch loss at step 38000: 1.339522
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# finish : 2016-12-01T23:38:27+0900
# Minibatch loss at step 38500: 0.440396
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# finish : 2016-12-01T23:39:29+0900
# Minibatch loss at step 39000: 0.695456
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.2%
# finish : 2016-12-01T23:40:31+0900
# Minibatch loss at step 39500: 0.697057
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# finish : 2016-12-01T23:41:32+0900
# Minibatch loss at step 40000: 0.289450
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# finish : 2016-12-01T23:42:34+0900
# Minibatch loss at step 40500: 0.443721
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# finish : 2016-12-01T23:43:36+0900
# Minibatch loss at step 41000: 0.443599
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 93.8%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# finish : 2016-12-01T23:44:38+0900
# Minibatch loss at step 41500: 0.341491
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.2%
# finish : 2016-12-01T23:45:40+0900
# Minibatch loss at step 42000: 0.447758
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# finish : 2016-12-01T23:46:42+0900
# Minibatch loss at step 42500: 0.800468
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 85.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.1%
# finish : 2016-12-01T23:47:44+0900
# Minibatch loss at step 43000: 0.903933
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# finish : 2016-12-01T23:48:46+0900
# Minibatch loss at step 43500: 0.378142
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 96.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# finish : 2016-12-01T23:49:49+0900
# Minibatch loss at step 44000: 1.186603
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# finish : 2016-12-01T23:50:51+0900
# Minibatch loss at step 44500: 0.344132
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.8%
# finish : 2016-12-01T23:51:53+0900
# Minibatch loss at step 45000: 0.589394
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# finish : 2016-12-01T23:52:55+0900
# Minibatch loss at step 45500: 0.210515
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.3%
# finish : 2016-12-01T23:53:57+0900
# Minibatch loss at step 46000: 0.306878
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.7%
# finish : 2016-12-01T23:54:59+0900
# Minibatch loss at step 46500: 0.331166
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 92.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# finish : 2016-12-01T23:56:01+0900
# Minibatch loss at step 47000: 0.542375
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# finish : 2016-12-01T23:57:03+0900
# Minibatch loss at step 47500: 0.230419
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.3%
# finish : 2016-12-01T23:58:06+0900
# Minibatch loss at step 48000: 0.675889
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.5%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# finish : 2016-12-01T23:59:08+0900
# Minibatch loss at step 48500: 0.215795
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.6%
# finish : 2016-12-02T00:00:10+0900
# Minibatch loss at step 49000: 0.461601
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# finish : 2016-12-02T00:01:12+0900
# Minibatch loss at step 49500: 0.572290
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 96.2%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.1%
# finish : 2016-12-02T00:02:15+0900
# Minibatch loss at step 50000: 0.305991
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# finish : 2016-12-02T00:03:17+0900
# Minibatch loss at step 50500: 0.414038
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 90.6%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.0%
# finish : 2016-12-02T00:04:19+0900
# Minibatch loss at step 51000: 0.285660
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-12-02T00:05:21+0900
# Minibatch loss at step 51500: 0.396254
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.1%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.8%
# finish : 2016-12-02T00:06:24+0900
# Minibatch loss at step 52000: 0.178355
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# finish : 2016-12-02T00:07:26+0900
# Minibatch loss at step 52500: 0.346652
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-12-02T00:08:28+0900
# Minibatch loss at step 53000: 0.278561
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.0%
# finish : 2016-12-02T00:09:31+0900
# Minibatch loss at step 53500: 0.204071
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# finish : 2016-12-02T00:10:33+0900
# Minibatch loss at step 54000: 0.241330
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.0%
# finish : 2016-12-02T00:11:35+0900
# Minibatch loss at step 54500: 0.581795
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 94.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.5%
# finish : 2016-12-02T00:12:37+0900
# Minibatch loss at step 55000: 0.708896
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.5%
# Minibatch accuracy_digit_3: 88.2%
# Minibatch accuracy_digit_4: 50.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# finish : 2016-12-02T00:13:39+0900
# Minibatch loss at step 55500: 0.246825
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-12-02T00:14:41+0900
# Minibatch loss at step 56000: 0.351778
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# finish : 2016-12-02T00:15:43+0900
# Minibatch loss at step 56500: 0.711287
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 90.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# finish : 2016-12-02T00:16:45+0900
# Minibatch loss at step 57000: 0.437971
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.3%
# finish : 2016-12-02T00:17:48+0900
# Minibatch loss at step 57500: 0.396576
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.7%
# finish : 2016-12-02T00:18:50+0900
# Minibatch loss at step 58000: 1.440447
# Minibatch accuracy_length: 93.8%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 90.3%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# finish : 2016-12-02T00:19:52+0900
# Minibatch loss at step 58500: 0.383932
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# finish : 2016-12-02T00:20:55+0900
# Minibatch loss at step 59000: 0.488751
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# finish : 2016-12-02T00:21:57+0900
# Minibatch loss at step 59500: 0.218969
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.4%
# finish : 2016-12-02T00:22:59+0900
# Minibatch loss at step 60000: 0.340913
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 94.4%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-12-02T00:24:02+0900
# Minibatch loss at step 60500: 0.187758
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# finish : 2016-12-02T00:25:04+0900
# Minibatch loss at step 61000: 0.150067
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# finish : 2016-12-02T00:26:07+0900
# Minibatch loss at step 61500: 0.521686
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 93.8%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# finish : 2016-12-02T00:27:09+0900
# Minibatch loss at step 62000: 0.326588
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.2%
# finish : 2016-12-02T00:28:11+0900
# Minibatch loss at step 62500: 0.447561
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.8%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.2%
# finish : 2016-12-02T00:29:13+0900
# Minibatch loss at step 63000: 0.404764
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# finish : 2016-12-02T00:30:15+0900
# Minibatch loss at step 63500: 0.328714
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.7%
# finish : 2016-12-02T00:31:18+0900
# Minibatch loss at step 64000: 0.822661
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# finish : 2016-12-02T00:32:20+0900
# Minibatch loss at step 64500: 0.285354
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.7%
# finish : 2016-12-02T00:33:23+0900
# Minibatch loss at step 65000: 0.478604
# Minibatch accuracy_length: 96.9%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 95.7%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.9%
# finish : 2016-12-02T00:34:25+0900
# Minibatch loss at step 65500: 0.230792
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# finish : 2016-12-02T00:35:27+0900
# Minibatch loss at step 66000: 0.732721
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.0%
# finish : 2016-12-02T00:36:30+0900
# Minibatch loss at step 66500: 0.225299
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.5%
# finish : 2016-12-02T00:37:32+0900
# Minibatch loss at step 67000: 0.193444
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# finish : 2016-12-02T00:38:34+0900
# Minibatch loss at step 67500: 0.306222
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 93.1%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# finish : 2016-12-02T00:39:36+0900
# Minibatch loss at step 68000: 0.223894
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 95.2%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# finish : 2016-12-02T00:40:39+0900
# Minibatch loss at step 68500: 0.489400
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 93.8%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# finish : 2016-12-02T00:41:42+0900
# Minibatch loss at step 69000: 0.276952
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.9%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# finish : 2016-12-02T00:42:44+0900
# Minibatch loss at step 69500: 0.240722
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 96.7%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.8%
# finish : 2016-12-02T00:43:47+0900
# Minibatch loss at step 70000: 0.409872
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 90.6%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# finish : 2016-12-02T00:44:49+0900
# Minibatch loss at step 70500: 0.361461
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 87.5%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# finish : 2016-12-02T00:45:52+0900
# Minibatch loss at step 71000: 0.482316
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 96.9%
# Minibatch accuracy_digit_1: 96.9%
# Minibatch accuracy_digit_2: 96.6%
# Minibatch accuracy_digit_3: 90.9%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# finish : 2016-12-02T00:46:55+0900
# Minibatch loss at step 71500: 0.191825
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# ...
# Validation accuracy: 87.7%
# finish : 2016-12-02T04:25:49+0900
# Minibatch loss at step 177000: 0.083064
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:26:51+0900
# Minibatch loss at step 177500: 0.099215
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# finish : 2016-12-02T04:27:54+0900
# Minibatch loss at step 178000: 0.082527
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# finish : 2016-12-02T04:28:56+0900
# Minibatch loss at step 178500: 0.118471
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# finish : 2016-12-02T04:29:58+0900
# Minibatch loss at step 179000: 0.081875
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:31:00+0900
# Minibatch loss at step 179500: 0.090121
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-12-02T04:32:02+0900
# Minibatch loss at step 180000: 0.092732
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-12-02T04:33:04+0900
# Minibatch loss at step 180500: 0.081827
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-12-02T04:34:06+0900
# Minibatch loss at step 181000: 0.089674
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-12-02T04:35:08+0900
# Minibatch loss at step 181500: 0.078475
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:36:10+0900
# Minibatch loss at step 182000: 0.096642
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# finish : 2016-12-02T04:37:12+0900
# Minibatch loss at step 182500: 0.101300
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# finish : 2016-12-02T04:38:14+0900
# Minibatch loss at step 183000: 0.131651
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.9%
# finish : 2016-12-02T04:39:16+0900
# Minibatch loss at step 183500: 0.085364
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# finish : 2016-12-02T04:40:19+0900
# Minibatch loss at step 184000: 0.107318
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:41:21+0900
# Minibatch loss at step 184500: 0.095010
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:42:23+0900
# Minibatch loss at step 185000: 0.079963
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# finish : 2016-12-02T04:43:25+0900
# Minibatch loss at step 185500: 0.081962
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-12-02T04:44:27+0900
# Minibatch loss at step 186000: 0.082039
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-12-02T04:45:29+0900
# Minibatch loss at step 186500: 0.092532
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-12-02T04:46:31+0900
# Minibatch loss at step 187000: 0.092225
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# finish : 2016-12-02T04:47:33+0900
# Minibatch loss at step 187500: 0.081155
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-12-02T04:48:35+0900
# Minibatch loss at step 188000: 0.081478
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.6%
# finish : 2016-12-02T04:49:37+0900
# Minibatch loss at step 188500: 0.080964
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:50:39+0900
# Minibatch loss at step 189000: 0.102960
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# finish : 2016-12-02T04:51:41+0900
# Minibatch loss at step 189500: 0.098902
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# finish : 2016-12-02T04:52:43+0900
# Minibatch loss at step 190000: 0.087916
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# finish : 2016-12-02T04:53:45+0900
# Minibatch loss at step 190500: 0.097759
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# finish : 2016-12-02T04:54:47+0900
# Minibatch loss at step 191000: 0.078590
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:55:50+0900
# Minibatch loss at step 191500: 0.110747
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:56:51+0900
# Minibatch loss at step 192000: 0.074616
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T04:57:53+0900
# Minibatch loss at step 192500: 0.085587
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-12-02T04:58:55+0900
# Minibatch loss at step 193000: 0.071271
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-12-02T04:59:57+0900
# Minibatch loss at step 193500: 0.109827
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# finish : 2016-12-02T05:00:59+0900
# Minibatch loss at step 194000: 0.077406
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# finish : 2016-12-02T05:02:01+0900
# Minibatch loss at step 194500: 0.077493
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# finish : 2016-12-02T05:03:03+0900
# Minibatch loss at step 195000: 0.081630
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# finish : 2016-12-02T05:04:05+0900
# Minibatch loss at step 195500: 0.073049
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-12-02T05:05:07+0900
# Minibatch loss at step 196000: 0.080518
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 0.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# finish : 2016-12-02T05:06:09+0900
# Minibatch loss at step 196500: 0.083264
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.6%
# finish : 2016-12-02T05:07:11+0900
# Minibatch loss at step 197000: 0.080544
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# finish : 2016-12-02T05:08:14+0900
# Minibatch loss at step 197500: 0.088336
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# finish : 2016-12-02T05:09:15+0900
# Minibatch loss at step 198000: 0.077836
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-12-02T05:10:17+0900
# Minibatch loss at step 198500: 0.072529
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# finish : 2016-12-02T05:11:19+0900
# Minibatch loss at step 199000: 0.086979
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# finish : 2016-12-02T05:12:21+0900
# Minibatch loss at step 199500: 0.080459
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# finish : 2016-12-02T05:13:23+0900
# Minibatch loss at step 200000: 0.074711
# Minibatch accuracy_length: 100.0%
# Minibatch accuracy_digit_0: 100.0%
# Minibatch accuracy_digit_1: 100.0%
# Minibatch accuracy_digit_2: 100.0%
# Minibatch accuracy_digit_3: 100.0%
# Minibatch accuracy_digit_4: 100.0%
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# finish : 2016-12-02T05:14:25+0900
# Test accuracy: 88.1%
# finish : 2016-12-02T05:14:29+0900
# Converted 32 variables to const ops.
